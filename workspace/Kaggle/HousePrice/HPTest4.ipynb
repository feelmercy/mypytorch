# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize']=(8,6)
# %matplotlib inline

# %%
df_train=pd.read_csv('F:\\study\\ml\\DataSet\\House_Prices\\train.csv')
df_test=pd.read_csv('F:\\study\\ml\\DataSet\\House_Prices\\test.csv')

# %%
sns.distplot(df_train.SalePrice)

# %%
plt.subplots(figsize=(10,8))
sns.boxplot(df_train.OverallQual,df_train.SalePrice)

# %%
plt.subplots(figsize=(10,8))
sns.boxplot(df_train.YearBuilt,df_train.SalePrice)

# %%
corrmat=df_train.corr()
plt.subplots(figsize=(10,8))
sns.heatmap(corrmat,vmax=0.6,square=True)

# %%
corrmat.nlargest(10,'SalePrice')
# Out:
#                     Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# SalePrice    -0.021917   -0.084284     0.351799  0.263843     0.790982
# OverallQual  -0.028365    0.032628     0.251646  0.105806     1.000000
# GrLivArea     0.008273    0.074853     0.402797  0.263116     0.593007
# GarageCars    0.016570   -0.040110     0.285691  0.154871     0.600671
# GarageArea    0.017634   -0.098672     0.344997  0.180403     0.562022
# TotalBsmtSF  -0.015415   -0.238518     0.392075  0.260833     0.537808
# 1stFlrSF      0.010496   -0.251758     0.457181  0.299475     0.476224
# FullBath      0.005587    0.131608     0.198769  0.126031     0.550600
# TotRmsAbvGrd  0.027239    0.040380     0.352096  0.190015     0.427452
# YearBuilt    -0.012713    0.027850     0.123349  0.014228     0.572323
#
#               OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# SalePrice       -0.077856   0.522897      0.507101    0.477493    0.386420
# ...

# %%
corrmat.nlargest(10,'SalePrice')['SalePrice']
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# Name: SalePrice, dtype: float64

# %%
corrmat.nlargest(10,'SalePrice')['SalePrice'].index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
plt.subplots(figsize=(10,8))
k=10
cols=corrmat.nlargest(k,'SalePrice')['SalePrice'].index
cm=np.corrcoef(df_train[cols].values.T)
sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='0.2f',annot_kws={'size':10},yticklabels=cols,
           xticklabels=cols)

# %%
cm
# Out:
# array([[1.        , 0.7909816 , 0.70862448, 0.6404092 , 0.62343144,
#         0.61358055, 0.60585218, 0.56066376, 0.53372316, 0.52289733],
#        [0.7909816 , 1.        , 0.59300743, 0.60067072, 0.56202176,
#         0.5378085 , 0.47622383, 0.55059971, 0.42745234, 0.57232277],
#        [0.70862448, 0.59300743, 1.        , 0.46724742, 0.46899748,
#         0.4548682 , 0.56602397, 0.63001165, 0.82548937, 0.19900971],
#        [0.6404092 , 0.60067072, 0.46724742, 1.        , 0.88247541,
#         0.43458483, 0.43931681, 0.46967204, 0.36228857, 0.53785009],
#        [0.62343144, 0.56202176, 0.46899748, 0.88247541, 1.        ,
#         0.48666546, 0.48978165, 0.40565621, 0.33782212, 0.47895382],
#        [0.61358055, 0.5378085 , 0.4548682 , 0.43458483, 0.48666546,
#         1.        , 0.81952998, 0.32372241, 0.28557256, 0.391452  ],
#        [0.60585218, 0.47622383, 0.56602397, 0.43931681, 0.48978165,
#         0.81952998, 1.        , 0.38063749, 0.40951598, 0.28198586],
# ...

# %%
df_train.corr()['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# ...

# %%
np.array(df_train.corr())
# Out:
# array([[ 1.00000000e+00,  1.11564782e-02, -3.32255186e-02, ...,
#          2.11721766e-02,  7.11794017e-04, -2.19167194e-02],
#        [ 1.11564782e-02,  1.00000000e+00, -1.39781082e-01, ...,
#         -1.35846432e-02, -2.14070379e-02, -8.42841351e-02],
#        [-3.32255186e-02, -1.39781082e-01,  1.00000000e+00, ...,
#          1.20498822e-03, -1.42614073e-02,  2.63843354e-01],
#        ...,
#        [ 2.11721766e-02, -1.35846432e-02,  1.20498822e-03, ...,
#          1.00000000e+00, -1.45721413e-01,  4.64322452e-02],
#        [ 7.11794017e-04, -2.14070379e-02, -1.42614073e-02, ...,
#         -1.45721413e-01,  1.00000000e+00, -2.89225852e-02],
#        [-2.19167194e-02, -8.42841351e-02,  2.63843354e-01, ...,
#          4.64322452e-02, -2.89225852e-02,  1.00000000e+00]])

# %%
cols
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
cols.values
# Out:
# array(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars',
#        'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath',
#        'TotRmsAbvGrd', 'YearBuilt'], dtype=object)

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea','GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols],size=2.5)

# %%
##################### for nan data

# %%
total=df_train.isnull().sum().sort_values(ascending=False)
total
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
#                  ...
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
percent=(df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=['Total','Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %%
df_train=df_train.drop((missing_data[missing_data['Total'] >= 1]).index,1)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %%
df_train.isnull().sum().max()
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler

# %%
saleprice_scaled=StandardScaler().fit_transform(df_train.SalePrice[:,np.newaxis])
low_range=saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
hight_range=saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
low_range
# Out:
# array([[-1.83870376],
#        [-1.83352844],
#        [-1.80092766],
#        [-1.78329881],
#        [-1.77448439],
#        [-1.62337999],
#        [-1.61708398],
#        [-1.58560389],
#        [-1.58560389],
#        [-1.5731    ]])

# %%
hight_range
# Out:
# array([[3.82897043],
#        [4.04098249],
#        [4.49634819],
#        [4.71041276],
#        [4.73032076],
#        [5.06214602],
#        [5.42383959],
#        [5.59185509],
#        [7.10289909],
#        [7.22881942]])

# %%
from scipy import stats

# %%
sns.distplot(df_train.SalePrice,fit=stats.norm)

# %%
stats.probplot(df_train.SalePrice,plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74160.16474519415, 180921.19589041095, 0.9319665641512986))

# %%
df_train.SalePrice.skew()
# Out:
# 1.8828757597682129

# %%
df_train.SalePrice.kurt()
# Out:
# 6.536281860064529

# %%
df_train['SalePrice']=np.log(df_train.SalePrice)

# %%
sns.distplot(df_train.SalePrice,fit=stats.norm)

# %%
stats.probplot(df_train.SalePrice,plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([10.46024211, 10.47194981, 10.54270639, ..., 13.34550693,
#          13.5211395 , 13.53447303])),
#  (0.39826223081618867, 12.024050901109383, 0.9953761475636614))

# %%
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %%
pd.get_dummies(df_train)
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# 5        6          50    14115            5            5       1993
# 6        7          20    10084            8            5       2004
# 7        8          60    10382            7            6       1973
# 8        9          50     6120            7            5       1931
# 9       10         190     7420            5            6       1939
# 10      11          20    11200            5            5       1965
# 11      12          60    11924            9            5       2005
# 12      13          20    12968            5            6       1962
# ...
