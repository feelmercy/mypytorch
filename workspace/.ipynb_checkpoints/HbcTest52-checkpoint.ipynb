# %%
import pandas as pd
import numpy as np
import time


ac = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\action_train.csv')
order = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\orderFuture_train.csv')
order_his = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\orderHistory_train.csv')
comment = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\userComment_train.csv')
profile = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\userProfile_train.csv')

ac_test = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\action_test.csv')
order_test = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\orderFuture_test.csv')
order_his_test = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\orderHistory_test.csv')
comment_test = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\userComment_test.csv')
profile_test = pd.read_csv('F:\\study\\ml\\DataSet\\Hbc_csv\\test\\userProfile_test.csv')

# %%
ac.head()
# Out:
#          userid  actionType  actionTime
# 0  100000000013           1  1474300753
# 1  100000000013           5  1474300763
# 2  100000000013           6  1474300874
# 3  100000000013           5  1474300911
# 4  100000000013           6  1474300936

# %%
def time_help(x):
    timeArray = time.localtime(x)
    return time.strftime('%Y-%m-%d %H:%M:%S',timeArray)

# %%
ac.actionTime=pd.to_datetime(ac.actionTime.apply(lambda x:time_help(x)),format='%Y-%m-%d %H:%M:%S')
order_his.orderTime=pd.to_datetime(order_his.orderTime.apply(lambda x:time_help(x)),format='%Y-%m-%d %H:%M:%S')
ac_test.actionTime=pd.to_datetime(ac_test.actionTime.apply(lambda x:time_help(x)),format='%Y-%m-%d %H:%M:%S')
order_his_test.orderTime=pd.to_datetime(order_his_test.orderTime.apply(lambda x:time_help(x)),format='%Y-%m-%d %H:%M:%S')

# %%
order_his_test.head()
# Out:
#          userid  orderid           orderTime  orderType city country continent
# 0  100000000371  1000029 2017-08-23 07:13:05          0   东京      日本        亚洲
# 1  100000001445  1000089 2016-11-07 23:24:35          0  新加坡     新加坡        亚洲
# 2  100000001445  1000085 2017-04-04 16:53:36          0  西雅图      美国       北美洲
# 3  100000001445  1000083 2016-11-07 18:27:22          0  新加坡     新加坡        亚洲
# 4  100000001445  1000086 2016-11-08 02:59:08          0  新加坡     新加坡        亚洲

# %%
ac['day']=ac.actionTime.apply(lambda x:x.day)
ac_test['day']=ac_test.actionTime.apply(lambda x:x.day)

# %%
ac.head()
# Out:
#          userid  actionType          actionTime  day
# 0  100000000013           1 2016-09-19 23:59:13   19
# 1  100000000013           5 2016-09-19 23:59:23   19
# 2  100000000013           6 2016-09-20 00:01:14   20
# 3  100000000013           5 2016-09-20 00:01:51   20
# 4  100000000013           6 2016-09-20 00:02:16   20

# %%
def orderHistory_feat(df):
    grouped=df[['userid','orderType']].groupby('userid',as_index=False)
    df_count=grouped.count()
    df_count.rename(columns={'orderType':'df_count'},inplace=True)
    df_sum=grouped.sum()
    df_sum.rename(columns={'orderType':'df_sum'},inplace=True)
    df_merge=pd.merge(df_count,df_sum,on='userid',how='left')
    df_merge['rate']=df_merge['df_sum']/df_merge['df_count']
    del df_merge['df_count']
    df_merge.rename(columns={'df_sum':'orderHistory_feat_sum','rate':'orderHistory_feat_rate'},inplace=True)
    del df_merge['orderHistory_feat_rate']
    return df_merge

# %%
orderHistory_feat(order_his).head()
# Out:
#          userid  orderHistory_feat_sum
# 0  100000000013                      0
# 1  100000000393                      0
# 2  100000000459                      0
# 3  100000000637                      0
# 4  100000000695                      0

# %%
def actions_orderType(df):
    df['count']=1
    df_count=df[['userid','count']].groupby('userid',as_index=False).count()
    actionType=pd.get_dummies(df['actionType'],prefix='actionType')
    df=pd.concat([df['userid'],actionType],axis=1)
    df=df.groupby('userid',as_index=False).sum()
    for column in range(1,df.shape[1]):
        df['actionType_{}'.format(column)]=df['actionType_{}'.format(column)]/df_count['count']
    return df

# %%
actions_orderType(ac).head()
# Out:
#          userid  actionType_1  actionType_2  actionType_3  actionType_4  \
# 0  100000000013      0.552448      0.006993      0.027972      0.006993
# 1  100000000111      0.333333      0.000000      0.000000      0.000000
# 2  100000000127      0.333333      0.000000      0.000000      0.000000
# 3  100000000231      0.340909      0.136364      0.045455      0.113636
# 4  100000000379      0.500000      0.035714      0.083333      0.071429
#
#    actionType_5  actionType_6  actionType_7  actionType_8  actionType_9
# 0      0.223776      0.125874      0.006993      0.027972      0.020979
# 1      0.333333      0.333333      0.000000      0.000000      0.000000
# 2      0.333333      0.000000      0.333333      0.000000      0.000000
# 3      0.227273      0.136364      0.000000      0.000000      0.000000
# 4      0.166667      0.130952      0.011905      0.000000      0.000000

# %%
df = ac
df['count']=1
df_count=df[['userid','count']].groupby('userid',as_index=False).count()
actionType=pd.get_dummies(df['actionType'],prefix='actionType')
df=pd.concat([df['userid'],actionType],axis=1)
df=df.groupby('userid',as_index=False).sum()
for column in range(1,df.shape[1]):
    df['actionType_{}'.format(column)]=df['actionType_{}'.format(column)]/df_count['count']
df
# Out:
#              userid  actionType_1  actionType_2  actionType_3  actionType_4  \
# 0      100000000013      0.552448      0.006993      0.027972      0.006993
# 1      100000000111      0.333333      0.000000      0.000000      0.000000
# 2      100000000127      0.333333      0.000000      0.000000      0.000000
# 3      100000000231      0.340909      0.136364      0.045455      0.113636
# 4      100000000379      0.500000      0.035714      0.083333      0.071429
# 5      100000000393      0.605263      0.000000      0.026316      0.000000
# 6      100000000423      0.561194      0.037313      0.016418      0.022388
# 7      100000000459      0.239437      0.000000      0.000000      0.000000
# 8      100000000465      0.500000      0.000000      0.000000      0.000000
# 9      100000000471      0.090909      0.000000      0.136364      0.000000
# 10     100000000637      0.341463      0.000000      0.000000      0.000000
# 11     100000000695      0.129032      0.096774      0.032258      0.161290
# 12     100000000745      0.718750      0.000000      0.000000      0.000000
# 13     100000000755      0.400000      0.000000      0.000000      0.000000
# 14     100000000867      0.106796      0.067961      0.417476      0.135922
# 15     100000000949      0.282609      0.043478      0.021739      0.021739
# 16     100000000975      0.298246      0.087719      0.052632      0.035088
# 17     100000001023      0.468828      0.009975      0.012469      0.004988
# 18     100000001195      0.333333      0.000000      0.000000      0.000000
# 19     100000001231      0.428571      0.000000      0.000000      0.000000
# 20     100000001295      0.307692      0.000000      0.000000      0.000000
# 21     100000001343      0.266667      0.000000      0.000000      0.000000
# 22     100000001505      0.160494      0.086420      0.061728      0.012346
# 23     100000001557      0.363636      0.000000      0.000000      0.000000
# 24     100000001683      0.360000      0.040000      0.000000      0.000000
# 25     100000001711      0.093023      0.000000      0.000000      0.000000
# 26     100000001803      0.312500      0.000000      0.000000      0.000000
# 27     100000001955      0.153846      0.038462      0.000000      0.000000
# 28     100000001963      0.250000      0.000000      0.000000      0.000000
# 29     100000002111      0.259259      0.000000      0.000000      0.000000
# ...             ...           ...           ...           ...           ...
# 40277  114869267343      0.300000      0.000000      0.000000      0.000000
# 40278  114869267443      0.468750      0.000000      0.093750      0.000000
# 40279  114869267447      0.166667      0.166667      0.000000      0.000000
# 40280  114869467148      0.000000      0.100000      0.300000      0.000000
# 40281  114869467440      0.000000      0.000000      0.000000      0.000000
# 40282  114869567147      0.151515      0.030303      0.000000      0.121212
# 40283  114869567242      0.250000      0.000000      0.000000      0.000000
# 40284  114869652742      0.200000      0.133333      0.066667      0.000000
# 40285  114869667242      0.222222      0.000000      0.000000      0.000000
# 40286  114869667840      0.250000      0.000000      0.000000      0.000000
# 40287  114869669649      0.054054      0.189189      0.405405      0.000000
# 40288  114869767141      0.090909      0.204545      0.227273      0.022727
# 40289  114869767649      0.090909      0.060606      0.303030      0.000000
# 40290  114869769143      0.142857      0.000000      0.000000      0.000000
# 40291  114869867143      0.173913      0.130435      0.000000      0.043478
# 40292  114869867443      0.000000      0.000000      0.000000      0.000000
# 40293  114869867749      0.304348      0.217391      0.000000      0.043478
# 40294  114869967142      0.318182      0.090909      0.000000      0.000000
# 40295  114869967540      0.200000      0.000000      0.000000      0.000000
# 40296  114869967746      0.250000      0.000000      0.000000      0.000000
# 40297  114869969143      0.166667      0.111111      0.000000      0.111111
# 40298  114869969641      0.250000      0.000000      0.000000      0.000000
# 40299  114869969842      0.222222      0.000000      0.111111      0.166667
# 40300  114999082932      0.409836      0.000000      0.000000      0.000000
# 40301  114999082935      0.400000      0.000000      0.000000      0.000000
# 40302  114999280232      0.200000      0.000000      0.000000      0.000000
# 40303  114999480334      0.428571      0.000000      0.000000      0.000000
# 40304  114999482932      0.583333      0.000000      0.000000      0.000000
# 40305  114999582132      0.118644      0.050847      0.084746      0.033898
# 40306  114999782736      0.250000      0.000000      0.000000      0.000000
#
#        actionType_5  actionType_6  actionType_7  actionType_8  actionType_9
# 0          0.223776      0.125874      0.006993      0.027972      0.020979
# 1          0.333333      0.333333      0.000000      0.000000      0.000000
# 2          0.333333      0.000000      0.333333      0.000000      0.000000
# 3          0.227273      0.136364      0.000000      0.000000      0.000000
# 4          0.166667      0.130952      0.011905      0.000000      0.000000
# 5          0.210526      0.078947      0.026316      0.026316      0.026316
# 6          0.080597      0.020896      0.019403      0.228358      0.013433
# 7          0.267606      0.422535      0.000000      0.028169      0.042254
# 8          0.200000      0.150000      0.000000      0.075000      0.075000
# 9          0.500000      0.227273      0.000000      0.045455      0.000000
# 10         0.439024      0.219512      0.000000      0.000000      0.000000
# 11         0.322581      0.129032      0.064516      0.032258      0.032258
# 12         0.125000      0.093750      0.000000      0.031250      0.031250
# 13         0.600000      0.000000      0.000000      0.000000      0.000000
# 14         0.223301      0.029126      0.019417      0.000000      0.000000
# 15         0.239130      0.173913      0.086957      0.065217      0.065217
# 16         0.315789      0.157895      0.017544      0.017544      0.017544
# 17         0.279302      0.174564      0.014963      0.027431      0.007481
# 18         0.666667      0.000000      0.000000      0.000000      0.000000
# 19         0.457143      0.085714      0.000000      0.028571      0.000000
# 20         0.461538      0.128205      0.051282      0.025641      0.025641
# 21         0.200000      0.266667      0.066667      0.133333      0.066667
# 22         0.234568      0.209877      0.086420      0.074074      0.074074
# 23         0.545455      0.090909      0.000000      0.000000      0.000000
# 24         0.360000      0.200000      0.040000      0.000000      0.000000
# 25         0.465116      0.348837      0.000000      0.046512      0.046512
# 26         0.687500      0.000000      0.000000      0.000000      0.000000
# 27         0.230769      0.192308      0.153846      0.115385      0.115385
# 28         0.500000      0.250000      0.000000      0.000000      0.000000
# 29         0.518519      0.222222      0.000000      0.000000      0.000000
# ...             ...           ...           ...           ...           ...
# 40277      0.300000      0.300000      0.100000      0.000000      0.000000
# 40278      0.187500      0.125000      0.062500      0.031250      0.031250
# 40279      0.166667      0.333333      0.166667      0.000000      0.000000
# 40280      0.300000      0.200000      0.100000      0.000000      0.000000
# 40281      0.000000      0.500000      0.500000      0.000000      0.000000
# 40282      0.393939      0.272727      0.030303      0.000000      0.000000
# 40283      0.250000      0.250000      0.250000      0.000000      0.000000
# 40284      0.433333      0.066667      0.033333      0.033333      0.033333
# 40285      0.444444      0.333333      0.000000      0.000000      0.000000
# 40286      0.250000      0.250000      0.250000      0.000000      0.000000
# 40287      0.216216      0.108108      0.027027      0.000000      0.000000
# 40288      0.318182      0.113636      0.022727      0.000000      0.000000
# 40289      0.484848      0.030303      0.030303      0.000000      0.000000
# 40290      0.285714      0.428571      0.142857      0.000000      0.000000
# 40291      0.347826      0.217391      0.086957      0.000000      0.000000
# 40292      0.000000      0.000000      1.000000      0.000000      0.000000
# 40293      0.130435      0.130435      0.043478      0.086957      0.043478
# 40294      0.363636      0.181818      0.045455      0.000000      0.000000
# 40295      0.400000      0.200000      0.200000      0.000000      0.000000
# 40296      0.250000      0.500000      0.000000      0.000000      0.000000
# 40297      0.444444      0.166667      0.000000      0.000000      0.000000
# 40298      0.250000      0.250000      0.250000      0.000000      0.000000
# 40299      0.166667      0.166667      0.055556      0.055556      0.055556
# 40300      0.426230      0.147541      0.000000      0.016393      0.000000
# 40301      0.200000      0.200000      0.000000      0.100000      0.100000
# 40302      0.320000      0.280000      0.000000      0.120000      0.080000
# 40303      0.428571      0.142857      0.000000      0.000000      0.000000
# 40304      0.333333      0.083333      0.000000      0.000000      0.000000
# 40305      0.423729      0.271186      0.016949      0.000000      0.000000
# 40306      0.500000      0.250000      0.000000      0.000000      0.000000
#
# [40307 rows x 10 columns]

# %%
def get_two(arr):
    try:
        tem = int(arr.iloc[-2])
        return tem
    except:
        np.nan
    
def get_three(arr):
    try:
        tem = int(arr.iloc[-3])
        return tem
    except:
        return np.nan

# %%
def last_action(df):
    last_type=df[['userid','actionType']].groupby('userid',as_index=False).agg('last')
    last_type.rename(columns={'actionType':'last_type'},inplace=True)
    
    two_type=df[['userid','actionType']].groupby('userid',as_index=False).agg(get_two)
    two_type.rename(columns={'actionType':'two_type'},inplace=True)
    
    three_type=df[['userid','actionType']].groupby('userid',as_index=False).agg(get_three)
    three_type.rename(columns={'actionType':'three_type'},inplace=True)
    
    last=pd.merge(last_type,two_type,on='userid',how='left')
    last=pd.merge(last,three_type,on='userid',how='left')
    return last

# %%
last_action(ac).head()
# Out:
#          userid  last_type  two_type  three_type
# 0  100000000013          6       1.0         1.0
# 1  100000000111          6       5.0         1.0
# 2  100000000127          7       7.0         5.0
# 3  100000000231          2       2.0         1.0
# 4  100000000379          1       6.0         5.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
def last_city(train,test):
    city=list(order_his['city'].unique())
    city_test=list(order_his_test['city'].unique())
    
    for i in city_test:
        if i not in city:
            city.append(i)
    le.fit(city)
    
    new = order_his[['userid','city','continent']].drop_duplicates(subset='userid',keep='last')
    new['city']=le.transform(new['city'])
    
    new_test = order_his_test[['userid','city','continent']].drop_duplicates(subset='userid',keep='last')
    new_test['city']=le.transform(new_test['city'])
    
    new['continent']=le.fit_transform(new['continent'])
    new_test['continent']=le.fit_transform(new_test['continent'])
    
    train=pd.merge(train,new,on='userid',how='left')
    test=pd.merge(test,new_test,on='userid',how='left')
    return train,test

# %%
def profile_me(train,test):
    for i in ['province','gender','age']:
        train[i]=train[i].factorize()[0]
        test[i]=test[i].factorize()[0]
        
        train[i]=le.fit_transform(train[i])
        test[i]=le.fit_transform(test[i])
    return train,test

# %%
def fun1(arr):
    try:
        return ((arr.iloc[-1])-(arr.iloc[-2])).seconds
    except:
        return np.nan
    
def fun2(arr):
    try:
        return ((arr.iloc[-1])-(arr.iloc[-2])).days
    except:
        return np.nan
def fun3(arr):
    try:
        return ((arr.iloc[-2]) - (arr.iloc[-3])).days
    except:
        return np.nan

def fun4(arr):
    try:
        return ((arr.iloc[-2]) - (arr.iloc[-3])).seconds
    except:
        return np.nan

# %%
def ac_time(train,test):
    las_two_day=ac[['userid','actionTime']].groupby('userid',as_index=False).agg(fun2)
    las_two_day.rename(columns={'actionTime':'last_two_day'},inplace=True)
    
    las_two_second = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun1)
    las_two_second.rename(columns={'actionTime':'last_two_second'}, inplace=True)
    
    two_three_day = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun3)
    two_three_day.rename(columns={'actionTime':'two_three_day'}, inplace=True)
    
    two_three_second = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
    two_three_second.rename(columns={'actionTime':'two_three_second'}, inplace=True)
    
    train=pd.merge(train,las_two_day,on='userid',how='left')
    train = pd.merge(train, las_two_second, on='userid', how='left')
    train = pd.merge(train, two_three_day, on='userid', how='left')
    train = pd.merge(train, two_three_second, on='userid', how='left')
    
    las_two_day_ = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun2)
    las_two_day_.rename(columns={'actionTime':'last_two_day'}, inplace=True)
    las_two_second_ = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun1)
    las_two_second_.rename(columns={'actionTime':'last_two_second'}, inplace=True)
    
    two_three_day = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun3)
    two_three_day.rename(columns={'actionTime':'two_three_day'}, inplace=True)
    two_three_second = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
    two_three_second.rename(columns={'actionTime':'two_three_second'}, inplace=True)
    
    test = pd.merge(test, las_two_day_, on='userid', how='left')
    test = pd.merge(test, las_two_second_, on='userid', how='left')
    test = pd.merge(test, two_three_day, on='userid', how='left')
    test = pd.merge(test, two_three_second, on='userid', how='left')
    
    return train,test

# %%
def fun5(timeseries):
    sum=[]
    for i in range(len(timeseries)-1):
        sum.append((timeseries.iloc[i+1]-timeseries.iloc[i]).seconds)
    return np.mean(sum)

def fun6(timeseries):
    sum=[]
    for i in range(len(timeseries)-1):
        sum.append((timeseries.iloc[i+1]-timeseries.iloc[i]).seconds)
    return np.std(sum)

# %%
def time_delta(train,test):
    time_mean=ac[['userid','actionTime']].groupby('userid',as_index=False).agg(fun5)
    time_mean.rename(columns={'actionTime':'timedelta_mean'}, inplace=True)
    
    time_std = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun5)
    time_std.rename(columns={'actionTime':'timedelta_std'}, inplace=True)
    
    train = pd.merge(train,time_mean,on='userid',how='left')
    train = pd.merge(train,time_std,on='userid',how='left')
    
    time_mean = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun5)
    time_mean.rename(columns={'actionTime':'timedelta_mean'}, inplace=True)
    time_std = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun6)
    time_std.rename(columns={'actionTime':'timedelta_std'}, inplace=True)
    
    test = pd.merge(test, time_mean, on='userid', how='left')
    test = pd.merge(test, time_std, on='userid', how='left')
    return train, test

# %%
def his_s(train,test):
    df = order_his.drop_duplicates(subset='userid',keep='last').reset_index(drop=True)
    last_type=[]
    for i in range(len(df)):
        temp_time = df.loc[i,'orderTime']
        time_id=df.loc[i,'userid']
        new = ac[ac.userid == temp_id]
        new = new[new.actionTime < temp_time]
        if(len(new) != 0 ):
            new = new.iloc[-1]
            last_type.append(new.actionType)
        else:
            last_type.append(np.nan)
    last_type=pd.Series(np.array(last_type))
    last_type.index=df.index
    last_type=pd.DataFrame(last_type,columns=['hist_type'])
    last_type['userid']=df['userid']
    train=pd.merge(train,last_type,on='userid',how='left')
    
    df = order_his_test.drop_duplicates(subset='userid', keep='last').reset_index(drop=True)
    last_type = []
    for i in range(len(df)):
        temp_time = df.loc[i, 'orderTime']
        temp_id = df.loc[i, 'userid']
        new = ac_test[ac_test.userid == temp_id]
        new = new[new.actionTime < temp_time]
        if(len(new) != 0):
            new = new.iloc[-1]
            last_type.append(new.actionType)
        else:
            last_type.append(np.nan)
    last_type = pd.Series(np.array(last_type))
    last_type.index = df.index
    last_type = pd.DataFrame(last_type, columns=['hist_type'])
    last_type['userid'] = df['userid']
    
    test = pd.merge(test, last_type, on='userid', how='left')
    
    return train,test

# %%
def distance_last(odf,a=5):
    name='flag_'+str(a)
    odf[name]=(odf.actionType == a)*1
    
    id = []
    dis = []
    for i in list(odf.userid.unique()):
        id.append(i)
        
        df=odf[odf.userid == i]
        time1 = df.actionTime.iloc[-1]
        
        df = df[df[name]==1]
        if(len(df)!= 0):
            if df.iloc[-1].actionTime == time1:
                df = df[:-1]
            if len(df) >= 1:
                dis.append((time1 - df.iloc[-1].actionTime).seconds)
            else:
                dis.append(np.nan)
        else:
            dis.append(np.nan)
            
    column_name = 'last_'+str(a)+'dis'
    new_df = pd.DataFrame({'userid':id,column_name:dis})
    return new_df

# %%
def action_count(train,test):
    count=[]
    id=[]
    for i in (ac.userid.unique()):
        id.append(i)
        df = ac[ac.userid ==i]
        df=df.loc[df.day == df.iloc[-1].day]
        count.append(len(df))
    new=pd.DataFrame({'userid':id,'count':count})
    train = pd.merge(train,new,on='userid',how='left')
    
    count = []
    id = []
    for i in (ac_test.userid.unique()):
        id.append(i)
        df = ac_test[ac_test.userid == i]
        df = df.loc[df.day == df.iloc[-1].day]
        count.append(len(df))
    new = pd.DataFrame({'userid':id, 
                       'count':count})
    test = pd.merge(test, new, on='userid', how='left')
    return train, test

# %%
def flags_buy(df):
    flags=[]
    id=[]
    for i in list(df.userid.unique()):
        id.append(i)
        df_=df[df.userid == i]
        if df_.orderType.sum() != 0:
            flag.append(1)
        else:
            flags.append(0)
    new = pd.DataFrame({'userid':id,'buy_flags':flags})
    return new

# %%
def gen_train_feat():
    actions = order
    actions_test = order_test
    
    actions = pd.merge(actions, distance_last(ac, 5), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 5), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 6), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 6), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 7), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 7), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 8), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 8), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 9), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 9), on='userid', how='left')
    actions, actions_test = action_count(actions, actions_test)
    actions = pd.merge(actions,orderHistory_feat(order_his),on='userid',how='left')
    actions = pd.merge(actions,actions_orderType(ac),on='userid',how='left')
    actions = pd.merge(actions,last_action(ac),on='userid',how='left')  
    
    actions_test = pd.merge(actions_test,orderHistory_feat(order_his_test),on='userid',how='left')
    actions_test = pd.merge(actions_test,actions_orderType(ac_test),on='userid',how='left')
    actions_test = pd.merge(actions_test,last_action(ac_test),on='userid',how='left')
    
    actions, actions_test = last_city(actions, actions_test)
    
    profile_, profile_test_ = profile_me(profile, profile_test)
    actions = pd.merge(actions, profile_, on='userid', how='left')
    actions_test = pd.merge(actions_test, profile_test_, on='userid', how='left')
    actions, actions_test = ac_time(actions, actions_test)
    
    actions = pd.merge(actions, comment[['userid', 'rating']], on='userid', how='left')
    actions_test = pd.merge(actions_test, comment_test[['userid', 'rating']], on='userid', how='left')
    
    actions['flag_five'] = (actions['last_type'] == 5) * 1
    actions['flag_six'] = (actions['last_type'] == 6) * 1
    actions['flag_seven'] = (actions['last_type'] == 7) * 1
    
    actions_test['flag_five'] = (actions_test['last_type'] == 5) * 1
    actions_test['flag_six'] = (actions_test['last_type'] == 6) * 1
    actions_test['flag_seven'] = (actions_test['last_type'] == 7) * 1
    
    
#     actions = pd.merge(actions, flags_buy(order_his), on='userid', how='left')
#     actions_test = pd.merge(actions_test, flags_buy(order_his_test), on='userid', how='left')
    
#     actions, actions_test = time_delta(actions, actions_test)

#     actions, actions_test = his_s(actions, actions_test)
    return actions, actions_test

# %%
order.rename(columns={'orderType':'label'},inplace=True)
train_data,test_data=gen_train_feat()
train_data.head()
# Out:
#          userid  label  last_5dis  last_6dis  last_7dis  last_8dis  last_9dis  \
# 0  100000000013      0     1761.0    69194.0    69097.0    69093.0    69082.0
# 1  100000000111      0       33.0        NaN        NaN        NaN        NaN
# 2  100000000127      0    35264.0        NaN    70086.0        NaN        NaN
# 3  100000000231      0     9853.0     9841.0        NaN        NaN        NaN
# 4  100000000379      0    70045.0    70004.0     7171.0        NaN        NaN
#
#    count  orderHistory_feat_sum  actionType_1     ...      province  age  \
# 0     11                    0.0      0.552448     ...             0    1
# 1      3                    NaN      0.333333     ...             1    0
# 2      1                    NaN      0.333333     ...             1    0
# 3     16                    NaN      0.340909     ...             2    2
# 4      1                    NaN      0.500000     ...             2    0
#
#    last_two_day  last_two_second  two_three_day  two_three_second  rating  \
# 0           2.0          67530.0            0.0           69377.0     4.0
# 1           0.0             33.0            0.0              13.0     NaN
# 2          37.0          70086.0           43.0           51578.0     NaN
# 3           0.0              5.0            0.0              55.0     5.0
# 4           2.0          70004.0            0.0              41.0     NaN
#
#    flag_five  flag_six  flag_seven
# 0          0         1           0
# 1          0         1           0
# 2          0         0           1
# 3          0         0           0
# 4          0         0           0
#
# [5 rows x 34 columns]

# %%
test_data.head()
# Out:
#          userid  last_5dis  last_6dis  last_7dis  last_8dis  last_9dis  count  \
# 0  100000000371      387.0       90.0      517.0        NaN        NaN     13
# 1  100000001215       65.0    18353.0        NaN        NaN        NaN      5
# 2  100000001445      141.0      274.0        NaN    50262.0    63132.0      5
# 3  100000001575       24.0       69.0        NaN    85015.0        NaN     18
# 4  100000001601    53071.0    52994.0        NaN     4775.0     4766.0      7
#
#    orderHistory_feat_sum  actionType_1  actionType_2     ...      province  \
# 0                    0.0      0.076923           0.0     ...             1
# 1                    NaN      0.407407           0.0     ...             0
# 2                    0.0      0.477011           0.0     ...             2
# 3                    1.0      0.226190           0.0     ...             3
# 4                    NaN      0.466667           0.0     ...             1
#
#    age  last_two_day  last_two_second  two_three_day  two_three_second  \
# 0    0           0.0             90.0            0.0              13.0
# 1    0           0.0             65.0            0.0               4.0
# 2    0           0.0            141.0            0.0             133.0
# 3    0           0.0             24.0            0.0              45.0
# 4    0          13.0          76948.0            1.0           74279.0
#
#    rating  flag_five  flag_six  flag_seven
# 0     NaN          0         0           1
# 1     NaN          0         1           0
# 2     5.0          0         1           0
# 3     5.0          0         1           0
# 4     5.0          0         0           0
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
train_label=train_data['label']
del train_data['label']
x_train,x_val,y_train,y_val=train_test_split(train_data,train_label,test_size=0.2,random_state=100)

x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32245 entries, 5544 to 38408
# Data columns (total 33 columns):
# userid                   32245 non-null int64
# last_5dis                30476 non-null float64
# last_6dis                26282 non-null float64
# last_7dis                7203 non-null float64
# last_8dis                9526 non-null float64
# last_9dis                7135 non-null float64
# count                    32245 non-null int64
# orderHistory_feat_sum    8518 non-null float64
# actionType_1             32245 non-null float64
# actionType_2             32245 non-null float64
# actionType_3             32245 non-null float64
# actionType_4             32245 non-null float64
# actionType_5             32245 non-null float64
# actionType_6             32245 non-null float64
# actionType_7             32245 non-null float64
# actionType_8             32245 non-null float64
# actionType_9             32245 non-null float64
# last_type                32245 non-null int64
# two_type                 31240 non-null float64
# three_type               30649 non-null float64
# city                     8518 non-null float64
# continent                8518 non-null float64
# gender                   32245 non-null int64
# province                 32245 non-null int64
# age                      32245 non-null int64
# last_two_day             31240 non-null float64
# last_two_second          31240 non-null float64
# two_three_day            30649 non-null float64
# two_three_second         30649 non-null float64
# rating                   7857 non-null float64
# flag_five                32245 non-null int32
# flag_six                 32245 non-null int32
# flag_seven               32245 non-null int32
# dtypes: float64(24), int32(3), int64(6)
# memory usage: 8.0 MB

# %%
x_train.shape
# Out:
# (32245, 33)

# %%
x_val.shape
# Out:
# (8062, 33)

# %%
y_train.shape
# Out:
# (32245,)

# %% [raw]
# y_val.shape

# %%
x_train.head()
# Out:
#              userid  last_5dis  last_6dis  last_7dis  last_8dis  last_9dis  \
# 5544   110177235060      192.0        NaN        NaN        NaN        NaN
# 38604  114822952248      137.0       63.0        NaN        NaN        NaN
# 23935  111850246159        1.0    86078.0        NaN    85651.0    85632.0
# 19307  111422313011    47000.0     1817.0        NaN        NaN        NaN
# 29472  112538965587      116.0    23889.0        NaN        NaN        NaN
#
#        count  orderHistory_feat_sum  actionType_1  actionType_2     ...      \
# 5544       3                    NaN      0.333333           0.0     ...
# 38604      3                    NaN      0.000000           0.0     ...
# 23935      3                    NaN      0.321429           0.0     ...
# 19307      2                    NaN      0.384615           0.0     ...
# 29472      3                    NaN      0.200000           0.0     ...
#
#        province  age  last_two_day  last_two_second  two_three_day  \
# 5544         13    0           0.0            192.0            0.0
# 38604         1    0           0.0             63.0            0.0
# 23935         0    0           0.0              1.0            0.0
# 19307        13    0           0.0            129.0            1.0
# 29472         2    0           0.0            116.0            0.0
#
#        two_three_second  rating  flag_five  flag_six  flag_seven
# 5544               98.0     NaN          0         1           0
# 38604              74.0     NaN          0         0           1
# 23935               6.0     5.0          1         0           0
# 19307           12248.0     NaN          0         0           0
# 29472               4.0     NaN          0         1           0
#
# [5 rows x 33 columns]

# %%
import xgboost as xgb
print('start runing...')
dtrain= xgb.DMatrix(x_train,label=y_train)
dval=xgb.DMatrix(x_val,label=y_val)

param = {'learning_rate' : 0.1,
        'n_estimators': 1000,
        'max_depth': 4,
        'min_child_weight': 7,
        'gamma': 0.9,
        'subsample': 0.94,
        'colsample_bytree': 0.75,
        'eta': 0.05,
        'silent': 1,
        'objective': 'binary:logistic',
        'scale_pos_weight':1}
# Out:
# start runing...

# %%
num_round =1000
plst = list(param.items())
plst += [('eval_metric', 'auc')]
evallist = [(dval, 'eval'), (dtrain, 'train')]
bst=xgb.train(plst,dtrain,num_round,evallist,early_stopping_rounds=100)
dtest = xgb.DMatrix(test_data)
y = bst.predict(dtest)
# Out:
# [0]	eval-auc:0.770355	train-auc:0.766018
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	eval-auc:0.817193	train-auc:0.811441
# [2]	eval-auc:0.844599	train-auc:0.838981
# [3]	eval-auc:0.846769	train-auc:0.841018
# [4]	eval-auc:0.855276	train-auc:0.848468
# [5]	eval-auc:0.854552	train-auc:0.848938
# [6]	eval-auc:0.857338	train-auc:0.849051
# [7]	eval-auc:0.861189	train-auc:0.851315
# [8]	eval-auc:0.872113	train-auc:0.859691
# [9]	eval-auc:0.871125	train-auc:0.858376
# [10]	eval-auc:0.8713	train-auc:0.857715
# [11]	eval-auc:0.870361	train-auc:0.858241
# [12]	eval-auc:0.870753	train-auc:0.857983
# [13]	eval-auc:0.872052	train-auc:0.858926
# [14]	eval-auc:0.879138	train-auc:0.866213
# [15]	eval-auc:0.882904	train-auc:0.869696
# [16]	eval-auc:0.890361	train-auc:0.878599
# [17]	eval-auc:0.89345	train-auc:0.882528
# [18]	eval-auc:0.898269	train-auc:0.888695
# [19]	eval-auc:0.900292	train-auc:0.891607
# [20]	eval-auc:0.900389	train-auc:0.891679
# [21]	eval-auc:0.90271	train-auc:0.893903
# [22]	eval-auc:0.903449	train-auc:0.895926
# [23]	eval-auc:0.903824	train-auc:0.896019
# [24]	eval-auc:0.903261	train-auc:0.895802
# [25]	eval-auc:0.90484	train-auc:0.897258
# [26]	eval-auc:0.909537	train-auc:0.902588
# [27]	eval-auc:0.911156	train-auc:0.904849
# [28]	eval-auc:0.912253	train-auc:0.90599
# [29]	eval-auc:0.913964	train-auc:0.907407
# [30]	eval-auc:0.914403	train-auc:0.908594
# [31]	eval-auc:0.915049	train-auc:0.909052
# [32]	eval-auc:0.91599	train-auc:0.910106
# [33]	eval-auc:0.91655	train-auc:0.910791
# [34]	eval-auc:0.918155	train-auc:0.912641
# [35]	eval-auc:0.918566	train-auc:0.912889
# [36]	eval-auc:0.92034	train-auc:0.914876
# [37]	eval-auc:0.920441	train-auc:0.914833
# [38]	eval-auc:0.921398	train-auc:0.91601
# [39]	eval-auc:0.921981	train-auc:0.91656
# [40]	eval-auc:0.922258	train-auc:0.916872
# [41]	eval-auc:0.922739	train-auc:0.917164
# [42]	eval-auc:0.922758	train-auc:0.917366
# [43]	eval-auc:0.924341	train-auc:0.918918
# [44]	eval-auc:0.925889	train-auc:0.920408
# [45]	eval-auc:0.926443	train-auc:0.920957
# [46]	eval-auc:0.926853	train-auc:0.921521
# [47]	eval-auc:0.927493	train-auc:0.922071
# [48]	eval-auc:0.928197	train-auc:0.92298
# [49]	eval-auc:0.928827	train-auc:0.924006
# [50]	eval-auc:0.929376	train-auc:0.924437
# [51]	eval-auc:0.92943	train-auc:0.92494
# [52]	eval-auc:0.930786	train-auc:0.926212
# [53]	eval-auc:0.931433	train-auc:0.92689
# [54]	eval-auc:0.932828	train-auc:0.928261
# [55]	eval-auc:0.933093	train-auc:0.928677
# [56]	eval-auc:0.933651	train-auc:0.929261
# [57]	eval-auc:0.933737	train-auc:0.929278
# [58]	eval-auc:0.934657	train-auc:0.930556
# [59]	eval-auc:0.934972	train-auc:0.930973
# [60]	eval-auc:0.935403	train-auc:0.931663
# [61]	eval-auc:0.935533	train-auc:0.931879
# [62]	eval-auc:0.935666	train-auc:0.932233
# [63]	eval-auc:0.935899	train-auc:0.932436
# [64]	eval-auc:0.936274	train-auc:0.932755
# [65]	eval-auc:0.936511	train-auc:0.933319
# [66]	eval-auc:0.936592	train-auc:0.933573
# [67]	eval-auc:0.937056	train-auc:0.933921
# [68]	eval-auc:0.937547	train-auc:0.934593
# [69]	eval-auc:0.937481	train-auc:0.934791
# [70]	eval-auc:0.937507	train-auc:0.934998
# [71]	eval-auc:0.937611	train-auc:0.935135
# [72]	eval-auc:0.937665	train-auc:0.935292
# [73]	eval-auc:0.937834	train-auc:0.935484
# [74]	eval-auc:0.937881	train-auc:0.935583
# [75]	eval-auc:0.938468	train-auc:0.936101
# [76]	eval-auc:0.938614	train-auc:0.936222
# [77]	eval-auc:0.938802	train-auc:0.936403
# [78]	eval-auc:0.938785	train-auc:0.93648
# [79]	eval-auc:0.938883	train-auc:0.936606
# [80]	eval-auc:0.938988	train-auc:0.936758
# [81]	eval-auc:0.939037	train-auc:0.93696
# [82]	eval-auc:0.939111	train-auc:0.937034
# [83]	eval-auc:0.939626	train-auc:0.93768
# [84]	eval-auc:0.939793	train-auc:0.937939
# [85]	eval-auc:0.940251	train-auc:0.938726
# [86]	eval-auc:0.940401	train-auc:0.939187
# [87]	eval-auc:0.940462	train-auc:0.939306
# [88]	eval-auc:0.940537	train-auc:0.939516
# [89]	eval-auc:0.940586	train-auc:0.939569
# [90]	eval-auc:0.940841	train-auc:0.939799
# [91]	eval-auc:0.940972	train-auc:0.94012
# [92]	eval-auc:0.941035	train-auc:0.940322
# [93]	eval-auc:0.941058	train-auc:0.94048
# [94]	eval-auc:0.941226	train-auc:0.940716
# [95]	eval-auc:0.941172	train-auc:0.940836
# [96]	eval-auc:0.941167	train-auc:0.940957
# [97]	eval-auc:0.941226	train-auc:0.941166
# [98]	eval-auc:0.941218	train-auc:0.941239
# [99]	eval-auc:0.941247	train-auc:0.941379
# [100]	eval-auc:0.941428	train-auc:0.941566
# [101]	eval-auc:0.941447	train-auc:0.94163
# [102]	eval-auc:0.941457	train-auc:0.941754
# [103]	eval-auc:0.941478	train-auc:0.941995
# [104]	eval-auc:0.941583	train-auc:0.942128
# [105]	eval-auc:0.94171	train-auc:0.942318
# [106]	eval-auc:0.941939	train-auc:0.942609
# [107]	eval-auc:0.941948	train-auc:0.942655
# [108]	eval-auc:0.942155	train-auc:0.942817
# [109]	eval-auc:0.94211	train-auc:0.942846
# [110]	eval-auc:0.94223	train-auc:0.942931
# [111]	eval-auc:0.942205	train-auc:0.942982
# [112]	eval-auc:0.942396	train-auc:0.943313
# [113]	eval-auc:0.942411	train-auc:0.943336
# [114]	eval-auc:0.942405	train-auc:0.943405
# [115]	eval-auc:0.942458	train-auc:0.943554
# [116]	eval-auc:0.942554	train-auc:0.943763
# [117]	eval-auc:0.942634	train-auc:0.943953
# [118]	eval-auc:0.942572	train-auc:0.944111
# [119]	eval-auc:0.942589	train-auc:0.944186
# [120]	eval-auc:0.942581	train-auc:0.944265
# [121]	eval-auc:0.942697	train-auc:0.944556
# [122]	eval-auc:0.942712	train-auc:0.944696
# [123]	eval-auc:0.942828	train-auc:0.944851
# [124]	eval-auc:0.942947	train-auc:0.944996
# [125]	eval-auc:0.942931	train-auc:0.944998
# [126]	eval-auc:0.942978	train-auc:0.945091
# [127]	eval-auc:0.942988	train-auc:0.945441
# [128]	eval-auc:0.943576	train-auc:0.945849
# [129]	eval-auc:0.943696	train-auc:0.946012
# [130]	eval-auc:0.943737	train-auc:0.946072
# [131]	eval-auc:0.943829	train-auc:0.946252
# [132]	eval-auc:0.944016	train-auc:0.946369
# [133]	eval-auc:0.943997	train-auc:0.946451
# [134]	eval-auc:0.944062	train-auc:0.946628
# [135]	eval-auc:0.944	train-auc:0.94688
# [136]	eval-auc:0.944058	train-auc:0.94699
# [137]	eval-auc:0.944113	train-auc:0.947085
# [138]	eval-auc:0.944143	train-auc:0.947227
# [139]	eval-auc:0.944391	train-auc:0.947614
# [140]	eval-auc:0.944412	train-auc:0.947744
# [141]	eval-auc:0.944467	train-auc:0.947976
# [142]	eval-auc:0.94463	train-auc:0.948201
# [143]	eval-auc:0.944644	train-auc:0.94829
# [144]	eval-auc:0.944684	train-auc:0.948527
# [145]	eval-auc:0.944707	train-auc:0.948641
# [146]	eval-auc:0.945155	train-auc:0.949018
# [147]	eval-auc:0.945193	train-auc:0.949162
# [148]	eval-auc:0.945274	train-auc:0.949256
# [149]	eval-auc:0.945231	train-auc:0.949313
# [150]	eval-auc:0.945383	train-auc:0.949441
# [151]	eval-auc:0.945478	train-auc:0.949562
# [152]	eval-auc:0.945568	train-auc:0.949754
# [153]	eval-auc:0.945617	train-auc:0.949827
# [154]	eval-auc:0.945755	train-auc:0.950027
# [155]	eval-auc:0.945735	train-auc:0.950055
# [156]	eval-auc:0.945909	train-auc:0.950254
# [157]	eval-auc:0.945959	train-auc:0.950406
# [158]	eval-auc:0.945955	train-auc:0.950509
# [159]	eval-auc:0.94603	train-auc:0.950714
# [160]	eval-auc:0.946014	train-auc:0.950787
# [161]	eval-auc:0.946043	train-auc:0.950789
# [162]	eval-auc:0.946388	train-auc:0.951037
# [163]	eval-auc:0.946518	train-auc:0.951084
# [164]	eval-auc:0.946674	train-auc:0.951369
# [165]	eval-auc:0.946703	train-auc:0.951443
# [166]	eval-auc:0.946719	train-auc:0.951625
# [167]	eval-auc:0.946692	train-auc:0.951674
# [168]	eval-auc:0.947048	train-auc:0.951982
# [169]	eval-auc:0.947501	train-auc:0.952308
# [170]	eval-auc:0.947641	train-auc:0.95249
# [171]	eval-auc:0.947624	train-auc:0.952601
# [172]	eval-auc:0.947711	train-auc:0.952773
# [173]	eval-auc:0.947713	train-auc:0.952869
# [174]	eval-auc:0.947788	train-auc:0.952943
# [175]	eval-auc:0.947675	train-auc:0.953026
# [176]	eval-auc:0.94772	train-auc:0.953075
# [177]	eval-auc:0.947692	train-auc:0.953215
# [178]	eval-auc:0.947794	train-auc:0.953338
# [179]	eval-auc:0.947784	train-auc:0.953456
# [180]	eval-auc:0.947785	train-auc:0.953532
# [181]	eval-auc:0.947848	train-auc:0.953708
# [182]	eval-auc:0.947915	train-auc:0.95384
# [183]	eval-auc:0.947886	train-auc:0.95393
# [184]	eval-auc:0.947908	train-auc:0.953977
# [185]	eval-auc:0.947951	train-auc:0.953983
# [186]	eval-auc:0.947969	train-auc:0.954009
# [187]	eval-auc:0.948105	train-auc:0.954146
# [188]	eval-auc:0.948091	train-auc:0.954239
# [189]	eval-auc:0.948087	train-auc:0.954287
# [190]	eval-auc:0.948311	train-auc:0.954484
# [191]	eval-auc:0.948308	train-auc:0.954548
# [192]	eval-auc:0.94833	train-auc:0.954575
# [193]	eval-auc:0.948283	train-auc:0.954751
# [194]	eval-auc:0.948279	train-auc:0.954811
# [195]	eval-auc:0.948339	train-auc:0.954924
# [196]	eval-auc:0.948358	train-auc:0.954957
# [197]	eval-auc:0.948396	train-auc:0.955057
# [198]	eval-auc:0.948346	train-auc:0.955106
# [199]	eval-auc:0.948336	train-auc:0.955184
# [200]	eval-auc:0.948321	train-auc:0.955323
# [201]	eval-auc:0.948294	train-auc:0.955371
# [202]	eval-auc:0.948306	train-auc:0.955513
# [203]	eval-auc:0.948466	train-auc:0.955652
# [204]	eval-auc:0.94891	train-auc:0.956028
# [205]	eval-auc:0.948902	train-auc:0.956054
# [206]	eval-auc:0.948966	train-auc:0.956167
# [207]	eval-auc:0.949023	train-auc:0.956219
# [208]	eval-auc:0.949059	train-auc:0.956418
# [209]	eval-auc:0.949078	train-auc:0.956539
# [210]	eval-auc:0.949125	train-auc:0.956631
# [211]	eval-auc:0.949151	train-auc:0.956728
# [212]	eval-auc:0.949263	train-auc:0.956894
# [213]	eval-auc:0.949341	train-auc:0.956955
# [214]	eval-auc:0.949514	train-auc:0.957068
# [215]	eval-auc:0.949548	train-auc:0.957152
# [216]	eval-auc:0.949547	train-auc:0.957191
# [217]	eval-auc:0.949541	train-auc:0.957272
# [218]	eval-auc:0.949536	train-auc:0.957394
# [219]	eval-auc:0.949543	train-auc:0.957428
# [220]	eval-auc:0.949613	train-auc:0.957537
# [221]	eval-auc:0.94961	train-auc:0.957571
# [222]	eval-auc:0.949613	train-auc:0.957624
# [223]	eval-auc:0.949739	train-auc:0.957802
# [224]	eval-auc:0.949777	train-auc:0.957863
# [225]	eval-auc:0.94979	train-auc:0.95798
# [226]	eval-auc:0.949771	train-auc:0.958035
# [227]	eval-auc:0.949884	train-auc:0.958191
# [228]	eval-auc:0.949879	train-auc:0.958223
# [229]	eval-auc:0.949888	train-auc:0.958291
# [230]	eval-auc:0.949902	train-auc:0.958325
# [231]	eval-auc:0.950004	train-auc:0.958459
# [232]	eval-auc:0.950201	train-auc:0.95856
# [233]	eval-auc:0.950215	train-auc:0.958603
# [234]	eval-auc:0.950252	train-auc:0.958774
# [235]	eval-auc:0.950264	train-auc:0.958803
# [236]	eval-auc:0.950313	train-auc:0.95893
# [237]	eval-auc:0.950377	train-auc:0.959018
# [238]	eval-auc:0.950407	train-auc:0.959129
# [239]	eval-auc:0.950417	train-auc:0.959224
# [240]	eval-auc:0.950404	train-auc:0.959259
# [241]	eval-auc:0.950389	train-auc:0.959299
# [242]	eval-auc:0.950419	train-auc:0.959394
# [243]	eval-auc:0.950446	train-auc:0.959453
# [244]	eval-auc:0.950409	train-auc:0.959536
# [245]	eval-auc:0.950401	train-auc:0.959585
# [246]	eval-auc:0.950403	train-auc:0.95969
# [247]	eval-auc:0.950519	train-auc:0.959799
# [248]	eval-auc:0.950527	train-auc:0.95989
# [249]	eval-auc:0.950517	train-auc:0.959984
# [250]	eval-auc:0.950624	train-auc:0.960151
# [251]	eval-auc:0.950608	train-auc:0.960174
# [252]	eval-auc:0.950548	train-auc:0.96021
# [253]	eval-auc:0.950557	train-auc:0.96027
# [254]	eval-auc:0.950536	train-auc:0.96032
# [255]	eval-auc:0.950544	train-auc:0.96041
# [256]	eval-auc:0.950717	train-auc:0.960517
# [257]	eval-auc:0.950665	train-auc:0.9606
# [258]	eval-auc:0.950665	train-auc:0.960692
# [259]	eval-auc:0.950644	train-auc:0.960771
# [260]	eval-auc:0.950689	train-auc:0.960883
# [261]	eval-auc:0.95071	train-auc:0.960933
# [262]	eval-auc:0.950691	train-auc:0.961097
# [263]	eval-auc:0.950717	train-auc:0.961197
# [264]	eval-auc:0.950666	train-auc:0.96125
# [265]	eval-auc:0.950652	train-auc:0.961335
# [266]	eval-auc:0.950618	train-auc:0.961395
# [267]	eval-auc:0.950614	train-auc:0.961408
# [268]	eval-auc:0.950578	train-auc:0.961446
# [269]	eval-auc:0.950586	train-auc:0.961502
# [270]	eval-auc:0.950593	train-auc:0.961554
# [271]	eval-auc:0.95063	train-auc:0.961695
# [272]	eval-auc:0.950615	train-auc:0.96172
# [273]	eval-auc:0.950595	train-auc:0.961842
# [274]	eval-auc:0.950655	train-auc:0.961956
# [275]	eval-auc:0.950612	train-auc:0.962029
# [276]	eval-auc:0.950621	train-auc:0.962115
# [277]	eval-auc:0.950707	train-auc:0.962231
# [278]	eval-auc:0.950738	train-auc:0.962272
# [279]	eval-auc:0.950717	train-auc:0.96231
# [280]	eval-auc:0.950672	train-auc:0.962375
# [281]	eval-auc:0.950658	train-auc:0.962457
# [282]	eval-auc:0.950645	train-auc:0.96248
# [283]	eval-auc:0.950714	train-auc:0.962578
# [284]	eval-auc:0.950725	train-auc:0.96261
# [285]	eval-auc:0.95068	train-auc:0.962638
# [286]	eval-auc:0.950671	train-auc:0.962699
# [287]	eval-auc:0.950686	train-auc:0.962786
# [288]	eval-auc:0.950685	train-auc:0.962815
# [289]	eval-auc:0.950959	train-auc:0.962969
# [290]	eval-auc:0.950991	train-auc:0.963057
# [291]	eval-auc:0.950884	train-auc:0.963137
# [292]	eval-auc:0.950865	train-auc:0.963184
# [293]	eval-auc:0.950928	train-auc:0.963247
# [294]	eval-auc:0.95088	train-auc:0.963374
# [295]	eval-auc:0.950832	train-auc:0.963535
# [296]	eval-auc:0.950831	train-auc:0.963555
# [297]	eval-auc:0.95084	train-auc:0.963679
# [298]	eval-auc:0.950927	train-auc:0.963785
# [299]	eval-auc:0.950885	train-auc:0.963811
# [300]	eval-auc:0.950859	train-auc:0.963857
# [301]	eval-auc:0.95086	train-auc:0.963861
# [302]	eval-auc:0.950876	train-auc:0.963921
# [303]	eval-auc:0.950896	train-auc:0.963943
# [304]	eval-auc:0.950888	train-auc:0.964011
# [305]	eval-auc:0.95091	train-auc:0.96408
# [306]	eval-auc:0.950922	train-auc:0.9641
# [307]	eval-auc:0.950991	train-auc:0.964199
# [308]	eval-auc:0.950969	train-auc:0.96426
# [309]	eval-auc:0.950968	train-auc:0.964351
# [310]	eval-auc:0.950972	train-auc:0.964378
# [311]	eval-auc:0.950962	train-auc:0.964432
# [312]	eval-auc:0.950955	train-auc:0.964474
# [313]	eval-auc:0.951003	train-auc:0.964593
# [314]	eval-auc:0.951021	train-auc:0.964616
# [315]	eval-auc:0.951037	train-auc:0.964656
# [316]	eval-auc:0.951043	train-auc:0.964697
# [317]	eval-auc:0.951021	train-auc:0.964744
# [318]	eval-auc:0.950974	train-auc:0.964816
# [319]	eval-auc:0.951034	train-auc:0.964872
# [320]	eval-auc:0.951003	train-auc:0.964907
# [321]	eval-auc:0.951012	train-auc:0.964975
# [322]	eval-auc:0.951005	train-auc:0.965048
# [323]	eval-auc:0.950997	train-auc:0.96504
# [324]	eval-auc:0.950987	train-auc:0.965069
# [325]	eval-auc:0.950999	train-auc:0.965116
# [326]	eval-auc:0.951054	train-auc:0.965144
# [327]	eval-auc:0.951055	train-auc:0.965199
# [328]	eval-auc:0.951057	train-auc:0.965248
# [329]	eval-auc:0.95114	train-auc:0.965326
# [330]	eval-auc:0.95116	train-auc:0.965393
# [331]	eval-auc:0.951148	train-auc:0.965435
# [332]	eval-auc:0.951194	train-auc:0.965531
# [333]	eval-auc:0.951195	train-auc:0.965548
# [334]	eval-auc:0.95136	train-auc:0.965634
# [335]	eval-auc:0.951384	train-auc:0.965732
# [336]	eval-auc:0.951334	train-auc:0.965793
# [337]	eval-auc:0.951398	train-auc:0.965865
# [338]	eval-auc:0.951346	train-auc:0.965913
# [339]	eval-auc:0.951406	train-auc:0.965982
# [340]	eval-auc:0.951441	train-auc:0.966048
# [341]	eval-auc:0.951439	train-auc:0.966064
# [342]	eval-auc:0.951421	train-auc:0.966135
# [343]	eval-auc:0.951403	train-auc:0.966169
# [344]	eval-auc:0.951377	train-auc:0.966255
# [345]	eval-auc:0.951343	train-auc:0.966276
# [346]	eval-auc:0.951394	train-auc:0.966312
# [347]	eval-auc:0.951397	train-auc:0.966372
# [348]	eval-auc:0.951412	train-auc:0.966402
# [349]	eval-auc:0.951381	train-auc:0.966426
# [350]	eval-auc:0.951392	train-auc:0.966505
# [351]	eval-auc:0.951394	train-auc:0.966526
# [352]	eval-auc:0.951552	train-auc:0.966626
# [353]	eval-auc:0.951555	train-auc:0.966646
# [354]	eval-auc:0.951563	train-auc:0.966682
# [355]	eval-auc:0.951581	train-auc:0.966761
# [356]	eval-auc:0.951583	train-auc:0.966797
# [357]	eval-auc:0.951561	train-auc:0.966889
# [358]	eval-auc:0.951519	train-auc:0.96691
# [359]	eval-auc:0.951593	train-auc:0.966985
# [360]	eval-auc:0.951626	train-auc:0.967062
# [361]	eval-auc:0.951622	train-auc:0.967062
# [362]	eval-auc:0.951645	train-auc:0.967126
# [363]	eval-auc:0.951619	train-auc:0.967188
# [364]	eval-auc:0.951611	train-auc:0.967218
# [365]	eval-auc:0.951629	train-auc:0.967279
# [366]	eval-auc:0.951619	train-auc:0.967319
# [367]	eval-auc:0.951599	train-auc:0.967336
# [368]	eval-auc:0.951612	train-auc:0.967396
# [369]	eval-auc:0.951604	train-auc:0.967437
# [370]	eval-auc:0.951542	train-auc:0.967553
# [371]	eval-auc:0.951558	train-auc:0.967588
# [372]	eval-auc:0.951537	train-auc:0.967642
# [373]	eval-auc:0.951523	train-auc:0.9677
# [374]	eval-auc:0.951498	train-auc:0.967716
# [375]	eval-auc:0.951445	train-auc:0.967815
# [376]	eval-auc:0.951402	train-auc:0.967879
# [377]	eval-auc:0.951384	train-auc:0.967935
# [378]	eval-auc:0.951362	train-auc:0.967981
# [379]	eval-auc:0.95137	train-auc:0.96806
# [380]	eval-auc:0.951376	train-auc:0.968086
# [381]	eval-auc:0.951386	train-auc:0.968139
# [382]	eval-auc:0.951415	train-auc:0.968265
# [383]	eval-auc:0.951514	train-auc:0.968365
# [384]	eval-auc:0.951464	train-auc:0.968389
# [385]	eval-auc:0.951397	train-auc:0.968413
# [386]	eval-auc:0.95143	train-auc:0.968459
# [387]	eval-auc:0.951411	train-auc:0.968499
# [388]	eval-auc:0.95143	train-auc:0.968555
# [389]	eval-auc:0.951455	train-auc:0.968653
# [390]	eval-auc:0.951429	train-auc:0.96872
# [391]	eval-auc:0.951415	train-auc:0.968774
# [392]	eval-auc:0.951395	train-auc:0.968813
# [393]	eval-auc:0.951391	train-auc:0.96882
# [394]	eval-auc:0.951372	train-auc:0.96891
# [395]	eval-auc:0.951396	train-auc:0.968958
# [396]	eval-auc:0.951354	train-auc:0.968975
# [397]	eval-auc:0.951368	train-auc:0.969037
# [398]	eval-auc:0.951328	train-auc:0.969088
# [399]	eval-auc:0.951321	train-auc:0.969168
# [400]	eval-auc:0.951311	train-auc:0.969181
# [401]	eval-auc:0.951334	train-auc:0.969235
# [402]	eval-auc:0.951318	train-auc:0.969266
# [403]	eval-auc:0.951316	train-auc:0.969282
# [404]	eval-auc:0.951304	train-auc:0.969303
# [405]	eval-auc:0.951311	train-auc:0.969323
# [406]	eval-auc:0.951314	train-auc:0.969407
# [407]	eval-auc:0.951349	train-auc:0.969442
# [408]	eval-auc:0.951336	train-auc:0.96949
# [409]	eval-auc:0.951271	train-auc:0.969546
# [410]	eval-auc:0.951258	train-auc:0.969636
# [411]	eval-auc:0.951271	train-auc:0.969752
# [412]	eval-auc:0.95127	train-auc:0.96979
# [413]	eval-auc:0.951341	train-auc:0.969816
# [414]	eval-auc:0.951309	train-auc:0.969845
# [415]	eval-auc:0.951341	train-auc:0.969881
# [416]	eval-auc:0.951355	train-auc:0.969923
# [417]	eval-auc:0.951397	train-auc:0.969977
# [418]	eval-auc:0.951677	train-auc:0.970162
# [419]	eval-auc:0.951774	train-auc:0.970198
# [420]	eval-auc:0.951764	train-auc:0.97023
# [421]	eval-auc:0.951745	train-auc:0.970273
# [422]	eval-auc:0.951751	train-auc:0.970289
# [423]	eval-auc:0.95175	train-auc:0.970351
# [424]	eval-auc:0.951736	train-auc:0.970376
# [425]	eval-auc:0.951766	train-auc:0.970429
# [426]	eval-auc:0.951782	train-auc:0.970467
# [427]	eval-auc:0.951822	train-auc:0.970515
# [428]	eval-auc:0.951827	train-auc:0.970546
# [429]	eval-auc:0.951786	train-auc:0.970613
# [430]	eval-auc:0.951813	train-auc:0.970673
# [431]	eval-auc:0.95177	train-auc:0.970707
# [432]	eval-auc:0.95176	train-auc:0.97074
# [433]	eval-auc:0.951753	train-auc:0.970796
# [434]	eval-auc:0.951754	train-auc:0.97084
# [435]	eval-auc:0.951808	train-auc:0.970899
# [436]	eval-auc:0.951858	train-auc:0.970923
# [437]	eval-auc:0.951805	train-auc:0.970994
# [438]	eval-auc:0.951828	train-auc:0.971069
# [439]	eval-auc:0.951771	train-auc:0.971124
# [440]	eval-auc:0.951769	train-auc:0.971233
# [441]	eval-auc:0.951805	train-auc:0.971254
# [442]	eval-auc:0.951825	train-auc:0.971318
# [443]	eval-auc:0.951802	train-auc:0.971364
# [444]	eval-auc:0.951785	train-auc:0.971371
# [445]	eval-auc:0.951746	train-auc:0.971422
# [446]	eval-auc:0.95174	train-auc:0.971458
# [447]	eval-auc:0.95174	train-auc:0.97147
# [448]	eval-auc:0.951712	train-auc:0.971489
# [449]	eval-auc:0.951692	train-auc:0.971523
# [450]	eval-auc:0.951728	train-auc:0.971553
# [451]	eval-auc:0.951721	train-auc:0.971609
# [452]	eval-auc:0.95172	train-auc:0.971637
# [453]	eval-auc:0.951722	train-auc:0.971644
# [454]	eval-auc:0.951713	train-auc:0.971693
# [455]	eval-auc:0.951712	train-auc:0.971712
# [456]	eval-auc:0.951729	train-auc:0.971747
# [457]	eval-auc:0.951739	train-auc:0.971801
# [458]	eval-auc:0.951813	train-auc:0.971863
# [459]	eval-auc:0.951908	train-auc:0.971912
# [460]	eval-auc:0.951901	train-auc:0.971969
# [461]	eval-auc:0.951909	train-auc:0.972006
# [462]	eval-auc:0.95194	train-auc:0.972086
# [463]	eval-auc:0.951961	train-auc:0.97215
# [464]	eval-auc:0.95195	train-auc:0.972197
# [465]	eval-auc:0.951961	train-auc:0.972209
# [466]	eval-auc:0.951966	train-auc:0.972245
# [467]	eval-auc:0.95198	train-auc:0.972266
# [468]	eval-auc:0.951932	train-auc:0.972385
# [469]	eval-auc:0.951886	train-auc:0.972452
# [470]	eval-auc:0.951878	train-auc:0.9725
# [471]	eval-auc:0.951917	train-auc:0.97254
# [472]	eval-auc:0.951939	train-auc:0.972569
# [473]	eval-auc:0.951936	train-auc:0.972619
# [474]	eval-auc:0.951905	train-auc:0.972627
# [475]	eval-auc:0.951914	train-auc:0.972653
# [476]	eval-auc:0.951906	train-auc:0.972698
# [477]	eval-auc:0.951915	train-auc:0.972728
# [478]	eval-auc:0.951919	train-auc:0.972772
# [479]	eval-auc:0.951918	train-auc:0.972805
# [480]	eval-auc:0.951888	train-auc:0.972841
# [481]	eval-auc:0.951893	train-auc:0.972868
# [482]	eval-auc:0.951901	train-auc:0.972936
# [483]	eval-auc:0.951962	train-auc:0.97301
# [484]	eval-auc:0.951947	train-auc:0.973019
# [485]	eval-auc:0.951929	train-auc:0.973077
# [486]	eval-auc:0.951909	train-auc:0.973084
# [487]	eval-auc:0.951965	train-auc:0.973128
# [488]	eval-auc:0.951952	train-auc:0.97314
# [489]	eval-auc:0.951965	train-auc:0.973166
# [490]	eval-auc:0.951991	train-auc:0.97321
# [491]	eval-auc:0.95199	train-auc:0.973235
# [492]	eval-auc:0.951978	train-auc:0.973288
# [493]	eval-auc:0.952003	train-auc:0.973303
# [494]	eval-auc:0.952002	train-auc:0.973336
# [495]	eval-auc:0.95199	train-auc:0.973414
# [496]	eval-auc:0.951985	train-auc:0.973478
# [497]	eval-auc:0.952009	train-auc:0.973554
# [498]	eval-auc:0.951962	train-auc:0.97358
# [499]	eval-auc:0.951986	train-auc:0.973592
# [500]	eval-auc:0.95201	train-auc:0.973635
# [501]	eval-auc:0.95204	train-auc:0.973698
# [502]	eval-auc:0.952039	train-auc:0.973726
# [503]	eval-auc:0.952039	train-auc:0.973763
# [504]	eval-auc:0.952037	train-auc:0.973766
# [505]	eval-auc:0.952022	train-auc:0.973824
# [506]	eval-auc:0.95208	train-auc:0.973877
# [507]	eval-auc:0.952091	train-auc:0.973937
# [508]	eval-auc:0.95211	train-auc:0.974011
# [509]	eval-auc:0.952097	train-auc:0.974051
# [510]	eval-auc:0.952142	train-auc:0.9741
# [511]	eval-auc:0.952186	train-auc:0.974138
# [512]	eval-auc:0.952234	train-auc:0.974168
# [513]	eval-auc:0.952234	train-auc:0.974228
# [514]	eval-auc:0.95223	train-auc:0.97424
# [515]	eval-auc:0.952201	train-auc:0.974306
# [516]	eval-auc:0.952222	train-auc:0.974323
# [517]	eval-auc:0.952217	train-auc:0.974392
# [518]	eval-auc:0.952189	train-auc:0.974429
# [519]	eval-auc:0.9522	train-auc:0.974476
# [520]	eval-auc:0.952226	train-auc:0.974515
# [521]	eval-auc:0.952234	train-auc:0.974542
# [522]	eval-auc:0.952264	train-auc:0.974557
# [523]	eval-auc:0.952278	train-auc:0.974565
# [524]	eval-auc:0.95233	train-auc:0.974631
# [525]	eval-auc:0.952357	train-auc:0.974665
# [526]	eval-auc:0.952358	train-auc:0.974737
# [527]	eval-auc:0.952397	train-auc:0.974803
# [528]	eval-auc:0.952386	train-auc:0.974833
# [529]	eval-auc:0.952383	train-auc:0.97484
# [530]	eval-auc:0.952382	train-auc:0.974847
# [531]	eval-auc:0.952385	train-auc:0.97486
# [532]	eval-auc:0.952357	train-auc:0.974909
# [533]	eval-auc:0.952363	train-auc:0.974953
# [534]	eval-auc:0.95237	train-auc:0.97496
# [535]	eval-auc:0.952337	train-auc:0.974992
# [536]	eval-auc:0.952393	train-auc:0.975038
# [537]	eval-auc:0.952386	train-auc:0.975066
# [538]	eval-auc:0.952393	train-auc:0.975124
# [539]	eval-auc:0.952335	train-auc:0.975182
# [540]	eval-auc:0.952365	train-auc:0.9752
# [541]	eval-auc:0.952341	train-auc:0.975245
# [542]	eval-auc:0.952366	train-auc:0.975298
# [543]	eval-auc:0.952369	train-auc:0.975315
# [544]	eval-auc:0.952359	train-auc:0.975349
# [545]	eval-auc:0.952363	train-auc:0.975387
# [546]	eval-auc:0.952376	train-auc:0.975398
# [547]	eval-auc:0.952314	train-auc:0.975434
# [548]	eval-auc:0.952312	train-auc:0.975449
# [549]	eval-auc:0.95229	train-auc:0.975467
# [550]	eval-auc:0.95229	train-auc:0.975482
# [551]	eval-auc:0.952311	train-auc:0.975505
# [552]	eval-auc:0.952266	train-auc:0.975548
# [553]	eval-auc:0.952254	train-auc:0.975566
# [554]	eval-auc:0.952252	train-auc:0.975577
# [555]	eval-auc:0.952254	train-auc:0.975637
# [556]	eval-auc:0.952271	train-auc:0.975682
# [557]	eval-auc:0.952216	train-auc:0.975701
# [558]	eval-auc:0.952233	train-auc:0.975727
# [559]	eval-auc:0.952205	train-auc:0.975741
# [560]	eval-auc:0.952181	train-auc:0.975752
# [561]	eval-auc:0.952216	train-auc:0.975817
# [562]	eval-auc:0.952211	train-auc:0.975858
# [563]	eval-auc:0.952199	train-auc:0.975863
# [564]	eval-auc:0.952251	train-auc:0.975888
# [565]	eval-auc:0.952252	train-auc:0.975936
# [566]	eval-auc:0.952239	train-auc:0.975956
# [567]	eval-auc:0.95226	train-auc:0.975997
# [568]	eval-auc:0.952246	train-auc:0.976023
# [569]	eval-auc:0.952283	train-auc:0.976058
# [570]	eval-auc:0.952306	train-auc:0.976071
# [571]	eval-auc:0.952302	train-auc:0.976082
# [572]	eval-auc:0.952278	train-auc:0.976124
# [573]	eval-auc:0.95229	train-auc:0.976133
# [574]	eval-auc:0.952284	train-auc:0.976158
# [575]	eval-auc:0.952266	train-auc:0.976164
# [576]	eval-auc:0.952312	train-auc:0.976189
# [577]	eval-auc:0.952339	train-auc:0.976236
# [578]	eval-auc:0.95237	train-auc:0.97632
# [579]	eval-auc:0.952347	train-auc:0.976359
# [580]	eval-auc:0.952322	train-auc:0.976402
# [581]	eval-auc:0.952361	train-auc:0.976431
# [582]	eval-auc:0.952379	train-auc:0.976465
# [583]	eval-auc:0.952324	train-auc:0.976504
# [584]	eval-auc:0.952323	train-auc:0.976557
# [585]	eval-auc:0.952337	train-auc:0.976576
# [586]	eval-auc:0.952337	train-auc:0.976588
# [587]	eval-auc:0.95234	train-auc:0.976623
# [588]	eval-auc:0.952336	train-auc:0.976656
# [589]	eval-auc:0.952338	train-auc:0.976718
# [590]	eval-auc:0.95238	train-auc:0.976736
# [591]	eval-auc:0.952363	train-auc:0.976756
# [592]	eval-auc:0.952363	train-auc:0.976782
# [593]	eval-auc:0.952337	train-auc:0.976795
# [594]	eval-auc:0.952348	train-auc:0.976806
# [595]	eval-auc:0.952415	train-auc:0.976875
# [596]	eval-auc:0.952411	train-auc:0.976907
# [597]	eval-auc:0.952452	train-auc:0.97695
# [598]	eval-auc:0.952464	train-auc:0.976981
# [599]	eval-auc:0.952429	train-auc:0.976997
# [600]	eval-auc:0.952392	train-auc:0.977036
# [601]	eval-auc:0.952391	train-auc:0.977048
# [602]	eval-auc:0.952407	train-auc:0.977106
# [603]	eval-auc:0.952385	train-auc:0.977113
# [604]	eval-auc:0.952387	train-auc:0.977126
# [605]	eval-auc:0.952384	train-auc:0.977176
# [606]	eval-auc:0.95235	train-auc:0.977187
# [607]	eval-auc:0.952372	train-auc:0.977229
# [608]	eval-auc:0.952383	train-auc:0.977235
# [609]	eval-auc:0.9524	train-auc:0.977274
# [610]	eval-auc:0.952388	train-auc:0.977293
# [611]	eval-auc:0.952404	train-auc:0.977302
# [612]	eval-auc:0.952393	train-auc:0.977371
# [613]	eval-auc:0.952383	train-auc:0.977397
# [614]	eval-auc:0.952371	train-auc:0.977426
# [615]	eval-auc:0.952354	train-auc:0.977441
# [616]	eval-auc:0.952347	train-auc:0.977447
# [617]	eval-auc:0.952343	train-auc:0.977453
# [618]	eval-auc:0.95235	train-auc:0.977463
# [619]	eval-auc:0.95234	train-auc:0.977498
# [620]	eval-auc:0.952315	train-auc:0.97751
# [621]	eval-auc:0.952357	train-auc:0.977545
# [622]	eval-auc:0.952415	train-auc:0.9776
# [623]	eval-auc:0.952382	train-auc:0.977647
# [624]	eval-auc:0.952364	train-auc:0.977672
# [625]	eval-auc:0.952377	train-auc:0.977699
# [626]	eval-auc:0.952361	train-auc:0.977702
# [627]	eval-auc:0.952361	train-auc:0.97773
# [628]	eval-auc:0.95235	train-auc:0.977759
# [629]	eval-auc:0.952322	train-auc:0.97783
# [630]	eval-auc:0.95228	train-auc:0.977854
# [631]	eval-auc:0.952299	train-auc:0.977895
# [632]	eval-auc:0.952271	train-auc:0.97794
# [633]	eval-auc:0.952256	train-auc:0.977996
# [634]	eval-auc:0.952286	train-auc:0.978049
# [635]	eval-auc:0.952298	train-auc:0.978066
# [636]	eval-auc:0.952307	train-auc:0.978082
# [637]	eval-auc:0.952333	train-auc:0.978126
# [638]	eval-auc:0.95234	train-auc:0.978142
# [639]	eval-auc:0.952321	train-auc:0.97815
# [640]	eval-auc:0.952335	train-auc:0.97818
# [641]	eval-auc:0.952419	train-auc:0.978221
# [642]	eval-auc:0.952412	train-auc:0.978226
# [643]	eval-auc:0.952418	train-auc:0.97824
# [644]	eval-auc:0.95241	train-auc:0.978299
# [645]	eval-auc:0.9524	train-auc:0.978332
# [646]	eval-auc:0.952414	train-auc:0.978393
# [647]	eval-auc:0.952431	train-auc:0.978427
# [648]	eval-auc:0.952446	train-auc:0.978468
# [649]	eval-auc:0.952426	train-auc:0.978519
# [650]	eval-auc:0.952428	train-auc:0.97855
# [651]	eval-auc:0.952394	train-auc:0.978565
# [652]	eval-auc:0.952375	train-auc:0.978589
# [653]	eval-auc:0.95235	train-auc:0.978652
# [654]	eval-auc:0.952351	train-auc:0.978684
# [655]	eval-auc:0.952305	train-auc:0.978726
# [656]	eval-auc:0.952302	train-auc:0.978727
# [657]	eval-auc:0.952325	train-auc:0.97878
# [658]	eval-auc:0.952316	train-auc:0.978801
# [659]	eval-auc:0.952319	train-auc:0.978815
# [660]	eval-auc:0.952288	train-auc:0.978862
# [661]	eval-auc:0.952286	train-auc:0.978886
# [662]	eval-auc:0.952345	train-auc:0.978938
# [663]	eval-auc:0.952336	train-auc:0.978974
# [664]	eval-auc:0.952374	train-auc:0.978996
# [665]	eval-auc:0.952362	train-auc:0.978995
# [666]	eval-auc:0.952375	train-auc:0.979007
# [667]	eval-auc:0.952358	train-auc:0.97902
# [668]	eval-auc:0.952352	train-auc:0.979031
# [669]	eval-auc:0.952329	train-auc:0.979049
# [670]	eval-auc:0.952319	train-auc:0.979073
# [671]	eval-auc:0.952302	train-auc:0.979085
# [672]	eval-auc:0.952347	train-auc:0.979116
# [673]	eval-auc:0.952357	train-auc:0.979128
# [674]	eval-auc:0.952356	train-auc:0.979156
# [675]	eval-auc:0.952373	train-auc:0.979158
# [676]	eval-auc:0.952375	train-auc:0.97917
# [677]	eval-auc:0.952377	train-auc:0.979219
# [678]	eval-auc:0.952375	train-auc:0.979236
# [679]	eval-auc:0.952377	train-auc:0.979258
# [680]	eval-auc:0.952398	train-auc:0.97927
# [681]	eval-auc:0.952369	train-auc:0.979301
# [682]	eval-auc:0.952337	train-auc:0.979342
# [683]	eval-auc:0.952344	train-auc:0.979367
# [684]	eval-auc:0.95234	train-auc:0.979374
# [685]	eval-auc:0.952331	train-auc:0.979392
# [686]	eval-auc:0.952333	train-auc:0.979444
# [687]	eval-auc:0.952325	train-auc:0.979473
# [688]	eval-auc:0.952345	train-auc:0.979493
# [689]	eval-auc:0.952316	train-auc:0.979531
# [690]	eval-auc:0.952283	train-auc:0.979561
# [691]	eval-auc:0.952304	train-auc:0.979568
# [692]	eval-auc:0.952336	train-auc:0.979587
# [693]	eval-auc:0.952329	train-auc:0.979631
# [694]	eval-auc:0.952361	train-auc:0.979694
# [695]	eval-auc:0.952271	train-auc:0.979752
# [696]	eval-auc:0.952254	train-auc:0.979786
# [697]	eval-auc:0.952272	train-auc:0.979796
# [698]	eval-auc:0.952278	train-auc:0.979843
# [699]	eval-auc:0.952289	train-auc:0.979843
# [700]	eval-auc:0.952326	train-auc:0.979852
# [701]	eval-auc:0.952355	train-auc:0.979899
# [702]	eval-auc:0.952354	train-auc:0.979915
# [703]	eval-auc:0.952354	train-auc:0.979937
# [704]	eval-auc:0.952366	train-auc:0.97997
# [705]	eval-auc:0.952349	train-auc:0.980015
# [706]	eval-auc:0.952333	train-auc:0.980032
# [707]	eval-auc:0.95234	train-auc:0.980074
# [708]	eval-auc:0.952314	train-auc:0.980085
# [709]	eval-auc:0.952308	train-auc:0.980095
# [710]	eval-auc:0.952308	train-auc:0.980095
# [711]	eval-auc:0.952325	train-auc:0.980113
# [712]	eval-auc:0.952322	train-auc:0.980127
# [713]	eval-auc:0.952301	train-auc:0.980135
# [714]	eval-auc:0.952271	train-auc:0.980192
# [715]	eval-auc:0.952293	train-auc:0.9802
# [716]	eval-auc:0.952309	train-auc:0.980224
# [717]	eval-auc:0.952426	train-auc:0.980275
# [718]	eval-auc:0.952407	train-auc:0.980335
# [719]	eval-auc:0.952392	train-auc:0.980357
# [720]	eval-auc:0.952406	train-auc:0.980376
# [721]	eval-auc:0.952413	train-auc:0.980401
# [722]	eval-auc:0.952439	train-auc:0.98043
# [723]	eval-auc:0.952451	train-auc:0.980451
# [724]	eval-auc:0.952453	train-auc:0.980469
# [725]	eval-auc:0.952454	train-auc:0.980476
# [726]	eval-auc:0.952464	train-auc:0.980484
# [727]	eval-auc:0.952448	train-auc:0.980512
# [728]	eval-auc:0.952574	train-auc:0.980538
# [729]	eval-auc:0.952534	train-auc:0.980595
# [730]	eval-auc:0.952556	train-auc:0.980655
# [731]	eval-auc:0.952525	train-auc:0.980687
# [732]	eval-auc:0.952593	train-auc:0.980718
# [733]	eval-auc:0.952579	train-auc:0.980736
# [734]	eval-auc:0.952585	train-auc:0.980777
# [735]	eval-auc:0.952593	train-auc:0.980798
# [736]	eval-auc:0.952591	train-auc:0.980806
# [737]	eval-auc:0.952605	train-auc:0.980829
# [738]	eval-auc:0.9526	train-auc:0.980842
# [739]	eval-auc:0.952626	train-auc:0.980875
# [740]	eval-auc:0.95263	train-auc:0.980903
# [741]	eval-auc:0.952643	train-auc:0.980923
# [742]	eval-auc:0.952656	train-auc:0.980939
# [743]	eval-auc:0.952659	train-auc:0.980965
# [744]	eval-auc:0.952642	train-auc:0.980969
# [745]	eval-auc:0.952635	train-auc:0.981023
# [746]	eval-auc:0.952653	train-auc:0.981027
# [747]	eval-auc:0.952622	train-auc:0.981041
# [748]	eval-auc:0.952624	train-auc:0.981043
# [749]	eval-auc:0.952607	train-auc:0.981057
# [750]	eval-auc:0.952567	train-auc:0.98112
# [751]	eval-auc:0.952568	train-auc:0.981145
# [752]	eval-auc:0.952553	train-auc:0.981147
# [753]	eval-auc:0.952554	train-auc:0.98116
# [754]	eval-auc:0.952516	train-auc:0.981169
# [755]	eval-auc:0.952529	train-auc:0.981168
# [756]	eval-auc:0.952532	train-auc:0.981171
# [757]	eval-auc:0.952554	train-auc:0.981183
# [758]	eval-auc:0.952541	train-auc:0.981209
# [759]	eval-auc:0.952501	train-auc:0.98123
# [760]	eval-auc:0.952467	train-auc:0.981246
# [761]	eval-auc:0.952486	train-auc:0.981296
# [762]	eval-auc:0.95249	train-auc:0.981307
# [763]	eval-auc:0.952492	train-auc:0.981342
# [764]	eval-auc:0.952494	train-auc:0.981364
# [765]	eval-auc:0.952495	train-auc:0.981399
# [766]	eval-auc:0.952496	train-auc:0.981429
# [767]	eval-auc:0.952473	train-auc:0.981447
# [768]	eval-auc:0.952479	train-auc:0.981451
# [769]	eval-auc:0.952485	train-auc:0.98147
# [770]	eval-auc:0.952469	train-auc:0.981482
# [771]	eval-auc:0.952511	train-auc:0.981515
# [772]	eval-auc:0.952505	train-auc:0.981518
# [773]	eval-auc:0.952483	train-auc:0.981539
# [774]	eval-auc:0.952465	train-auc:0.981561
# [775]	eval-auc:0.952459	train-auc:0.981584
# [776]	eval-auc:0.952494	train-auc:0.981601
# [777]	eval-auc:0.952473	train-auc:0.98163
# [778]	eval-auc:0.952514	train-auc:0.981674
# [779]	eval-auc:0.952526	train-auc:0.9817
# [780]	eval-auc:0.95252	train-auc:0.981736
# [781]	eval-auc:0.95255	train-auc:0.981739
# [782]	eval-auc:0.952528	train-auc:0.981748
# [783]	eval-auc:0.952535	train-auc:0.981766
# [784]	eval-auc:0.952527	train-auc:0.981796
# [785]	eval-auc:0.952529	train-auc:0.981818
# [786]	eval-auc:0.952531	train-auc:0.981822
# [787]	eval-auc:0.952543	train-auc:0.981865
# [788]	eval-auc:0.952582	train-auc:0.98191
# [789]	eval-auc:0.952612	train-auc:0.981935
# [790]	eval-auc:0.952601	train-auc:0.981981
# [791]	eval-auc:0.952616	train-auc:0.982
# [792]	eval-auc:0.9526	train-auc:0.982007
# [793]	eval-auc:0.9526	train-auc:0.982015
# [794]	eval-auc:0.952591	train-auc:0.982027
# [795]	eval-auc:0.952615	train-auc:0.98204
# [796]	eval-auc:0.952629	train-auc:0.982066
# [797]	eval-auc:0.952624	train-auc:0.982058
# [798]	eval-auc:0.952633	train-auc:0.98208
# [799]	eval-auc:0.952625	train-auc:0.982082
# [800]	eval-auc:0.952618	train-auc:0.982092
# [801]	eval-auc:0.952631	train-auc:0.982108
# [802]	eval-auc:0.952609	train-auc:0.98215
# [803]	eval-auc:0.952597	train-auc:0.982164
# [804]	eval-auc:0.952577	train-auc:0.98218
# [805]	eval-auc:0.952573	train-auc:0.982178
# [806]	eval-auc:0.95261	train-auc:0.982196
# [807]	eval-auc:0.952645	train-auc:0.982209
# [808]	eval-auc:0.952636	train-auc:0.982238
# [809]	eval-auc:0.952619	train-auc:0.982282
# [810]	eval-auc:0.952617	train-auc:0.9823
# [811]	eval-auc:0.9526	train-auc:0.982322
# [812]	eval-auc:0.952597	train-auc:0.982326
# [813]	eval-auc:0.952626	train-auc:0.982373
# [814]	eval-auc:0.952607	train-auc:0.982404
# [815]	eval-auc:0.952608	train-auc:0.982432
# [816]	eval-auc:0.952614	train-auc:0.982444
# [817]	eval-auc:0.952617	train-auc:0.98246
# [818]	eval-auc:0.952595	train-auc:0.982488
# [819]	eval-auc:0.952563	train-auc:0.982494
# [820]	eval-auc:0.952563	train-auc:0.982494
# [821]	eval-auc:0.95258	train-auc:0.982517
# [822]	eval-auc:0.952613	train-auc:0.982551
# [823]	eval-auc:0.952664	train-auc:0.982599
# [824]	eval-auc:0.95267	train-auc:0.982601
# [825]	eval-auc:0.952631	train-auc:0.982628
# [826]	eval-auc:0.952652	train-auc:0.982646
# [827]	eval-auc:0.952643	train-auc:0.982655
# [828]	eval-auc:0.952627	train-auc:0.982684
# [829]	eval-auc:0.952615	train-auc:0.982726
# [830]	eval-auc:0.952584	train-auc:0.982765
# [831]	eval-auc:0.952595	train-auc:0.982791
# [832]	eval-auc:0.95257	train-auc:0.982798
# [833]	eval-auc:0.952556	train-auc:0.982827
# [834]	eval-auc:0.952577	train-auc:0.982845
# [835]	eval-auc:0.952563	train-auc:0.982865
# [836]	eval-auc:0.952582	train-auc:0.982871
# [837]	eval-auc:0.952585	train-auc:0.982914
# [838]	eval-auc:0.952559	train-auc:0.982925
# [839]	eval-auc:0.952542	train-auc:0.982943
# [840]	eval-auc:0.952543	train-auc:0.982959
# [841]	eval-auc:0.95261	train-auc:0.982976
# [842]	eval-auc:0.952599	train-auc:0.982985
# [843]	eval-auc:0.952604	train-auc:0.983007
# [844]	eval-auc:0.952626	train-auc:0.983016
# [845]	eval-auc:0.952595	train-auc:0.983042
# [846]	eval-auc:0.952597	train-auc:0.983057
# [847]	eval-auc:0.95259	train-auc:0.983082
# [848]	eval-auc:0.952584	train-auc:0.983097
# [849]	eval-auc:0.952558	train-auc:0.983115
# [850]	eval-auc:0.952549	train-auc:0.983129
# [851]	eval-auc:0.952575	train-auc:0.98316
# [852]	eval-auc:0.952578	train-auc:0.98318
# [853]	eval-auc:0.952579	train-auc:0.983224
# [854]	eval-auc:0.952577	train-auc:0.983234
# [855]	eval-auc:0.952525	train-auc:0.983253
# [856]	eval-auc:0.952503	train-auc:0.983285
# [857]	eval-auc:0.952527	train-auc:0.983302
# [858]	eval-auc:0.952531	train-auc:0.983311
# [859]	eval-auc:0.952517	train-auc:0.983331
# [860]	eval-auc:0.952525	train-auc:0.983338
# [861]	eval-auc:0.952489	train-auc:0.983345
# [862]	eval-auc:0.952487	train-auc:0.98336
# [863]	eval-auc:0.952509	train-auc:0.983388
# [864]	eval-auc:0.952502	train-auc:0.98341
# [865]	eval-auc:0.952488	train-auc:0.983425
# [866]	eval-auc:0.952484	train-auc:0.983442
# [867]	eval-auc:0.952483	train-auc:0.983444
# [868]	eval-auc:0.952489	train-auc:0.983471
# [869]	eval-auc:0.952467	train-auc:0.98352
# [870]	eval-auc:0.952456	train-auc:0.983559
# [871]	eval-auc:0.952503	train-auc:0.983568
# [872]	eval-auc:0.952468	train-auc:0.983617
# [873]	eval-auc:0.95251	train-auc:0.983654
# [874]	eval-auc:0.952507	train-auc:0.983667
# [875]	eval-auc:0.952494	train-auc:0.983687
# [876]	eval-auc:0.952464	train-auc:0.983729
# [877]	eval-auc:0.952475	train-auc:0.983749
# [878]	eval-auc:0.952473	train-auc:0.983772
# [879]	eval-auc:0.952467	train-auc:0.98382
# [880]	eval-auc:0.95264	train-auc:0.983838
# [881]	eval-auc:0.952623	train-auc:0.983865
# [882]	eval-auc:0.952607	train-auc:0.983881
# [883]	eval-auc:0.952595	train-auc:0.983916
# [884]	eval-auc:0.952614	train-auc:0.983928
# [885]	eval-auc:0.952622	train-auc:0.983944
# [886]	eval-auc:0.952603	train-auc:0.983964
# [887]	eval-auc:0.95259	train-auc:0.983969
# [888]	eval-auc:0.952585	train-auc:0.983983
# [889]	eval-auc:0.95259	train-auc:0.984
# [890]	eval-auc:0.952608	train-auc:0.984044
# [891]	eval-auc:0.952582	train-auc:0.984068
# [892]	eval-auc:0.952576	train-auc:0.98408
# [893]	eval-auc:0.952613	train-auc:0.984099
# [894]	eval-auc:0.952612	train-auc:0.984116
# [895]	eval-auc:0.952631	train-auc:0.98413
# [896]	eval-auc:0.952661	train-auc:0.984154
# [897]	eval-auc:0.952688	train-auc:0.984166
# [898]	eval-auc:0.952694	train-auc:0.984201
# [899]	eval-auc:0.952687	train-auc:0.984234
# [900]	eval-auc:0.952661	train-auc:0.98425
# [901]	eval-auc:0.952684	train-auc:0.98428
# [902]	eval-auc:0.952677	train-auc:0.984287
# [903]	eval-auc:0.952652	train-auc:0.984314
# [904]	eval-auc:0.952683	train-auc:0.984358
# [905]	eval-auc:0.952672	train-auc:0.984371
# [906]	eval-auc:0.952711	train-auc:0.984404
# [907]	eval-auc:0.952725	train-auc:0.984442
# [908]	eval-auc:0.952716	train-auc:0.984472
# [909]	eval-auc:0.952714	train-auc:0.98448
# [910]	eval-auc:0.952702	train-auc:0.984501
# [911]	eval-auc:0.95271	train-auc:0.984504
# [912]	eval-auc:0.952706	train-auc:0.984517
# [913]	eval-auc:0.952706	train-auc:0.984524
# [914]	eval-auc:0.952706	train-auc:0.984524
# [915]	eval-auc:0.952697	train-auc:0.984565
# [916]	eval-auc:0.952669	train-auc:0.984618
# [917]	eval-auc:0.952645	train-auc:0.984634
# [918]	eval-auc:0.952638	train-auc:0.984666
# [919]	eval-auc:0.952601	train-auc:0.984696
# [920]	eval-auc:0.952587	train-auc:0.984709
# [921]	eval-auc:0.952613	train-auc:0.984723
# [922]	eval-auc:0.952628	train-auc:0.984744
# [923]	eval-auc:0.952621	train-auc:0.984752
# [924]	eval-auc:0.952601	train-auc:0.98476
# [925]	eval-auc:0.95259	train-auc:0.984767
# [926]	eval-auc:0.952588	train-auc:0.984769
# [927]	eval-auc:0.952601	train-auc:0.984783
# [928]	eval-auc:0.952579	train-auc:0.98481
# [929]	eval-auc:0.952572	train-auc:0.984816
# [930]	eval-auc:0.952567	train-auc:0.984821
# [931]	eval-auc:0.95259	train-auc:0.984853
# [932]	eval-auc:0.952598	train-auc:0.984866
# [933]	eval-auc:0.952585	train-auc:0.984867
# [934]	eval-auc:0.952582	train-auc:0.984869
# [935]	eval-auc:0.952569	train-auc:0.984874
# [936]	eval-auc:0.952563	train-auc:0.984882
# [937]	eval-auc:0.952657	train-auc:0.984893
# [938]	eval-auc:0.952672	train-auc:0.984914
# [939]	eval-auc:0.952621	train-auc:0.984943
# [940]	eval-auc:0.95261	train-auc:0.984983
# [941]	eval-auc:0.952625	train-auc:0.985003
# [942]	eval-auc:0.952639	train-auc:0.985029
# [943]	eval-auc:0.952636	train-auc:0.985041
# [944]	eval-auc:0.952645	train-auc:0.985053
# [945]	eval-auc:0.952598	train-auc:0.985073
# [946]	eval-auc:0.952563	train-auc:0.985094
# [947]	eval-auc:0.95257	train-auc:0.985132
# [948]	eval-auc:0.952565	train-auc:0.985147
# [949]	eval-auc:0.952565	train-auc:0.985151
# [950]	eval-auc:0.952558	train-auc:0.985169
# [951]	eval-auc:0.952555	train-auc:0.985176
# [952]	eval-auc:0.95255	train-auc:0.985196
# [953]	eval-auc:0.952559	train-auc:0.9852
# [954]	eval-auc:0.952555	train-auc:0.985219
# [955]	eval-auc:0.952546	train-auc:0.985222
# [956]	eval-auc:0.952549	train-auc:0.985265
# [957]	eval-auc:0.95255	train-auc:0.985294
# [958]	eval-auc:0.952533	train-auc:0.985326
# [959]	eval-auc:0.952512	train-auc:0.985328
# [960]	eval-auc:0.952515	train-auc:0.985347
# [961]	eval-auc:0.952511	train-auc:0.985348
# [962]	eval-auc:0.952517	train-auc:0.985379
# [963]	eval-auc:0.952514	train-auc:0.98539
# [964]	eval-auc:0.952482	train-auc:0.985408
# [965]	eval-auc:0.952437	train-auc:0.985428
# [966]	eval-auc:0.952433	train-auc:0.985433
# [967]	eval-auc:0.952415	train-auc:0.98544
# [968]	eval-auc:0.952372	train-auc:0.985463
# [969]	eval-auc:0.952367	train-auc:0.98549
# [970]	eval-auc:0.952359	train-auc:0.985493
# [971]	eval-auc:0.952356	train-auc:0.985496
# [972]	eval-auc:0.952336	train-auc:0.985497
# [973]	eval-auc:0.952316	train-auc:0.985519
# [974]	eval-auc:0.952305	train-auc:0.985526
# [975]	eval-auc:0.952267	train-auc:0.98554
# [976]	eval-auc:0.952275	train-auc:0.985547
# [977]	eval-auc:0.952259	train-auc:0.985555
# [978]	eval-auc:0.952253	train-auc:0.985564
# [979]	eval-auc:0.95221	train-auc:0.985585
# [980]	eval-auc:0.952195	train-auc:0.985623
# [981]	eval-auc:0.95217	train-auc:0.985629
# [982]	eval-auc:0.952161	train-auc:0.985643
# [983]	eval-auc:0.952173	train-auc:0.985662
# [984]	eval-auc:0.952162	train-auc:0.98567
# [985]	eval-auc:0.952164	train-auc:0.985676
# [986]	eval-auc:0.952162	train-auc:0.985688
# [987]	eval-auc:0.952155	train-auc:0.985702
# [988]	eval-auc:0.95215	train-auc:0.98573
# [989]	eval-auc:0.952149	train-auc:0.985756
# [990]	eval-auc:0.952233	train-auc:0.985766
# [991]	eval-auc:0.952254	train-auc:0.985787
# [992]	eval-auc:0.952235	train-auc:0.985797
# [993]	eval-auc:0.952264	train-auc:0.98583
# [994]	eval-auc:0.952257	train-auc:0.985847
# [995]	eval-auc:0.952259	train-auc:0.985864
# [996]	eval-auc:0.952247	train-auc:0.985889
# [997]	eval-auc:0.952238	train-auc:0.985932
# [998]	eval-auc:0.952233	train-auc:0.98594
# [999]	eval-auc:0.952245	train-auc:0.985947

# %%
from xgboost import plot_importance 
from matplotlib import pyplot as plt

# %%
plot_importance(bst)
plt.show()

# %%
pd.Series(bst.get_fscore()).sort_values(ascending=False)
# Out:
# two_three_second         930
# userid                   904
# last_6dis                890
# last_5dis                860
# last_two_second          696
# actionType_5             548
# actionType_6             535
# actionType_1             439
# city                     298
# last_8dis                283
# count                    280
# last_7dis                278
# three_type               244
# province                 219
# actionType_2             199
# last_type                196
# actionType_7             193
# two_type                 186
# actionType_8             173
# actionType_4             172
# actionType_3             158
# last_9dis                141
# actionType_9             120
# gender                    99
# continent                 97
# two_three_day             96
# rating                    93
# age                       90
# last_two_day              90
# flag_seven                83
# flag_six                  79
# orderHistory_feat_sum     79
# flag_five                 77
# dtype: int64
