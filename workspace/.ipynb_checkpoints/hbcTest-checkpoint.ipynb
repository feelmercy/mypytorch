# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split

from sklearn.cross_validation import *
from sklearn.grid_search import GridSearchCV

train = pd.read_csv("F:\\study\\ml\\DataSet\\Hbc_csv\\hbcTrain.csv")
test = pd.read_csv("F:\\study\\ml\\DataSet\\Hbc_csv\\hbcTest.csv")
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#train.head()
features=list(train.columns)
features.remove('actionType')
print(features)

train = train.fillna(-999)
test = test.fillna(-999)
# Out:
# ['userid', 'actionTime', 'Horderid', 'orderTime', 'orderType', 'cityNo', 'countryNo', 'continentNo', 'Corderid', 'rating', 'genderNo', 'province', 'provinceNo', 'age', 'ageNo', 'PorderType']

# %%
xgb_model=xgb.XGBClassifier()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['binary:logistic'],
              'learning_rate': [0.1], #so called `eta` value
              'max_depth': [6],
              'min_child_weight': [11],
              'silent': [0],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [5], #number of trees, change it to 1000 for better results
              'missing':[-999]}

clf = GridSearchCV(xgb_model, parameters, n_jobs=5, 
                   cv=StratifiedKFold(train['actionType'], n_folds=5, shuffle=True), 
                   scoring='roc_auc',
                   verbose=2, refit=True)

clf.fit(train[features], train["actionType"])

best_parameters, score, _ = max(clf.grid_scores_, key=lambda x: x[1])
print('Raw AUC score:', score)
for param_name in sorted(best_parameters.keys()):
    print("%s: %r" % (param_name, best_parameters[param_name]))
    
test_probs = clf.predict_proba(test[features])[:,1]
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   15.7s remaining:   23.6s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   22.0s remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   22.0s finished
# Raw AUC score: 0.8396162284659408
# colsample_bytree: 0.7
# learning_rate: 0.1
# max_depth: 6
# min_child_weight: 11
# missing: -999
# n_estimators: 5
# nthread: 4
# objective: 'binary:logistic'
# seed: 1337
# silent: 0
# subsample: 0.7

# %%
train.head()
# Out:
#          userid  actionType    actionTime  Horderid   orderTime     orderType  \
# 0  100000000013           0  100000000013         1  1474300753  1.000000e+11
# 1  100000000013           0  100000000013         1  1474300753  1.000000e+11
# 2  100000000013           0  100000000013         5  1474300763  1.000000e+11
# 3  100000000013           0  100000000013         5  1474300763  1.000000e+11
# 4  100000000013           0  100000000013         6  1474300874  1.000000e+11
#
#       cityNo     countryNo  continentNo  Corderid  rating      genderNo  \
# 0  1000015.0  1.481715e+09        108.0      27.0     4.0  1.000000e+11
# 1  1000014.0  1.501960e+09         26.0       2.0     1.0  1.000000e+11
# 2  1000015.0  1.481715e+09        108.0      27.0     4.0  1.000000e+11
# 3  1000014.0  1.501960e+09         26.0       2.0     1.0  1.000000e+11
# 4  1000015.0  1.481715e+09        108.0      27.0     4.0  1.000000e+11
#
#     province    provinceNo  age  ageNo  PorderType
# 0  1000015.0  100000000013  1.0    5.0      -999.0
# 1  1000015.0  100000000013  1.0    5.0      -999.0
# 2  1000015.0  100000000013  1.0    5.0      -999.0
# 3  1000015.0  100000000013  1.0    5.0      -999.0
# 4  1000015.0  100000000013  1.0    5.0      -999.0

# %%
train_label=train['actionType']
train_data=train.drop('actionType',axis=1)
x_train,x_val,y_train,y_val=train_test_split(train_data,train_label,test_size=0.2,random_state=100)
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2110520 entries, 111123 to 1873416
# Data columns (total 16 columns):
# userid         int64
# actionTime     int64
# Horderid       int64
# orderTime      int64
# orderType      float64
# cityNo         float64
# countryNo      float64
# continentNo    float64
# Corderid       float64
# rating         float64
# genderNo       float64
# province       float64
# provinceNo     int64
# age            float64
# ageNo          float64
# PorderType     float64
# dtypes: float64(11), int64(5)
# memory usage: 273.7 MB

# %%
param = {'learning_rate' : 0.1,
        'n_estimators': 1000,
        'max_depth': 4,
        'min_child_weight': 7,
        'gamma': 0,
        'subsample': 0.94,
        'colsample_bytree': 0.75,
        'eta': 0.05,
        'silent': 1,
        'objective':
        'binary:logistic',
        'scale_pos_weight':1}
num_round =666
param['eval_metric'] = 'auc'

dtrain = xgb.DMatrix(x_train,label=y_train)
dtest = dtrain
evallist  = [(dtest,'eval'), (dtrain,'train')]
bst=xgb.train(param,dtrain,num_round,evallist,early_stopping_rounds=100)



#bst = xgb.train( param, dtrain, num_round, evallist )
bst.dump_model('E:\\study\\dataset\\Hbc_csv\\dump.raw.txt')
# Out:
# [0]	eval-auc:0.760592	train-auc:0.760592
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	eval-auc:0.766578	train-auc:0.766578
# [2]	eval-auc:0.772258	train-auc:0.772258
# [3]	eval-auc:0.777943	train-auc:0.777943
# [4]	eval-auc:0.782536	train-auc:0.782536
# [5]	eval-auc:0.789352	train-auc:0.789352
# [6]	eval-auc:0.79227	train-auc:0.79227
# [7]	eval-auc:0.793343	train-auc:0.793343
# [8]	eval-auc:0.794535	train-auc:0.794535
# [9]	eval-auc:0.795009	train-auc:0.795009
# [10]	eval-auc:0.800415	train-auc:0.800415
# [11]	eval-auc:0.806408	train-auc:0.806408
# [12]	eval-auc:0.809565	train-auc:0.809565
# [13]	eval-auc:0.809546	train-auc:0.809546
# [14]	eval-auc:0.810402	train-auc:0.810402
# [15]	eval-auc:0.814231	train-auc:0.814231
# [16]	eval-auc:0.815466	train-auc:0.815466
# [17]	eval-auc:0.817239	train-auc:0.817239
# [18]	eval-auc:0.819228	train-auc:0.819228
# [19]	eval-auc:0.821205	train-auc:0.821205
# [20]	eval-auc:0.823636	train-auc:0.823636
# [21]	eval-auc:0.827011	train-auc:0.827011
# [22]	eval-auc:0.826993	train-auc:0.826993
# [23]	eval-auc:0.829192	train-auc:0.829192
# [24]	eval-auc:0.830985	train-auc:0.830985
# [25]	eval-auc:0.832426	train-auc:0.832426
# [26]	eval-auc:0.833423	train-auc:0.833423
# [27]	eval-auc:0.834351	train-auc:0.834351
# [28]	eval-auc:0.83617	train-auc:0.83617
# [29]	eval-auc:0.837704	train-auc:0.837704
# [30]	eval-auc:0.838564	train-auc:0.838564
# [31]	eval-auc:0.839204	train-auc:0.839204
# [32]	eval-auc:0.841691	train-auc:0.841691
# [33]	eval-auc:0.842561	train-auc:0.842561
# [34]	eval-auc:0.843662	train-auc:0.843662
# [35]	eval-auc:0.844042	train-auc:0.844042
# [36]	eval-auc:0.845602	train-auc:0.845602
# [37]	eval-auc:0.846197	train-auc:0.846197
# [38]	eval-auc:0.84647	train-auc:0.84647
# [39]	eval-auc:0.847145	train-auc:0.847145
# [40]	eval-auc:0.847546	train-auc:0.847546
# [41]	eval-auc:0.848728	train-auc:0.848728
# [42]	eval-auc:0.850348	train-auc:0.850348
# [43]	eval-auc:0.850599	train-auc:0.850599
# [44]	eval-auc:0.851781	train-auc:0.851781
# [45]	eval-auc:0.851995	train-auc:0.851995
# [46]	eval-auc:0.853009	train-auc:0.853009
# [47]	eval-auc:0.853714	train-auc:0.853714
# [48]	eval-auc:0.853772	train-auc:0.853772
# [49]	eval-auc:0.854114	train-auc:0.854114
# [50]	eval-auc:0.85525	train-auc:0.85525
# [51]	eval-auc:0.855549	train-auc:0.855549
# [52]	eval-auc:0.855725	train-auc:0.855725
# [53]	eval-auc:0.856092	train-auc:0.856092
# [54]	eval-auc:0.856618	train-auc:0.856618
# [55]	eval-auc:0.857261	train-auc:0.857261
# [56]	eval-auc:0.857973	train-auc:0.857973
# [57]	eval-auc:0.859541	train-auc:0.859541
# [58]	eval-auc:0.860155	train-auc:0.860155
# [59]	eval-auc:0.861085	train-auc:0.861085
# [60]	eval-auc:0.862053	train-auc:0.862053
# [61]	eval-auc:0.862345	train-auc:0.862345
# [62]	eval-auc:0.862723	train-auc:0.862723
# [63]	eval-auc:0.863059	train-auc:0.863059
# [64]	eval-auc:0.863488	train-auc:0.863488
# [65]	eval-auc:0.863993	train-auc:0.863993
# [66]	eval-auc:0.864755	train-auc:0.864755
# [67]	eval-auc:0.8652	train-auc:0.8652
# [68]	eval-auc:0.865505	train-auc:0.865505
# [69]	eval-auc:0.865873	train-auc:0.865873
# [70]	eval-auc:0.866244	train-auc:0.866244
# [71]	eval-auc:0.866334	train-auc:0.866334
# [72]	eval-auc:0.8666	train-auc:0.8666
# [73]	eval-auc:0.867649	train-auc:0.867649
# [74]	eval-auc:0.86794	train-auc:0.86794
# [75]	eval-auc:0.868372	train-auc:0.868372
# [76]	eval-auc:0.868844	train-auc:0.868844
# [77]	eval-auc:0.869661	train-auc:0.869661
# [78]	eval-auc:0.870302	train-auc:0.870302
# [79]	eval-auc:0.871288	train-auc:0.871288
# [80]	eval-auc:0.871578	train-auc:0.871578
# [81]	eval-auc:0.872249	train-auc:0.872249
# [82]	eval-auc:0.87239	train-auc:0.87239
# [83]	eval-auc:0.873032	train-auc:0.873032
# [84]	eval-auc:0.873288	train-auc:0.873288
# [85]	eval-auc:0.873813	train-auc:0.873813
# [86]	eval-auc:0.874255	train-auc:0.874255
# [87]	eval-auc:0.874964	train-auc:0.874964
# [88]	eval-auc:0.875413	train-auc:0.875413
# [89]	eval-auc:0.876425	train-auc:0.876425
# [90]	eval-auc:0.877108	train-auc:0.877108
# [91]	eval-auc:0.877589	train-auc:0.877589
# [92]	eval-auc:0.878087	train-auc:0.878087
# [93]	eval-auc:0.878384	train-auc:0.878384
# [94]	eval-auc:0.879149	train-auc:0.879149
# [95]	eval-auc:0.879342	train-auc:0.879342
# [96]	eval-auc:0.879617	train-auc:0.879617
# [97]	eval-auc:0.880023	train-auc:0.880023
# [98]	eval-auc:0.880565	train-auc:0.880565
# [99]	eval-auc:0.880588	train-auc:0.880588
# [100]	eval-auc:0.881121	train-auc:0.881121
# [101]	eval-auc:0.881616	train-auc:0.881616
# [102]	eval-auc:0.881805	train-auc:0.881805
# [103]	eval-auc:0.882205	train-auc:0.882205
# [104]	eval-auc:0.882734	train-auc:0.882734
# [105]	eval-auc:0.882906	train-auc:0.882906
# [106]	eval-auc:0.883444	train-auc:0.883444
# [107]	eval-auc:0.88389	train-auc:0.88389
# [108]	eval-auc:0.88413	train-auc:0.88413
# [109]	eval-auc:0.884759	train-auc:0.884759
# [110]	eval-auc:0.884946	train-auc:0.884946
# [111]	eval-auc:0.885385	train-auc:0.885385
# [112]	eval-auc:0.885547	train-auc:0.885547
# [113]	eval-auc:0.885738	train-auc:0.885738
# [114]	eval-auc:0.885783	train-auc:0.885783
# [115]	eval-auc:0.886143	train-auc:0.886143
# [116]	eval-auc:0.88659	train-auc:0.88659
# [117]	eval-auc:0.886664	train-auc:0.886664
# [118]	eval-auc:0.887022	train-auc:0.887022
# [119]	eval-auc:0.88734	train-auc:0.88734
# [120]	eval-auc:0.887926	train-auc:0.887926
# [121]	eval-auc:0.888057	train-auc:0.888057
# [122]	eval-auc:0.888335	train-auc:0.888335
# [123]	eval-auc:0.888527	train-auc:0.888527
# [124]	eval-auc:0.888732	train-auc:0.888732
# [125]	eval-auc:0.889173	train-auc:0.889173
# [126]	eval-auc:0.889587	train-auc:0.889587
# [127]	eval-auc:0.889709	train-auc:0.889709
# [128]	eval-auc:0.889767	train-auc:0.889767
# [129]	eval-auc:0.89002	train-auc:0.89002
# [130]	eval-auc:0.890453	train-auc:0.890453
# [131]	eval-auc:0.89106	train-auc:0.89106
# [132]	eval-auc:0.891529	train-auc:0.891529
# [133]	eval-auc:0.891626	train-auc:0.891626
# [134]	eval-auc:0.891989	train-auc:0.891989
# [135]	eval-auc:0.892263	train-auc:0.892263
# [136]	eval-auc:0.892531	train-auc:0.892531
# [137]	eval-auc:0.892744	train-auc:0.892744
# [138]	eval-auc:0.892967	train-auc:0.892967
# [139]	eval-auc:0.893158	train-auc:0.893158
# [140]	eval-auc:0.893302	train-auc:0.893302
# [141]	eval-auc:0.893541	train-auc:0.893541
# [142]	eval-auc:0.893624	train-auc:0.893624
# [143]	eval-auc:0.893935	train-auc:0.893935
# [144]	eval-auc:0.894197	train-auc:0.894197
# [145]	eval-auc:0.894427	train-auc:0.894427
# [146]	eval-auc:0.894691	train-auc:0.894691
# [147]	eval-auc:0.894886	train-auc:0.894886
# [148]	eval-auc:0.895198	train-auc:0.895198
# [149]	eval-auc:0.895353	train-auc:0.895353
# [150]	eval-auc:0.895543	train-auc:0.895543
# [151]	eval-auc:0.896013	train-auc:0.896013
# [152]	eval-auc:0.896164	train-auc:0.896164
# [153]	eval-auc:0.896466	train-auc:0.896466
# [154]	eval-auc:0.896638	train-auc:0.896638
# [155]	eval-auc:0.896834	train-auc:0.896834
# [156]	eval-auc:0.897161	train-auc:0.897161
# [157]	eval-auc:0.897335	train-auc:0.897335
# [158]	eval-auc:0.897523	train-auc:0.897523
# [159]	eval-auc:0.897713	train-auc:0.897713
# [160]	eval-auc:0.897844	train-auc:0.897844
# [161]	eval-auc:0.897909	train-auc:0.897909
# [162]	eval-auc:0.898065	train-auc:0.898065
# [163]	eval-auc:0.898467	train-auc:0.898467
# [164]	eval-auc:0.898672	train-auc:0.898672
# [165]	eval-auc:0.898867	train-auc:0.898867
# [166]	eval-auc:0.899087	train-auc:0.899087
# [167]	eval-auc:0.89922	train-auc:0.89922
# [168]	eval-auc:0.899327	train-auc:0.899327
# [169]	eval-auc:0.899404	train-auc:0.899404
# [170]	eval-auc:0.899762	train-auc:0.899762
# [171]	eval-auc:0.900073	train-auc:0.900073
# [172]	eval-auc:0.900076	train-auc:0.900076
# [173]	eval-auc:0.900373	train-auc:0.900373
# [174]	eval-auc:0.900439	train-auc:0.900439
# [175]	eval-auc:0.900668	train-auc:0.900668
# [176]	eval-auc:0.901059	train-auc:0.901059
# [177]	eval-auc:0.901244	train-auc:0.901244
# [178]	eval-auc:0.90153	train-auc:0.90153
# [179]	eval-auc:0.901745	train-auc:0.901745
# [180]	eval-auc:0.901921	train-auc:0.901921
# [181]	eval-auc:0.902144	train-auc:0.902144
# [182]	eval-auc:0.902364	train-auc:0.902364
# [183]	eval-auc:0.902447	train-auc:0.902447
# [184]	eval-auc:0.90249	train-auc:0.90249
# [185]	eval-auc:0.902708	train-auc:0.902708
# [186]	eval-auc:0.902949	train-auc:0.902949
# [187]	eval-auc:0.903177	train-auc:0.903177
# [188]	eval-auc:0.903337	train-auc:0.903337
# [189]	eval-auc:0.903425	train-auc:0.903425
# [190]	eval-auc:0.903635	train-auc:0.903635
# [191]	eval-auc:0.903887	train-auc:0.903887
# [192]	eval-auc:0.904033	train-auc:0.904033
# [193]	eval-auc:0.90424	train-auc:0.90424
# [194]	eval-auc:0.904334	train-auc:0.904334
# [195]	eval-auc:0.904468	train-auc:0.904468
# [196]	eval-auc:0.904495	train-auc:0.904495
# [197]	eval-auc:0.904522	train-auc:0.904522
# [198]	eval-auc:0.904695	train-auc:0.904695
# [199]	eval-auc:0.904848	train-auc:0.904848
# [200]	eval-auc:0.904889	train-auc:0.904889
# [201]	eval-auc:0.90505	train-auc:0.90505
# [202]	eval-auc:0.905143	train-auc:0.905143
# [203]	eval-auc:0.905163	train-auc:0.905163
# [204]	eval-auc:0.905276	train-auc:0.905276
# [205]	eval-auc:0.9055	train-auc:0.9055
# [206]	eval-auc:0.905704	train-auc:0.905704
# [207]	eval-auc:0.90602	train-auc:0.90602
# [208]	eval-auc:0.906308	train-auc:0.906308
# [209]	eval-auc:0.90633	train-auc:0.90633
# [210]	eval-auc:0.906605	train-auc:0.906605
# [211]	eval-auc:0.906853	train-auc:0.906853
# [212]	eval-auc:0.907153	train-auc:0.907153
# [213]	eval-auc:0.907335	train-auc:0.907335
# [214]	eval-auc:0.907506	train-auc:0.907506
# [215]	eval-auc:0.907643	train-auc:0.907643
# [216]	eval-auc:0.907781	train-auc:0.907781
# [217]	eval-auc:0.90796	train-auc:0.90796
# [218]	eval-auc:0.908076	train-auc:0.908076
# [219]	eval-auc:0.908251	train-auc:0.908251
# [220]	eval-auc:0.908387	train-auc:0.908387
# [221]	eval-auc:0.908533	train-auc:0.908533
# [222]	eval-auc:0.908853	train-auc:0.908853
# [223]	eval-auc:0.90907	train-auc:0.90907
# [224]	eval-auc:0.909289	train-auc:0.909289
# [225]	eval-auc:0.909479	train-auc:0.909479
# [226]	eval-auc:0.909608	train-auc:0.909608
# [227]	eval-auc:0.909875	train-auc:0.909875
# [228]	eval-auc:0.910091	train-auc:0.910091
# [229]	eval-auc:0.910157	train-auc:0.910157
# [230]	eval-auc:0.910179	train-auc:0.910179
# [231]	eval-auc:0.910356	train-auc:0.910356
# [232]	eval-auc:0.910497	train-auc:0.910497
# [233]	eval-auc:0.910639	train-auc:0.910639
# [234]	eval-auc:0.910845	train-auc:0.910845
# [235]	eval-auc:0.911018	train-auc:0.911018
# [236]	eval-auc:0.911103	train-auc:0.911103
# [237]	eval-auc:0.911157	train-auc:0.911157
# [238]	eval-auc:0.911366	train-auc:0.911366
# [239]	eval-auc:0.911447	train-auc:0.911447
# [240]	eval-auc:0.911759	train-auc:0.911759
# [241]	eval-auc:0.911777	train-auc:0.911777
# [242]	eval-auc:0.911903	train-auc:0.911903
# [243]	eval-auc:0.912002	train-auc:0.912002
# [244]	eval-auc:0.912039	train-auc:0.912039
# [245]	eval-auc:0.912141	train-auc:0.912141
# [246]	eval-auc:0.91237	train-auc:0.91237
# [247]	eval-auc:0.912571	train-auc:0.912571
# [248]	eval-auc:0.91274	train-auc:0.91274
# [249]	eval-auc:0.912803	train-auc:0.912803
# [250]	eval-auc:0.912868	train-auc:0.912868
# [251]	eval-auc:0.912955	train-auc:0.912955
# [252]	eval-auc:0.913046	train-auc:0.913046
# [253]	eval-auc:0.913323	train-auc:0.913323
# [254]	eval-auc:0.913401	train-auc:0.913401
# [255]	eval-auc:0.913602	train-auc:0.913602
# [256]	eval-auc:0.913713	train-auc:0.913713
# [257]	eval-auc:0.913806	train-auc:0.913806
# [258]	eval-auc:0.913931	train-auc:0.913931
# [259]	eval-auc:0.913956	train-auc:0.913956
# [260]	eval-auc:0.914134	train-auc:0.914134
# [261]	eval-auc:0.91439	train-auc:0.91439
# [262]	eval-auc:0.914503	train-auc:0.914503
# [263]	eval-auc:0.914771	train-auc:0.914771
# [264]	eval-auc:0.915045	train-auc:0.915045
# [265]	eval-auc:0.915144	train-auc:0.915144
# [266]	eval-auc:0.915239	train-auc:0.915239
# [267]	eval-auc:0.915397	train-auc:0.915397
# [268]	eval-auc:0.915527	train-auc:0.915527
# [269]	eval-auc:0.915584	train-auc:0.915584
# [270]	eval-auc:0.915727	train-auc:0.915727
# [271]	eval-auc:0.915817	train-auc:0.915817
# [272]	eval-auc:0.91601	train-auc:0.91601
# [273]	eval-auc:0.916216	train-auc:0.916216
# [274]	eval-auc:0.916336	train-auc:0.916336
# [275]	eval-auc:0.916485	train-auc:0.916485
# [276]	eval-auc:0.916554	train-auc:0.916554
# [277]	eval-auc:0.916747	train-auc:0.916747
# [278]	eval-auc:0.916938	train-auc:0.916938
# [279]	eval-auc:0.916996	train-auc:0.916996
# [280]	eval-auc:0.91705	train-auc:0.91705
# [281]	eval-auc:0.917151	train-auc:0.917151
# [282]	eval-auc:0.917416	train-auc:0.917416
# [283]	eval-auc:0.917586	train-auc:0.917586
# [284]	eval-auc:0.917742	train-auc:0.917742
# [285]	eval-auc:0.91776	train-auc:0.91776
# [286]	eval-auc:0.917816	train-auc:0.917816
# [287]	eval-auc:0.918096	train-auc:0.918096
# [288]	eval-auc:0.918112	train-auc:0.918112
# [289]	eval-auc:0.91821	train-auc:0.91821
# [290]	eval-auc:0.918269	train-auc:0.918269
# [291]	eval-auc:0.918323	train-auc:0.918323
# [292]	eval-auc:0.918475	train-auc:0.918475
# [293]	eval-auc:0.918587	train-auc:0.918587
# [294]	eval-auc:0.918683	train-auc:0.918683
# [295]	eval-auc:0.918774	train-auc:0.918774
# [296]	eval-auc:0.918993	train-auc:0.918993
# [297]	eval-auc:0.919081	train-auc:0.919081
# [298]	eval-auc:0.919205	train-auc:0.919205
# [299]	eval-auc:0.919375	train-auc:0.919375
# [300]	eval-auc:0.919584	train-auc:0.919584
# [301]	eval-auc:0.919674	train-auc:0.919674
# [302]	eval-auc:0.919747	train-auc:0.919747
# [303]	eval-auc:0.919886	train-auc:0.919886
# [304]	eval-auc:0.919977	train-auc:0.919977
# [305]	eval-auc:0.920127	train-auc:0.920127
# [306]	eval-auc:0.920325	train-auc:0.920325
# [307]	eval-auc:0.920519	train-auc:0.920519
# [308]	eval-auc:0.920676	train-auc:0.920676
# [309]	eval-auc:0.920723	train-auc:0.920723
# [310]	eval-auc:0.920792	train-auc:0.920792
# [311]	eval-auc:0.920901	train-auc:0.920901
# [312]	eval-auc:0.920995	train-auc:0.920995
# [313]	eval-auc:0.921071	train-auc:0.921071
# [314]	eval-auc:0.921222	train-auc:0.921222
# [315]	eval-auc:0.921302	train-auc:0.921302
# [316]	eval-auc:0.92138	train-auc:0.92138
# [317]	eval-auc:0.921395	train-auc:0.921395
# [318]	eval-auc:0.921411	train-auc:0.921411
# [319]	eval-auc:0.921484	train-auc:0.921484
# [320]	eval-auc:0.921498	train-auc:0.921498
# [321]	eval-auc:0.92163	train-auc:0.92163
# [322]	eval-auc:0.921694	train-auc:0.921694
# [323]	eval-auc:0.921878	train-auc:0.921878
# [324]	eval-auc:0.921954	train-auc:0.921954
# [325]	eval-auc:0.922061	train-auc:0.922061
# [326]	eval-auc:0.922091	train-auc:0.922091
# [327]	eval-auc:0.922225	train-auc:0.922225
# [328]	eval-auc:0.922374	train-auc:0.922374
# [329]	eval-auc:0.922564	train-auc:0.922564
# [330]	eval-auc:0.922653	train-auc:0.922653
# [331]	eval-auc:0.922851	train-auc:0.922851
# [332]	eval-auc:0.922939	train-auc:0.922939
# [333]	eval-auc:0.923055	train-auc:0.923055
# [334]	eval-auc:0.923189	train-auc:0.923189
# [335]	eval-auc:0.923272	train-auc:0.923272
# [336]	eval-auc:0.923335	train-auc:0.923335
# [337]	eval-auc:0.923337	train-auc:0.923337
# [338]	eval-auc:0.923519	train-auc:0.923519
# [339]	eval-auc:0.923617	train-auc:0.923617
# [340]	eval-auc:0.923737	train-auc:0.923737
# [341]	eval-auc:0.923826	train-auc:0.923826
# [342]	eval-auc:0.923916	train-auc:0.923916
# [343]	eval-auc:0.924073	train-auc:0.924073
# [344]	eval-auc:0.924191	train-auc:0.924191
# [345]	eval-auc:0.92422	train-auc:0.92422
# [346]	eval-auc:0.924309	train-auc:0.924309
# [347]	eval-auc:0.924354	train-auc:0.924354
# [348]	eval-auc:0.924403	train-auc:0.924403
# [349]	eval-auc:0.924568	train-auc:0.924568
# [350]	eval-auc:0.924622	train-auc:0.924622
# [351]	eval-auc:0.924715	train-auc:0.924715
# [352]	eval-auc:0.924904	train-auc:0.924904
# [353]	eval-auc:0.925118	train-auc:0.925118
# [354]	eval-auc:0.925233	train-auc:0.925233
# [355]	eval-auc:0.925312	train-auc:0.925312
# [356]	eval-auc:0.925327	train-auc:0.925327
# [357]	eval-auc:0.925434	train-auc:0.925434
# [358]	eval-auc:0.925561	train-auc:0.925561
# [359]	eval-auc:0.925831	train-auc:0.925831
# [360]	eval-auc:0.925969	train-auc:0.925969
# [361]	eval-auc:0.926039	train-auc:0.926039
# [362]	eval-auc:0.926139	train-auc:0.926139
# [363]	eval-auc:0.926279	train-auc:0.926279
# [364]	eval-auc:0.926359	train-auc:0.926359
# [365]	eval-auc:0.926389	train-auc:0.926389
# [366]	eval-auc:0.92651	train-auc:0.92651
# [367]	eval-auc:0.926549	train-auc:0.926549
# [368]	eval-auc:0.92657	train-auc:0.92657
# [369]	eval-auc:0.926737	train-auc:0.926737
# [370]	eval-auc:0.926814	train-auc:0.926814
# [371]	eval-auc:0.926906	train-auc:0.926906
# [372]	eval-auc:0.926965	train-auc:0.926965
# [373]	eval-auc:0.926989	train-auc:0.926989
# [374]	eval-auc:0.927025	train-auc:0.927025
# [375]	eval-auc:0.92709	train-auc:0.92709
# [376]	eval-auc:0.927198	train-auc:0.927198
# [377]	eval-auc:0.927299	train-auc:0.927299
# [378]	eval-auc:0.927377	train-auc:0.927377
# [379]	eval-auc:0.9274	train-auc:0.9274
# [380]	eval-auc:0.927435	train-auc:0.927435
# [381]	eval-auc:0.927495	train-auc:0.927495
# [382]	eval-auc:0.927502	train-auc:0.927502
# [383]	eval-auc:0.927508	train-auc:0.927508
# [384]	eval-auc:0.927621	train-auc:0.927621
# [385]	eval-auc:0.927737	train-auc:0.927737
# [386]	eval-auc:0.927805	train-auc:0.927805
# [387]	eval-auc:0.92786	train-auc:0.92786
# [388]	eval-auc:0.927982	train-auc:0.927982
# [389]	eval-auc:0.928147	train-auc:0.928147
# [390]	eval-auc:0.928359	train-auc:0.928359
# [391]	eval-auc:0.928505	train-auc:0.928505
# [392]	eval-auc:0.928521	train-auc:0.928521
# [393]	eval-auc:0.928548	train-auc:0.928548
# [394]	eval-auc:0.928679	train-auc:0.928679
# [395]	eval-auc:0.928745	train-auc:0.928745
# [396]	eval-auc:0.928868	train-auc:0.928868
# [397]	eval-auc:0.928989	train-auc:0.928989
# [398]	eval-auc:0.92906	train-auc:0.92906
# [399]	eval-auc:0.929108	train-auc:0.929108
# [400]	eval-auc:0.929116	train-auc:0.929116
# [401]	eval-auc:0.929123	train-auc:0.929123
# [402]	eval-auc:0.929216	train-auc:0.929216
# [403]	eval-auc:0.929249	train-auc:0.929249
# [404]	eval-auc:0.929315	train-auc:0.929315
# [405]	eval-auc:0.929438	train-auc:0.929438
# [406]	eval-auc:0.929475	train-auc:0.929475
# [407]	eval-auc:0.929515	train-auc:0.929515
# [408]	eval-auc:0.929595	train-auc:0.929595
# [409]	eval-auc:0.929699	train-auc:0.929699
# [410]	eval-auc:0.929718	train-auc:0.929718
# [411]	eval-auc:0.929749	train-auc:0.929749
# [412]	eval-auc:0.92982	train-auc:0.92982
# [413]	eval-auc:0.929897	train-auc:0.929897
# [414]	eval-auc:0.929973	train-auc:0.929973
# [415]	eval-auc:0.930117	train-auc:0.930117
# [416]	eval-auc:0.930181	train-auc:0.930181
# [417]	eval-auc:0.930256	train-auc:0.930256
# [418]	eval-auc:0.930348	train-auc:0.930348
# [419]	eval-auc:0.930418	train-auc:0.930418
# [420]	eval-auc:0.930523	train-auc:0.930523
# [421]	eval-auc:0.930637	train-auc:0.930637
# [422]	eval-auc:0.930684	train-auc:0.930684
# [423]	eval-auc:0.930746	train-auc:0.930746
# [424]	eval-auc:0.930865	train-auc:0.930865
# [425]	eval-auc:0.930921	train-auc:0.930921
# [426]	eval-auc:0.931006	train-auc:0.931006
# [427]	eval-auc:0.931103	train-auc:0.931103
# [428]	eval-auc:0.931125	train-auc:0.931125
# [429]	eval-auc:0.931134	train-auc:0.931134
# [430]	eval-auc:0.931165	train-auc:0.931165
# [431]	eval-auc:0.931245	train-auc:0.931245
# [432]	eval-auc:0.931422	train-auc:0.931422
# [433]	eval-auc:0.93152	train-auc:0.93152
# [434]	eval-auc:0.931593	train-auc:0.931593
# [435]	eval-auc:0.931682	train-auc:0.931682
# [436]	eval-auc:0.931767	train-auc:0.931767
# [437]	eval-auc:0.931887	train-auc:0.931887
# [438]	eval-auc:0.931944	train-auc:0.931944
# [439]	eval-auc:0.932059	train-auc:0.932059
# [440]	eval-auc:0.932232	train-auc:0.932232
# [441]	eval-auc:0.932349	train-auc:0.932349
# [442]	eval-auc:0.932411	train-auc:0.932411
# [443]	eval-auc:0.93243	train-auc:0.93243
# [444]	eval-auc:0.932601	train-auc:0.932601
# [445]	eval-auc:0.932753	train-auc:0.932753
# [446]	eval-auc:0.932786	train-auc:0.932786
# [447]	eval-auc:0.932827	train-auc:0.932827
# [448]	eval-auc:0.93294	train-auc:0.93294
# [449]	eval-auc:0.932988	train-auc:0.932988
# [450]	eval-auc:0.933008	train-auc:0.933008
# [451]	eval-auc:0.933045	train-auc:0.933045
# [452]	eval-auc:0.933139	train-auc:0.933139
# [453]	eval-auc:0.933206	train-auc:0.933206
# [454]	eval-auc:0.933268	train-auc:0.933268
# [455]	eval-auc:0.93336	train-auc:0.93336
# [456]	eval-auc:0.933381	train-auc:0.933381
# [457]	eval-auc:0.933418	train-auc:0.933418
# [458]	eval-auc:0.933524	train-auc:0.933524
# [459]	eval-auc:0.933909	train-auc:0.933909
# [460]	eval-auc:0.933947	train-auc:0.933947
# [461]	eval-auc:0.934011	train-auc:0.934011
# [462]	eval-auc:0.934081	train-auc:0.934081
# [463]	eval-auc:0.934197	train-auc:0.934197
# [464]	eval-auc:0.934203	train-auc:0.934203
# [465]	eval-auc:0.934252	train-auc:0.934252
# [466]	eval-auc:0.93434	train-auc:0.93434
# [467]	eval-auc:0.934437	train-auc:0.934437
# [468]	eval-auc:0.934483	train-auc:0.934483
# [469]	eval-auc:0.934563	train-auc:0.934563
# [470]	eval-auc:0.934581	train-auc:0.934581
# [471]	eval-auc:0.934644	train-auc:0.934644
# [472]	eval-auc:0.934662	train-auc:0.934662
# [473]	eval-auc:0.934676	train-auc:0.934676
# [474]	eval-auc:0.934707	train-auc:0.934707
# [475]	eval-auc:0.93486	train-auc:0.93486
# [476]	eval-auc:0.934929	train-auc:0.934929
# [477]	eval-auc:0.934952	train-auc:0.934952
# [478]	eval-auc:0.93504	train-auc:0.93504
# [479]	eval-auc:0.935067	train-auc:0.935067
# [480]	eval-auc:0.935176	train-auc:0.935176
# [481]	eval-auc:0.935251	train-auc:0.935251
# [482]	eval-auc:0.935324	train-auc:0.935324
# [483]	eval-auc:0.935339	train-auc:0.935339
# [484]	eval-auc:0.935447	train-auc:0.935447
# [485]	eval-auc:0.935499	train-auc:0.935499
# [486]	eval-auc:0.935638	train-auc:0.935638
# [487]	eval-auc:0.935751	train-auc:0.935751
# [488]	eval-auc:0.93583	train-auc:0.93583
# [489]	eval-auc:0.93591	train-auc:0.93591
# [490]	eval-auc:0.93598	train-auc:0.93598
# [491]	eval-auc:0.936044	train-auc:0.936044
# [492]	eval-auc:0.936186	train-auc:0.936186
# [493]	eval-auc:0.936212	train-auc:0.936212
# [494]	eval-auc:0.936339	train-auc:0.936339
# [495]	eval-auc:0.936422	train-auc:0.936422
# [496]	eval-auc:0.936444	train-auc:0.936444
# [497]	eval-auc:0.936525	train-auc:0.936525
# [498]	eval-auc:0.936548	train-auc:0.936548
# [499]	eval-auc:0.936553	train-auc:0.936553
# [500]	eval-auc:0.936635	train-auc:0.936635
# [501]	eval-auc:0.936725	train-auc:0.936725
# [502]	eval-auc:0.936838	train-auc:0.936838
# [503]	eval-auc:0.936929	train-auc:0.936929
# [504]	eval-auc:0.936935	train-auc:0.936935
# [505]	eval-auc:0.937018	train-auc:0.937018
# [506]	eval-auc:0.937164	train-auc:0.937164
# [507]	eval-auc:0.937241	train-auc:0.937241
# [508]	eval-auc:0.937278	train-auc:0.937278
# [509]	eval-auc:0.937267	train-auc:0.937267
# [510]	eval-auc:0.937384	train-auc:0.937384
# [511]	eval-auc:0.937536	train-auc:0.937536
# [512]	eval-auc:0.937604	train-auc:0.937604
# [513]	eval-auc:0.937652	train-auc:0.937652
# [514]	eval-auc:0.937704	train-auc:0.937704
# [515]	eval-auc:0.937716	train-auc:0.937716
# [516]	eval-auc:0.937764	train-auc:0.937764
# [517]	eval-auc:0.937863	train-auc:0.937863
# [518]	eval-auc:0.93792	train-auc:0.93792
# [519]	eval-auc:0.938025	train-auc:0.938025
# [520]	eval-auc:0.938048	train-auc:0.938048
# [521]	eval-auc:0.938084	train-auc:0.938084
# [522]	eval-auc:0.938201	train-auc:0.938201
# [523]	eval-auc:0.93845	train-auc:0.93845
# [524]	eval-auc:0.938474	train-auc:0.938474
# [525]	eval-auc:0.938562	train-auc:0.938562
# [526]	eval-auc:0.938647	train-auc:0.938647
# [527]	eval-auc:0.938688	train-auc:0.938688
# [528]	eval-auc:0.938831	train-auc:0.938831
# [529]	eval-auc:0.938954	train-auc:0.938954
# [530]	eval-auc:0.939065	train-auc:0.939065
# [531]	eval-auc:0.939071	train-auc:0.939071
# [532]	eval-auc:0.939114	train-auc:0.939114
# [533]	eval-auc:0.939277	train-auc:0.939277
# [534]	eval-auc:0.939354	train-auc:0.939354
# [535]	eval-auc:0.939524	train-auc:0.939524
# [536]	eval-auc:0.939535	train-auc:0.939535
# [537]	eval-auc:0.939643	train-auc:0.939643
# [538]	eval-auc:0.939647	train-auc:0.939647
# [539]	eval-auc:0.939777	train-auc:0.939777
# [540]	eval-auc:0.939868	train-auc:0.939868
# [541]	eval-auc:0.939877	train-auc:0.939877
# [542]	eval-auc:0.93989	train-auc:0.93989
# [543]	eval-auc:0.93998	train-auc:0.93998
# [544]	eval-auc:0.939987	train-auc:0.939987
# [545]	eval-auc:0.940101	train-auc:0.940101
# [546]	eval-auc:0.940145	train-auc:0.940145
# [547]	eval-auc:0.940195	train-auc:0.940195
# [548]	eval-auc:0.940199	train-auc:0.940199
# [549]	eval-auc:0.940264	train-auc:0.940264
# [550]	eval-auc:0.940373	train-auc:0.940373
# [551]	eval-auc:0.940422	train-auc:0.940422
# [552]	eval-auc:0.940524	train-auc:0.940524
# [553]	eval-auc:0.940615	train-auc:0.940615
# [554]	eval-auc:0.940652	train-auc:0.940652
# [555]	eval-auc:0.940764	train-auc:0.940764
# [556]	eval-auc:0.940875	train-auc:0.940875
# [557]	eval-auc:0.940948	train-auc:0.940948
# [558]	eval-auc:0.941082	train-auc:0.941082
# [559]	eval-auc:0.941155	train-auc:0.941155
# [560]	eval-auc:0.94117	train-auc:0.94117
# [561]	eval-auc:0.94123	train-auc:0.94123
# [562]	eval-auc:0.941279	train-auc:0.941279
# [563]	eval-auc:0.941289	train-auc:0.941289
# [564]	eval-auc:0.941352	train-auc:0.941352
# [565]	eval-auc:0.941403	train-auc:0.941403
# [566]	eval-auc:0.941409	train-auc:0.941409
# [567]	eval-auc:0.941473	train-auc:0.941473
# [568]	eval-auc:0.941552	train-auc:0.941552
# [569]	eval-auc:0.94159	train-auc:0.94159
# [570]	eval-auc:0.941627	train-auc:0.941627
# [571]	eval-auc:0.941703	train-auc:0.941703
# [572]	eval-auc:0.941804	train-auc:0.941804
# [573]	eval-auc:0.941951	train-auc:0.941951
# [574]	eval-auc:0.942013	train-auc:0.942013
# [575]	eval-auc:0.942043	train-auc:0.942043
# [576]	eval-auc:0.942078	train-auc:0.942078
# [577]	eval-auc:0.942138	train-auc:0.942138
# [578]	eval-auc:0.942133	train-auc:0.942133
# [579]	eval-auc:0.94223	train-auc:0.94223
# [580]	eval-auc:0.942268	train-auc:0.942268
# [581]	eval-auc:0.942356	train-auc:0.942356
# [582]	eval-auc:0.942414	train-auc:0.942414
# [583]	eval-auc:0.942489	train-auc:0.942489
# [584]	eval-auc:0.942498	train-auc:0.942498
# [585]	eval-auc:0.942585	train-auc:0.942585
# [586]	eval-auc:0.942637	train-auc:0.942637
# [587]	eval-auc:0.942645	train-auc:0.942645
# [588]	eval-auc:0.94269	train-auc:0.94269
# [589]	eval-auc:0.942727	train-auc:0.942727
# [590]	eval-auc:0.942788	train-auc:0.942788
# [591]	eval-auc:0.942835	train-auc:0.942835
# [592]	eval-auc:0.942843	train-auc:0.942843
# [593]	eval-auc:0.942918	train-auc:0.942918
# [594]	eval-auc:0.943018	train-auc:0.943018
# [595]	eval-auc:0.943024	train-auc:0.943024
# [596]	eval-auc:0.943025	train-auc:0.943025
# [597]	eval-auc:0.943086	train-auc:0.943086
# [598]	eval-auc:0.943192	train-auc:0.943192
# [599]	eval-auc:0.943269	train-auc:0.943269
# [600]	eval-auc:0.943351	train-auc:0.943351
# [601]	eval-auc:0.943409	train-auc:0.943409
# [602]	eval-auc:0.94343	train-auc:0.94343
# [603]	eval-auc:0.943466	train-auc:0.943466
# [604]	eval-auc:0.943493	train-auc:0.943493
# [605]	eval-auc:0.943556	train-auc:0.943556
# [606]	eval-auc:0.943628	train-auc:0.943628
# [607]	eval-auc:0.943728	train-auc:0.943728
# [608]	eval-auc:0.943759	train-auc:0.943759
# [609]	eval-auc:0.94379	train-auc:0.94379
# [610]	eval-auc:0.943849	train-auc:0.943849
# [611]	eval-auc:0.943876	train-auc:0.943876
# [612]	eval-auc:0.943938	train-auc:0.943938
# [613]	eval-auc:0.943993	train-auc:0.943993
# [614]	eval-auc:0.944047	train-auc:0.944047
# [615]	eval-auc:0.944109	train-auc:0.944109
# [616]	eval-auc:0.94419	train-auc:0.94419
# [617]	eval-auc:0.944235	train-auc:0.944235
# [618]	eval-auc:0.944273	train-auc:0.944273
# [619]	eval-auc:0.944343	train-auc:0.944343
# [620]	eval-auc:0.944394	train-auc:0.944394
# [621]	eval-auc:0.944417	train-auc:0.944417
# [622]	eval-auc:0.944493	train-auc:0.944493
# [623]	eval-auc:0.944517	train-auc:0.944517
# [624]	eval-auc:0.94458	train-auc:0.94458
# [625]	eval-auc:0.944645	train-auc:0.944645
# [626]	eval-auc:0.944681	train-auc:0.944681
# [627]	eval-auc:0.944754	train-auc:0.944754
# [628]	eval-auc:0.944795	train-auc:0.944795
# [629]	eval-auc:0.944838	train-auc:0.944838
# [630]	eval-auc:0.944888	train-auc:0.944888
# [631]	eval-auc:0.944955	train-auc:0.944955
# [632]	eval-auc:0.94504	train-auc:0.94504
# [633]	eval-auc:0.945093	train-auc:0.945093
# [634]	eval-auc:0.94514	train-auc:0.94514
# [635]	eval-auc:0.945183	train-auc:0.945183
# [636]	eval-auc:0.945188	train-auc:0.945188
# [637]	eval-auc:0.945216	train-auc:0.945216
# [638]	eval-auc:0.945247	train-auc:0.945247
# [639]	eval-auc:0.945294	train-auc:0.945294
# [640]	eval-auc:0.945367	train-auc:0.945367
# [641]	eval-auc:0.945415	train-auc:0.945415
# [642]	eval-auc:0.94545	train-auc:0.94545
# [643]	eval-auc:0.945457	train-auc:0.945457
# [644]	eval-auc:0.945503	train-auc:0.945503
# [645]	eval-auc:0.945585	train-auc:0.945585
# [646]	eval-auc:0.945585	train-auc:0.945585
# [647]	eval-auc:0.94568	train-auc:0.94568
# [648]	eval-auc:0.945689	train-auc:0.945689
# [649]	eval-auc:0.945726	train-auc:0.945726
# [650]	eval-auc:0.945744	train-auc:0.945744
# [651]	eval-auc:0.945808	train-auc:0.945808
# [652]	eval-auc:0.945843	train-auc:0.945843
# [653]	eval-auc:0.945881	train-auc:0.945881
# [654]	eval-auc:0.945935	train-auc:0.945935
# [655]	eval-auc:0.945998	train-auc:0.945998
# [656]	eval-auc:0.946029	train-auc:0.946029
# [657]	eval-auc:0.946085	train-auc:0.946085
# [658]	eval-auc:0.946159	train-auc:0.946159
# [659]	eval-auc:0.946218	train-auc:0.946218
# [660]	eval-auc:0.946246	train-auc:0.946246
# [661]	eval-auc:0.946281	train-auc:0.946281
# [662]	eval-auc:0.946317	train-auc:0.946317
# [663]	eval-auc:0.946346	train-auc:0.946346
# [664]	eval-auc:0.946372	train-auc:0.946372
# [665]	eval-auc:0.946396	train-auc:0.946396
