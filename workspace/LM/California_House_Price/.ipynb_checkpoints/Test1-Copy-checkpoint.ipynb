# %%
import pandas as pd
import numpy as np
import torch
import torchvision
from torch import nn,optim
import matplotlib.pyplot as plt
# %matplotlib auto

# %%
train_data=pd.read_csv(r'F:\study\ml\california-house-prices\train.csv')
test_data=pd.read_csv(r'F:\study\ml\california-house-prices\test.csv')

# %%
train_data.shape
# Out:
# (47439, 41)

# %%
test_data.shape
# Out:
# (31626, 40)

# %%
train_data.head()
# Out:
#    Id            Address  Sold Price  \
# 0   0        540 Pine Ln   3825000.0
# 1   1     1727 W 67th St    505000.0
# 2   2     28093 Pine Ave    140000.0
# 3   3  10750 Braddock Dr   1775000.0
# 4   4  7415 O Donovan Rd   1175000.0
#
#                                              Summary          Type  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...  SingleFamily
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...  SingleFamily
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...  SingleFamily
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...  SingleFamily
# 4  Beautiful 200 acre ranch land with several pas...    VacantLand
#
#    Year built                                       Heating  \
# 0      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1      1926.0                                   Combination
# 2      1958.0                                    Forced air
# 3      1947.0                                       Central
# 4         NaN                                           NaN
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                          Parking     Lot  ...  \
# 0             Garage, Garage - Attached, Covered     1.0  ...
# 1                       Detached Carport, Garage  4047.0  ...
# 2                                       0 spaces  9147.0  ...
# 3  Detached Carport, Driveway, Garage - Two Door     NaN  ...
# 4                                       0 spaces     NaN  ...
#
#                                 Parking features  Tax assessed value  \
# 0             Garage, Garage - Attached, Covered            886486.0
# 1                       Detached Carport, Garage            505000.0
# 2                                            NaN             49627.0
# 3  Detached Carport, Driveway, Garage - Two Door           1775000.0
# 4                                            NaN                 NaN
#
#    Annual tax amount   Listed On  Listed Price  Last Sold On Last Sold Price  \
# 0            12580.0  2019-10-24     4198000.0           NaN             NaN
# 1             6253.0  2019-10-16      525000.0    2019-08-30        328000.0
# 2              468.0  2019-08-25      180000.0           NaN             NaN
# 3            20787.0  2019-10-24     1895000.0    2016-08-30       1500000.0
# 4                NaN  2019-06-07     1595000.0    2016-06-27        900000.0
#
#           City    Zip  State
# 0    Los Altos  94022     CA
# 1  Los Angeles  90047     CA
# 2   Strawberry  95375     CA
# 3  Culver City  90230     CA
# 4      Creston  93432     CA
#
# [5 rows x 41 columns]

# %%
all_features=pd.concat((train_data.iloc[:,1:-1],test_data.iloc[:,1]))

# %%
numeric_features=all_features.dtypes[all_features.dtypes != 'object'].index

# %%
numeric_features
# Out:
# Index(['Annual tax amount', 'Bathrooms', 'Elementary School Distance',
#        'Elementary School Score', 'Full bathrooms', 'Garage spaces',
#        'High School Distance', 'High School Score', 'Last Sold Price',
#        'Listed Price', 'Lot', 'Middle School Distance', 'Middle School Score',
#        'Sold Price', 'Tax assessed value', 'Total interior livable area',
#        'Total spaces', 'Year built', 'Zip'],
#       dtype='object')

# %%
numeric_features_name=numeric_features.tolist()
numeric_features_name
# Out:
# ['Annual tax amount',
#  'Bathrooms',
#  'Elementary School Distance',
#  'Elementary School Score',
#  'Full bathrooms',
#  'Garage spaces',
#  'High School Distance',
#  'High School Score',
#  'Last Sold Price',
#  'Listed Price',
#  'Lot',
#  'Middle School Distance',
#  'Middle School Score',
#  'Sold Price',
#  'Tax assessed value',
#  'Total interior livable area',
#  'Total spaces',
#  'Year built',
#  'Zip']

# %%
numeric_features_name.remove('Sold Price')

# %%
numeric_features_name
# Out:
# ['Annual tax amount',
#  'Bathrooms',
#  'Elementary School Distance',
#  'Elementary School Score',
#  'Full bathrooms',
#  'Garage spaces',
#  'High School Distance',
#  'High School Score',
#  'Last Sold Price',
#  'Listed Price',
#  'Lot',
#  'Middle School Distance',
#  'Middle School Score',
#  'Tax assessed value',
#  'Total interior livable area',
#  'Total spaces',
#  'Year built',
#  'Zip']

# %%
all_features[numeric_features].isna().sum()
# Out:
# Annual tax amount              35936
# Bathrooms                      35091
# Elementary School Distance     36368
# Elementary School Score        36522
# Full bathrooms                 39491
# Garage spaces                  32543
# High School Distance           36627
# High School Score              36845
# Last Sold Price                49392
# Listed Price                   31626
# Lot                            45807
# Middle School Distance         48330
# Middle School Score            48331
# Sold Price                     31626
# Tax assessed value             35278
# Total interior livable area    34152
# Total spaces                   32542
# Year built                     32671
# Zip                            31626
# dtype: int64

# %%
all_features[numeric_features_name]=all_features[numeric_features_name].apply(lambda x : (x-x.mean()) / x.std())

# %%
all_features[numeric_features_name].mean()
# Out:
# Annual tax amount              1.154834e-16
# Bathrooms                     -7.522674e-16
# Elementary School Distance    -1.295063e-14
# Elementary School Score       -1.860748e-15
# Full bathrooms                 5.441759e-16
# Garage spaces                 -6.411489e-18
# High School Distance          -5.113973e-15
# High School Score             -2.770104e-15
# Last Sold Price               -4.286326e-15
# Listed Price                   7.066880e-17
# Lot                           -1.141437e-16
# Middle School Distance        -1.888407e-15
# Middle School Score            1.745464e-15
# Tax assessed value             1.565043e-16
# Total interior livable area    3.484298e-18
# Total spaces                  -3.626773e-16
# Year built                     1.295279e-15
# Zip                            9.063299e-16
# dtype: float64

# %%
all_features[numeric_features_name]=all_features[numeric_features_name].fillna(all_features[numeric_features_name].mean())

# %%
n_train=train_data.shape[0]

# %%
all_features.head()
# Out:
#      0            Address  Annual tax amount  \
# 0  NaN        540 Pine Ln       1.889303e-01
# 1  NaN     1727 W 67th St      -2.667658e-01
# 2  NaN     28093 Pine Ave      -6.834248e-01
# 3  NaN  10750 Braddock Dr       7.800315e-01
# 4  NaN  7415 O Donovan Rd       1.154834e-16
#
#                                  Appliances included     Bathrooms  \
# 0  Dishwasher, Dryer, Garbage disposal, Microwave... -1.981522e+00
# 1                                                NaN -2.991593e-01
# 2                                                NaN  5.420218e-01
# 3                                         Dishwasher  5.420218e-01
# 4                                                NaN -7.522674e-16
#
#                                             Bedrooms         City  \
# 0  Ground Floor Bedroom, Master Bedroom on Ground...    Los Altos
# 1                                                  3  Los Angeles
# 2                                                  2   Strawberry
# 3                                                  5  Culver City
# 4                                                NaN      Creston
#
#                                              Cooling  \
# 0    Multi-Zone, Central AC, Whole House / Attic Fan
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                                     Cooling features  \
# 0                                            Central
# 1  Wall/Window Unit(s), Evaporative Cooling, See ...
# 2                                                NaN
# 3                                        Central Air
# 4                                                NaN
#
#                    Elementary School  ...  \
# 0       Santa Rita Elementary School  ...
# 1   Raymond Avenue Elementary School  ...
# 2                                NaN  ...
# 3         Farragut Elementary School  ...
# 4  Santa Margarita Elementary School  ...
#
#                                 Parking features       Region Sold Price  \
# 0             Garage, Garage - Attached, Covered    Los Altos  3825000.0
# 1                       Detached Carport, Garage  Los Angeles   505000.0
# 2                                            NaN   Strawberry   140000.0
# 3  Detached Carport, Driveway, Garage - Two Door  Culver City  1775000.0
# 4                                            NaN      Creston  1175000.0
#
#                                              Summary  Tax assessed value  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...        8.652149e-02
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...       -2.429718e-01
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...       -6.362820e-01
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...        8.539399e-01
# 4  Beautiful 200 acre ranch land with several pas...        1.565043e-16
#
#   Total interior livable area  Total spaces          Type    Year built  \
# 0               -6.935771e-03 -1.738998e-01  SingleFamily  8.480730e-02
# 1               -5.889444e-03 -6.293187e-02  SingleFamily -2.101123e-01
# 2               -5.553082e-03 -1.738998e-01  SingleFamily  9.362749e-03
# 3               -3.799194e-03 -1.738998e-01  SingleFamily -6.608180e-02
# 4                3.484298e-18 -3.626773e-16    VacantLand  1.295279e-15
#
#         Zip
# 0  0.328180
# 1 -1.427982
# 2  0.925937
# 3 -1.347132
# 4  0.067517
#
# [5 rows x 40 columns]

# %%
all_features[numeric_features_name].head()
# Out:
#    Annual tax amount     Bathrooms  Elementary School Distance  \
# 0       1.889303e-01 -1.981522e+00               -3.225956e-01
# 1      -2.667658e-01 -2.991593e-01               -1.510960e-01
# 2      -6.834248e-01  5.420218e-01               -1.295063e-14
# 3       7.800315e-01  5.420218e-01               -4.083454e-01
# 4       1.154834e-16 -7.522674e-16                3.150272e+00
#
#    Elementary School Score  Full bathrooms  Garage spaces  \
# 0             6.081615e-01    5.441759e-16  -1.664093e-01
# 1            -1.293567e+00   -9.857719e-02  -5.485591e-02
# 2            -1.860748e-15   -1.136654e+00  -1.664093e-01
# 3             1.559026e+00    9.394999e-01  -1.664093e-01
# 4             1.327294e-01    5.441759e-16  -6.411489e-18
#
#    High School Distance  High School Score  Last Sold Price  Listed Price  \
# 0             -0.308768       9.400138e-01    -4.286326e-15      1.096403
# 1             -0.308768      -2.083096e+00    -4.073798e-01     -0.300868
# 2              2.138314      -2.770104e-15    -4.286326e-15     -0.432112
# 3             -0.614653       9.400138e-01     5.876091e-01      0.220303
# 4              2.277353      -6.768939e-02     7.822912e-02      0.106178
#
#             Lot  Middle School Distance  Middle School Score  \
# 0 -1.973466e-02           -1.888407e-15         1.745464e-15
# 1 -1.939537e-02           -2.402037e-01        -1.656310e+00
# 2 -1.896770e-02           -1.888407e-15         1.745464e-15
# 3 -1.141437e-16           -6.056297e-01         8.402341e-01
# 4 -1.141437e-16            3.454659e+00        -1.583836e-01
#
#    Tax assessed value  Total interior livable area  Total spaces  \
# 0        8.652149e-02                -6.935771e-03 -1.738998e-01
# 1       -2.429718e-01                -5.889444e-03 -6.293187e-02
# 2       -6.362820e-01                -5.553082e-03 -1.738998e-01
# 3        8.539399e-01                -3.799194e-03 -1.738998e-01
# 4        1.565043e-16                 3.484298e-18 -3.626773e-16
#
#      Year built       Zip
# 0  8.480730e-02  0.328180
# 1 -2.101123e-01 -1.427982
# 2  9.362749e-03  0.925937
# 3 -6.608180e-02 -1.347132
# 4  1.295279e-15  0.067517

# %%
train_features=torch.Tensor(all_features[numeric_features_name].iloc[:n_train,:].values)
test_features=torch.Tensor(all_features[numeric_features_name].iloc[n_train:,:].values)
train_labels=torch.Tensor(train_data['Sold Price'].values).reshape(-1,1)

# %%
loss=nn.MSELoss()

# %%
train_features.shape
# Out:
# torch.Size([47439, 18])

# %%
test_features.shape
# Out:
# torch.Size([31626, 18])

# %%
train_labels.shape
# Out:
# torch.Size([47439, 1])

# %%
def log_rmse(net,features,labels):
    clipped_preds=torch.clamp(net(features),1,float('inf'))
    rmse=torch.sqrt(loss(torch.log(clipped_preds),torch.log(labels)))
    return rmse.item()

# %%
def train_k_fold_data(net,num_epochs,lr,train_features,train_labels,test_features,test_labels,batch_size,montum,wd):
#     net=nn.Linear(train_features.shape[1],1)
#     net=nn.Sequential(nn.Linear(train_features.shape[1],1))
    loss=nn.MSELoss()
#     optimizer=optim.SGD(net.parameters(),lr=lr,momentum=montum,weight_decay=wd)
    optimizer=optim.Adam(net.parameters(),lr=lr,weight_decay=wd)
    dataset=torch.utils.data.TensorDataset(train_features,train_labels)
    data_iter=torch.utils.data.DataLoader(dataset,batch_size,shuffle=True)
    train_l,test_l=[],[]
    
    min_test_loss=10000
    early_stop_cnt=0
    train_loss,test_loss=0,0
    
    for e in range(num_epochs):
        net.train()
        for x,y in data_iter:
            l=loss(net(x),y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
#         if (e+1) %1000==0 and test_features is not  None:
        net.eval()
        with torch.no_grad():
            test_loss=log_rmse(net,test_features,test_labels)
            if test_loss<min_test_loss:
                min_test_loss=test_loss
#                 test_l.append(test_loss)
                train_loss=log_rmse(net,train_features,train_labels)
                test_l.append(test_loss)
                train_l.append(train_loss)
                print('epoch = %d train_loss : %f , test loss : %f' % (e+1,train_loss,test_loss))
                early_stop_cnt=0
            else:
                early_stop_cnt+=1
        if early_stop_cnt > 500:
            
            break
                
#             net.eval()
#             with torch.no_grad():
#                 train_l.append(loss(net(train_features),train_labels).item())
#                 test_l.append(loss(net(test_features),test_labels).item())
# #                 print('epoch ',(e+1),'train loss : ',train_l[-1],'test loss : ',test_l[-1])
    print('train log loss: ',train_loss)
    print('test log loss: ',test_loss)
    return train_l,test_l

# %%
def get_kfold_data(k,j,x,y,random_state=13):
    assert k>=1, 'k must >=1'
    fold_size = x.shape[0] // k
    x_train,y_train=None,None
    row_list=list(range(x.shape[0]))
    np.random.seed(random_state)
    np.random.shuffle(row_list)
    for i in range(k):
        idx=slice(fold_size*i,fold_size*(i+1))
        x_part,y_part=x[row_list[idx],:],y[row_list[idx],:]
        if i==j:
            x_val,y_val=x_part,y_part
        elif x_train is None:
            x_train,y_train=x_part,y_part
        else:
            x_train=torch.cat((x_train,x_part))
            y_train=torch.cat((y_train,y_part))
    return x_train,y_train,x_val,y_val

# %%
def train_kfold(net1,num_epochs,lr,k,x_data,y_data,batch_size,montum,wd):
    train_sum_l,test_sum_l=[],[]
    train_l,test_l=[],[]
#     net=nn.Linear(x_data.shape[1])
    for j in range(k):
        net1=get_net()
#         for p in net1.parameters():
#             torch.nn.init.normal_(p)
        net=net1
        data=get_kfold_data(k,j,x_data,y_data)
        train_l,test_l=train_k_fold_data(net,num_epochs,lr,*data,batch_size,montum,wd)
        train_sum_l.append(train_l[-1])
        test_sum_l.append(test_l[-1])
        print('--------------------------------------------------------------------------')
        print('fold %d,train loss mean : %f,test loss : %f' % (j+1,train_l[-1],test_l[-1]))
        print('-------------------------------------------------------------------------')
    print('%d fold ,total train loss mean : %f,total test loss mean : %f ' % (k,np.mean(train_sum_l),np.mean(test_sum_l)))
    print('-----------------------------------------------------------------------------')

# %%
def get_net():
    return nn.Sequential(nn.Linear(train_features.shape[1],256),nn.ReLU(),nn.Linear(256,128),nn.ReLU(),nn.Linear(128,64),nn.ReLU(),nn.Linear(64,32),
                        nn.ReLU(),nn.Linear(32,1))
net1=get_net()
train_kfold(net1,100000,0.0001,5,train_features,train_labels,256,0,0)
# Out:
# epoch = 1 train_loss : 12.633021 , test loss : 12.640697
# epoch = 2 train_loss : 9.657457 , test loss : 9.664833
# epoch = 3 train_loss : 7.819559 , test loss : 7.827017
# epoch = 4 train_loss : 6.505435 , test loss : 6.513237
# epoch = 5 train_loss : 5.475049 , test loss : 5.483235
# epoch = 6 train_loss : 4.666697 , test loss : 4.675470
# epoch = 7 train_loss : 3.986810 , test loss : 3.996228
# epoch = 8 train_loss : 3.424311 , test loss : 3.434443
# epoch = 9 train_loss : 2.939010 , test loss : 2.949781
# epoch = 10 train_loss : 2.526063 , test loss : 2.537444
# epoch = 11 train_loss : 2.173831 , test loss : 2.185898
# epoch = 12 train_loss : 1.869921 , test loss : 1.882700
# epoch = 13 train_loss : 1.612511 , test loss : 1.625983
# epoch = 14 train_loss : 1.401232 , test loss : 1.415331
# epoch = 15 train_loss : 1.228104 , test loss : 1.242701
# epoch = 16 train_loss : 1.093461 , test loss : 1.108346
# epoch = 17 train_loss : 0.990293 , test loss : 1.005203
# epoch = 18 train_loss : 0.913469 , test loss : 0.928120
# epoch = 1261 train_loss : 0.283385 , test loss : 0.284137
# epoch = 1278 train_loss : 0.282931 , test loss : 0.283668
# epoch = 1280 train_loss : 0.281133 , test loss : 0.282067
# epoch = 1294 train_loss : 0.280010 , test loss : 0.280934
# epoch = 1317 train_loss : 0.279623 , test loss : 0.280835
# epoch = 1322 train_loss : 0.279337 , test loss : 0.280338
# epoch = 1324 train_loss : 0.278657 , test loss : 0.279981
# epoch = 1327 train_loss : 0.277340 , test loss : 0.278651
# epoch = 1332 train_loss : 0.275693 , test loss : 0.277279
# epoch = 1342 train_loss : 0.274747 , test loss : 0.276285
# epoch = 1358 train_loss : 0.274136 , test loss : 0.275864
# epoch = 1366 train_loss : 0.272689 , test loss : 0.274588
# epoch = 1372 train_loss : 0.272583 , test loss : 0.274468
# epoch = 1378 train_loss : 0.272436 , test loss : 0.274426
# epoch = 1381 train_loss : 0.272056 , test loss : 0.274109
# epoch = 1382 train_loss : 0.271539 , test loss : 0.273781
# epoch = 1388 train_loss : 0.271190 , test loss : 0.273292
# epoch = 1392 train_loss : 0.270414 , test loss : 0.272628
# epoch = 1393 train_loss : 0.269260 , test loss : 0.271430
# epoch = 1405 train_loss : 0.268618 , test loss : 0.271108
# epoch = 1407 train_loss : 0.267761 , test loss : 0.270339
# epoch = 1417 train_loss : 0.267549 , test loss : 0.270303
# epoch = 1430 train_loss : 0.266507 , test loss : 0.269064
# epoch = 1441 train_loss : 0.264502 , test loss : 0.267771
# epoch = 1460 train_loss : 0.263451 , test loss : 0.266875
# epoch = 1466 train_loss : 0.261510 , test loss : 0.265089
# epoch = 1516 train_loss : 0.260680 , test loss : 0.264281
# epoch = 1541 train_loss : 0.259688 , test loss : 0.263714
# epoch = 1552 train_loss : 0.258740 , test loss : 0.262894
# epoch = 1562 train_loss : 0.257802 , test loss : 0.262432
# epoch = 1569 train_loss : 0.257543 , test loss : 0.261981
# epoch = 1595 train_loss : 0.257652 , test loss : 0.261975
# epoch = 1604 train_loss : 0.256808 , test loss : 0.261566
# epoch = 1615 train_loss : 0.256393 , test loss : 0.260788
# epoch = 1617 train_loss : 0.256095 , test loss : 0.260448
# epoch = 1643 train_loss : 0.255334 , test loss : 0.259969
# epoch = 1677 train_loss : 0.254411 , test loss : 0.259166
# epoch = 1713 train_loss : 0.254383 , test loss : 0.258747
# epoch = 1753 train_loss : 0.253380 , test loss : 0.258654
# epoch = 1778 train_loss : 0.253252 , test loss : 0.258322
# epoch = 1784 train_loss : 0.253081 , test loss : 0.258168
# epoch = 1789 train_loss : 0.253422 , test loss : 0.258082
# epoch = 1804 train_loss : 0.252840 , test loss : 0.258056
# epoch = 1808 train_loss : 0.252195 , test loss : 0.257186
# epoch = 1836 train_loss : 0.253058 , test loss : 0.257111

# %%
def get_net():
    return nn.Sequential(nn.Linear(train_features.shape[1],128),nn.ReLU(),nn.Linear(128,64),nn.ReLU(),nn.Linear(64,32),nn.ReLU(),nn.Linear(32,1))
net1=get_net()
train_kfold(net1,100000,0.0002,5,train_features,train_labels,128,0,0)
