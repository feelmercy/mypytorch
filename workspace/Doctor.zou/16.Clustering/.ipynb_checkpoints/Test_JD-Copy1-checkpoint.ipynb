# %%
import datetime
import threading
import requests
def func():
    print("爬虫开始执行")
    getdata()
    print("爬虫执行完毕")
    #如果需要循环调用，就要添加以下方法
    timer = threading.Timer(1, func)
    timer.start()

# 获取现在时间
now_time = datetime.datetime.now()
# 获取时间
next_time = now_time + datetime.timedelta(days=+0)
next_year = next_time.date().year
next_month = next_time.date().month
next_day = next_time.date().day
# 获取定时时间
next_time = datetime.datetime.strptime(str(next_year)+"-"+str(next_month)+"-"+str(next_day)+" 18:00:00", "%Y-%m-%d %H:%M:%S")
print(next_time)


# 获取距离定时时间差，单位为秒
timer_start_time = (next_time - now_time).total_seconds()
print(timer_start_time)
# 54186.75975


#定时器,参数为(多少时间后执行，单位为秒，执行的方法)
timer = threading.Timer(timer_start_time, func)
timer.start()
#爬虫
def getdata():
    headers = {
        'origin': 'https://prodev.m.jd.com',
        'accept-encoding': 'gzip, deflate',
        'accept-language': 'zh-CN,zh;q=0.8',
        'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0',
        'content-type': 'application/x-www-form-urlencoded',
        'accept': '*/*',
        'referer': 'https://prodev.m.jd.com/mall/active/2KwUoULZwmV1bH4A98vzC9DedVeP/index.html',
        'authority': 'api.m.jd.com',
        'cookie': 'areaId=22; ipLoc-djd=22-1930-50947-0; user-key=bde17081-2ce4-4868-9f76-0c61a3c03a0e; TrackID=1WLOpyTxROw3Qe7tTB3G-lMHo0z2TZVXxYKRzmGv2P4EU5hfjmc1sCZdVVkrs5OpsAkbuVvo5XKpaO4RxiMysvA; pinId=NHuBB8jVT1T1jn8Eu3f9tA; pin=feelmercy; unick=simenwan; ceshi3.com=201; _tp=o7a4ozhcuG800e2%2B9AK3WA%3D%3D; _pst=feelmercy; autoOpenApp_downCloseDate_auto=1591780613317_21600000; thor=; cn=95; unpl=V2_ZzNtbREEFxwnDENQfhFUB2IBFw9KVRYVIQ1BBCseCwdnChRfclRCFnQUR1NnGV0UZwUZXUpcQxBFCEdkexhdBGYCEFpBU3NXK14YECdSbDVkAyJdQ2dDEX0IRFZ%2bH18AbwAQXUVWSxN3CEJVeSlsAlczIlxyVnMURUMoVTYZWA1nARBYRFRGHXYKRlN6EVoHZwcTX3JWcxY%3d; __jdv=76161171|123.sogou.com|t_1000003625_sogoumz|tuiguang|bbe8c5454993434c93d1e46aa6f31873|1591780749899; __jdu=15913347249231609731503; __jda=122270672.15913347249231609731503.1591334724.1591772186.1591779376.16; __jdb=122270672.15.15913347249231609731503|16.1591779376; __jdc=122270672; shshshfp=6510c4fa3f04220c1fd166a597e28f49; shshshsID=ba3308bceb12522958e80b35584be618_13_1591780767912; shshshfpa=e20af-1591334728%3B%20__jdu%3D15913347249231609731503; shshshfpb=cnfXPvp6xq6bG7IQRMMRkrQ%3D%3D; UM_distinctid=1729d86fb320-014c2a1c3f84e2-1571466f-1fa400-1729d86fb334d3; 3AB9D23F7A4B3C9B=3ONTI4QZ25TDQNSHLJ4DSXZYKSWNVRZAPW7S6B2A4ZROFAFWPUXQ6LU6ND4ATMATARWPS2BVWO5FYRW4NP6XQAEUJY; __jd_ref_cls=Babel_FreeCouponExpo; mba_sid=15917807670609005250249848962.1; mba_muid=15913347249231609731503',
    }

    params = (
        ('functionId', 'newBabelAwardCollection'),
    )

    data = {
        'body': '{"activityId":"2KwUoULZwmV1bH4A98vzC9DedVeP","scene":"1","args":"key=A6A601CC67E02D49CD6596A3A46561D5E9FA685EF4CB51C272C5106F4D4BDD2CAB2577C86334298926F4BF085640B80C_babel,roleId=F6CE3D733837E982E3C76A3B076D9217_babel","platform":"3","orgType":"2","openId":"-1","pageClickKey":"-1","eid":"3ONTI4QZ25TDQNSHLJ4DSXZYKSWNVRZAPW7S6B2A4ZROFAFWPUXQ6LU6ND4ATMATARWPS2BVWO5FYRW4NP6XQAEUJY","fp":"38f4c8a905b54b0c7b555c224f6f86ae","shshshfp":"6510c4fa3f04220c1fd166a597e28f49","shshshfpa":"e20af-1591334728; __jdu=15913347249231609731503","shshshfpb":"cnfXPvp6xq6bG7IQRMMRkrQ==","childActivityUrl":"https://prodev.m.jd.com/mall/active/2KwUoULZwmV1bH4A98vzC9DedVeP/index.html","pageClick":"Babel_Coupon","mitemAddrId":"","geo":{"lng":"","lat":""},"addressId":"","posLng":"","posLat":"","focus":"","innerAnchor":"","cv":"2.0"}',
        'screen': '750*1334',b
        'client': 'wh5',
        'clientVersion': '1.0.0',
        'sid': '',
        'uuid': '15913347249231609731503',
        'area': ''
    }

    response = requests.post('https://api.m.jd.com/client.action', headers=headers, params=params, data=data)
    for i in response:
#         print(i)
        print(i.decode(encoding = r"utf-8"))
        
#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.post('https://api.m.jd.com/client.action?functionId=newBabelAwardCollection', headers=headers, data=data)
# Out:
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}2020-06-10 18:00:00
# 爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -3.561774
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫开始执行爬虫开始执行
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
#
# 爬虫开始执行
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行
# 爬虫执行完毕爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
# 爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
# 爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# 爬虫执行完毕
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫开始执行爬虫开始执行爬虫执行完毕爬虫执行完毕爬虫开始执行爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫执行完毕
#
#
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫执行完毕
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫开始执行
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行
#
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫执行完毕
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# 爬虫执行完毕
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
# 爬虫执行完毕
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫开始执行
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫开始执行爬虫开始执行
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫执行完毕爬虫开始执行
#
#
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行
#
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫执行完毕
# 爬虫执行完毕
#
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
# 爬虫执行完毕爬虫执行完毕
#
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕爬虫执行完毕爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
# 爬虫执行完毕爬虫执行完毕
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"本时段优惠券已抢完，请19:00再来吧！","subCode":"D2","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
#
#
#
#
#
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫执行完毕
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
# 爬虫执行完毕
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫开始执行爬虫执行完毕
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
# 爬虫执行完毕爬虫开始执行
#
# 爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行
# 爬虫执行完毕
#
# 爬虫执行完毕
#
#
# 爬虫执行完毕爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行
#
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫执行完毕
#
#
# 爬虫执行完毕
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫执行完毕
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
# 爬虫开始执行爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕爬虫执行完毕
#
#
#
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫开始执行爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# 爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫开始执行
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
#
# 爬虫执行完毕爬虫执行完毕
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕爬虫执行完毕
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫开始执行爬虫开始执行爬虫开始执行
#
#
#
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
# 爬虫执行完毕
#
#
#
#
#
# 爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫执行完毕
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
# 爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
# 爬虫执行完毕
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# 爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}{"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕爬虫执行完毕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫开始执行爬虫执行完毕
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
#
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫执行完毕
#
# 爬虫执行完毕
# 爬虫开始执行
# {"subCodeMsg":"很抱歉，没抢到~","subCode":"A28","code":"0","msg":null}爬虫开始执行爬虫开始执行
