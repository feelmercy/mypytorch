# %%
import numpy as np
import torch 
import pandas as pd
import torchvision
from torch import optim,nn
import seaborn as sns
from scipy import stats
from scipy.stats import norm,skew,kurtosis
import matplotlib.pyplot as plt
# %matplotlib auto
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df = pd.read_csv(r'F:\study\ml\DataSet\beijinPM25\PRSA_data_2010.1.1-2014.12.31.csv')
df.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      43824 non-null  int64
#  1   year    43824 non-null  int64
#  2   month   43824 non-null  int64
#  3   day     43824 non-null  int64
#  4   hour    43824 non-null  int64
#  5   pm2.5   41757 non-null  float64
#  6   DEWP    43824 non-null  int64
#  7   TEMP    43824 non-null  float64
#  8   PRES    43824 non-null  float64
#  9   cbwd    43824 non-null  object
#  10  Iws     43824 non-null  float64
#  11  Is      43824 non-null  int64
#  12  Ir      43824 non-null  int64
# dtypes: float64(4), int64(8), object(1)
# memory usage: 4.3+ MB

# %%
df['pm2.5'].isna().sum()
# Out:
# 2067

# %%
df = df[24:].fillna(method='ffill')
df['pm2.5'].isna().sum()
# Out:
# 0

# %%
import datetime

# %%
df['time']=df.apply(lambda x : datetime.datetime(year=x['year'],month=x['month'],day=x['day'],hour=x['hour']),axis=1)
df.head()
# Out:
#     No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd   Iws  Is  Ir  \
# 24  25  2010      1    2     0  129.0   -16  -4.0  1020.0   SE  1.79   0   0
# 25  26  2010      1    2     1  148.0   -15  -4.0  1020.0   SE  2.68   0   0
# 26  27  2010      1    2     2  159.0   -11  -5.0  1021.0   SE  3.57   0   0
# 27  28  2010      1    2     3  181.0    -7  -5.0  1022.0   SE  5.36   1   0
# 28  29  2010      1    2     4  138.0    -7  -5.0  1022.0   SE  6.25   2   0
#
#                   time
# 24 2010-01-02 00:00:00
# 25 2010-01-02 01:00:00
# 26 2010-01-02 02:00:00
# 27 2010-01-02 03:00:00
# 28 2010-01-02 04:00:00

# %%
df.drop(columns=['year','month','day','hour','No'],inplace=True)
df=df.set_index('time')
df.head()
# Out:
#                      pm2.5  DEWP  TEMP    PRES cbwd   Iws  Is  Ir
# time
# 2010-01-02 00:00:00  129.0   -16  -4.0  1020.0   SE  1.79   0   0
# 2010-01-02 01:00:00  148.0   -15  -4.0  1020.0   SE  2.68   0   0
# 2010-01-02 02:00:00  159.0   -11  -5.0  1021.0   SE  3.57   0   0
# 2010-01-02 03:00:00  181.0    -7  -5.0  1022.0   SE  5.36   1   0
# 2010-01-02 04:00:00  138.0    -7  -5.0  1022.0   SE  6.25   2   0

# %%
df['cbwd'].unique()
# Out:
# array(['SE', 'cv', 'NW', 'NE'], dtype=object)

# %%
df=df.join(pd.get_dummies(df['cbwd']))
df.head()
# Out:
#                      pm2.5  DEWP  TEMP    PRES cbwd   Iws  Is  Ir  NE  NW  SE  \
# time
# 2010-01-02 00:00:00  129.0   -16  -4.0  1020.0   SE  1.79   0   0   0   0   1
# 2010-01-02 01:00:00  148.0   -15  -4.0  1020.0   SE  2.68   0   0   0   0   1
# 2010-01-02 02:00:00  159.0   -11  -5.0  1021.0   SE  3.57   0   0   0   0   1
# 2010-01-02 03:00:00  181.0    -7  -5.0  1022.0   SE  5.36   1   0   0   0   1
# 2010-01-02 04:00:00  138.0    -7  -5.0  1022.0   SE  6.25   2   0   0   0   1
#
#                      cv
# time
# 2010-01-02 00:00:00   0
# 2010-01-02 01:00:00   0
# 2010-01-02 02:00:00   0
# 2010-01-02 03:00:00   0
# 2010-01-02 04:00:00   0

# %%
df.drop(columns=['cbwd'],inplace=True)
df.head()
# Out:
#                      pm2.5  DEWP  TEMP    PRES   Iws  Is  Ir  NE  NW  SE  cv
# time
# 2010-01-02 00:00:00  129.0   -16  -4.0  1020.0  1.79   0   0   0   0   1   0
# 2010-01-02 01:00:00  148.0   -15  -4.0  1020.0  2.68   0   0   0   0   1   0
# 2010-01-02 02:00:00  159.0   -11  -5.0  1021.0  3.57   0   0   0   0   1   0
# 2010-01-02 03:00:00  181.0    -7  -5.0  1022.0  5.36   1   0   0   0   1   0
# 2010-01-02 04:00:00  138.0    -7  -5.0  1022.0  6.25   2   0   0   0   1   0

# %%
plt.plot(df['pm2.5'][-1000:])
plt.show()

# %%
df['pm2.5'][-1000:].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
seq_len=5*24
delay=1*24

# %%
df.shape
# Out:
# (43800, 11)

# %%
df_=np.array([df.iloc[i:i+seq_len+delay].values for i in range(len(df)-seq_len-delay)])
df_.shape
# Out:
# (43656, 144, 11)

# %%
np.random.shuffle(df_)
x=df_[:,:5*24,:]
y=df_[:,-1,0]
x.shape,y.shape
# Out:
# ((43656, 120, 11), (43656,))

# %%
split = int(y.shape[0]*0.8)
train_x = x[:split]
train_y = y[:split]
test_x = x[split:]
test_y = y[split:]

# %%
mean = train_x.mean(axis=0)
std = train_x.std(axis=0)
train_x = (train_x - mean) / std
test_x = (test_x - mean) / std

# %%
mean.shape
# Out:
# (120, 11)

# %%
x.shape,y.shape
# Out:
# ((43656, 120, 11), (43656,))

# %%
net=nn.Sequential(nn.Linear(1320,32),nn.ReLU(),nn.Linear(32,1))

# %%
net.state_dict
# Out:
# <bound method Module.state_dict of Sequential(
#   (0): Linear(in_features=1320, out_features=32, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=32, out_features=1, bias=True)
# )>

# %%
def train_k_fold_data(net,num_epochs,lr,train_features,train_labels,test_features,test_labels,batch_size,montum,wd):
#     net=nn.Linear(train_features.shape[1],1)
#     net=nn.Sequential(nn.Linear(train_features.shape[1],1))
    loss=nn.MSELoss()
#     optimizer=optim.SGD(net.parameters(),lr=lr,momentum=montum,weight_decay=wd)
    optimizer=optim.Adam(net.parameters(),lr=lr,weight_decay=wd)
    dataset=torch.utils.data.TensorDataset(train_features,train_labels)
    data_iter=torch.utils.data.DataLoader(dataset,batch_size,shuffle=True)
    train_l,test_l=[],[]
    
    min_test_loss=50000
    early_stop_cnt=0
    train_loss,test_loss=0,0
    
    for e in range(num_epochs):
        net.train()
        for x,y in data_iter:
            l=loss(net(x),y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
#         if (e+1) %1000==0 and test_features is not  None:
        net.eval()
        with torch.no_grad():
            test_loss=loss(net(test_features),test_labels).item()
            if test_loss<min_test_loss:
                min_test_loss=test_loss
#                 test_l.append(test_loss)
                train_loss=loss(net(train_features),train_labels).item()
                test_l.append(test_loss)
                train_l.append(train_loss)
                print('epoch = %d train_loss : %f , test loss : %f' % (e+1,train_loss,test_loss))
                early_stop_cnt=0
            else:
                early_stop_cnt+=1
        if early_stop_cnt > 500:
            
            break
                
#             net.eval()
#             with torch.no_grad():
#                 train_l.append(loss(net(train_features),train_labels).item())
#                 test_l.append(loss(net(test_features),test_labels).item())
# #                 print('epoch ',(e+1),'train loss : ',train_l[-1],'test loss : ',test_l[-1])

    return train_l,test_l

# %%
def get_kfold_data(k,j,x,y,random_state=13):
    assert k>=1, 'k must >=1'
    fold_size = x.shape[0] // k
    x_train,y_train=None,None
    row_list=list(range(x.shape[0]))
    np.random.seed(random_state)
    np.random.shuffle(row_list)
    for i in range(k):
        idx=slice(fold_size*i,fold_size*(i+1))
        x_part,y_part=x[row_list[idx],:],y[row_list[idx],:]
        if i==j:
            x_val,y_val=x_part,y_part
        elif x_train is None:
            x_train,y_train=x_part,y_part
        else:
            x_train=torch.cat((x_train,x_part))
            y_train=torch.cat((y_train,y_part))
    return x_train,y_train,x_val,y_val

# %%
def train_kfold(net1,num_epochs,lr,k,x_data,y_data,batch_size,montum,wd):
    train_sum_l,test_sum_l=[],[]
    train_l,test_l=[],[]
#     net=nn.Linear(x_data.shape[1])
    for j in range(k):
        net1=get_net()
#         for p in net1.parameters():
#             torch.nn.init.normal_(p)
        net=net1
        data=get_kfold_data(k,j,x_data,y_data)
        train_l,test_l=train_k_fold_data(net,num_epochs,lr,*data,batch_size,montum,wd)
        train_sum_l.append(train_l[-1])
        test_sum_l.append(test_l[-1])
        print('--------------------------------------------------------------------------')
        print('fold %d,train loss mean : %f,test loss : %f' % (j+1,train_l[-1],test_l[-1]))
        print('-------------------------------------------------------------------------')
    print('%d fold ,total train loss mean : %f,total test loss mean : %f ' % (k,np.mean(train_sum_l),np.mean(test_sum_l)))
    print('-----------------------------------------------------------------------------')

# %%
def train_k_fold_data(net,num_epochs,lr,train_features,train_labels,test_features,test_labels,batch_size,montum,wd):

# %%
train_x.shape
# Out:
# (34924, 120, 11)

# %%
train_features=torch.Tensor(train_x.reshape(train_x.shape[0],-1))
train_labels=torch.Tensor(train_y.reshape(train_y.shape[0],-1))
test_features=torch.Tensor(test_x.reshape(test_x.shape[0],-1))
test_label=torch.Tensor(test_y.reshape(test_y.shape[0],-1))

# %%
net=nn.Sequential(nn.Linear(1320,32),nn.ReLU(),nn.Linear(32,1))
train_l,test_l=train_k_fold_data(net,50,0.001,train_features,train_labels,test_features,test_label,128,0,0)
# Out:
# epoch = 1 train_loss : 8403.296875 , test loss : 8438.263672
# epoch = 2 train_loss : 7487.285645 , test loss : 7552.664551
# epoch = 3 train_loss : 7035.862793 , test loss : 7152.354980
# epoch = 4 train_loss : 6732.287109 , test loss : 6885.092773
# epoch = 5 train_loss : 6538.276367 , test loss : 6733.839844
# epoch = 6 train_loss : 6358.506836 , test loss : 6583.605957
# epoch = 7 train_loss : 6243.080566 , test loss : 6503.300781
# epoch = 8 train_loss : 6120.350586 , test loss : 6416.171387
# epoch = 9 train_loss : 6041.989258 , test loss : 6370.854004
# epoch = 10 train_loss : 5961.003418 , test loss : 6344.894043
# epoch = 11 train_loss : 5879.475098 , test loss : 6273.316895
# epoch = 12 train_loss : 5839.708496 , test loss : 6247.293457
# epoch = 13 train_loss : 5764.096680 , test loss : 6200.216309
# epoch = 14 train_loss : 5702.664062 , test loss : 6158.218750
# epoch = 16 train_loss : 5596.700684 , test loss : 6095.931641
# epoch = 17 train_loss : 5534.546387 , test loss : 6046.288086
# epoch = 18 train_loss : 5482.853516 , test loss : 6021.100098
# epoch = 19 train_loss : 5443.459961 , test loss : 6000.719727
# epoch = 20 train_loss : 5374.105957 , test loss : 5954.509766
# epoch = 21 train_loss : 5321.797363 , test loss : 5924.181152
# epoch = 22 train_loss : 5267.373047 , test loss : 5904.224609
# epoch = 23 train_loss : 5206.290039 , test loss : 5844.669922
# epoch = 25 train_loss : 5120.137207 , test loss : 5821.014160
# epoch = 26 train_loss : 5046.864746 , test loss : 5784.581543
# epoch = 27 train_loss : 4989.798340 , test loss : 5736.498047
# epoch = 28 train_loss : 4937.403809 , test loss : 5702.611328
# epoch = 30 train_loss : 4847.187988 , test loss : 5663.219727
# epoch = 31 train_loss : 4799.266113 , test loss : 5639.209961
# epoch = 32 train_loss : 4763.729004 , test loss : 5625.781738
# epoch = 33 train_loss : 4737.489746 , test loss : 5611.426758
# epoch = 34 train_loss : 4652.269043 , test loss : 5545.979004
# epoch = 36 train_loss : 4577.581055 , test loss : 5528.763672
# epoch = 37 train_loss : 4530.883301 , test loss : 5476.593262
# epoch = 38 train_loss : 4490.155762 , test loss : 5465.261719
# epoch = 39 train_loss : 4427.505371 , test loss : 5435.323730
# epoch = 40 train_loss : 4390.086914 , test loss : 5406.687500
# epoch = 41 train_loss : 4342.851074 , test loss : 5392.319824
# epoch = 42 train_loss : 4310.879883 , test loss : 5384.105469
# epoch = 44 train_loss : 4230.467773 , test loss : 5349.188965
# epoch = 45 train_loss : 4192.997070 , test loss : 5311.767578
# epoch = 47 train_loss : 4106.916504 , test loss : 5294.368652
# epoch = 48 train_loss : 4096.336426 , test loss : 5290.981445
# epoch = 49 train_loss : 4040.034912 , test loss : 5261.019043
# epoch = 50 train_loss : 3990.584473 , test loss : 5227.615723

# %%
train_x.shape
# Out:
# (34924, 120, 11)

# %%
class LSTM_Reg(nn.Module):
    def __init__(self,input_size,hidden_size,output_size,layer_size=2):
        super().__init__()
        self.lstm_net=nn.LSTM(input_size=input_size,hidden_size=hidden_size,num_layers=layer_size)
        self.dense=nn.Linear(hidden_size,output_size)
        self.state=None
    
    def forward(self,x,state):
#         x=x.reshape(x.shape[0],-1)
        y,self.state=self.lstm_net(x,state)
        output=self.dense(y.view(-1,y.shape[-1]))
        return output,self.state

# %%
net2=LSTM_Reg(1320,32,1,2)
net2.state_dict
# Out:
# <bound method Module.state_dict of LSTM_Reg(
#   (lstm_net): LSTM(1320, 32, num_layers=2)
#   (dense): Linear(in_features=32, out_features=1, bias=True)
# )>

# %%
def train_k_fold_data_lstm(net,num_epochs,lr,train_features,train_labels,test_features,test_labels,batch_size,montum,wd):
#     net=nn.Linear(train_features.shape[1],1)
#     net=nn.Sequential(nn.Linear(train_features.shape[1],1))
    loss=nn.L1Loss()
#     optimizer=optim.SGD(net.parameters(),lr=lr,momentum=montum,weight_decay=wd)
    optimizer=optim.Adam(net.parameters(),lr=lr,weight_decay=wd)
    dataset=torch.utils.data.TensorDataset(train_features,train_labels)
    data_iter=torch.utils.data.DataLoader(dataset,batch_size,shuffle=True,drop_last=True)
    train_l,test_l=[],[]
    state=None
    
    min_test_loss=50000
    early_stop_cnt=0
    train_loss,test_loss=0,0
    
    for e in range(num_epochs):
        test_loss_list,train_loss_list=[],[]
        net.train()
        for x,y in data_iter:
            if state is not None:
                if isinstance(state,tuple):
                    state=(state[0].detach(),state[1].detach())
                else:
                    state=state.detach()
                    
            x=x.unsqueeze(dim=0)
            (output,state)=net(x,state)
            
            l=loss(output,y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
#             train_loss_list.append(l.item())
#       if (e+1) %1000==0 and test_features is not  None:
        net.eval()
        
        with torch.no_grad():
            dataset_train=torch.utils.data.TensorDataset(train_features,train_labels)
            data_iter_train=torch.utils.data.DataLoader(dataset_train,batch_size,shuffle=True,drop_last=True)
            
            dataset_test=torch.utils.data.TensorDataset(test_features,test_labels)
            data_iter_test=torch.utils.data.DataLoader(dataset_test,batch_size,shuffle=True,drop_last=True)
            
            for xx_test,yy_test in data_iter_test:
                xx_test=xx_test.unsqueeze(dim=0)
                (output_test,state)=net(xx_test,state)
                test_loss_list.append(loss(output_test,yy_test).item())
            test_loss=np.mean(test_loss_list)

            if test_loss<min_test_loss:
                min_test_loss=test_loss
                test_l.append(test_loss)
                for xx_train,yy_train in data_iter_train:
                    xx_train=xx_train.unsqueeze(dim=0)
                    (output_train,state)=net(xx_train,state)
                    train_loss_list.append(loss(output_train,yy_train).item())

                train_loss=np.mean(train_loss_list)
                
                test_l.append(test_loss)
                train_l.append(train_loss)
                print('epoch = %d train_loss : %f , test loss : %f' % (e+1,train_loss,test_loss))
                early_stop_cnt=0
            else:
                early_stop_cnt+=1
        if early_stop_cnt > 500:
            
            break
                
#             net.eval()
#             with torch.no_grad():
#                 train_l.append(loss(net(train_features),train_labels).item())
#                 test_l.append(loss(net(test_features),test_labels).item())
# #                 print('epoch ',(e+1),'train loss : ',train_l[-1],'test loss : ',test_l[-1])

    return train_l,test_l

# %%
net2=LSTM_Reg(1320,32,1,2)
train_l,test_l=train_k_fold_data_lstm(net2,150,0.01,train_features,train_labels,test_features,test_label,128,0,0)
# Out:
# epoch = 1 train_loss : 66.130819 , test loss : 65.253023
# epoch = 2 train_loss : 62.790143 , test loss : 62.144419
# epoch = 3 train_loss : 60.447237 , test loss : 60.343245
# epoch = 4 train_loss : 58.886456 , test loss : 59.222537
# epoch = 5 train_loss : 58.306775 , test loss : 59.062068
# epoch = 6 train_loss : 57.186980 , test loss : 57.939048
# epoch = 7 train_loss : 55.942257 , test loss : 56.715147
# epoch = 8 train_loss : 54.962582 , test loss : 55.920742
# epoch = 9 train_loss : 54.404262 , test loss : 55.658629
# epoch = 11 train_loss : 53.443366 , test loss : 54.986903
# epoch = 12 train_loss : 52.804585 , test loss : 54.249227
# epoch = 13 train_loss : 51.877995 , test loss : 53.858424
# epoch = 15 train_loss : 51.457012 , test loss : 53.626543
# epoch = 16 train_loss : 50.454840 , test loss : 53.023750
# epoch = 18 train_loss : 49.279906 , test loss : 52.044019
# epoch = 19 train_loss : 49.066283 , test loss : 51.998038
# epoch = 20 train_loss : 49.262209 , test loss : 51.973593
# epoch = 21 train_loss : 48.139154 , test loss : 51.176947
# epoch = 22 train_loss : 48.220324 , test loss : 50.997213
# epoch = 23 train_loss : 47.443760 , test loss : 50.864412
# epoch = 24 train_loss : 47.216373 , test loss : 49.895902
# epoch = 27 train_loss : 46.113820 , test loss : 49.709866
# epoch = 28 train_loss : 45.273637 , test loss : 49.441172
# epoch = 29 train_loss : 44.924504 , test loss : 49.049933
# epoch = 31 train_loss : 44.603556 , test loss : 48.878161
# epoch = 32 train_loss : 44.170549 , test loss : 48.861202
# epoch = 35 train_loss : 43.449196 , test loss : 47.976791
# epoch = 37 train_loss : 43.049468 , test loss : 47.905645
# epoch = 38 train_loss : 42.195910 , test loss : 47.311590
# epoch = 40 train_loss : 42.189227 , test loss : 47.224478
# epoch = 41 train_loss : 41.800281 , test loss : 46.818990
# epoch = 42 train_loss : 41.559886 , test loss : 46.749525
# epoch = 43 train_loss : 41.092303 , test loss : 46.475782
# epoch = 45 train_loss : 40.918676 , test loss : 46.221565
# epoch = 48 train_loss : 40.426328 , test loss : 46.033904
# epoch = 52 train_loss : 40.200153 , test loss : 45.956366
# epoch = 54 train_loss : 39.685072 , test loss : 45.940802
# epoch = 55 train_loss : 39.038621 , test loss : 45.022581
# epoch = 56 train_loss : 38.271541 , test loss : 44.839247
# epoch = 59 train_loss : 37.735319 , test loss : 44.561316
# epoch = 69 train_loss : 36.930328 , test loss : 44.179535
# epoch = 70 train_loss : 37.130457 , test loss : 44.017027
# epoch = 76 train_loss : 36.226556 , test loss : 43.518106
# epoch = 85 train_loss : 36.012658 , test loss : 42.882282
# epoch = 97 train_loss : 34.643693 , test loss : 42.628932
# epoch = 98 train_loss : 34.392649 , test loss : 42.600652
# epoch = 102 train_loss : 34.504461 , test loss : 42.572627
# epoch = 112 train_loss : 33.373009 , test loss : 41.711783
# epoch = 125 train_loss : 32.027469 , test loss : 41.671038
# epoch = 126 train_loss : 31.728737 , test loss : 41.265406
# epoch = 144 train_loss : 31.973361 , test loss : 41.171546
# epoch = 146 train_loss : 31.279654 , test loss : 40.898604

# %%
class LSTM_Reg3(nn.Module):
    def __init__(self,input_size,hidden_size,output_size,layer_size=1):
        super().__init__()
        self.lstm_net1=nn.LSTM(input_size=input_size,hidden_size=100,num_layers=layer_size,dropout=0.3)
        self.lstm_net2=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
#         self.lstm_net3=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
#         self.lstm_net4=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
        self.dense1=nn.Linear(100,50)
        self.dense2=nn.Linear(50,1)
        self.h=None
        self.c=None
    
    def forward(self,x,h,c):
#         x=x.reshape(x.shape[0],-1)
        y,self.h,self.c=self.lstm_net1(x,(h,c))
        y=self.dense1(y.reshape(-1,y.shape[-1]))
        self.h=self.dense1(self.h.reshape(-1,self.h.shape[-1]))
        self.h=self.dense1(self.c.reshape(-1,self.c.shape[-1]))
        y=y.unsqueeze(dim=0)
        self.h=self.h.unsqueeze(dim=0)
        self.c=self.c.unsqueeze(dim=0)
        y,(self.h,self.c)=self.lstm_net2(y,(self.h,self.c))
        output=self.dense2(y.view(-1,y.shape[-1]))
        return output,(self.h,self.c)

# %%
class LSTM_Reg4(nn.Module):
    def __init__(self,input_size,hidden_size,output_size,layer_size=1):
        super().__init__()
        self.lstm_net1=nn.LSTM(input_size=input_size,hidden_size=100,num_layers=layer_size,dropout=0.3)
        self.lstm_net2=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
        self.lstm_net3=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
        self.lstm_net4=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
        self.dense1=nn.Linear(100,50)
        self.dense2=nn.Linear(50,1)
        self.state=None
    
    def forward(self,x,state):
#         x=x.reshape(x.shape[0],-1)
        y,self.state=self.lstm_net1(x,state)
        y=self.dense1(y.reshape(-1,y.shape[-1]))
        self.state[0]=self.dense1(self.state[0].reshape(-1,self.state[0].shape[-1]))
        self.state[1]=self.dense1(self.state[1].reshape(-1,self.state[1].shape[-1]))
        y=y.unsqueeze(dim=0)
        self.state[0]=self.state[0].unsqueeze(dim=0)
        self.state[1]=self.state[1].unsqueeze(dim=0)
        y,self.state=self.lstm_net2(y,self.state)
        output=self.dense2(y.view(-1,y.shape[-1]))
        return output,self.state

# %%
net1=LSTM_Reg3(1320,100,1,1)
net1.state_dict
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# <bound method Module.state_dict of LSTM_Reg3(
#   (lstm_net1): LSTM(1320, 100, dropout=0.3)
#   (lstm_net2): LSTM(1320, 50, dropout=0.2)
#   (dense1): Linear(in_features=100, out_features=50, bias=True)
#   (dense2): Linear(in_features=50, out_features=1, bias=True)
# )>

# %%
net4=LSTM_Reg3(1320,32,1,1)
train_l,test_l=train_k_fold_data_lstm(net4,150,0.01,train_features,train_labels,test_features,test_label,64,0,0)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-b665b0c877d0> in <module>()
#       1 net4=LSTM_Reg3(1320,32,1,1)
# ----> 2 train_l,test_l=train_k_fold_data_lstm(net4,150,0.01,train_features,train_labels,test_features,test_label,64,0,0)
#
# <ipython-input-77-9a8398b4c9ce> in train_k_fold_data_lstm(net, num_epochs, lr, train_features, train_labels, test_features, test_labels, batch_size, montum, wd)
#      25
#      26             x=x.unsqueeze(dim=0)
# ---> 27             (output,state)=net(x,state)
#      28
#      29             l=loss(output,y)
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# TypeError: forward() missing 1 required positional argument: 'c'

# %%
class LSTM_Reg5(nn.Module):
    def __init__(self,input_size,hidden_size,output_size,layer_size=1):
        super().__init__()
        self.lstm_net1=nn.LSTM(input_size=input_size,hidden_size=100,num_layers=layer_size,dropout=0.3)
        self.lstm_net2=nn.LSTM(input_size=100,hidden_size=50,num_layers=layer_size,dropout=0.2)
#         self.lstm_net3=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
#         self.lstm_net4=nn.LSTM(input_size=input_size,hidden_size=50,num_layers=layer_size,dropout=0.2)
        self.dense1=nn.Linear(100,50)
        self.dense11=nn.Linear(50,100)
        self.dense2=nn.Linear(50,1)
        self.h=None
        self.c=None
    
    def forward(self,x,h,c):
#         x=x.reshape(x.shape[0],-1)if h is None:
        if h is None:
            y,(self.h,self.c)=self.lstm_net1(x,None)
        else:
            y,(self.h,self.c)=self.lstm_net1(x,(h,c))
#         y,self.h,self.c=self.lstm_net1(x,(h,c))
#         y=self.dense1(y.reshape(-1,y.shape[-1]))
        self.h=self.dense1(self.h.reshape(-1,self.h.shape[-1]))
        self.c=self.dense1(self.c.reshape(-1,self.c.shape[-1]))
#         y=y.unsqueeze(dim=0)
        self.h=self.h.unsqueeze(dim=0)
        self.c=self.c.unsqueeze(dim=0)
        print('y.shape ',y.shape)
        print('h.shape ',self.h.shape)
        print('c.shape ',self.c.shape)
        y,(self.h,self.c)=self.lstm_net2(y,(self.h,self.c))
        output=self.dense2(y.view(-1,y.shape[-1]))
        self.h=self.dense11(self.h)
        self.c=self.dense11(self.c)
        return output,self.h,self.c

# %%
def train_k_fold_data_lstm(net,num_epochs,lr,train_features,train_labels,test_features,test_labels,batch_size,montum,wd):
#     net=nn.Linear(train_features.shape[1],1)
#     net=nn.Sequential(nn.Linear(train_features.shape[1],1))
    loss=nn.L1Loss()
#     optimizer=optim.SGD(net.parameters(),lr=lr,momentum=montum,weight_decay=wd)
    optimizer=optim.Adam(net.parameters(),lr=lr,weight_decay=wd)
    dataset=torch.utils.data.TensorDataset(train_features,train_labels)
    data_iter=torch.utils.data.DataLoader(dataset,batch_size,shuffle=True,drop_last=True)
    train_l,test_l=[],[]
    h,c=None,None
    
    min_test_loss=50000
    early_stop_cnt=0
    train_loss,test_loss=0,0
    
    for e in range(num_epochs):
        test_loss_list,train_loss_list=[],[]
        net.train()
        for x,y in data_iter:
            i=1
            if h is not None:
                h=h.detach()
                c=c.detach()   
            x=x.unsqueeze(dim=0)
            output,h,c=net(x,h,c)
            
            l=loss(output,y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            print(i)
            i=i+1
#             train_loss_list.append(l.item())
#       if (e+1) %1000==0 and test_features is not  None:
        net.eval()
        
        with torch.no_grad():
            dataset_train=torch.utils.data.TensorDataset(train_features,train_labels)
            data_iter_train=torch.utils.data.DataLoader(dataset_train,batch_size,shuffle=True,drop_last=True)
            
            dataset_test=torch.utils.data.TensorDataset(test_features,test_labels)
            data_iter_test=torch.utils.data.DataLoader(dataset_test,batch_size,shuffle=True,drop_last=True)
            
            for xx_test,yy_test in data_iter_test:
                xx_test=xx_test.unsqueeze(dim=0)
                (output_test,h,c)=net(xx_test,h,c)
                test_loss_list.append(loss(output_test,yy_test).item())
            test_loss=np.mean(test_loss_list)

            if test_loss<min_test_loss:
                min_test_loss=test_loss
                test_l.append(test_loss)
                for xx_train,yy_train in data_iter_train:
                    xx_train=xx_train.unsqueeze(dim=0)
                    (output_train,h,c)=net(xx_train,h,c)
                    train_loss_list.append(loss(output_train,yy_train).item())

                train_loss=np.mean(train_loss_list)
                
                test_l.append(test_loss)
                train_l.append(train_loss)
                print('epoch = %d train_loss : %f , test loss : %f' % (e+1,train_loss,test_loss))
                early_stop_cnt=0
            else:
                early_stop_cnt+=1
        if early_stop_cnt > 500:
            
            break
                
#             net.eval()
#             with torch.no_grad():
#                 train_l.append(loss(net(train_features),train_labels).item())
#                 test_l.append(loss(net(test_features),test_labels).item())
# #                 print('epoch ',(e+1),'train loss : ',train_l[-1],'test loss : ',test_l[-1])

    return train_l,test_l

# %%
net3=LSTM_Reg5(1320,32,1,1)
train_l,test_l=train_k_fold_data_lstm(net3,150,0.01,train_features,train_labels,test_features,test_label,64,0,0)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.3 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:60: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# ...
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# y.shape  torch.Size([1, 64, 100])
# h.shape  torch.Size([1, 64, 50])
# c.shape  torch.Size([1, 64, 50])
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-5817c6895988> in <module>()
#       1 net3=LSTM_Reg5(1320,32,1,1)
# ----> 2 train_l,test_l=train_k_fold_data_lstm(net3,150,0.01,train_features,train_labels,test_features,test_label,64,0,0)
#
# <ipython-input-142-b5b04fe36d57> in train_k_fold_data_lstm(net, num_epochs, lr, train_features, train_labels, test_features, test_labels, batch_size, montum, wd)
#      23                 c=c.detach()
#      24             x=x.unsqueeze(dim=0)
# ---> 25             output,h,c=net(x,h,c)
#      26
#      27             l=loss(output,y)
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-141-ecdf52bb31d2> in forward(self, x, h, c)
#      17             y,(self.h,self.c)=self.lstm_net1(x,None)
#      18         else:
# ---> 19             y,(self.h,self.c)=self.lstm_net1(x,(h,c))
#      20 #         y,self.h,self.c=self.lstm_net1(x,(h,c))
#      21 #         y=self.dense1(y.reshape(-1,y.shape[-1]))
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#     575         if batch_sizes is None:
#     576             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 577                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     578         else:
#     579             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:
