# %%
#encoding=utf=8
from gensim.models import word2vec
from gensim.models import Word2Vec
import pandas as pd
import numpy as np
import os.path
import re
import jieba
from gensim.models.word2vec import LineSentence

finput=open('F:\\study\\ml\\DataSet\\Sogou_New_Data\\news_tensite_xml.smarty\\word_segment.txt',encoding='utf-8')
foutput=open('F:\\study\\ml\\DataSet\\Sogou_New_Data\\news_tensite_xml.smarty\\corpus.txt','w',encoding='utf-8')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
  space = " "
  i = 0

# %%
for line in finput:
    line_seg=jieba.cut(line)
    foutput.write(space.join(line_seg))
    i=i+1
    if (i % 1000 == 0):
        print("Saved " + str(i) + " articles_seg")
finput.close()
foutput.close()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.911 seconds.
# Prefix dict has been built succesfully.

# %%
inp=open('F:\\study\\ml\\DataSet\\Sogou_New_Data\\news_tensite_xml.smarty\\corpus.txt',encoding='utf-8')

# %%
model=Word2Vec(LineSentence(inp),size=400,window=5,min_count=5,workers=4)

# %%
result = model.most_similar(u'部门')
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
for word in result:
    print(word[0],word[1])
    
inp.close()
# Out:
# 和 0.9999815821647644
# 已 0.9999808669090271
# 会 0.9999796152114868
# 进行 0.9999790191650391
# 企业 0.9999783039093018
# 并 0.9999780654907227
# 而 0.9999780058860779
# 通过 0.9999774694442749
# 需求 0.9999774098396301
# 一个 0.999976634979248

# %%
len(model.wv.vocab)
# Out:
# 1625

# %%
model.wv.vocab
# Out:
# {'６': <gensim.models.keyedvectors.Vocab at 0x59acf60>,
#  '月': <gensim.models.keyedvectors.Vocab at 0x59acd30>,
#  '１': <gensim.models.keyedvectors.Vocab at 0x59acc50>,
#  '２': <gensim.models.keyedvectors.Vocab at 0x59accc0>,
#  '日': <gensim.models.keyedvectors.Vocab at 0x571ebe0>,
#  '消息': <gensim.models.keyedvectors.Vocab at 0x571eb38>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x571eb70>,
#  '记者': <gensim.models.keyedvectors.Vocab at 0x571e390>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x1250b0b8>,
#  '据': <gensim.models.keyedvectors.Vocab at 0x1250b080>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x1250b048>,
#  '《': <gensim.models.keyedvectors.Vocab at 0x1250b0f0>,
#  '新闻': <gensim.models.keyedvectors.Vocab at 0x1250b128>,
#  '晚': <gensim.models.keyedvectors.Vocab at 0x1250b160>,
#  '高峰': <gensim.models.keyedvectors.Vocab at 0x1250b198>,
#  '》': <gensim.models.keyedvectors.Vocab at 0x1250b1d0>,
#  '报道': <gensim.models.keyedvectors.Vocab at 0x1250b208>,
#  '，': <gensim.models.keyedvectors.Vocab at 0x1250b240>,
#  '今天': <gensim.models.keyedvectors.Vocab at 0x1250b278>,
#  '上午': <gensim.models.keyedvectors.Vocab at 0x1250b320>,
#  '０': <gensim.models.keyedvectors.Vocab at 0x1250b2b0>,
#  '专项': <gensim.models.keyedvectors.Vocab at 0x1250bc18>,
#  '行动': <gensim.models.keyedvectors.Vocab at 0x1250b2e8>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1250bb38>,
#  '统一': <gensim.models.keyedvectors.Vocab at 0x1250ba90>,
#  '销毁': <gensim.models.keyedvectors.Vocab at 0x1250bba8>,
#  '非法': <gensim.models.keyedvectors.Vocab at 0x1250ba58>,
#  '物品': <gensim.models.keyedvectors.Vocab at 0x1250b3c8>,
#  '活动': <gensim.models.keyedvectors.Vocab at 0x1250bc88>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1250bcc0>,
#  '在': <gensim.models.keyedvectors.Vocab at 0x1250bb00>,
#  '正式': <gensim.models.keyedvectors.Vocab at 0x1250bc50>,
#  '启动': <gensim.models.keyedvectors.Vocab at 0x1250bbe0>,
#  '枪支': <gensim.models.keyedvectors.Vocab at 0x1250bac8>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x1250bb70>,
#  '５': <gensim.models.keyedvectors.Vocab at 0x1250bcf8>,
#  '全国': <gensim.models.keyedvectors.Vocab at 0x1250bd30>,
#  '个': <gensim.models.keyedvectors.Vocab at 0x1250bd68>,
#  '城市': <gensim.models.keyedvectors.Vocab at 0x1250bda0>,
#  '被': <gensim.models.keyedvectors.Vocab at 0x1250bdd8>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x1250be10>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x1250be48>,
#  '现在': <gensim.models.keyedvectors.Vocab at 0x1250be80>,
#  '我': <gensim.models.keyedvectors.Vocab at 0x1250beb8>,
#  '宣布': <gensim.models.keyedvectors.Vocab at 0x1250bef0>,
#  '开始': <gensim.models.keyedvectors.Vocab at 0x1250bf28>,
#  '！': <gensim.models.keyedvectors.Vocab at 0x1250bf60>,
#  '随着': <gensim.models.keyedvectors.Vocab at 0x1250bf98>,
#  '公安部': <gensim.models.keyedvectors.Vocab at 0x1250bfd0>,
#  '副': <gensim.models.keyedvectors.Vocab at 0x16adb048>,
#  '大量': <gensim.models.keyedvectors.Vocab at 0x16adb080>,
#  '以及': <gensim.models.keyedvectors.Vocab at 0x16adb0b8>,
#  '与此同时': <gensim.models.keyedvectors.Vocab at 0x16adb0f0>,
#  '各': <gensim.models.keyedvectors.Vocab at 0x16adb128>,
#  '和': <gensim.models.keyedvectors.Vocab at 0x16adb160>,
#  '群众': <gensim.models.keyedvectors.Vocab at 0x16adb198>,
#  '主动': <gensim.models.keyedvectors.Vocab at 0x16adb1d0>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x16adb208>,
#  '集中': <gensim.models.keyedvectors.Vocab at 0x16adb240>,
#  '指定': <gensim.models.keyedvectors.Vocab at 0x16adb278>,
#  '场所': <gensim.models.keyedvectors.Vocab at 0x16adb2b0>,
#  '分别': <gensim.models.keyedvectors.Vocab at 0x16adb2e8>,
#  '介绍': <gensim.models.keyedvectors.Vocab at 0x16adb320>,
#  '三个': <gensim.models.keyedvectors.Vocab at 0x16adb358>,
#  '方面': <gensim.models.keyedvectors.Vocab at 0x16adb390>,
#  '打击': <gensim.models.keyedvectors.Vocab at 0x16adb3c8>,
#  '包括': <gensim.models.keyedvectors.Vocab at 0x16adb400>,
#  '犯罪': <gensim.models.keyedvectors.Vocab at 0x16adb438>,
#  '还有': <gensim.models.keyedvectors.Vocab at 0x16adb470>,
#  '从': <gensim.models.keyedvectors.Vocab at 0x16adb4a8>,
#  '境外': <gensim.models.keyedvectors.Vocab at 0x16adb4e0>,
#  '走私': <gensim.models.keyedvectors.Vocab at 0x16adb518>,
#  '现场': <gensim.models.keyedvectors.Vocab at 0x16adb550>,
#  '看到': <gensim.models.keyedvectors.Vocab at 0x16adb588>,
#  '了': <gensim.models.keyedvectors.Vocab at 0x16adb5c0>,
#  '也': <gensim.models.keyedvectors.Vocab at 0x16adb5f8>,
#  '制式': <gensim.models.keyedvectors.Vocab at 0x16adb630>,
#  '按照': <gensim.models.keyedvectors.Vocab at 0x16adb668>,
#  '我国': <gensim.models.keyedvectors.Vocab at 0x16adb6a0>,
#  '这些': <gensim.models.keyedvectors.Vocab at 0x16adb6d8>,
#  '都': <gensim.models.keyedvectors.Vocab at 0x16adb710>,
#  '是': <gensim.models.keyedvectors.Vocab at 0x16adb748>,
#  '个人': <gensim.models.keyedvectors.Vocab at 0x16adb780>,
#  '持有': <gensim.models.keyedvectors.Vocab at 0x16adb7b8>,
#  '世界': <gensim.models.keyedvectors.Vocab at 0x16adb7f0>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x16adb828>,
#  '最低': <gensim.models.keyedvectors.Vocab at 0x16adb860>,
#  '国家': <gensim.models.keyedvectors.Vocab at 0x16adb898>,
#  '之一': <gensim.models.keyedvectors.Vocab at 0x16adb8d0>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x16adb908>,
#  '美': <gensim.models.keyedvectors.Vocab at 0x16adb940>,
#  '跨国': <gensim.models.keyedvectors.Vocab at 0x16adb978>,
#  '武器弹药': <gensim.models.keyedvectors.Vocab at 0x16adb9b0>,
#  '案': <gensim.models.keyedvectors.Vocab at 0x16adb9e8>,
#  '近日': <gensim.models.keyedvectors.Vocab at 0x16adba20>,
#  '执法': <gensim.models.keyedvectors.Vocab at 0x16adba58>,
#  '部门': <gensim.models.keyedvectors.Vocab at 0x16adba90>,
#  '成功': <gensim.models.keyedvectors.Vocab at 0x16adbac8>,
#  '抓获': <gensim.models.keyedvectors.Vocab at 0x16adbb00>,
#  '嫌疑人': <gensim.models.keyedvectors.Vocab at 0x16adbb38>,
#  '３': <gensim.models.keyedvectors.Vocab at 0x16adbb70>,
#  '名': <gensim.models.keyedvectors.Vocab at 0x16adbba8>,
#  '缴获': <gensim.models.keyedvectors.Vocab at 0x16adbbe0>,
#  '各类': <gensim.models.keyedvectors.Vocab at 0x16adbc18>,
#  '９': <gensim.models.keyedvectors.Vocab at 0x16adbc50>,
#  '支': <gensim.models.keyedvectors.Vocab at 0x16adbc88>,
#  '配件': <gensim.models.keyedvectors.Vocab at 0x16adbcc0>,
#  '美国': <gensim.models.keyedvectors.Vocab at 0x16adbcf8>,
#  '这是': <gensim.models.keyedvectors.Vocab at 0x16adbd30>,
#  '与': <gensim.models.keyedvectors.Vocab at 0x16adbd68>,
#  '海关': <gensim.models.keyedvectors.Vocab at 0x16adbda0>,
#  '通过': <gensim.models.keyedvectors.Vocab at 0x16adbdd8>,
#  '联合': <gensim.models.keyedvectors.Vocab at 0x16adbe10>,
#  '调查': <gensim.models.keyedvectors.Vocab at 0x16adbe48>,
#  '方式': <gensim.models.keyedvectors.Vocab at 0x16adbe80>,
#  '重大': <gensim.models.keyedvectors.Vocab at 0x16adbeb8>,
#  '案件': <gensim.models.keyedvectors.Vocab at 0x16adbef0>,
#  '又': <gensim.models.keyedvectors.Vocab at 0x16adbf28>,
#  '一': <gensim.models.keyedvectors.Vocab at 0x16adbf60>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x16adbf98>,
#  '８': <gensim.models.keyedvectors.Vocab at 0x16adbfd0>,
#  '对': <gensim.models.keyedvectors.Vocab at 0x16ade048>,
#  '发': <gensim.models.keyedvectors.Vocab at 0x16ade080>,
#  '往': <gensim.models.keyedvectors.Vocab at 0x16ade0b8>,
#  '浙江': <gensim.models.keyedvectors.Vocab at 0x16ade0f0>,
#  '申报': <gensim.models.keyedvectors.Vocab at 0x16ade128>,
#  '为': <gensim.models.keyedvectors.Vocab at 0x16ade160>,
#  '进行': <gensim.models.keyedvectors.Vocab at 0x16ade198>,
#  '时': <gensim.models.keyedvectors.Vocab at 0x16ade1d0>,
#  '发现': <gensim.models.keyedvectors.Vocab at 0x16ade208>,
#  '货物': <gensim.models.keyedvectors.Vocab at 0x16ade240>,
#  '内': <gensim.models.keyedvectors.Vocab at 0x16ade278>,
#  '７': <gensim.models.keyedvectors.Vocab at 0x16ade2b0>,
#  '经': <gensim.models.keyedvectors.Vocab at 0x16ade2e8>,
#  '具有': <gensim.models.keyedvectors.Vocab at 0x16ade320>,
#  '及其': <gensim.models.keyedvectors.Vocab at 0x16ade358>,
#  '这': <gensim.models.keyedvectors.Vocab at 0x16ade390>,
#  '海关总署': <gensim.models.keyedvectors.Vocab at 0x16ade3c8>,
#  '成': <gensim.models.keyedvectors.Vocab at 0x16ade400>,
#  '因为': <gensim.models.keyedvectors.Vocab at 0x16ade438>,
#  '进口': <gensim.models.keyedvectors.Vocab at 0x16ade470>,
#  '检查': <gensim.models.keyedvectors.Vocab at 0x16ade4a8>,
#  '出来': <gensim.models.keyedvectors.Vocab at 0x16ade4e0>,
#  '说明': <gensim.models.keyedvectors.Vocab at 0x16ade518>,
#  '来源': <gensim.models.keyedvectors.Vocab at 0x16ade550>,
#  '说': <gensim.models.keyedvectors.Vocab at 0x16ade588>,
#  '国外': <gensim.models.keyedvectors.Vocab at 0x16ade5c0>,
#  '应该': <gensim.models.keyedvectors.Vocab at 0x16ade5f8>,
#  '一起': <gensim.models.keyedvectors.Vocab at 0x16ade630>,
#  '成立': <gensim.models.keyedvectors.Vocab at 0x16ade668>,
#  '专案组': <gensim.models.keyedvectors.Vocab at 0x16ade6a0>,
#  '侦查': <gensim.models.keyedvectors.Vocab at 0x16ade6d8>,
#  '于': <gensim.models.keyedvectors.Vocab at 0x16ade710>,
#  'Ｐ': <gensim.models.keyedvectors.Vocab at 0x16ade748>,
#  'Ｓ': <gensim.models.keyedvectors.Vocab at 0x16ade780>,
#  '处': <gensim.models.keyedvectors.Vocab at 0x16ade7b8>,
#  '将': <gensim.models.keyedvectors.Vocab at 0x16ade7f0>,
#  '王挺': <gensim.models.keyedvectors.Vocab at 0x16ade828>,
#  '男': <gensim.models.keyedvectors.Vocab at 0x16ade860>,
#  '岁': <gensim.models.keyedvectors.Vocab at 0x16ade898>,
#  '人': <gensim.models.keyedvectors.Vocab at 0x16ade8d0>,
#  '他': <gensim.models.keyedvectors.Vocab at 0x16ade908>,
#  '网站': <gensim.models.keyedvectors.Vocab at 0x16ade940>,
#  '林志富': <gensim.models.keyedvectors.Vocab at 0x16ade978>,
#  '以来': <gensim.models.keyedvectors.Vocab at 0x16ade9b0>,
#  '长期': <gensim.models.keyedvectors.Vocab at 0x16ade9e8>,
#  '居住': <gensim.models.keyedvectors.Vocab at 0x16adea20>,
#  '一个': <gensim.models.keyedvectors.Vocab at 0x16adea58>,
#  '群体': <gensim.models.keyedvectors.Vocab at 0x16adea90>,
#  '网络': <gensim.models.keyedvectors.Vocab at 0x16adeac8>,
#  '国内': <gensim.models.keyedvectors.Vocab at 0x16adeb00>,
#  '寻找': <gensim.models.keyedvectors.Vocab at 0x16adeb38>,
#  '枪支弹药': <gensim.models.keyedvectors.Vocab at 0x16adeb70>,
#  '买家': <gensim.models.keyedvectors.Vocab at 0x16adeba8>,
#  '并': <gensim.models.keyedvectors.Vocab at 0x16adebe0>,
#  '公司': <gensim.models.keyedvectors.Vocab at 0x16adec18>,
#  '纽约': <gensim.models.keyedvectors.Vocab at 0x16adec50>,
#  '多名': <gensim.models.keyedvectors.Vocab at 0x16adec88>,
#  '类似': <gensim.models.keyedvectors.Vocab at 0x16adecc0>,
#  '中间人': <gensim.models.keyedvectors.Vocab at 0x16adecf8>,
#  '再': <gensim.models.keyedvectors.Vocab at 0x16aded30>,
#  '发送给': <gensim.models.keyedvectors.Vocab at 0x16aded68>,
#  '此案': <gensim.models.keyedvectors.Vocab at 0x16adeda0>,
#  '交易': <gensim.models.keyedvectors.Vocab at 0x16adedd8>,
#  '强': <gensim.models.keyedvectors.Vocab at 0x16adee10>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x16adee48>,
#  '身份': <gensim.models.keyedvectors.Vocab at 0x16adee80>,
#  '体现': <gensim.models.keyedvectors.Vocab at 0x16adeeb8>,
#  '特别': <gensim.models.keyedvectors.Vocab at 0x16adeef0>,
#  '新': <gensim.models.keyedvectors.Vocab at 0x16adef28>,
#  '距离': <gensim.models.keyedvectors.Vocab at 0x16adef60>,
#  '经常': <gensim.models.keyedvectors.Vocab at 0x16adef98>,
#  '甚至': <gensim.models.keyedvectors.Vocab at 0x16adefd0>,
#  '这种': <gensim.models.keyedvectors.Vocab at 0x16ae1048>,
#  '改变': <gensim.models.keyedvectors.Vocab at 0x16ae1080>,
#  '要求': <gensim.models.keyedvectors.Vocab at 0x16ae10b8>,
#  '我们': <gensim.models.keyedvectors.Vocab at 0x16ae10f0>,
#  '各国': <gensim.models.keyedvectors.Vocab at 0x16ae1128>,
#  '警方': <gensim.models.keyedvectors.Vocab at 0x16ae1160>,
#  '合作': <gensim.models.keyedvectors.Vocab at 0x16ae1198>,
#  '作者': <gensim.models.keyedvectors.Vocab at 0x16ae11d0>,
#  '天津': <gensim.models.keyedvectors.Vocab at 0x16ae1208>,
#  '事件': <gensim.models.keyedvectors.Vocab at 0x16ae1240>,
#  '张绍': <gensim.models.keyedvectors.Vocab at 0x16ae1278>,
#  '刚': <gensim.models.keyedvectors.Vocab at 0x16ae12b0>,
#  '发出': <gensim.models.keyedvectors.Vocab at 0x16ae12e8>,
#  '称': <gensim.models.keyedvectors.Vocab at 0x16ae1320>,
#  '自己': <gensim.models.keyedvectors.Vocab at 0x16ae1358>,
#  '了解': <gensim.models.keyedvectors.Vocab at 0x16ae1390>,
#  '但': <gensim.models.keyedvectors.Vocab at 0x16ae13c8>,
#  '道歉': <gensim.models.keyedvectors.Vocab at 0x16ae1400>,
#  '没有': <gensim.models.keyedvectors.Vocab at 0x16ae1438>,
#  '得到': <gensim.models.keyedvectors.Vocab at 0x16ae1470>,
#  '网友': <gensim.models.keyedvectors.Vocab at 0x16ae14a8>,
#  '接受': <gensim.models.keyedvectors.Vocab at 0x16ae14e0>,
#  '有': <gensim.models.keyedvectors.Vocab at 0x16ae1518>,
#  '指出': <gensim.models.keyedvectors.Vocab at 0x16ae1550>,
#  '问题': <gensim.models.keyedvectors.Vocab at 0x16ae1588>,
#  '就': <gensim.models.keyedvectors.Vocab at 0x16ae15c0>,
#  '连': <gensim.models.keyedvectors.Vocab at 0x16ae15f8>,
#  '不会': <gensim.models.keyedvectors.Vocab at 0x16ae1630>,
#  '之前': <gensim.models.keyedvectors.Vocab at 0x16ae1668>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x16ae16a0>,
#  '表现': <gensim.models.keyedvectors.Vocab at 0x16ae16d8>,
#  '几天': <gensim.models.keyedvectors.Vocab at 0x16ae1710>,
#  '网上': <gensim.models.keyedvectors.Vocab at 0x16ae1748>,
#  '民意': <gensim.models.keyedvectors.Vocab at 0x16ae1780>,
#  '要': <gensim.models.keyedvectors.Vocab at 0x16ae17b8>,
#  '解释': <gensim.models.keyedvectors.Vocab at 0x16ae17f0>,
#  '＂': <gensim.models.keyedvectors.Vocab at 0x16ae1828>,
#  '你': <gensim.models.keyedvectors.Vocab at 0x16ae1860>,
#  '这样': <gensim.models.keyedvectors.Vocab at 0x16ae1898>,
#  '为了': <gensim.models.keyedvectors.Vocab at 0x16ae18d0>,
#  '而': <gensim.models.keyedvectors.Vocab at 0x16ae1908>,
#  '站': <gensim.models.keyedvectors.Vocab at 0x16ae1940>,
#  '角度': <gensim.models.keyedvectors.Vocab at 0x16ae1978>,
#  '考虑': <gensim.models.keyedvectors.Vocab at 0x16ae19b0>,
#  '当': <gensim.models.keyedvectors.Vocab at 0x16ae19e8>,
#  '不': <gensim.models.keyedvectors.Vocab at 0x16ae1a20>,
#  '时候': <gensim.models.keyedvectors.Vocab at 0x16ae1a58>,
#  '无法': <gensim.models.keyedvectors.Vocab at 0x16ae1a90>,
#  '建议': <gensim.models.keyedvectors.Vocab at 0x16ae1ac8>,
#  '今年以来': <gensim.models.keyedvectors.Vocab at 0x16ae1b00>,
#  '此': <gensim.models.keyedvectors.Vocab at 0x16ae1b38>,
#  '最后': <gensim.models.keyedvectors.Vocab at 0x16ae1b70>,
#  '表示': <gensim.models.keyedvectors.Vocab at 0x16ae1ba8>,
#  '很': <gensim.models.keyedvectors.Vocab at 0x16ae1be0>,
#  '努力': <gensim.models.keyedvectors.Vocab at 0x16ae1c18>,
#  '去': <gensim.models.keyedvectors.Vocab at 0x16ae1c50>,
#  '这个': <gensim.models.keyedvectors.Vocab at 0x16ae1c88>,
#  '所': <gensim.models.keyedvectors.Vocab at 0x16ae1cc0>,
#  '想': <gensim.models.keyedvectors.Vocab at 0x16ae1cf8>,
#  '跟': <gensim.models.keyedvectors.Vocab at 0x16ae1d30>,
#  '们': <gensim.models.keyedvectors.Vocab at 0x16ae1d68>,
#  '却': <gensim.models.keyedvectors.Vocab at 0x16ae1da0>,
#  '舞台': <gensim.models.keyedvectors.Vocab at 0x16ae1dd8>,
#  '学生': <gensim.models.keyedvectors.Vocab at 0x16ae1e10>,
#  '是否': <gensim.models.keyedvectors.Vocab at 0x16ae1e48>,
#  '而是': <gensim.models.keyedvectors.Vocab at 0x16ae1e80>,
#  '更': <gensim.models.keyedvectors.Vocab at 0x16ae1eb8>,
#  '认为': <gensim.models.keyedvectors.Vocab at 0x16ae1ef0>,
#  '存在': <gensim.models.keyedvectors.Vocab at 0x16ae1f28>,
#  '所有': <gensim.models.keyedvectors.Vocab at 0x16ae1f60>,
#  '对于': <gensim.models.keyedvectors.Vocab at 0x16ae1f98>,
#  '相关': <gensim.models.keyedvectors.Vocab at 0x16ae1fd0>,
#  '先': <gensim.models.keyedvectors.Vocab at 0x16ae4048>,
#  '以': <gensim.models.keyedvectors.Vocab at 0x16ae4080>,
#  '；': <gensim.models.keyedvectors.Vocab at 0x16ae40b8>,
#  '当地': <gensim.models.keyedvectors.Vocab at 0x16ae40f0>,
#  '生活': <gensim.models.keyedvectors.Vocab at 0x16ae4128>,
#  '经验': <gensim.models.keyedvectors.Vocab at 0x16ae4160>,
#  '对方': <gensim.models.keyedvectors.Vocab at 0x16ae4198>,
#  '然后': <gensim.models.keyedvectors.Vocab at 0x16ae41d0>,
#  '张': <gensim.models.keyedvectors.Vocab at 0x16ae4208>,
#  '请': <gensim.models.keyedvectors.Vocab at 0x16ae4240>,
#  '把': <gensim.models.keyedvectors.Vocab at 0x16ae4278>,
#  '处理': <gensim.models.keyedvectors.Vocab at 0x16ae42b0>,
#  '羊城晚报': <gensim.models.keyedvectors.Vocab at 0x16ae42e8>,
#  '山东': <gensim.models.keyedvectors.Vocab at 0x16ae4320>,
#  '４': <gensim.models.keyedvectors.Vocab at 0x16ae4358>,
#  '麦客': <gensim.models.keyedvectors.Vocab at 0x16ae4390>,
#  '街道': <gensim.models.keyedvectors.Vocab at 0x16ae43c8>,
#  '米': <gensim.models.keyedvectors.Vocab at 0x16ae4400>,
#  '间': <gensim.models.keyedvectors.Vocab at 0x16ae4438>,
#  '驾驶': <gensim.models.keyedvectors.Vocab at 0x16ae4470>,
#  '小麦': <gensim.models.keyedvectors.Vocab at 0x16ae44a8>,
#  '就是': <gensim.models.keyedvectors.Vocab at 0x16ae44e0>,
#  '投资': <gensim.models.keyedvectors.Vocab at 0x16ae4518>,
#  '购买': <gensim.models.keyedvectors.Vocab at 0x16ae4550>,
#  '大型': <gensim.models.keyedvectors.Vocab at 0x16ae4588>,
#  '成为': <gensim.models.keyedvectors.Vocab at 0x16ae45c0>,
#  '第一': <gensim.models.keyedvectors.Vocab at 0x16ae45f8>,
#  '晚上': <gensim.models.keyedvectors.Vocab at 0x16ae4630>,
#  '丈夫': <gensim.models.keyedvectors.Vocab at 0x16ae4668>,
#  '妻子': <gensim.models.keyedvectors.Vocab at 0x16ae46a0>,
#  '负责': <gensim.models.keyedvectors.Vocab at 0x16ae46d8>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x16ae4710>,
#  '等': <gensim.models.keyedvectors.Vocab at 0x16ae4748>,
#  '一天': <gensim.models.keyedvectors.Vocab at 0x16ae4780>,
#  '能': <gensim.models.keyedvectors.Vocab at 0x16ae47b8>,
#  '多': <gensim.models.keyedvectors.Vocab at 0x16ae47f0>,
#  '他们': <gensim.models.keyedvectors.Vocab at 0x16ae4828>,
#  '及时': <gensim.models.keyedvectors.Vocab at 0x16ae4860>,
#  '着': <gensim.models.keyedvectors.Vocab at 0x16ae4898>,
#  '同时': <gensim.models.keyedvectors.Vocab at 0x16ae48d0>,
#  '带来': <gensim.models.keyedvectors.Vocab at 0x16ae4908>,
#  '稳定': <gensim.models.keyedvectors.Vocab at 0x16ae4940>,
#  '收入': <gensim.models.keyedvectors.Vocab at 0x16ae4978>,
#  '新华社': <gensim.models.keyedvectors.Vocab at 0x16ae49b0>,
#  '摄': <gensim.models.keyedvectors.Vocab at 0x16ae49e8>,
#  '北京': <gensim.models.keyedvectors.Vocab at 0x16ae4a20>,
#  '凌晨': <gensim.models.keyedvectors.Vocab at 0x16ae4a58>,
#  '比赛': <gensim.models.keyedvectors.Vocab at 0x16ae4a90>,
#  '死亡': <gensim.models.keyedvectors.Vocab at 0x16ae4ac8>,
#  'Ｂ': <gensim.models.keyedvectors.Vocab at 0x16ae4b00>,
#  '葡萄牙队': <gensim.models.keyedvectors.Vocab at 0x16ae4b38>,
#  '正': <gensim.models.keyedvectors.Vocab at 0x16ae4b70>,
#  '面临': <gensim.models.keyedvectors.Vocab at 0x16ae4ba8>,
#  '提前': <gensim.models.keyedvectors.Vocab at 0x16ae4be0>,
#  '危险': <gensim.models.keyedvectors.Vocab at 0x16ae4c18>,
#  '之后': <gensim.models.keyedvectors.Vocab at 0x16ae4c50>,
#  '形势': <gensim.models.keyedvectors.Vocab at 0x16ae4c88>,
#  '德国': <gensim.models.keyedvectors.Vocab at 0x16ae4cc0>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x16ae4cf8>,
#  '葡萄牙': <gensim.models.keyedvectors.Vocab at 0x16ae4d30>,
#  '荷兰': <gensim.models.keyedvectors.Vocab at 0x16ae4d68>,
#  '球队': <gensim.models.keyedvectors.Vocab at 0x16ae4da0>,
#  '如果': <gensim.models.keyedvectors.Vocab at 0x16ae4dd8>,
#  '会': <gensim.models.keyedvectors.Vocab at 0x16ae4e10>,
#  '可以': <gensim.models.keyedvectors.Vocab at 0x16ae4e48>,
#  '输球': <gensim.models.keyedvectors.Vocab at 0x16ae4e80>,
#  '就要': <gensim.models.keyedvectors.Vocab at 0x16ae4eb8>,
#  '回家': <gensim.models.keyedvectors.Vocab at 0x16ae4ef0>,
#  'Ｃ': <gensim.models.keyedvectors.Vocab at 0x16ae4f28>,
#  '后': <gensim.models.keyedvectors.Vocab at 0x16ae4f60>,
#  '时间': <gensim.models.keyedvectors.Vocab at 0x16ae4f98>,
#  '点': <gensim.models.keyedvectors.Vocab at 0x16ae4fd0>,
#  '之下': <gensim.models.keyedvectors.Vocab at 0x16ae8048>,
#  '压力': <gensim.models.keyedvectors.Vocab at 0x16ae8080>,
#  '不过': <gensim.models.keyedvectors.Vocab at 0x16ae80b8>,
#  '受到': <gensim.models.keyedvectors.Vocab at 0x16ae80f0>,
#  '质疑': <gensim.models.keyedvectors.Vocab at 0x16ae8128>,
#  '大': <gensim.models.keyedvectors.Vocab at 0x16ae8160>,
#  '但是': <gensim.models.keyedvectors.Vocab at 0x16ae8198>,
#  '非常': <gensim.models.keyedvectors.Vocab at 0x16ae81d0>,
#  '严格': <gensim.models.keyedvectors.Vocab at 0x16ae8208>,
#  '证明': <gensim.models.keyedvectors.Vocab at 0x16ae8240>,
#  '强烈': <gensim.models.keyedvectors.Vocab at 0x16ae8278>,
#  '虽然': <gensim.models.keyedvectors.Vocab at 0x16ae82b0>,
#  '相信': <gensim.models.keyedvectors.Vocab at 0x16ae82e8>,
#  '一定': <gensim.models.keyedvectors.Vocab at 0x16ae8320>,
#  '能够': <gensim.models.keyedvectors.Vocab at 0x16ae8358>,
#  '媒体': <gensim.models.keyedvectors.Vocab at 0x16ae8390>,
#  '相比': <gensim.models.keyedvectors.Vocab at 0x16ae83c8>,
#  '产生': <gensim.models.keyedvectors.Vocab at 0x16ae8400>,
#  '早': <gensim.models.keyedvectors.Vocab at 0x16ae8438>,
#  '出现': <gensim.models.keyedvectors.Vocab at 0x16ae8470>,
#  '核心': <gensim.models.keyedvectors.Vocab at 0x16ae84a8>,
#  '两名': <gensim.models.keyedvectors.Vocab at 0x16ae84e0>,
#  '越来越': <gensim.models.keyedvectors.Vocab at 0x16ae8518>,
#  '涉及': <gensim.models.keyedvectors.Vocab at 0x16ae8550>,
#  '到': <gensim.models.keyedvectors.Vocab at 0x16ae8588>,
#  '之间': <gensim.models.keyedvectors.Vocab at 0x16ae85c0>,
#  '不能': <gensim.models.keyedvectors.Vocab at 0x16ae85f8>,
#  '有人': <gensim.models.keyedvectors.Vocab at 0x16ae8630>,
#  '太': <gensim.models.keyedvectors.Vocab at 0x16ae8668>,
#  '目前': <gensim.models.keyedvectors.Vocab at 0x16ae86a0>,
#  '两年': <gensim.models.keyedvectors.Vocab at 0x16ae86d8>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x16ae8710>,
#  '情况': <gensim.models.keyedvectors.Vocab at 0x16ae8748>,
#  '正常': <gensim.models.keyedvectors.Vocab at 0x16ae8780>,
#  '必须': <gensim.models.keyedvectors.Vocab at 0x16ae87b8>,
#  '好': <gensim.models.keyedvectors.Vocab at 0x16ae87f0>,
#  '内部': <gensim.models.keyedvectors.Vocab at 0x16ae8828>,
#  '来说': <gensim.models.keyedvectors.Vocab at 0x16ae8860>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x16ae8898>,
#  '正在': <gensim.models.keyedvectors.Vocab at 0x16ae88d0>,
#  '扎克': <gensim.models.keyedvectors.Vocab at 0x16ae8908>,
#  '伯格': <gensim.models.keyedvectors.Vocab at 0x16ae8940>,
#  '处于': <gensim.models.keyedvectors.Vocab at 0x16ae8978>,
#  '拥有': <gensim.models.keyedvectors.Vocab at 0x16ae89b0>,
#  '家': <gensim.models.keyedvectors.Vocab at 0x16ae89e8>,
#  '近': <gensim.models.keyedvectors.Vocab at 0x16ae8a20>,
#  '普通': <gensim.models.keyedvectors.Vocab at 0x16ae8a58>,
#  'Ｔ': <gensim.models.keyedvectors.Vocab at 0x16ae8a90>,
#  '一家': <gensim.models.keyedvectors.Vocab at 0x16ae8ac8>,
#  '买': <gensim.models.keyedvectors.Vocab at 0x16ae8b00>,
#  '两人': <gensim.models.keyedvectors.Vocab at 0x16ae8b38>,
#  '起来': <gensim.models.keyedvectors.Vocab at 0x16ae8b70>,
#  '英国': <gensim.models.keyedvectors.Vocab at 0x16ae8ba8>,
#  '每日': <gensim.models.keyedvectors.Vocab at 0x16ae8be0>,
#  '仅': <gensim.models.keyedvectors.Vocab at 0x16ae8c18>,
#  '约': <gensim.models.keyedvectors.Vocab at 0x16ae8c50>,
#  '人民币': <gensim.models.keyedvectors.Vocab at 0x16ae8c88>,
#  '元': <gensim.models.keyedvectors.Vocab at 0x16ae8cc0>,
#  '看': <gensim.models.keyedvectors.Vocab at 0x16ae8cf8>,
#  '由': <gensim.models.keyedvectors.Vocab at 0x16ae8d30>,
#  '则': <gensim.models.keyedvectors.Vocab at 0x16ae8d68>,
#  '给': <gensim.models.keyedvectors.Vocab at 0x16ae8da0>,
#  '食品': <gensim.models.keyedvectors.Vocab at 0x16ae8dd8>,
#  '吃': <gensim.models.keyedvectors.Vocab at 0x16ae8e10>,
#  '一位': <gensim.models.keyedvectors.Vocab at 0x16ae8e48>,
#  '路': <gensim.models.keyedvectors.Vocab at 0x16ae8e80>,
#  '告诉': <gensim.models.keyedvectors.Vocab at 0x16ae8eb8>,
#  '没': <gensim.models.keyedvectors.Vocab at 0x16ae8ef0>,
#  '只是': <gensim.models.keyedvectors.Vocab at 0x16ae8f28>,
#  '人群': <gensim.models.keyedvectors.Vocab at 0x16ae8f60>,
#  '最近': <gensim.models.keyedvectors.Vocab at 0x16ae8f98>,
#  '警察': <gensim.models.keyedvectors.Vocab at 0x16ae8fd0>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x16aeb048>,
#  '第': <gensim.models.keyedvectors.Vocab at 0x16aeb080>,
#  '今年': <gensim.models.keyedvectors.Vocab at 0x16aeb0b8>,
#  '上海': <gensim.models.keyedvectors.Vocab at 0x16aeb0f0>,
#  '让': <gensim.models.keyedvectors.Vocab at 0x16aeb128>,
#  '［': <gensim.models.keyedvectors.Vocab at 0x16aeb160>,
#  '］': <gensim.models.keyedvectors.Vocab at 0x16aeb198>,
#  '通讯员': <gensim.models.keyedvectors.Vocab at 0x16aeb1d0>,
#  '城区': <gensim.models.keyedvectors.Vocab at 0x16aeb208>,
#  '胶南市': <gensim.models.keyedvectors.Vocab at 0x16aeb240>,
#  '烟台': <gensim.models.keyedvectors.Vocab at 0x16aeb278>,
#  '社区': <gensim.models.keyedvectors.Vocab at 0x16aeb2b0>,
#  '演出': <gensim.models.keyedvectors.Vocab at 0x16aeb2e8>,
#  '附近': <gensim.models.keyedvectors.Vocab at 0x16aeb320>,
#  '居民': <gensim.models.keyedvectors.Vocab at 0x16aeb358>,
#  '更是': <gensim.models.keyedvectors.Vocab at 0x16aeb390>,
#  '负责人': <gensim.models.keyedvectors.Vocab at 0x16aeb3c8>,
#  '很多': <gensim.models.keyedvectors.Vocab at 0x16aeb400>,
#  '除了': <gensim.models.keyedvectors.Vocab at 0x16aeb438>,
#  '中心': <gensim.models.keyedvectors.Vocab at 0x16aeb470>,
#  '外': <gensim.models.keyedvectors.Vocab at 0x16aeb4a8>,
#  '还': <gensim.models.keyedvectors.Vocab at 0x16aeb4e0>,
#  '建设': <gensim.models.keyedvectors.Vocab at 0x16aeb518>,
#  '博物馆': <gensim.models.keyedvectors.Vocab at 0x16aeb550>,
#  '继续': <gensim.models.keyedvectors.Vocab at 0x16aeb588>,
#  '公共': <gensim.models.keyedvectors.Vocab at 0x16aeb5c0>,
#  '文化': <gensim.models.keyedvectors.Vocab at 0x16aeb5f8>,
#  '实施': <gensim.models.keyedvectors.Vocab at 0x16aeb630>,
#  '提升': <gensim.models.keyedvectors.Vocab at 0x16aeb668>,
#  '工程': <gensim.models.keyedvectors.Vocab at 0x16aeb6a0>,
#  '其中': <gensim.models.keyedvectors.Vocab at 0x16aeb6d8>,
#  '万元': <gensim.models.keyedvectors.Vocab at 0x16aeb710>,
#  '功能': <gensim.models.keyedvectors.Vocab at 0x16aeb748>,
#  '完善': <gensim.models.keyedvectors.Vocab at 0x16aeb780>,
#  '加大': <gensim.models.keyedvectors.Vocab at 0x16aeb7b8>,
#  '人民': <gensim.models.keyedvectors.Vocab at 0x16aeb7f0>,
#  '广场': <gensim.models.keyedvectors.Vocab at 0x16aeb828>,
#  '设施': <gensim.models.keyedvectors.Vocab at 0x16aeb860>,
#  '力度': <gensim.models.keyedvectors.Vocab at 0x16aeb898>,
#  '重点': <gensim.models.keyedvectors.Vocab at 0x16aeb8d0>,
#  '区域': <gensim.models.keyedvectors.Vocab at 0x16aeb908>,
#  '能力': <gensim.models.keyedvectors.Vocab at 0x16aeb940>,
#  '加强': <gensim.models.keyedvectors.Vocab at 0x16aeb978>,
#  '市': <gensim.models.keyedvectors.Vocab at 0x16aeb9b0>,
#  '图书馆': <gensim.models.keyedvectors.Vocab at 0x16aeb9e8>,
#  '服务': <gensim.models.keyedvectors.Vocab at 0x16aeba20>,
#  '基本': <gensim.models.keyedvectors.Vocab at 0x16aeba58>,
#  '起': <gensim.models.keyedvectors.Vocab at 0x16aeba90>,
#  '一些': <gensim.models.keyedvectors.Vocab at 0x16aebac8>,
#  '性': <gensim.models.keyedvectors.Vocab at 0x16aebb00>,
#  '总': <gensim.models.keyedvectors.Vocab at 0x16aebb38>,
#  '亿元': <gensim.models.keyedvectors.Vocab at 0x16aebb70>,
#  '市民': <gensim.models.keyedvectors.Vocab at 0x16aebba8>,
#  '已经': <gensim.models.keyedvectors.Vocab at 0x16aebbe0>,
#  '规划': <gensim.models.keyedvectors.Vocab at 0x16aebc18>,
#  '占地': <gensim.models.keyedvectors.Vocab at 0x16aebc50>,
#  '达到': <gensim.models.keyedvectors.Vocab at 0x16aebc88>,
#  '亩': <gensim.models.keyedvectors.Vocab at 0x16aebcc0>,
#  '．': <gensim.models.keyedvectors.Vocab at 0x16aebcf8>,
#  '即将': <gensim.models.keyedvectors.Vocab at 0x16aebd30>,
#  '近期': <gensim.models.keyedvectors.Vocab at 0x16aebd68>,
#  '三': <gensim.models.keyedvectors.Vocab at 0x16aebda0>,
#  '公里': <gensim.models.keyedvectors.Vocab at 0x16aebdd8>,
#  '建成': <gensim.models.keyedvectors.Vocab at 0x16aebe10>,
#  '进一步': <gensim.models.keyedvectors.Vocab at 0x16aebe48>,
#  '至': <gensim.models.keyedvectors.Vocab at 0x16aebe80>,
#  '基层': <gensim.models.keyedvectors.Vocab at 0x16aebeb8>,
#  '计划': <gensim.models.keyedvectors.Vocab at 0x16aebef0>,
#  '加快': <gensim.models.keyedvectors.Vocab at 0x16aebf28>,
#  '经济': <gensim.models.keyedvectors.Vocab at 0x16aebf60>,
#  '镇': <gensim.models.keyedvectors.Vocab at 0x16aebf98>,
#  '根据': <gensim.models.keyedvectors.Vocab at 0x16aebfd0>,
#  '每个': <gensim.models.keyedvectors.Vocab at 0x16aef048>,
#  '实际': <gensim.models.keyedvectors.Vocab at 0x16aef080>,
#  '农村': <gensim.models.keyedvectors.Vocab at 0x16aef0b8>,
#  '其': <gensim.models.keyedvectors.Vocab at 0x16aef0f0>,
#  'Ｄ': <gensim.models.keyedvectors.Vocab at 0x16aef128>,
#  '采取': <gensim.models.keyedvectors.Vocab at 0x16aef160>,
#  '办法': <gensim.models.keyedvectors.Vocab at 0x16aef198>,
#  '形成': <gensim.models.keyedvectors.Vocab at 0x16aef1d0>,
#  '连续': <gensim.models.keyedvectors.Vocab at 0x16aef208>,
#  '三年': <gensim.models.keyedvectors.Vocab at 0x16aef240>,
#  '基础': <gensim.models.keyedvectors.Vocab at 0x16aef278>,
#  '用于': <gensim.models.keyedvectors.Vocab at 0x16aef2b0>,
#  '改善': <gensim.models.keyedvectors.Vocab at 0x16aef2e8>,
#  '全市': <gensim.models.keyedvectors.Vocab at 0x16aef320>,
#  '已': <gensim.models.keyedvectors.Vocab at 0x16aef358>,
#  '综合': <gensim.models.keyedvectors.Vocab at 0x16aef390>,
#  '全部': <gensim.models.keyedvectors.Vocab at 0x16aef3c8>,
#  '％': <gensim.models.keyedvectors.Vocab at 0x16aef400>,
#  '满足': <gensim.models.keyedvectors.Vocab at 0x16aef438>,
#  '需求': <gensim.models.keyedvectors.Vocab at 0x16aef470>,
#  '效应': <gensim.models.keyedvectors.Vocab at 0x16aef4a8>,
#  '分馆': <gensim.models.keyedvectors.Vocab at 0x16aef4e0>,
#  '建立': <gensim.models.keyedvectors.Vocab at 0x16aef518>,
#  '工作人员': <gensim.models.keyedvectors.Vocab at 0x16aef550>,
#  '可': <gensim.models.keyedvectors.Vocab at 0x16aef588>,
#  '不要': <gensim.models.keyedvectors.Vocab at 0x16aef5c0>,
#  '只有': <gensim.models.keyedvectors.Vocab at 0x16aef5f8>,
#  '纳入': <gensim.models.keyedvectors.Vocab at 0x16aef630>,
#  '实现': <gensim.models.keyedvectors.Vocab at 0x16aef668>,
#  '村民': <gensim.models.keyedvectors.Vocab at 0x16aef6a0>,
#  '那么': <gensim.models.keyedvectors.Vocab at 0x16aef6d8>,
#  '一步': <gensim.models.keyedvectors.Vocab at 0x16aef710>,
#  '电子': <gensim.models.keyedvectors.Vocab at 0x16aef748>,
#  '信息': <gensim.models.keyedvectors.Vocab at 0x16aef780>,
#  '推进': <gensim.models.keyedvectors.Vocab at 0x16aef7b8>,
#  '设立': <gensim.models.keyedvectors.Vocab at 0x16aef7f0>,
#  '之': <gensim.models.keyedvectors.Vocab at 0x16aef828>,
#  '带动': <gensim.models.keyedvectors.Vocab at 0x16aef860>,
#  '标准': <gensim.models.keyedvectors.Vocab at 0x16aef898>,
#  '资源': <gensim.models.keyedvectors.Vocab at 0x16aef8d0>,
#  '坚持': <gensim.models.keyedvectors.Vocab at 0x16aef908>,
#  '采用': <gensim.models.keyedvectors.Vocab at 0x16aef940>,
#  '送': <gensim.models.keyedvectors.Vocab at 0x16aef978>,
#  '不断': <gensim.models.keyedvectors.Vocab at 0x16aef9b0>,
#  '持续': <gensim.models.keyedvectors.Vocab at 0x16aef9e8>,
#  '开展': <gensim.models.keyedvectors.Vocab at 0x16aefa20>,
#  '财政': <gensim.models.keyedvectors.Vocab at 0x16aefa58>,
#  '确保': <gensim.models.keyedvectors.Vocab at 0x16aefa90>,
#  '万': <gensim.models.keyedvectors.Vocab at 0x16aefac8>,
#  '保障': <gensim.models.keyedvectors.Vocab at 0x16aefb00>,
#  '积极': <gensim.models.keyedvectors.Vocab at 0x16aefb38>,
#  '引导': <gensim.models.keyedvectors.Vocab at 0x16aefb70>,
#  '鼓励': <gensim.models.keyedvectors.Vocab at 0x16aefba8>,
#  '发展': <gensim.models.keyedvectors.Vocab at 0x16aefbe0>,
#  '原则': <gensim.models.keyedvectors.Vocab at 0x16aefc18>,
#  '水平': <gensim.models.keyedvectors.Vocab at 0x16aefc50>,
#  '高': <gensim.models.keyedvectors.Vocab at 0x16aefc88>,
#  '人员': <gensim.models.keyedvectors.Vocab at 0x16aefcc0>,
#  '规模': <gensim.models.keyedvectors.Vocab at 0x16aefcf8>,
#  '市场': <gensim.models.keyedvectors.Vocab at 0x16aefd30>,
#  '中新网': <gensim.models.keyedvectors.Vocab at 0x16aefd68>,
#  '日电': <gensim.models.keyedvectors.Vocab at 0x16aefda0>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x16aefdd8>,
#  '参加': <gensim.models.keyedvectors.Vocab at 0x16aefe10>,
#  '自': <gensim.models.keyedvectors.Vocab at 0x16aefe48>,
#  '安排': <gensim.models.keyedvectors.Vocab at 0x16aefe80>,
#  '给予': <gensim.models.keyedvectors.Vocab at 0x16aefeb8>,
#  '只': <gensim.models.keyedvectors.Vocab at 0x16aefef0>,
#  '准备': <gensim.models.keyedvectors.Vocab at 0x16aeff28>,
#  '回应': <gensim.models.keyedvectors.Vocab at 0x16aeff60>,
#  '日前': <gensim.models.keyedvectors.Vocab at 0x16aeff98>,
#  '发布': <gensim.models.keyedvectors.Vocab at 0x16aeffd0>,
#  '中央': <gensim.models.keyedvectors.Vocab at 0x16af1048>,
#  '企业': <gensim.models.keyedvectors.Vocab at 0x16af1080>,
#  '审计': <gensim.models.keyedvectors.Vocab at 0x16af10b8>,
#  '结果': <gensim.models.keyedvectors.Vocab at 0x16af10f0>,
#  '公告': <gensim.models.keyedvectors.Vocab at 0x16af1128>,
#  '社会': <gensim.models.keyedvectors.Vocab at 0x16af1160>,
#  '监督': <gensim.models.keyedvectors.Vocab at 0x16af1198>,
#  '审计署': <gensim.models.keyedvectors.Vocab at 0x16af11d0>,
#  '提出': <gensim.models.keyedvectors.Vocab at 0x16af1208>,
#  '制度': <gensim.models.keyedvectors.Vocab at 0x16af1240>,
#  '据悉': <gensim.models.keyedvectors.Vocab at 0x16af1278>,
#  '公布': <gensim.models.keyedvectors.Vocab at 0x16af12b0>,
#  '石油': <gensim.models.keyedvectors.Vocab at 0x16af12e8>,
#  '披露': <gensim.models.keyedvectors.Vocab at 0x16af1320>,
#  '管理': <gensim.models.keyedvectors.Vocab at 0x16af1358>,
#  '集团': <gensim.models.keyedvectors.Vocab at 0x16af1390>,
#  '补贴': <gensim.models.keyedvectors.Vocab at 0x16af13c8>,
#  '工作': <gensim.models.keyedvectors.Vocab at 0x16af1400>,
#  '整改': <gensim.models.keyedvectors.Vocab at 0x16af1438>,
#  '报告': <gensim.models.keyedvectors.Vocab at 0x16af1470>,
#  '其他': <gensim.models.keyedvectors.Vocab at 0x16af14a8>,
#  '做出': <gensim.models.keyedvectors.Vocab at 0x16af14e0>,
#  '不同': <gensim.models.keyedvectors.Vocab at 0x16af1518>,
#  '程度': <gensim.models.keyedvectors.Vocab at 0x16af1550>,
#  '对此': <gensim.models.keyedvectors.Vocab at 0x16af1588>,
#  '截至': <gensim.models.keyedvectors.Vocab at 0x16af15c0>,
#  '已有': <gensim.models.keyedvectors.Vocab at 0x16af15f8>,
#  '完成': <gensim.models.keyedvectors.Vocab at 0x16af1630>,
#  '此次': <gensim.models.keyedvectors.Vocab at 0x16af1668>,
#  '关注': <gensim.models.keyedvectors.Vocab at 0x16af16a0>,
#  '意见': <gensim.models.keyedvectors.Vocab at 0x16af16d8>,
#  '改革': <gensim.models.keyedvectors.Vocab at 0x16af1710>,
#  '取得': <gensim.models.keyedvectors.Vocab at 0x16af1748>,
#  '很大': <gensim.models.keyedvectors.Vocab at 0x16af1780>,
#  '经营': <gensim.models.keyedvectors.Vocab at 0x16af17b8>,
#  '督促': <gensim.models.keyedvectors.Vocab at 0x16af17f0>,
#  '原因': <gensim.models.keyedvectors.Vocab at 0x16af1828>,
#  '风险': <gensim.models.keyedvectors.Vocab at 0x16af1860>,
#  '规范': <gensim.models.keyedvectors.Vocab at 0x16af1898>,
#  '行为': <gensim.models.keyedvectors.Vocab at 0x16af18d0>,
#  '当前': <gensim.models.keyedvectors.Vocab at 0x16af1908>,
#  '证监会': <gensim.models.keyedvectors.Vocab at 0x16af1940>,
#  '召开': <gensim.models.keyedvectors.Vocab at 0x16af1978>,
#  '关于': <gensim.models.keyedvectors.Vocab at 0x16af19b0>,
#  '上市公司': <gensim.models.keyedvectors.Vocab at 0x16af19e8>,
#  '资产重组': <gensim.models.keyedvectors.Vocab at 0x16af1a20>,
#  '股票': <gensim.models.keyedvectors.Vocab at 0x16af1a58>,
#  '异常': <gensim.models.keyedvectors.Vocab at 0x16af1a90>,
#  '监管': <gensim.models.keyedvectors.Vocab at 0x16af1ac8>,
#  '征求意见': <gensim.models.keyedvectors.Vocab at 0x16af1b00>,
#  '稿': <gensim.models.keyedvectors.Vocab at 0x16af1b38>,
#  '向': <gensim.models.keyedvectors.Vocab at 0x16af1b70>,
#  '公开': <gensim.models.keyedvectors.Vocab at 0x16af1ba8>,
#  '该': <gensim.models.keyedvectors.Vocab at 0x16af1be0>,
#  '规定': <gensim.models.keyedvectors.Vocab at 0x16af1c18>,
#  '进入': <gensim.models.keyedvectors.Vocab at 0x16af1c50>,
#  '程序': <gensim.models.keyedvectors.Vocab at 0x16af1c88>,
#  '证券': <gensim.models.keyedvectors.Vocab at 0x16af1cc0>,
#  '立即': <gensim.models.keyedvectors.Vocab at 0x16af1cf8>,
#  '核查': <gensim.models.keyedvectors.Vocab at 0x16af1d30>,
#  '上报': <gensim.models.keyedvectors.Vocab at 0x16af1d68>,
#  '如': <gensim.models.keyedvectors.Vocab at 0x16af1da0>,
#  '涉嫌': <gensim.models.keyedvectors.Vocab at 0x16af1dd8>,
#  '决定': <gensim.models.keyedvectors.Vocab at 0x16af1e10>,
#  '应': <gensim.models.keyedvectors.Vocab at 0x16af1e48>,
#  '重组': <gensim.models.keyedvectors.Vocab at 0x16af1e80>,
#  '提示': <gensim.models.keyedvectors.Vocab at 0x16af1eb8>,
#  '明确': <gensim.models.keyedvectors.Vocab at 0x16af1ef0>,
#  '股东': <gensim.models.keyedvectors.Vocab at 0x16af1f28>,
#  '控制': <gensim.models.keyedvectors.Vocab at 0x16af1f60>,
#  '占': <gensim.models.keyedvectors.Vocab at 0x16af1f98>,
#  '本次': <gensim.models.keyedvectors.Vocab at 0x16af1fd0>,
#  '比例': <gensim.models.keyedvectors.Vocab at 0x16af6048>,
#  '以上': <gensim.models.keyedvectors.Vocab at 0x16af6080>,
#  '因': <gensim.models.keyedvectors.Vocab at 0x16af60b8>,
#  '或者': <gensim.models.keyedvectors.Vocab at 0x16af60f0>,
#  '审核': <gensim.models.keyedvectors.Vocab at 0x16af6128>,
#  '网': <gensim.models.keyedvectors.Vocab at 0x16af6160>,
#  '台湾': <gensim.models.keyedvectors.Vocab at 0x16af6198>,
#  'Ａ': <gensim.models.keyedvectors.Vocab at 0x16af61d0>,
#  '钱': <gensim.models.keyedvectors.Vocab at 0x16af6208>,
#  '涉案': <gensim.models.keyedvectors.Vocab at 0x16af6240>,
#  '教授': <gensim.models.keyedvectors.Vocab at 0x16af6278>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x16af62b0>,
#  '领域': <gensim.models.keyedvectors.Vocab at 0x16af62e8>,
#  '由于': <gensim.models.keyedvectors.Vocab at 0x16af6320>,
#  '大学': <gensim.models.keyedvectors.Vocab at 0x16af6358>,
#  '或': <gensim.models.keyedvectors.Vocab at 0x16af6390>,
#  '冲击': <gensim.models.keyedvectors.Vocab at 0x16af63c8>,
#  '股市': <gensim.models.keyedvectors.Vocab at 0x16af6400>,
#  '大跌': <gensim.models.keyedvectors.Vocab at 0x16af6438>,
#  '国际': <gensim.models.keyedvectors.Vocab at 0x16af6470>,
#  '影响': <gensim.models.keyedvectors.Vocab at 0x16af64a8>,
#  '今日': <gensim.models.keyedvectors.Vocab at 0x16af64e0>,
#  '大幅': <gensim.models.keyedvectors.Vocab at 0x16af6518>,
#  '跳空': <gensim.models.keyedvectors.Vocab at 0x16af6550>,
#  '报': <gensim.models.keyedvectors.Vocab at 0x16af6588>,
#  '跌幅': <gensim.models.keyedvectors.Vocab at 0x16af65c0>,
#  '周期': <gensim.models.keyedvectors.Vocab at 0x16af65f8>,
#  '行业': <gensim.models.keyedvectors.Vocab at 0x16af6630>,
#  '疲软': <gensim.models.keyedvectors.Vocab at 0x16af6668>,
#  '相对': <gensim.models.keyedvectors.Vocab at 0x16af66a0>,
#  '餐饮': <gensim.models.keyedvectors.Vocab at 0x16af66d8>,
#  '旅游': <gensim.models.keyedvectors.Vocab at 0x16af6710>,
#  '指数': <gensim.models.keyedvectors.Vocab at 0x16af6748>,
#  '以内': <gensim.models.keyedvectors.Vocab at 0x16af6780>,
#  '投资者': <gensim.models.keyedvectors.Vocab at 0x16af67b8>,
#  '资金': <gensim.models.keyedvectors.Vocab at 0x16af67f0>,
#  '全面': <gensim.models.keyedvectors.Vocab at 0x16af6828>,
#  '重要': <gensim.models.keyedvectors.Vocab at 0x16af6860>,
#  '结束': <gensim.models.keyedvectors.Vocab at 0x16af6898>,
#  '一年': <gensim.models.keyedvectors.Vocab at 0x16af68d0>,
#  '增持': <gensim.models.keyedvectors.Vocab at 0x16af6908>,
#  '看来': <gensim.models.keyedvectors.Vocab at 0x16af6940>,
#  '并未': <gensim.models.keyedvectors.Vocab at 0x16af6978>,
#  '股价': <gensim.models.keyedvectors.Vocab at 0x16af69b0>,
#  '走势': <gensim.models.keyedvectors.Vocab at 0x16af69e8>,
#  '来看': <gensim.models.keyedvectors.Vocab at 0x16af6a20>,
#  '去年': <gensim.models.keyedvectors.Vocab at 0x16af6a58>,
#  '整体': <gensim.models.keyedvectors.Vocab at 0x16af6a90>,
#  '环境': <gensim.models.keyedvectors.Vocab at 0x16af6ac8>,
#  '比较': <gensim.models.keyedvectors.Vocab at 0x16af6b00>,
#  '下跌': <gensim.models.keyedvectors.Vocab at 0x16af6b38>,
#  '幅度': <gensim.models.keyedvectors.Vocab at 0x16af6b70>,
#  '显示': <gensim.models.keyedvectors.Vocab at 0x16af6ba8>,
#  '至今': <gensim.models.keyedvectors.Vocab at 0x16af6be0>,
#  '一直': <gensim.models.keyedvectors.Vocab at 0x16af6c18>,
#  '多次': <gensim.models.keyedvectors.Vocab at 0x16af6c50>,
#  '支撑': <gensim.models.keyedvectors.Vocab at 0x16af6c88>,
#  '再次': <gensim.models.keyedvectors.Vocab at 0x16af6cc0>,
#  '下降': <gensim.models.keyedvectors.Vocab at 0x16af6cf8>,
#  '尽管': <gensim.models.keyedvectors.Vocab at 0x16af6d30>,
#  '试点': <gensim.models.keyedvectors.Vocab at 0x16af6d68>,
#  '真正': <gensim.models.keyedvectors.Vocab at 0x16af6da0>,
#  '令': <gensim.models.keyedvectors.Vocab at 0x16af6dd8>,
#  '还是': <gensim.models.keyedvectors.Vocab at 0x16af6e10>,
#  '增速': <gensim.models.keyedvectors.Vocab at 0x16af6e48>,
#  '下滑': <gensim.models.keyedvectors.Vocab at 0x16af6e80>,
#  '有效': <gensim.models.keyedvectors.Vocab at 0x16af6eb8>,
#  '政策': <gensim.models.keyedvectors.Vocab at 0x16af6ef0>,
#  '过去': <gensim.models.keyedvectors.Vocab at 0x16af6f28>,
#  '产能': <gensim.models.keyedvectors.Vocab at 0x16af6f60>,
#  '结构': <gensim.models.keyedvectors.Vocab at 0x16af6f98>,
#  '转型': <gensim.models.keyedvectors.Vocab at 0x16af6fd0>,
#  '逐渐': <gensim.models.keyedvectors.Vocab at 0x16af9048>,
#  '背景': <gensim.models.keyedvectors.Vocab at 0x16af9080>,
#  '未来': <gensim.models.keyedvectors.Vocab at 0x16af90b8>,
#  '上涨': <gensim.models.keyedvectors.Vocab at 0x16af90f0>,
#  '空间': <gensim.models.keyedvectors.Vocab at 0x16af9128>,
#  '估值': <gensim.models.keyedvectors.Vocab at 0x16af9160>,
#  '较': <gensim.models.keyedvectors.Vocab at 0x16af9198>,
#  '低': <gensim.models.keyedvectors.Vocab at 0x16af91d0>,
#  '因此': <gensim.models.keyedvectors.Vocab at 0x16af9208>,
#  'Ｌ': <gensim.models.keyedvectors.Vocab at 0x16af9240>,
#  '型': <gensim.models.keyedvectors.Vocab at 0x16af9278>,
#  '年内': <gensim.models.keyedvectors.Vocab at 0x16af92b0>,
#  '意味着': <gensim.models.keyedvectors.Vocab at 0x16af92e8>,
#  '仍': <gensim.models.keyedvectors.Vocab at 0x16af9320>,
#  '新华网': <gensim.models.keyedvectors.Vocab at 0x16af9358>,
#  '行政': <gensim.models.keyedvectors.Vocab at 0x16af9390>,
#  '机构': <gensim.models.keyedvectors.Vocab at 0x16af93c8>,
#  '陈冲': <gensim.models.keyedvectors.Vocab at 0x16af9400>,
#  '在野党': <gensim.models.keyedvectors.Vocab at 0x16af9438>,
#  '立委': <gensim.models.keyedvectors.Vocab at 0x16af9470>,
#  '开放': <gensim.models.keyedvectors.Vocab at 0x16af94a8>,
#  '电价': <gensim.models.keyedvectors.Vocab at 0x16af94e0>,
#  '证所税': <gensim.models.keyedvectors.Vocab at 0x16af9518>,
#  '立法院': <gensim.models.keyedvectors.Vocab at 0x16af9550>,
#  '依法': <gensim.models.keyedvectors.Vocab at 0x16af9588>,
#  '造成': <gensim.models.keyedvectors.Vocab at 0x16af95c0>,
#  '未': <gensim.models.keyedvectors.Vocab at 0x16af95f8>,
#  '承诺': <gensim.models.keyedvectors.Vocab at 0x16af9630>,
#  '陷入': <gensim.models.keyedvectors.Vocab at 0x16af9668>,
#  '民进党': <gensim.models.keyedvectors.Vocab at 0x16af96a0>,
#  '做': <gensim.models.keyedvectors.Vocab at 0x16af96d8>,
#  '立刻': <gensim.models.keyedvectors.Vocab at 0x16af9710>,
#  '停止': <gensim.models.keyedvectors.Vocab at 0x16af9748>,
#  '呼吁': <gensim.models.keyedvectors.Vocab at 0x16af9780>,
#  '会议': <gensim.models.keyedvectors.Vocab at 0x16af97b8>,
#  '随后': <gensim.models.keyedvectors.Vocab at 0x16af97f0>,
#  '人数': <gensim.models.keyedvectors.Vocab at 0x16af9828>,
#  '历史': <gensim.models.keyedvectors.Vocab at 0x16af9860>,
#  '超过': <gensim.models.keyedvectors.Vocab at 0x16af9898>,
#  '…': <gensim.models.keyedvectors.Vocab at 0x16af98d0>,
#  '地区': <gensim.models.keyedvectors.Vocab at 0x16af9908>,
#  '遭遇': <gensim.models.keyedvectors.Vocab at 0x16af9940>,
#  '至少': <gensim.models.keyedvectors.Vocab at 0x16af9978>,
#  '来': <gensim.models.keyedvectors.Vocab at 0x16af99b0>,
#  '最': <gensim.models.keyedvectors.Vocab at 0x16af99e8>,
#  '一种': <gensim.models.keyedvectors.Vocab at 0x16af9a20>,
#  '特殊': <gensim.models.keyedvectors.Vocab at 0x16af9a58>,
#  '大肠杆菌': <gensim.models.keyedvectors.Vocab at 0x16af9a90>,
#  '引发': <gensim.models.keyedvectors.Vocab at 0x16af9ac8>,
#  '一名': <gensim.models.keyedvectors.Vocab at 0x16af9b00>,
#  '儿童': <gensim.models.keyedvectors.Vocab at 0x16af9b38>,
#  '疾病': <gensim.models.keyedvectors.Vocab at 0x16af9b70>,
#  '预防': <gensim.models.keyedvectors.Vocab at 0x16af9ba8>,
#  '医院': <gensim.models.keyedvectors.Vocab at 0x16af9be0>,
#  '上周': <gensim.models.keyedvectors.Vocab at 0x16af9c18>,
#  '曾': <gensim.models.keyedvectors.Vocab at 0x16af9c50>,
#  '病菌': <gensim.models.keyedvectors.Vocab at 0x16af9c88>,
#  '导致': <gensim.models.keyedvectors.Vocab at 0x16af9cc0>,
#  '民众': <gensim.models.keyedvectors.Vocab at 0x16af9cf8>,
#  '研究': <gensim.models.keyedvectors.Vocab at 0x16af9d30>,
#  '才': <gensim.models.keyedvectors.Vocab at 0x16af9d68>,
#  '确认': <gensim.models.keyedvectors.Vocab at 0x16af9da0>,
#  '长': <gensim.models.keyedvectors.Vocab at 0x16af9dd8>,
#  '－': <gensim.models.keyedvectors.Vocab at 0x16af9e10>,
#  '天': <gensim.models.keyedvectors.Vocab at 0x16af9e48>,
#  '严重': <gensim.models.keyedvectors.Vocab at 0x16af9e80>,
#  '降低': <gensim.models.keyedvectors.Vocab at 0x16af9eb8>,
#  '证实': <gensim.models.keyedvectors.Vocab at 0x16af9ef0>,
#  '提醒': <gensim.models.keyedvectors.Vocab at 0x16af9f28>,
#  '避免': <gensim.models.keyedvectors.Vocab at 0x16af9f60>,
#  '需': <gensim.models.keyedvectors.Vocab at 0x16af9f98>,
#  '食物': <gensim.models.keyedvectors.Vocab at 0x16af9fd0>,
#  '老': <gensim.models.keyedvectors.Vocab at 0x16afd048>,
#  '相机': <gensim.models.keyedvectors.Vocab at 0x16afd080>,
#  '制造': <gensim.models.keyedvectors.Vocab at 0x16afd0b8>,
#  '生产线': <gensim.models.keyedvectors.Vocab at 0x16afd0f0>,
#  '阶段': <gensim.models.keyedvectors.Vocab at 0x16afd128>,
#  '生产': <gensim.models.keyedvectors.Vocab at 0x16afd160>,
#  '产业': <gensim.models.keyedvectors.Vocab at 0x16afd198>,
#  '此外': <gensim.models.keyedvectors.Vocab at 0x16afd1d0>,
#  '人们': <gensim.models.keyedvectors.Vocab at 0x16afd208>,
#  '债务': <gensim.models.keyedvectors.Vocab at 0x16afd240>,
#  '加上': <gensim.models.keyedvectors.Vocab at 0x16afd278>,
#  '宽松': <gensim.models.keyedvectors.Vocab at 0x16afd2b0>,
#  '央行': <gensim.models.keyedvectors.Vocab at 0x16afd2e8>,
#  '降息': <gensim.models.keyedvectors.Vocab at 0x16afd320>,
#  '欧债': <gensim.models.keyedvectors.Vocab at 0x16afd358>,
#  '危机': <gensim.models.keyedvectors.Vocab at 0x16afd390>,
#  '全球': <gensim.models.keyedvectors.Vocab at 0x16afd3c8>,
#  '新一轮': <gensim.models.keyedvectors.Vocab at 0x16afd400>,
#  '量化': <gensim.models.keyedvectors.Vocab at 0x16afd438>,
#  '利率': <gensim.models.keyedvectors.Vocab at 0x16afd470>,
#  '基点': <gensim.models.keyedvectors.Vocab at 0x16afd4a8>,
#  '符合': <gensim.models.keyedvectors.Vocab at 0x16afd4e0>,
#  '预期': <gensim.models.keyedvectors.Vocab at 0x16afd518>,
#  '及': <gensim.models.keyedvectors.Vocab at 0x16afd550>,
#  '受': <gensim.models.keyedvectors.Vocab at 0x16afd588>,
#  '银行业': <gensim.models.keyedvectors.Vocab at 0x16afd5c0>,
#  '研究员': <gensim.models.keyedvectors.Vocab at 0x16afd5f8>,
#  '增长': <gensim.models.keyedvectors.Vocab at 0x16afd630>,
#  '分析': <gensim.models.keyedvectors.Vocab at 0x16afd668>,
#  '动力': <gensim.models.keyedvectors.Vocab at 0x16afd6a0>,
#  '一季度': <gensim.models.keyedvectors.Vocab at 0x16afd6d8>,
#  '数据': <gensim.models.keyedvectors.Vocab at 0x16afd710>,
#  '低于': <gensim.models.keyedvectors.Vocab at 0x16afd748>,
#  '反弹': <gensim.models.keyedvectors.Vocab at 0x16afd780>,
#  '通胀': <gensim.models.keyedvectors.Vocab at 0x16afd7b8>,
#  'Ｉ': <gensim.models.keyedvectors.Vocab at 0x16afd7f0>,
#  '均': <gensim.models.keyedvectors.Vocab at 0x16afd828>,
#  '日本': <gensim.models.keyedvectors.Vocab at 0x16afd860>,
#  '同比': <gensim.models.keyedvectors.Vocab at 0x16afd898>,
#  '短期': <gensim.models.keyedvectors.Vocab at 0x16afd8d0>,
#  '然而': <gensim.models.keyedvectors.Vocab at 0x16afd908>,
#  '明显': <gensim.models.keyedvectors.Vocab at 0x16afd940>,
#  '刺激': <gensim.models.keyedvectors.Vocab at 0x16afd978>,
#  '过程': <gensim.models.keyedvectors.Vocab at 0x16afd9b0>,
#  '使得': <gensim.models.keyedvectors.Vocab at 0x16afd9e8>,
#  '货币政策': <gensim.models.keyedvectors.Vocab at 0x16afda20>,
#  '难以': <gensim.models.keyedvectors.Vocab at 0x16afda58>,
#  '实体': <gensim.models.keyedvectors.Vocab at 0x16afda90>,
#  '作用': <gensim.models.keyedvectors.Vocab at 0x16afdac8>,
#  '损失': <gensim.models.keyedvectors.Vocab at 0x16afdb00>,
#  '外部': <gensim.models.keyedvectors.Vocab at 0x16afdb38>,
#  '流动性': <gensim.models.keyedvectors.Vocab at 0x16afdb70>,
#  '若': <gensim.models.keyedvectors.Vocab at 0x16afdba8>,
#  '维持': <gensim.models.keyedvectors.Vocab at 0x16afdbe0>,
#  '出口': <gensim.models.keyedvectors.Vocab at 0x16afdc18>,
#  '应对': <gensim.models.keyedvectors.Vocab at 0x16afdc50>,
#  '需要': <gensim.models.keyedvectors.Vocab at 0x16afdc88>,
#  '民间': <gensim.models.keyedvectors.Vocab at 0x16afdcc0>,
#  '完': <gensim.models.keyedvectors.Vocab at 0x16afdcf8>,
#  '轻纺城': <gensim.models.keyedvectors.Vocab at 0x16afdd30>,
#  '资产': <gensim.models.keyedvectors.Vocab at 0x16afdd68>,
#  '方案': <gensim.models.keyedvectors.Vocab at 0x16afdda0>,
#  '获得': <gensim.models.keyedvectors.Vocab at 0x16afddd8>,
#  '中国证监会': <gensim.models.keyedvectors.Vocab at 0x16afde10>,
#  '条件': <gensim.models.keyedvectors.Vocab at 0x16afde48>,
#  '委': <gensim.models.keyedvectors.Vocab at 0x16afde80>,
#  '现金': <gensim.models.keyedvectors.Vocab at 0x16afdeb8>,
#  '发行': <gensim.models.keyedvectors.Vocab at 0x16afdef0>,
#  '股份': <gensim.models.keyedvectors.Vocab at 0x16afdf28>,
#  '有限公司': <gensim.models.keyedvectors.Vocab at 0x16afdf60>,
#  '事项': <gensim.models.keyedvectors.Vocab at 0x16afdf98>,
#  '文件': <gensim.models.keyedvectors.Vocab at 0x16afdfd0>,
#  '每股': <gensim.models.keyedvectors.Vocab at 0x16b01048>,
#  '价格': <gensim.models.keyedvectors.Vocab at 0x16b01080>,
#  '标的': <gensim.models.keyedvectors.Vocab at 0x16b010b8>,
#  '万股': <gensim.models.keyedvectors.Vocab at 0x16b010f0>,
#  '按': <gensim.models.keyedvectors.Vocab at 0x16b01128>,
#  '支付': <gensim.models.keyedvectors.Vocab at 0x16b01160>,
#  '债券': <gensim.models.keyedvectors.Vocab at 0x16b01198>,
#  '货币': <gensim.models.keyedvectors.Vocab at 0x16b011d0>,
#  '作为': <gensim.models.keyedvectors.Vocab at 0x16b01208>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x16b01240>,
#  '此前': <gensim.models.keyedvectors.Vocab at 0x16b01278>,
#  '最终': <gensim.models.keyedvectors.Vocab at 0x16b012b0>,
#  '相应': <gensim.models.keyedvectors.Vocab at 0x16b012e8>,
#  '租金': <gensim.models.keyedvectors.Vocab at 0x16b01320>,
#  '上述': <gensim.models.keyedvectors.Vocab at 0x16b01358>,
#  '确定': <gensim.models.keyedvectors.Vocab at 0x16b01390>,
#  '开发': <gensim.models.keyedvectors.Vocab at 0x16b013c8>,
#  '非': <gensim.models.keyedvectors.Vocab at 0x16b01400>,
#  '／': <gensim.models.keyedvectors.Vocab at 0x16b01438>,
#  '股': <gensim.models.keyedvectors.Vocab at 0x16b01470>,
#  '不足': <gensim.models.keyedvectors.Vocab at 0x16b014a8>,
#  '解决': <gensim.models.keyedvectors.Vocab at 0x16b014e0>,
#  '启运': <gensim.models.keyedvectors.Vocab at 0x16b01518>,
#  '港': <gensim.models.keyedvectors.Vocab at 0x16b01550>,
#  '退税': <gensim.models.keyedvectors.Vocab at 0x16b01588>,
#  '通知': <gensim.models.keyedvectors.Vocab at 0x16b015c0>,
#  '自治区': <gensim.models.keyedvectors.Vocab at 0x16b015f8>,
#  '广东': <gensim.models.keyedvectors.Vocab at 0x16b01630>,
#  '国务院': <gensim.models.keyedvectors.Vocab at 0x16b01668>,
#  '有关': <gensim.models.keyedvectors.Vocab at 0x16b016a0>,
#  '青岛': <gensim.models.keyedvectors.Vocab at 0x16b016d8>,
#  '武汉': <gensim.models.keyedvectors.Vocab at 0x16b01710>,
#  '保税': <gensim.models.keyedvectors.Vocab at 0x16b01748>,
#  '以下': <gensim.models.keyedvectors.Vocab at 0x16b01780>,
#  '离境': <gensim.models.keyedvectors.Vocab at 0x16b017b8>,
#  '属于': <gensim.models.keyedvectors.Vocab at 0x16b017f0>,
#  '具体': <gensim.models.keyedvectors.Vocab at 0x16b01828>,
#  '无': <gensim.models.keyedvectors.Vocab at 0x16b01860>,
#  '违法': <gensim.models.keyedvectors.Vocab at 0x16b01898>,
#  '主管': <gensim.models.keyedvectors.Vocab at 0x16b018d0>,
#  '税务机关': <gensim.models.keyedvectors.Vocab at 0x16b01908>,
#  '办理': <gensim.models.keyedvectors.Vocab at 0x16b01940>,
#  '手续': <gensim.models.keyedvectors.Vocab at 0x16b01978>,
#  '主要': <gensim.models.keyedvectors.Vocab at 0x16b019b0>,
#  '备案': <gensim.models.keyedvectors.Vocab at 0x16b019e8>,
#  '申请': <gensim.models.keyedvectors.Vocab at 0x16b01a20>,
#  '报关单': <gensim.models.keyedvectors.Vocab at 0x16b01a58>,
#  '核销': <gensim.models.keyedvectors.Vocab at 0x16b01a90>,
#  '国家税务总局': <gensim.models.keyedvectors.Vocab at 0x16b01ac8>,
#  '内容': <gensim.models.keyedvectors.Vocab at 0x16b01b00>,
#  '项目': <gensim.models.keyedvectors.Vocab at 0x16b01b38>,
#  '增加': <gensim.models.keyedvectors.Vocab at 0x16b01b70>,
#  '调整': <gensim.models.keyedvectors.Vocab at 0x16b01ba8>,
#  '日起': <gensim.models.keyedvectors.Vocab at 0x16b01be0>,
#  '不再': <gensim.models.keyedvectors.Vocab at 0x16b01c18>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x16b01c50>,
#  '制定': <gensim.models.keyedvectors.Vocab at 0x16b01c88>,
#  '各地': <gensim.models.keyedvectors.Vocab at 0x16b01cc0>,
#  '沟通': <gensim.models.keyedvectors.Vocab at 0x16b01cf8>,
#  '配合': <gensim.models.keyedvectors.Vocab at 0x16b01d30>,
#  '机制': <gensim.models.keyedvectors.Vocab at 0x16b01d68>,
#  '诚信': <gensim.models.keyedvectors.Vocab at 0x16b01da0>,
#  '出': <gensim.models.keyedvectors.Vocab at 0x16b01dd8>,
#  '财政部': <gensim.models.keyedvectors.Vocab at 0x16b01e10>,
#  '劳务': <gensim.models.keyedvectors.Vocab at 0x16b01e48>,
#  '本': <gensim.models.keyedvectors.Vocab at 0x16b01e80>,
#  '执行': <gensim.models.keyedvectors.Vocab at 0x16b01eb8>,
#  '多家': <gensim.models.keyedvectors.Vocab at 0x16b01ef0>,
#  '银行': <gensim.models.keyedvectors.Vocab at 0x16b01f28>,
#  '员工': <gensim.models.keyedvectors.Vocab at 0x16b01f60>,
#  '不可': <gensim.models.keyedvectors.Vocab at 0x16b01f98>,
#  '存款': <gensim.models.keyedvectors.Vocab at 0x16b01fd0>,
#  '任务': <gensim.models.keyedvectors.Vocab at 0x16b04048>,
#  '某': <gensim.models.keyedvectors.Vocab at 0x16b04080>,
#  '业务': <gensim.models.keyedvectors.Vocab at 0x16b040b8>,
#  '指标': <gensim.models.keyedvectors.Vocab at 0x16b040f0>,
#  '年化': <gensim.models.keyedvectors.Vocab at 0x16b04128>,
#  '理财产品': <gensim.models.keyedvectors.Vocab at 0x16b04160>,
#  '她': <gensim.models.keyedvectors.Vocab at 0x16b04198>,
#  '领导': <gensim.models.keyedvectors.Vocab at 0x16b041d0>,
#  '见': <gensim.models.keyedvectors.Vocab at 0x16b04208>,
#  '客户': <gensim.models.keyedvectors.Vocab at 0x16b04240>,
#  '希望': <gensim.models.keyedvectors.Vocab at 0x16b04278>,
#  '吸引': <gensim.models.keyedvectors.Vocab at 0x16b042b0>,
#  '小时': <gensim.models.keyedvectors.Vocab at 0x16b042e8>,
#  '费用': <gensim.models.keyedvectors.Vocab at 0x16b04320>,
#  '各项': <gensim.models.keyedvectors.Vocab at 0x16b04358>,
#  '有些': <gensim.models.keyedvectors.Vocab at 0x16b04390>,
#  '打': <gensim.models.keyedvectors.Vocab at 0x16b043c8>,
#  '维护': <gensim.models.keyedvectors.Vocab at 0x16b04400>,
#  '一下': <gensim.models.keyedvectors.Vocab at 0x16b04438>,
#  '基准利率': <gensim.models.keyedvectors.Vocab at 0x16b04470>,
#  '模式': <gensim.models.keyedvectors.Vocab at 0x16b044a8>,
#  '比': <gensim.models.keyedvectors.Vocab at 0x16b044e0>,
#  '设置': <gensim.models.keyedvectors.Vocab at 0x16b04518>,
#  '人士': <gensim.models.keyedvectors.Vocab at 0x16b04550>,
#  '重庆': <gensim.models.keyedvectors.Vocab at 0x16b04588>,
#  '分行': <gensim.models.keyedvectors.Vocab at 0x16b045c0>,
#  '办公室': <gensim.models.keyedvectors.Vocab at 0x16b045f8>,
#  '一般': <gensim.models.keyedvectors.Vocab at 0x16b04630>,
#  '直接': <gensim.models.keyedvectors.Vocab at 0x16b04668>,
#  '左右': <gensim.models.keyedvectors.Vocab at 0x16b046a0>,
#  '达': <gensim.models.keyedvectors.Vocab at 0x16b046d8>,
#  '一年期': <gensim.models.keyedvectors.Vocab at 0x16b04710>,
#  '贷款': <gensim.models.keyedvectors.Vocab at 0x16b04748>,
#  '专家': <gensim.models.keyedvectors.Vocab at 0x16b04780>,
#  '市场化': <gensim.models.keyedvectors.Vocab at 0x16b047b8>,
#  '金融': <gensim.models.keyedvectors.Vocab at 0x16b047f0>,
#  '体系': <gensim.models.keyedvectors.Vocab at 0x16b04828>,
#  '只能': <gensim.models.keyedvectors.Vocab at 0x16b04860>,
#  '提高': <gensim.models.keyedvectors.Vocab at 0x16b04898>,
#  '针对': <gensim.models.keyedvectors.Vocab at 0x16b048d0>,
#  '这一': <gensim.models.keyedvectors.Vocab at 0x16b04908>,
#  '透露': <gensim.models.keyedvectors.Vocab at 0x16b04940>,
#  '各家': <gensim.models.keyedvectors.Vocab at 0x16b04978>,
#  '作出': <gensim.models.keyedvectors.Vocab at 0x16b049b0>,
#  '富国': <gensim.models.keyedvectors.Vocab at 0x16b049e8>,
#  '天盈': <gensim.models.keyedvectors.Vocab at 0x16b04a20>,
#  '分级': <gensim.models.keyedvectors.Vocab at 0x16b04a58>,
#  '债基': <gensim.models.keyedvectors.Vocab at 0x16b04a90>,
#  '份额': <gensim.models.keyedvectors.Vocab at 0x16b04ac8>,
#  '约定': <gensim.models.keyedvectors.Vocab at 0x16b04b00>,
#  '收益率': <gensim.models.keyedvectors.Vocab at 0x16b04b38>,
#  '申购': <gensim.models.keyedvectors.Vocab at 0x16b04b70>,
#  '月份': <gensim.models.keyedvectors.Vocab at 0x16b04ba8>,
#  '产品': <gensim.models.keyedvectors.Vocab at 0x16b04be0>,
#  '打开': <gensim.models.keyedvectors.Vocab at 0x16b04c18>,
#  '券商': <gensim.models.keyedvectors.Vocab at 0x16b04c50>,
#  '收益': <gensim.models.keyedvectors.Vocab at 0x16b04c88>,
#  '业内人士': <gensim.models.keyedvectors.Vocab at 0x16b04cc0>,
#  '放松': <gensim.models.keyedvectors.Vocab at 0x16b04cf8>,
#  '回落': <gensim.models.keyedvectors.Vocab at 0x16b04d30>,
#  '趋势': <gensim.models.keyedvectors.Vocab at 0x16b04d68>,
#  '基金': <gensim.models.keyedvectors.Vocab at 0x16b04da0>,
#  '月底': <gensim.models.keyedvectors.Vocab at 0x16b04dd8>,
#  '运作': <gensim.models.keyedvectors.Vocab at 0x16b04e10>,
#  '定存': <gensim.models.keyedvectors.Vocab at 0x16b04e48>,
#  '赎回': <gensim.models.keyedvectors.Vocab at 0x16b04e80>,
#  '承担': <gensim.models.keyedvectors.Vocab at 0x16b04eb8>,
#  '两个': <gensim.models.keyedvectors.Vocab at 0x16b04ef0>,
#  '而且': <gensim.models.keyedvectors.Vocab at 0x16b04f28>,
#  '固定': <gensim.models.keyedvectors.Vocab at 0x16b04f60>,
#  '更加': <gensim.models.keyedvectors.Vocab at 0x16b04f98>,
#  '存贷款': <gensim.models.keyedvectors.Vocab at 0x16b04fd0>,
#  '小': <gensim.models.keyedvectors.Vocab at 0x16b08048>,
#  '首次': <gensim.models.keyedvectors.Vocab at 0x16b08080>,
#  '普遍': <gensim.models.keyedvectors.Vocab at 0x16b080b8>,
#  '基本上': <gensim.models.keyedvectors.Vocab at 0x16b080f0>,
#  '保证': <gensim.models.keyedvectors.Vocab at 0x16b08128>,
#  '亏损': <gensim.models.keyedvectors.Vocab at 0x16b08160>,
#  '类型': <gensim.models.keyedvectors.Vocab at 0x16b08198>,
#  '业内': <gensim.models.keyedvectors.Vocab at 0x16b081d0>,
#  '部': <gensim.models.keyedvectors.Vocab at 0x16b08208>,
#  '总监': <gensim.models.keyedvectors.Vocab at 0x16b08240>,
#  '前提': <gensim.models.keyedvectors.Vocab at 0x16b08278>,
#  '杠杆': <gensim.models.keyedvectors.Vocab at 0x16b082b0>,
#  '从而': <gensim.models.keyedvectors.Vocab at 0x16b082e8>,
#  '推动': <gensim.models.keyedvectors.Vocab at 0x16b08320>,
#  '经理': <gensim.models.keyedvectors.Vocab at 0x16b08358>,
#  ...}

# %%
#查看词向量
model.wv.vectors
# Out:
# array([[ 0.20448099,  0.628497  ,  0.06810124, ..., -0.17633776,
#          0.30054116, -0.11800776],
#        [ 0.2159384 ,  0.6596818 ,  0.07596891, ..., -0.18513583,
#          0.31441703, -0.12257133],
#        [ 0.20915683,  0.6387336 ,  0.07081808, ..., -0.1762327 ,
#          0.30332926, -0.11996534],
#        ...,
#        [ 0.01259028,  0.04152717,  0.00391793, ..., -0.01223294,
#          0.01961918, -0.00736018],
#        [ 0.02844506,  0.08855458,  0.01002395, ..., -0.02434964,
#          0.04078903, -0.01744588],
#        [ 0.02610435,  0.0791555 ,  0.00743924, ..., -0.02228414,
#          0.03874483, -0.01394919]], dtype=float32)
