# %%
import numpy as np
import time
import torch
from torch import nn,optim
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sys.path.append(r'F:\study\ml\python_packages')
import d2l

# %%
def get_data_ch7():
    data = np.genfromtxt(
        r'F:\study\ml\DataSet\airfoil_self_noise\airfoil_self_noise.dat',
        delimiter='\t')
    data = (data - data.mean(axis=0)) / data.std(axis=0)
    return torch.tensor(data[:1500, :-1], dtype=torch.float32),\
    torch.tensor(data[:1500,-1],dtype=torch.float32)

# %%
features,labels=get_data_ch7()
features.shape
# Out:
# torch.Size([1500, 5])

# %%
features[:5]
# Out:
# tensor([[-0.6620, -1.1464,  1.7993,  1.3129, -0.6448],
#         [-0.5986, -1.1464,  1.7993,  1.3129, -0.6448],
#         [-0.5192, -1.1464,  1.7993,  1.3129, -0.6448],
#         [-0.4082, -1.1464,  1.7993,  1.3129, -0.6448],
#         [-0.2813, -1.1464,  1.7993,  1.3129, -0.6448]])

# %%
a=np.array([[1,2],[3,4]])
a.mean(axis=0)
# Out:
# array([2., 3.])

# %%
def sgd(params,states,hyperparams,batch_size):
    for p in params:
        print('p.grad : ',p.grad.data)
        p.data -= hyperparams['lr'] * p.grad.data/batch_size

# %%
def linreg(x,w,b):
    return torch.mm(x,w)+b

# %%
def squared_loss(y_hat,y):
    return ((y_hat - y.view(y_hat.size()) )**2) /2

# %% [markdown]
# - dl/dw=dl/y * dy/dw
# =2(y_hat-y) * x=2(xw+b-y)*x
#
# - dl/db=dl/dy * dy/db
# =2(y_hat-y) * 1=2(xw+b-y)

# %%
def train_ch7(optimizer_fn,
              states,
              hyperparams,
              features,
              labels,
              batch_size=10,
              num_epochs=2):
#     net, loss = linreg, squared_loss
    net, loss = linreg, nn.MSELoss()
    w = torch.nn.Parameter(torch.tensor(np.random.normal(
        0, 1, size=(features.shape[1], 1)),dtype=torch.float32),
                           requires_grad=True)
    b = torch.nn.Parameter(torch.zeros(1, dtype=torch.float32),
                           requires_grad=True)

    def eval_loss():
        return loss(net(features, w, b), labels).mean().item()/2
    
    def wx_grad(x,y,w,b,batch_size):
        return torch.mm(x.transpose(1,0),(torch.mm(x,w)+b-y.view(batch_size,1)) )*2 /1500/2

    ls = [eval_loss()]
    data_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
        features, labels),batch_size,shuffle=True)
    
#     optimizer=optimizer_fn(net.parameters(),**optimizer_hyperparams)
    for _ in range(num_epochs):
        start = time.time()
        for batch_i, (X, y) in enumerate(data_iter):
#             print('--------------------------------------')
#             print('wx_grad :',wx_grad(X,y,w,b,batch_size))
#             print('--------------------------------------')
            l = loss(net(X, w, b), y).mean()/2
            l.backward()
#             optimizer_fn([w, b], hyperparams)
#             optimizer.step()
            print('l : ',l)
            print('eval l :',eval_loss())
#             if w.grad is not None:
#                 print('---------grad zero--------------')
            w.grad.data.zero_()
            b.grad.data.zero_()
            l.backward()
        
            optimizer_fn([w, b], states, hyperparams)
            if (batch_i + 1) * batch_size % 100 == 0:
                ls.append(eval_loss())
    print('loss : %f ,%f sec per epoch' % (ls[-1], time.time() - start))
    plt.plot(np.linspace(0,num_epochs,len(ls)),ls)
    plt.xlabel('epoch')
    plt.ylabel('loss')

# %%
def train_sgd(lr,batch_size,num_epochs=2):
    train_ch7(sgd,None,{'lr':lr},features,labels,batch_size,num_epochs)

# %%
train_sgd(1,1500,6)
# Out:
# l :  tensor(1.9870, grad_fn=<DivBackward0>)
# eval l : 1.9870355129241943
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-153-fc94e21e71d4> in <module>()
# ----> 1 train_sgd(1,1500,6)
#
# <ipython-input-152-6eeeca638a9c> in train_sgd(lr, batch_size, num_epochs)
#       1 def train_sgd(lr,batch_size,num_epochs=2):
# ----> 2     train_ch7(sgd,None,{'lr':lr},features,labels,batch_size,num_epochs)
#
# <ipython-input-151-d080427b8b42> in train_ch7(optimizer_fn, states, hyperparams, features, labels, batch_size, num_epochs)
#      41             w.grad.data.zero_()
#      42             b.grad.data.zero_()
# ---> 43             l.backward()
#      44
#      45             optimizer_fn([w, b], states, hyperparams)
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# D:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# RuntimeError: Trying to backward through the graph a second time, but the buffers have already been freed. Specify retain_graph=True when calling backward the first time.

# %%
train_sgd(0.005,1)
# Out:
# p.grad :  tensor([[ 0.4816],
#         [ 0.3727],
#         [-1.2499],
#         [ 0.4062],
#         [-0.5901]])
# p.grad :  tensor([1.3631])
# l :  tensor(0.9290, grad_fn=<DivBackward0>)
# eval l : 2.649698495864868
# p.grad :  tensor([[ 0.0659],
#         [ 0.0069],
#         [ 0.0166],
#         [ 0.1289],
#         [-0.0270]])
# p.grad :  tensor([0.0982])
# l :  tensor(0.0048, grad_fn=<DivBackward0>)
# eval l : 2.6501402854919434
# p.grad :  tensor([[ 1.4193],
#         [-1.0028],
#         [-1.0397],
#         [-0.6327],
#         [-0.7128]])
# p.grad :  tensor([0.8747])
# l :  tensor(0.3826, grad_fn=<DivBackward0>)
# eval l : 2.648372173309326
# p.grad :  tensor([[ 0.1111],
#         [ 0.2117],
#         [-0.1536],
#         [-0.2700],
#         [ 0.4691]])
# p.grad :  tensor([-0.9059])
# l :  tensor(0.4103, grad_fn=<DivBackward0>)
# eval l : 2.6420907974243164
# p.grad :  tensor([[ 2.1750],
#         [-0.2233],
#         [-2.5118],
#         [ 1.8457],
#         [-0.2345]])
# p.grad :  tensor([-2.5516])
# l :  tensor(3.2553, grad_fn=<DivBackward0>)
# eval l : 2.6232118606567383
# p.grad :  tensor([[-1.1255],
#         [ 1.9238],
#         [-3.0194],
#         [ 1.2139],
#         [ 1.0261]])
# p.grad :  tensor([-1.6781])
# l :  tensor(1.4081, grad_fn=<DivBackward0>)
# eval l : 2.582213878631592
# p.grad :  tensor([[ 0.5907],
#         [-0.1838],
#         [-2.0673],
#         [-2.7573],
#         [ 0.1117]])
# p.grad :  tensor([-2.1001])
# l :  tensor(2.2052, grad_fn=<DivBackward0>)
# eval l : 2.5582900047302246
# p.grad :  tensor([[-2.0778],
#         [ 6.6366],
#         [-3.0270],
#         [ 3.3435],
#         [ 1.9910]])
# p.grad :  tensor([2.5466])
# l :  tensor(3.2426, grad_fn=<DivBackward0>)
# eval l : 2.4895663261413574
# p.grad :  tensor([[-3.0111],
#         [ 6.7790],
#         [-1.6999],
#         [-3.2900],
#         [14.4307]])
# p.grad :  tensor([4.5483])
# l :  tensor(10.3435, grad_fn=<DivBackward0>)
# eval l : 2.3572208881378174
# p.grad :  tensor([[-0.0823],
#         [-0.7691],
#         [-0.7974],
#         [-0.8257],
#         [-0.5461]])
# p.grad :  tensor([0.6709])
# l :  tensor(0.2250, grad_fn=<DivBackward0>)
# eval l : 2.3561811447143555
# p.grad :  tensor([[ 2.7694],
#         [ 2.4729],
#         [-6.9597],
#         [ 2.7979],
#         [ 1.8191]])
# p.grad :  tensor([-3.8680])
# l :  tensor(7.4808, grad_fn=<DivBackward0>)
# eval l : 2.277033567428589
# p.grad :  tensor([[-1.1378],
#         [ 2.8521],
#         [-1.8889],
#         [ 0.4736],
#         [ 0.6565]])
# p.grad :  tensor([1.5892])
# l :  tensor(1.2627, grad_fn=<DivBackward0>)
# eval l : 2.246161937713623
# p.grad :  tensor([[ 0.9987],
#         [-0.2895],
#         [ 0.6059],
#         [ 0.1834],
#         [-0.3209]])
# p.grad :  tensor([0.6155])
# l :  tensor(0.1894, grad_fn=<DivBackward0>)
# eval l : 2.2530035972595215
# p.grad :  tensor([[ 2.5657],
#         [ 3.0253],
#         [-6.0967],
#         [ 2.4510],
#         [ 1.8607]])
# p.grad :  tensor([-3.3884])
# l :  tensor(5.7405, grad_fn=<DivBackward0>)
# eval l : 2.180621385574341
# p.grad :  tensor([[ 1.2870],
#         [-0.4669],
#         [-0.2964],
#         [ 1.0414],
#         [-0.5498]])
# p.grad :  tensor([0.7932])
# l :  tensor(0.3146, grad_fn=<DivBackward0>)
# eval l : 2.1836748123168945
# p.grad :  tensor([[ 0.8445],
#         [-0.3705],
#         [ 0.3869],
#         [ 0.7487],
#         [-0.1039]])
# p.grad :  tensor([-1.0351])
# l :  tensor(0.5357, grad_fn=<DivBackward0>)
# eval l : 2.189518451690674
# p.grad :  tensor([[ 0.3369],
#         [-0.2514],
#         [ 0.3062],
#         [-0.2250],
#         [-0.1816]])
# p.grad :  tensor([0.3111])
# l :  tensor(0.0484, grad_fn=<DivBackward0>)
# eval l : 2.1931347846984863
# p.grad :  tensor([[-0.4854],
#         [ 1.1091],
#         [-0.4445],
#         [ 1.5613],
#         [ 2.0480]])
# p.grad :  tensor([1.1892])
# l :  tensor(0.7071, grad_fn=<DivBackward0>)
# eval l : 2.1782662868499756
# p.grad :  tensor([[ 0.2132],
#         [ 1.3429],
#         [ 0.4320],
#         [-1.8434],
#         [ 2.3637]])
# p.grad :  tensor([2.5484])
# l :  tensor(3.2471, grad_fn=<DivBackward0>)
# eval l : 2.1594035625457764
# p.grad :  tensor([[ 0.6717],
#         [-0.3650],
#         [-0.2318],
#         [ 0.1848],
#         [-0.4212]])
# p.grad :  tensor([0.6201])
# l :  tensor(0.1923, grad_fn=<DivBackward0>)
# eval l : 2.1608941555023193
# p.grad :  tensor([[ 3.5207],
#         [ 2.8530],
#         [-8.0294],
#         [-5.8590],
#         [ 2.3364]])
# p.grad :  tensor([-4.4625])
# l :  tensor(9.9570, grad_fn=<DivBackward0>)
# eval l : 2.055870294570923
# p.grad :  tensor([[ 1.2144],
#         [-0.5273],
#         [ 1.1037],
#         [-1.3799],
#         [-0.5159]])
# p.grad :  tensor([1.1211])
# l :  tensor(0.6285, grad_fn=<DivBackward0>)
# eval l : 2.0646817684173584
# p.grad :  tensor([[12.5646],
#         [-1.0118],
#         [-3.5892],
#         [ 0.8999],
#         [-2.3582]])
# p.grad :  tensor([3.0196])
# l :  tensor(4.5590, grad_fn=<DivBackward0>)
# eval l : 2.0399997234344482
# p.grad :  tensor([[ 1.5857],
#         [-0.8574],
#         [ 0.8952],
#         [-3.1448],
#         [ 0.1514]])
# p.grad :  tensor([-2.3952])
# l :  tensor(2.8685, grad_fn=<DivBackward0>)
# eval l : 2.0420162677764893
# p.grad :  tensor([[ 1.3626],
#         [ 0.4205],
#         [-0.3051],
#         [-2.3626],
#         [ 0.9757]])
# p.grad :  tensor([-1.7995])
# l :  tensor(1.6191, grad_fn=<DivBackward0>)
# eval l : 2.026714324951172
# p.grad :  tensor([[-0.9328],
#         [ 0.4738],
#         [-0.4068],
#         [-0.5426],
#         [ 0.2828]])
# p.grad :  tensor([-0.4132])
# l :  tensor(0.0854, grad_fn=<DivBackward0>)
# eval l : 2.0197970867156982
# p.grad :  tensor([[ 0.3465],
#         [-0.0715],
#         [-0.2538],
#         [ 0.2804],
#         [-0.1672]])
# p.grad :  tensor([0.2135])
# l :  tensor(0.0228, grad_fn=<DivBackward0>)
# eval l : 2.0192201137542725
# p.grad :  tensor([[ 2.1687],
#         [ 1.6993],
#         [-4.7825],
#         [ 1.9226],
#         [ 1.2500]])
# p.grad :  tensor([-2.6580])
# l :  tensor(3.5324, grad_fn=<DivBackward0>)
# eval l : 1.9708129167556763
# p.grad :  tensor([[0.0029],
#         [0.0273],
#         [0.0218],
#         [0.0293],
#         [0.0187]])
# p.grad :  tensor([-0.0238])
# l :  tensor(0.0003, grad_fn=<DivBackward0>)
# eval l : 1.9708110094070435
# p.grad :  tensor([[-1.3113],
#         [ 1.7081],
#         [-0.6845],
#         [ 0.5458],
#         [ 3.5782]])
# p.grad :  tensor([1.8315])
# l :  tensor(1.6772, grad_fn=<DivBackward0>)
# eval l : 1.94339919090271
# p.grad :  tensor([[ 2.5110],
#         [ 1.4473],
#         [-5.5373],
#         [ 2.2261],
#         [ 1.2509]])
# p.grad :  tensor([-3.0775])
# l :  tensor(4.7355, grad_fn=<DivBackward0>)
# eval l : 1.8928736448287964
# p.grad :  tensor([[ 0.1815],
#         [ 0.7397],
#         [ 0.5916],
#         [-0.8471],
#         [ 0.5104]])
# p.grad :  tensor([-0.6452])
# l :  tensor(0.2081, grad_fn=<DivBackward0>)
# eval l : 1.8895041942596436
# p.grad :  tensor([[ 0.9062],
#         [ 0.9285],
#         [-1.1308],
#         [ 1.4138],
#         [ 0.6480]])
# p.grad :  tensor([-1.1487])
# l :  tensor(0.6597, grad_fn=<DivBackward0>)
# eval l : 1.8764410018920898
# p.grad :  tensor([[-2.1154],
#         [ 2.3584],
#         [-0.9451],
#         [-3.1124],
#         [ 5.9124]])
# p.grad :  tensor([2.5288])
# l :  tensor(3.1973, grad_fn=<DivBackward0>)
# eval l : 1.829115390777588
# p.grad :  tensor([[ 5.3114],
#         [ 7.1428],
#         [-4.4966],
#         [-3.5470],
#         [ 6.3858]])
# p.grad :  tensor([4.9036])
# l :  tensor(12.0227, grad_fn=<DivBackward0>)
# eval l : 1.7284423112869263
# p.grad :  tensor([[-2.4496],
#         [ 5.2553],
#         [-3.4806],
#         [ 0.8726],
#         [ 1.2097]])
# p.grad :  tensor([2.9282])
# l :  tensor(4.2872, grad_fn=<DivBackward0>)
# eval l : 1.684006690979004
# p.grad :  tensor([[-1.4108],
#         [ 2.5340],
#         [-1.0155],
#         [-1.9653],
#         [ 6.1357]])
# p.grad :  tensor([2.7170])
# l :  tensor(3.6910, grad_fn=<DivBackward0>)
# eval l : 1.643523931503296
# p.grad :  tensor([[0.0336],
#         [0.1196],
#         [0.2513],
#         [0.1982],
#         [0.2004]])
# p.grad :  tensor([-0.2741])
# l :  tensor(0.0376, grad_fn=<DivBackward0>)
# eval l : 1.6443204879760742
# p.grad :  tensor([[-1.2702],
#         [ 2.7939],
#         [-1.8504],
#         [ 2.0439],
#         [ 0.5879]])
# p.grad :  tensor([1.5568])
# l :  tensor(1.2118, grad_fn=<DivBackward0>)
# eval l : 1.6260161399841309
# p.grad :  tensor([[ 0.1191],
#         [-0.2035],
#         [-0.2110],
#         [-0.2185],
#         [-0.1445]])
# p.grad :  tensor([0.1775])
# l :  tensor(0.0158, grad_fn=<DivBackward0>)
# eval l : 1.6253184080123901
# p.grad :  tensor([[ 0.1001],
#         [-0.1292],
#         [-0.0416],
#         [-0.3220],
#         [-0.1522]])
# p.grad :  tensor([-0.2452])
# l :  tensor(0.0301, grad_fn=<DivBackward0>)
# eval l : 1.6252104043960571
# p.grad :  tensor([[ 2.3801],
#         [ 2.5422],
#         [-7.1548],
#         [-5.2208],
#         [ 2.0819]])
# p.grad :  tensor([-3.9764])
# l :  tensor(7.9059, grad_fn=<DivBackward0>)
# eval l : 1.5496898889541626
# p.grad :  tensor([[-0.5941],
#         [ 1.9593],
#         [-0.8229],
#         [ 1.1781],
#         [ 1.5685]])
# p.grad :  tensor([0.8973])
# l :  tensor(0.4026, grad_fn=<DivBackward0>)
# eval l : 1.5358819961547852
# p.grad :  tensor([[-1.2454],
#         [ 4.1299],
#         [-1.6550],
#         [-5.4502],
#         [10.3533]])
# p.grad :  tensor([4.4282])
# l :  tensor(9.8043, grad_fn=<DivBackward0>)
# eval l : 1.473213791847229
# p.grad :  tensor([[-0.1577],
#         [ 2.3084],
#         [-1.5289],
#         [-0.9304],
#         [ 0.5950]])
# p.grad :  tensor([1.2863])
# l :  tensor(0.8272, grad_fn=<DivBackward0>)
# eval l : 1.4543408155441284
# p.grad :  tensor([[ 0.7437],
#         [ 1.2879],
#         [-0.1904],
#         [-1.4750],
#         [ 0.8154]])
# p.grad :  tensor([-1.1234])
# l :  tensor(0.6310, grad_fn=<DivBackward0>)
# eval l : 1.443175196647644
# p.grad :  tensor([[-0.1709],
#         [ 0.1662],
#         [-0.5572],
#         [-0.7479],
#         [-0.2465]])
# p.grad :  tensor([0.6077])
# l :  tensor(0.1846, grad_fn=<DivBackward0>)
# eval l : 1.4391947984695435
# p.grad :  tensor([[ 0.8685],
#         [ 1.9742],
#         [-5.5562],
#         [-4.0543],
#         [ 1.6167]])
# p.grad :  tensor([-3.0880])
# l :  tensor(4.7679, grad_fn=<DivBackward0>)
# eval l : 1.387904405593872
# p.grad :  tensor([[-0.6730],
#         [ 1.3693],
#         [-0.8620],
#         [-0.6800],
#         [ 1.2242]])
# p.grad :  tensor([0.9401])
# l :  tensor(0.4418, grad_fn=<DivBackward0>)
# eval l : 1.3760995864868164
# p.grad :  tensor([[ 1.8668],
#         [-0.9481],
#         [ 1.4881],
#         [-0.5982],
#         [-0.5057]])
# p.grad :  tensor([0.8270])
# l :  tensor(0.3420, grad_fn=<DivBackward0>)
# eval l : 1.3849461078643799
# p.grad :  tensor([[ 1.3343],
#         [-0.8406],
#         [-0.2704],
#         [-0.4753],
#         [-1.1774]])
# p.grad :  tensor([-1.5951])
# l :  tensor(1.2721, grad_fn=<DivBackward0>)
# eval l : 1.3858394622802734
# p.grad :  tensor([[ 1.7271],
#         [ 2.9908],
#         [-4.6940],
#         [ 3.2110],
#         [ 1.5533]])
# p.grad :  tensor([-2.6088])
# l :  tensor(3.4030, grad_fn=<DivBackward0>)
# eval l : 1.3490639925003052
# p.grad :  tensor([[ 0.6186],
#         [ 0.7013],
#         [ 0.4453],
#         [-0.3551],
#         [ 0.8092]])
# p.grad :  tensor([-1.1914])
# l :  tensor(0.7098, grad_fn=<DivBackward0>)
# eval l : 1.3460148572921753
# p.grad :  tensor([[-0.0008],
#         [ 0.0007],
#         [-0.0018],
#         [-0.0011],
#         [-0.0008]])
# p.grad :  tensor([0.0015])
# l :  tensor(1.1233e-06, grad_fn=<DivBackward0>)
# eval l : 1.3460044860839844
# p.grad :  tensor([[ 0.1908],
#         [-0.1141],
#         [ 0.1191],
#         [ 0.2306],
#         [-0.0320]])
# p.grad :  tensor([-0.3188])
# l :  tensor(0.0508, grad_fn=<DivBackward0>)
# eval l : 1.3471397161483765
# p.grad :  tensor([[ 1.7631],
#         [ 3.0531],
#         [-4.7918],
#         [ 1.9264],
#         [ 1.6285]])
# p.grad :  tensor([-2.6632])
# l :  tensor(3.5462, grad_fn=<DivBackward0>)
# eval l : 1.3093067407608032
# p.grad :  tensor([[-1.6642],
#         [ 4.0093],
#         [ 0.6912],
#         [-2.9492],
#         [14.6611]])
# p.grad :  tensor([4.0771])
# l :  tensor(8.3115, grad_fn=<DivBackward0>)
# eval l : 1.2684297561645508
# p.grad :  tensor([[ 0.6572],
#         [ 0.9549],
#         [-0.8200],
#         [ 0.6025],
#         [ 0.5452]])
# p.grad :  tensor([-0.8330])
# l :  tensor(0.3469, grad_fn=<DivBackward0>)
# eval l : 1.260859489440918
# p.grad :  tensor([[ 0.3104],
#         [-0.2724],
#         [-0.1730],
#         [ 0.1379],
#         [-0.3144]])
# p.grad :  tensor([0.4629])
# l :  tensor(0.1071, grad_fn=<DivBackward0>)
# eval l : 1.2609304189682007
# p.grad :  tensor([[ 1.5308],
#         [ 2.9318],
#         [-4.6015],
#         [-0.7621],
#         [ 1.6165]])
# p.grad :  tensor([-2.5574])
# l :  tensor(3.2702, grad_fn=<DivBackward0>)
# eval l : 1.2240115404129028
# p.grad :  tensor([[ 1.7129],
#         [ 1.3881],
#         [-3.9066],
#         [ 1.5705],
#         [ 1.0211]])
# p.grad :  tensor([-2.1712])
# l :  tensor(2.3570, grad_fn=<DivBackward0>)
# eval l : 1.1996099948883057
# p.grad :  tensor([[ 0.5163],
#         [ 1.4500],
#         [-0.2144],
#         [-1.6606],
#         [ 0.9180]])
# p.grad :  tensor([-1.2648])
# l :  tensor(0.7999, grad_fn=<DivBackward0>)
# eval l : 1.1907013654708862
# p.grad :  tensor([[ 1.2198],
#         [ 0.5489],
#         [-0.3982],
#         [-3.0844],
#         [ 1.2738]])
# p.grad :  tensor([-2.3493])
# l :  tensor(2.7595, grad_fn=<DivBackward0>)
# eval l : 1.178757667541504
# p.grad :  tensor([[ 0.7086],
#         [ 1.1849],
#         [-4.5334],
#         [-3.3080],
#         [ 1.1810]])
# p.grad :  tensor([-2.5196])
# l :  tensor(3.1741, grad_fn=<DivBackward0>)
# eval l : 1.1465559005737305
# p.grad :  tensor([[-3.3065e-03],
#         [-8.1881e-04],
#         [-9.2113e-03],
#         [-2.7885e-03],
#         [-2.1866e-05]])
# p.grad :  tensor([-0.0094])
# l :  tensor(4.3779e-05, grad_fn=<DivBackward0>)
# eval l : 1.146515130996704
# p.grad :  tensor([[ 1.2985],
#         [ 1.9369],
#         [-3.9033],
#         [ 1.5692],
#         [ 1.1913]])
# p.grad :  tensor([-2.1694])
# l :  tensor(2.3531, grad_fn=<DivBackward0>)
# eval l : 1.1237117052078247
# p.grad :  tensor([[ 0.0284],
#         [-0.0473],
#         [-0.0300],
#         [ 0.0239],
#         [-0.0546]])
# p.grad :  tensor([0.0803])
# l :  tensor(0.0032, grad_fn=<DivBackward0>)
# eval l : 1.1237080097198486
# p.grad :  tensor([[-0.3366],
#         [ 0.1285],
#         [-0.4311],
#         [-0.3400],
#         [-0.1959]])
# p.grad :  tensor([0.4701])
# l :  tensor(0.1105, grad_fn=<DivBackward0>)
# eval l : 1.121672511100769
# p.grad :  tensor([[-0.8919],
#         [ 1.5246],
#         [-2.3928],
#         [-1.7460],
#         [ 0.8575]])
# p.grad :  tensor([-1.3299])
# l :  tensor(0.8843, grad_fn=<DivBackward0>)
# eval l : 1.1058892011642456
# p.grad :  tensor([[-0.1829],
#         [ 2.2237],
#         [-0.5576],
#         [ 1.9588],
#         [ 3.6983]])
# p.grad :  tensor([1.4920])
# l :  tensor(1.1130, grad_fn=<DivBackward0>)
# eval l : 1.0977706909179688
# p.grad :  tensor([[ 0.1573],
#         [ 0.3013],
#         [ 0.0982],
#         [-0.0783],
#         [ 0.1964]])
# p.grad :  tensor([-0.2629])
# l :  tensor(0.0345, grad_fn=<DivBackward0>)
# eval l : 1.0972344875335693
# p.grad :  tensor([[ 0.6065],
#         [ 0.2927],
#         [-1.1499],
#         [ 0.8450],
#         [ 0.4440]])
# p.grad :  tensor([-1.1681])
# l :  tensor(0.6823, grad_fn=<DivBackward0>)
# eval l : 1.0916645526885986
# p.grad :  tensor([[ 0.7330],
#         [ 0.3298],
#         [-0.2393],
#         [-0.4207],
#         [ 0.7310]])
# p.grad :  tensor([-1.4117])
# l :  tensor(0.9965, grad_fn=<DivBackward0>)
# eval l : 1.08771812915802
# p.grad :  tensor([[ 1.3891],
#         [-0.1243],
#         [-0.2985],
#         [-2.3117],
#         [ 0.4848]])
# p.grad :  tensor([-1.7607])
# l :  tensor(1.5501, grad_fn=<DivBackward0>)
# eval l : 1.0806548595428467
# p.grad :  tensor([[ 0.6495],
#         [ 0.1924],
#         [-0.1396],
#         [-1.0809],
#         [ 0.4464]])
# p.grad :  tensor([-0.8233])
# l :  tensor(0.3389, grad_fn=<DivBackward0>)
# eval l : 1.076825499534607
# p.grad :  tensor([[ 1.7314],
#         [-1.1565],
#         [-0.3720],
#         [-2.8814],
#         [-1.3623]])
# p.grad :  tensor([-2.1946])
# l :  tensor(2.4082, grad_fn=<DivBackward0>)
# eval l : 1.0724893808364868
# p.grad :  tensor([[-0.5003],
#         [-0.3648],
#         [-0.7664],
#         [-0.6046],
#         [-0.6112]])
# p.grad :  tensor([0.8358])
# l :  tensor(0.3493, grad_fn=<DivBackward0>)
# eval l : 1.0699461698532104
# p.grad :  tensor([[-0.8092],
#         [ 4.3289],
#         [-1.8180],
#         [-1.4341],
#         [ 3.8222]])
# p.grad :  tensor([1.9826])
# l :  tensor(1.9653, grad_fn=<DivBackward0>)
# eval l : 1.0500880479812622
# p.grad :  tensor([[ 0.4933],
#         [-0.5397],
#         [ 0.2163],
#         [-0.7597],
#         [-0.9965]])
# p.grad :  tensor([-0.5787])
# l :  tensor(0.1674, grad_fn=<DivBackward0>)
# eval l : 1.0512806177139282
# p.grad :  tensor([[-0.0610],
#         [-0.0349],
#         [ 0.0253],
#         [-0.1840],
#         [-0.0669]])
# p.grad :  tensor([0.1495])
# l :  tensor(0.0112, grad_fn=<DivBackward0>)
# eval l : 1.0513098239898682
# p.grad :  tensor([[ 0.0012],
#         [-0.0018],
#         [ 0.0021],
#         [ 0.0013],
#         [-0.0003]])
# p.grad :  tensor([-0.0018])
# l :  tensor(1.6305e-06, grad_fn=<DivBackward0>)
# eval l : 1.0513222217559814
# p.grad :  tensor([[ 0.9705],
#         [ 0.5957],
#         [-2.3407],
#         [-3.1218],
#         [ 1.0754]])
# p.grad :  tensor([-2.3777])
# l :  tensor(2.8268, grad_fn=<DivBackward0>)
# eval l : 1.0343616008758545
# p.grad :  tensor([[ 0.7504],
#         [ 1.1753],
#         [-3.3078],
#         [-0.5479],
#         [ 0.9251]])
# p.grad :  tensor([-1.8384])
# l :  tensor(1.6899, grad_fn=<DivBackward0>)
# eval l : 1.016823410987854
# p.grad :  tensor([[ 0.7175],
#         [ 0.6499],
#         [-1.3603],
#         [ 0.9996],
#         [ 0.6730]])
# p.grad :  tensor([-1.3819])
# l :  tensor(0.9548, grad_fn=<DivBackward0>)
# eval l : 1.0105315446853638
# p.grad :  tensor([[-0.0192],
#         [ 0.2631],
#         [ 0.0858],
#         [-0.0684],
#         [ 0.1714]])
# p.grad :  tensor([-0.2295])
# l :  tensor(0.0263, grad_fn=<DivBackward0>)
# eval l : 1.0104900598526
# p.grad :  tensor([[ 0.2569],
#         [-0.0795],
#         [-0.2819],
#         [-0.1716],
#         [-0.1846]])
# p.grad :  tensor([0.2372])
# l :  tensor(0.0281, grad_fn=<DivBackward0>)
# eval l : 1.0088744163513184
# p.grad :  tensor([[ 1.2307],
#         [ 3.2484],
#         [-1.3017],
#         [-2.5194],
#         [ 7.8654]])
# p.grad :  tensor([3.4829])
# l :  tensor(6.0654, grad_fn=<DivBackward0>)
# eval l : 0.986155092716217
# p.grad :  tensor([[-0.0351],
#         [ 0.1510],
#         [ 0.0486],
#         [ 0.3762],
#         [ 0.1779]])
# p.grad :  tensor([0.2865])
# l :  tensor(0.0410, grad_fn=<DivBackward0>)
# eval l : 0.9864977598190308
# p.grad :  tensor([[ 0.3397],
#         [-1.1020],
#         [-0.3593],
#         [-1.1832],
#         [-0.7049]])
# p.grad :  tensor([0.9613])
# l :  tensor(0.4620, grad_fn=<DivBackward0>)
# eval l : 0.9841431379318237
# p.grad :  tensor([[-0.0208],
#         [-0.4469],
#         [ 0.2960],
#         [-0.3269],
#         [-0.0940]])
# p.grad :  tensor([-0.2490])
# l :  tensor(0.0310, grad_fn=<DivBackward0>)
# eval l : 0.9855003356933594
# p.grad :  tensor([[ 6.2514],
#         [-2.3493],
#         [-2.4359],
#         [-1.4824],
#         [-1.6698]])
# p.grad :  tensor([2.0493])
# l :  tensor(2.0999, grad_fn=<DivBackward0>)
# eval l : 0.9676169157028198
# p.grad :  tensor([[ 1.8716],
#         [ 1.1624],
#         [-4.4472],
#         [ 1.7878],
#         [ 1.0047]])
# p.grad :  tensor([-2.4716])
# l :  tensor(3.0545, grad_fn=<DivBackward0>)
# eval l : 0.9484707713127136
# p.grad :  tensor([[0.4890],
#         [0.0095],
#         [0.2553],
#         [0.8407],
#         [0.2707]])
# p.grad :  tensor([-0.6830])
# l :  tensor(0.2333, grad_fn=<DivBackward0>)
# eval l : 0.949873149394989
# p.grad :  tensor([[ 2.8449],
#         [-2.0100],
#         [-0.6553],
#         [-1.2682],
#         [-1.2906]])
# p.grad :  tensor([1.7533])
# l :  tensor(1.5370, grad_fn=<DivBackward0>)
# eval l : 0.9444199800491333
# p.grad :  tensor([[-1.1532],
#         [ 2.6350],
#         [-1.0559],
#         [-3.4773],
#         [ 6.6056]])
# p.grad :  tensor([2.8252])
# l :  tensor(3.9910, grad_fn=<DivBackward0>)
# eval l : 0.9283856749534607
# p.grad :  tensor([[ 2.3502],
#         [-0.2521],
#         [-2.8355],
#         [-0.8584],
#         [-0.0067]])
# p.grad :  tensor([-2.8805])
# l :  tensor(4.1485, grad_fn=<DivBackward0>)
# eval l : 0.9146648049354553
# p.grad :  tensor([[-0.1088],
#         [ 0.8317],
#         [-2.3406],
#         [-1.7079],
#         [ 0.6811]])
# p.grad :  tensor([-1.3009])
# l :  tensor(0.8461, grad_fn=<DivBackward0>)
# eval l : 0.9035555720329285
# p.grad :  tensor([[ 0.0980],
#         [-0.2242],
#         [ 0.2731],
#         [-0.2007],
#         [-0.1619]])
# p.grad :  tensor([0.2774])
# l :  tensor(0.0385, grad_fn=<DivBackward0>)
# eval l : 0.904377281665802
# p.grad :  tensor([[ 0.8026],
#         [ 2.2541],
#         [-3.5379],
#         [-2.5816],
#         [ 1.2679]])
# p.grad :  tensor([-1.9663])
# l :  tensor(1.9331, grad_fn=<DivBackward0>)
# eval l : 0.8862767219543457
# p.grad :  tensor([[ 0.4286],
#         [ 0.6489],
#         [-0.5572],
#         [ 0.6966],
#         [ 0.3624]])
# p.grad :  tensor([-0.5660])
# l :  tensor(0.1602, grad_fn=<DivBackward0>)
# eval l : 0.8841444253921509
# p.grad :  tensor([[ 0.6383],
#         [ 2.6311],
#         [-1.6563],
#         [-1.3065],
#         [ 2.3522]])
# p.grad :  tensor([1.8063])
# l :  tensor(1.6313, grad_fn=<DivBackward0>)
# eval l : 0.872783899307251
# p.grad :  tensor([[ 2.3697],
#         [ 2.0404],
#         [-0.8177],
#         [ 2.8724],
#         [ 3.7677]])
# p.grad :  tensor([2.1878])
# l :  tensor(2.3932, grad_fn=<DivBackward0>)
# eval l : 0.8666224479675293
# p.grad :  tensor([[ 0.1061],
#         [-0.1413],
#         [ 0.2957],
#         [-0.2173],
#         [-0.1463]])
# p.grad :  tensor([0.3004])
# l :  tensor(0.0451, grad_fn=<DivBackward0>)
# eval l : 0.8672500848770142
# p.grad :  tensor([[ 0.3525],
#         [-0.3226],
#         [ 0.3962],
#         [-0.5673],
#         [-0.0964]])
# p.grad :  tensor([-0.4321])
# l :  tensor(0.0933, grad_fn=<DivBackward0>)
# eval l : 0.8678050637245178
# p.grad :  tensor([[ 1.0020],
#         [ 0.6223],
#         [-1.3027],
#         [-0.3944],
#         [ 0.6899]])
# p.grad :  tensor([-1.3233])
# l :  tensor(0.8756, grad_fn=<DivBackward0>)
# eval l : 0.8616965413093567
# p.grad :  tensor([[ 0.3691],
#         [-0.9877],
#         [ 0.4148],
#         [ 0.3272],
#         [-0.8721]])
# p.grad :  tensor([-0.4523])
# l :  tensor(0.1023, grad_fn=<DivBackward0>)
# eval l : 0.8638399839401245
# p.grad :  tensor([[ 0.1119],
#         [ 0.0640],
#         [-0.0465],
#         [ 0.1982],
#         [ 0.1311]])
# p.grad :  tensor([-0.2741])
# l :  tensor(0.0376, grad_fn=<DivBackward0>)
# eval l : 0.8637903928756714
# p.grad :  tensor([[-0.1600],
#         [ 0.2999],
#         [ 0.0965],
#         [ 0.1696],
#         [ 0.4200]])
# p.grad :  tensor([0.5690])
# l :  tensor(0.1619, grad_fn=<DivBackward0>)
# eval l : 0.8639971017837524
# p.grad :  tensor([[0.0655],
#         [0.1446],
#         [0.0471],
#         [0.0912],
#         [0.0928]])
# p.grad :  tensor([-0.1261])
# l :  tensor(0.0080, grad_fn=<DivBackward0>)
# eval l : 0.8641471862792969
# p.grad :  tensor([[-0.0651],
#         [ 0.4579],
#         [ 0.2907],
#         [-1.0213],
#         [ 0.5392]])
# p.grad :  tensor([-0.7779])
# l :  tensor(0.3026, grad_fn=<DivBackward0>)
# eval l : 0.8640444874763489
# p.grad :  tensor([[-0.3540],
#         [-0.5669],
#         [ 0.0838],
#         [-0.3577],
#         [-0.3463]])
# p.grad :  tensor([0.4945])
# l :  tensor(0.1223, grad_fn=<DivBackward0>)
# eval l : 0.864478588104248
# p.grad :  tensor([[10.4520],
#         [-2.2066],
#         [ 1.8948],
#         [ 2.5271],
#         [-1.3172]])
# p.grad :  tensor([1.9248])
# l :  tensor(1.8524, grad_fn=<DivBackward0>)
# eval l : 0.8630959391593933
# p.grad :  tensor([[ 1.2854],
#         [ 0.6202],
#         [-2.4369],
#         [-3.2502],
#         [ 1.1196]])
# p.grad :  tensor([-2.4755])
# l :  tensor(3.0641, grad_fn=<DivBackward0>)
# eval l : 0.8498090505599976
# p.grad :  tensor([[-0.3119],
#         [ 0.3687],
#         [-0.1477],
#         [-0.2859],
#         [ 0.8927]])
# p.grad :  tensor([0.3953])
# l :  tensor(0.0781, grad_fn=<DivBackward0>)
# eval l : 0.8485034704208374
# p.grad :  tensor([[-0.0680],
#         [ 0.1255],
#         [-0.0790],
#         [ 0.0257],
#         [ 0.1052]])
# p.grad :  tensor([0.0862])
# l :  tensor(0.0037, grad_fn=<DivBackward0>)
# eval l : 0.8481950759887695
# p.grad :  tensor([[ 0.1124],
#         [-0.3370],
#         [ 0.2232],
#         [-0.0560],
#         [-0.0776]])
# p.grad :  tensor([-0.1878])
# l :  tensor(0.0176, grad_fn=<DivBackward0>)
# eval l : 0.8490168452262878
# p.grad :  tensor([[-1.3071],
#         [ 2.7520],
#         [-1.8227],
#         [ 2.0133],
#         [ 0.5790]])
# p.grad :  tensor([1.5334])
# l :  tensor(1.1757, grad_fn=<DivBackward0>)
# eval l : 0.8447316288948059
# p.grad :  tensor([[ 0.1792],
#         [ 0.3432],
#         [-0.0507],
#         [ 0.3685],
#         [ 0.2060]])
# p.grad :  tensor([-0.2994])
# l :  tensor(0.0448, grad_fn=<DivBackward0>)
# eval l : 0.8447443246841431
# p.grad :  tensor([[ 0.0452],
#         [ 0.1842],
#         [-0.0272],
#         [ 0.1162],
#         [ 0.1125]])
# p.grad :  tensor([-0.1607])
# l :  tensor(0.0129, grad_fn=<DivBackward0>)
# eval l : 0.8447129130363464
# p.grad :  tensor([[-0.0940],
#         [-0.3830],
#         [-0.3064],
#         [ 0.0996],
#         [-0.2638]])
# p.grad :  tensor([0.3341])
# l :  tensor(0.0558, grad_fn=<DivBackward0>)
# eval l : 0.8439828157424927
# p.grad :  tensor([[ 4.1791],
#         [-0.4590],
#         [-1.6284],
#         [ 0.4083],
#         [-1.0699]])
# p.grad :  tensor([1.3700])
# l :  tensor(0.9384, grad_fn=<DivBackward0>)
# eval l : 0.8352856040000916
# p.grad :  tensor([[ 0.7035],
#         [ 1.0492],
#         [ 0.3375],
#         [-1.4402],
#         [ 1.8467]])
# p.grad :  tensor([1.9910])
# l :  tensor(1.9820, grad_fn=<DivBackward0>)
# eval l : 0.8323496580123901
# p.grad :  tensor([[ 1.5080],
#         [ 0.6312],
#         [-2.4801],
#         [-3.3078],
#         [ 1.1395]])
# p.grad :  tensor([-2.5194])
# l :  tensor(3.1737, grad_fn=<DivBackward0>)
# eval l : 0.8195465803146362
# p.grad :  tensor([[ 0.7141],
#         [ 1.3678],
#         [-2.1467],
#         [ 1.4685],
#         [ 0.7104]])
# p.grad :  tensor([-1.1931])
# l :  tensor(0.7117, grad_fn=<DivBackward0>)
# eval l : 0.8137505650520325
# p.grad :  tensor([[ 8.9360],
#         [-2.4619],
#         [-2.5526],
#         [-1.5534],
#         [-1.7498]])
# p.grad :  tensor([2.1475])
# l :  tensor(2.3060, grad_fn=<DivBackward0>)
# eval l : 0.7978075742721558
# p.grad :  tensor([[ 0.0996],
#         [-0.0412],
#         [ 0.1380],
#         [-0.0449],
#         [ 0.0652]])
# p.grad :  tensor([-0.1505])
# l :  tensor(0.0113, grad_fn=<DivBackward0>)
# eval l : 0.7981506586074829
# p.grad :  tensor([[ 5.0576],
#         [-1.9007],
#         [ 0.2811],
#         [ 0.4941],
#         [-1.1872]])
# p.grad :  tensor([1.6580])
# l :  tensor(1.3744, grad_fn=<DivBackward0>)
# eval l : 0.7974461913108826
# p.grad :  tensor([[-0.0381],
#         [ 0.0150],
#         [-0.0423],
#         [-0.0308],
#         [ 0.0123]])
# p.grad :  tensor([-0.0235])
# l :  tensor(0.0003, grad_fn=<DivBackward0>)
# eval l : 0.7972919940948486
# p.grad :  tensor([[ 2.9113],
#         [-0.8521],
#         [ 1.7172],
#         [ 1.2530],
#         [-0.5643]])
# p.grad :  tensor([0.9544])
# l :  tensor(0.4554, grad_fn=<DivBackward0>)
# eval l : 0.8032826781272888
# p.grad :  tensor([[-0.1156],
#         [-0.5872],
#         [ 0.3889],
#         [-0.4296],
#         [-0.1236]])
# p.grad :  tensor([-0.3272])
# l :  tensor(0.0535, grad_fn=<DivBackward0>)
# eval l : 0.8044778108596802
# p.grad :  tensor([[-0.0922],
#         [ 0.1577],
#         [ 0.1261],
#         [-0.0410],
#         [ 0.1086]])
# p.grad :  tensor([-0.1375])
# l :  tensor(0.0095, grad_fn=<DivBackward0>)
# eval l : 0.8047739863395691
# p.grad :  tensor([[ 0.0052],
#         [-0.0292],
#         [ 0.0611],
#         [-0.0449],
#         [-0.0302]])
# p.grad :  tensor([0.0620])
# l :  tensor(0.0019, grad_fn=<DivBackward0>)
# eval l : 0.8049306869506836
# p.grad :  tensor([[0.0095],
#         [0.0455],
#         [0.0289],
#         [0.0951],
#         [0.0507]])
# p.grad :  tensor([-0.0773])
# l :  tensor(0.0030, grad_fn=<DivBackward0>)
# eval l : 0.8050989508628845
# p.grad :  tensor([[ 1.1785],
#         [-5.1310],
#         [ 2.3403],
#         [-2.5850],
#         [-1.5394]])
# p.grad :  tensor([-1.9689])
# l :  tensor(1.9383, grad_fn=<DivBackward0>)
# eval l : 0.8137626647949219
# p.grad :  tensor([[-0.2632],
#         [ 1.1067],
#         [-0.4648],
#         [ 0.6654],
#         [ 0.8859]])
# p.grad :  tensor([0.5068])
# l :  tensor(0.1284, grad_fn=<DivBackward0>)
# eval l : 0.8115425109863281
# p.grad :  tensor([[-0.0766],
#         [ 0.1709],
#         [-0.5731],
#         [-0.7692],
#         [-0.2535]])
# p.grad :  tensor([0.6249])
# l :  tensor(0.1953, grad_fn=<DivBackward0>)
# eval l : 0.808743953704834
# p.grad :  tensor([[ 0.1500],
#         [ 1.6722],
#         [-0.6701],
#         [ 0.5343],
#         [ 3.5029]])
# p.grad :  tensor([1.7929])
# l :  tensor(1.6073, grad_fn=<DivBackward0>)
# eval l : 0.8033605217933655
# p.grad :  tensor([[ 0.7535],
#         [ 0.0146],
#         [ 0.3933],
#         [-0.3136],
#         [ 0.4744]])
# p.grad :  tensor([-1.0524])
# l :  tensor(0.5538, grad_fn=<DivBackward0>)
# eval l : 0.803995668888092
# p.grad :  tensor([[-0.2472],
#         [ 0.0428],
#         [ 0.1027],
#         [-0.4380],
#         [-0.0944]])
# p.grad :  tensor([0.6056])
# l :  tensor(0.1834, grad_fn=<DivBackward0>)
# eval l : 0.8038190007209778
# p.grad :  tensor([[ 0.1791],
#         [ 0.9337],
#         [-2.6279],
#         [-1.9176],
#         [ 0.7647]])
# p.grad :  tensor([-1.4605])
# l :  tensor(1.0666, grad_fn=<DivBackward0>)
# eval l : 0.7928817868232727
# p.grad :  tensor([[ 0.7415],
#         [ 0.7915],
#         [-0.9639],
#         [-1.2856],
#         [ 0.6115]])
# p.grad :  tensor([-0.9792])
# l :  tensor(0.4794, grad_fn=<DivBackward0>)
# eval l : 0.787950873374939
# p.grad :  tensor([[ 0.8985],
#         [ 0.6383],
#         [-1.3360],
#         [ 1.6704],
#         [ 0.6245]])
# p.grad :  tensor([-1.3572])
# l :  tensor(0.9210, grad_fn=<DivBackward0>)
# eval l : 0.7851273417472839
# p.grad :  tensor([[ 1.7143],
#         [ 1.2178],
#         [-4.6592],
#         [-3.3998],
#         [ 1.2138]])
# p.grad :  tensor([-2.5894])
# l :  tensor(3.3526, grad_fn=<DivBackward0>)
# eval l : 0.7672007083892822
# p.grad :  tensor([[-0.0059],
#         [-0.0554],
#         [-0.0181],
#         [-0.0595],
#         [-0.0354]])
# p.grad :  tensor([0.0483])
# l :  tensor(0.0012, grad_fn=<DivBackward0>)
# eval l : 0.7670980095863342
# p.grad :  tensor([[-0.6146],
#         [ 0.7535],
#         [-0.8954],
#         [-0.5449],
#         [ 0.1080]])
# p.grad :  tensor([0.7533])
# l :  tensor(0.2837, grad_fn=<DivBackward0>)
# eval l : 0.7636694312095642
# p.grad :  tensor([[ 0.5024],
#         [-0.5169],
#         [ 0.1270],
#         [-0.5419],
#         [-0.4668]])
# p.grad :  tensor([0.7491])
# l :  tensor(0.2806, grad_fn=<DivBackward0>)
# eval l : 0.7633480429649353
# p.grad :  tensor([[ 0.6115],
#         [ 0.6904],
#         [-0.8408],
#         [ 1.0512],
#         [ 0.4818]])
# p.grad :  tensor([-0.8541])
# l :  tensor(0.3647, grad_fn=<DivBackward0>)
# eval l : 0.7617149353027344
# p.grad :  tensor([[ 0.3366],
#         [-0.2978],
#         [ 0.7706],
#         [-0.8512],
#         [ 0.3419]])
# p.grad :  tensor([-0.6483])
# l :  tensor(0.2102, grad_fn=<DivBackward0>)
# eval l : 0.7631971836090088
# p.grad :  tensor([[-0.3130],
#         [ 1.0337],
#         [-0.4715],
#         [ 0.5208],
#         [ 0.3101]])
# p.grad :  tensor([0.3967])
# l :  tensor(0.0787, grad_fn=<DivBackward0>)
# eval l : 0.7619847655296326
# p.grad :  tensor([[-0.0965],
#         [-0.1847],
#         [-0.0602],
#         [-0.1166],
#         [-0.1186]])
# p.grad :  tensor([0.1611])
# l :  tensor(0.0130, grad_fn=<DivBackward0>)
# eval l : 0.761736273765564
# p.grad :  tensor([[ 4.4848],
#         [-1.6855],
#         [-0.5495],
#         [ 1.9303],
#         [-1.1105]])
# p.grad :  tensor([1.4702])
# l :  tensor(1.0808, grad_fn=<DivBackward0>)
# eval l : 0.7610548138618469
# p.grad :  tensor([[-0.0993],
#         [ 1.7679],
#         [-0.7425],
#         [ 1.0630],
#         [ 1.4153]])
# p.grad :  tensor([0.8097])
# l :  tensor(0.3278, grad_fn=<DivBackward0>)
# eval l : 0.7588041424751282
# p.grad :  tensor([[ 0.0625],
#         [-0.8566],
#         [ 0.1267],
#         [-0.9197],
#         [-0.5142]])
# p.grad :  tensor([0.7472])
# l :  tensor(0.2792, grad_fn=<DivBackward0>)
# eval l : 0.75829017162323
# p.grad :  tensor([[ 0.6770],
#         [ 1.2966],
#         [-2.0350],
#         [-1.4849],
#         [ 0.7293]])
# p.grad :  tensor([-1.1310])
# l :  tensor(0.6396, grad_fn=<DivBackward0>)
# eval l : 0.750789999961853
# p.grad :  tensor([[ 0.0911],
#         [-0.0632],
#         [ 0.1635],
#         [ 0.1693],
#         [ 0.0683]])
# p.grad :  tensor([-0.1376])
# l :  tensor(0.0095, grad_fn=<DivBackward0>)
# eval l : 0.751427412033081
# p.grad :  tensor([[ 0.0300],
#         [ 0.0086],
#         [-0.0062],
#         [ 0.0266],
#         [ 0.0176]])
# p.grad :  tensor([-0.0367])
# l :  tensor(0.0007, grad_fn=<DivBackward0>)
# eval l : 0.7514358162879944
# p.grad :  tensor([[ 0.0214],
#         [ 0.4585],
#         [-0.3037],
#         [-0.1848],
#         [ 0.1182]])
# p.grad :  tensor([0.2555])
# l :  tensor(0.0326, grad_fn=<DivBackward0>)
# eval l : 0.7502139806747437
# p.grad :  tensor([[ 1.5699],
#         [-0.7123],
#         [ 0.7437],
#         [-2.6126],
#         [ 0.1258]])
# p.grad :  tensor([-1.9899])
# l :  tensor(1.9798, grad_fn=<DivBackward0>)
# eval l : 0.7502642869949341
# p.grad :  tensor([[ 4.1757],
#         [ 0.1306],
#         [ 0.3136],
#         [-1.3382],
#         [-0.2882]])
# p.grad :  tensor([1.8500])
# l :  tensor(1.7112, grad_fn=<DivBackward0>)
# eval l : 0.7487469911575317
# p.grad :  tensor([[ 0.1360],
#         [-0.1044],
#         [ 0.2702],
#         [ 0.2797],
#         [ 0.1128]])
# p.grad :  tensor([-0.2273])
# l :  tensor(0.0258, grad_fn=<DivBackward0>)
# eval l : 0.7498093247413635
# p.grad :  tensor([[-0.2336],
#         [-0.1964],
#         [-0.4126],
#         [-0.3255],
#         [-0.3290]])
# p.grad :  tensor([0.4500])
# l :  tensor(0.1012, grad_fn=<DivBackward0>)
# eval l : 0.7483762502670288
# p.grad :  tensor([[ 0.8954],
#         [ 1.1024],
#         [-3.1026],
#         [-2.2640],
#         [ 0.9028]])
# p.grad :  tensor([-1.7244])
# l :  tensor(1.4867, grad_fn=<DivBackward0>)
# eval l : 0.737816572189331
# p.grad :  tensor([[-0.4802],
#         [-0.7689],
#         [ 0.1137],
#         [ 0.1999],
#         [-0.4803]])
# p.grad :  tensor([0.6707])
# l :  tensor(0.2249, grad_fn=<DivBackward0>)
# eval l : 0.7383537888526917
# p.grad :  tensor([[ 0.2537],
#         [ 0.5767],
#         [-1.6231],
#         [-0.2688],
#         [ 0.4539]])
# p.grad :  tensor([-0.9021])
# l :  tensor(0.4069, grad_fn=<DivBackward0>)
# eval l : 0.7338082790374756
# p.grad :  tensor([[-0.2154],
#         [ 0.2279],
#         [ 0.2363],
#         [ 0.1438],
#         [ 0.1620]])
# p.grad :  tensor([-0.1988])
# l :  tensor(0.0198, grad_fn=<DivBackward0>)
# eval l : 0.7345883250236511
# p.grad :  tensor([[ 0.3853],
#         [ 0.5999],
#         [-0.7305],
#         [ 0.9134],
#         [ 0.4187]])
# p.grad :  tensor([-0.7421])
# l :  tensor(0.2754, grad_fn=<DivBackward0>)
# eval l : 0.7335188984870911
# p.grad :  tensor([[-0.0201],
#         [ 0.0555],
#         [-0.0233],
#         [ 0.0334],
#         [ 0.0445]])
# p.grad :  tensor([0.0254])
# l :  tensor(0.0003, grad_fn=<DivBackward0>)
# eval l : 0.7334588766098022
# p.grad :  tensor([[ 0.5506],
#         [ 0.4261],
#         [-1.4289],
#         [-1.9179],
#         [-0.6321]])
# p.grad :  tensor([1.5583])
# l :  tensor(1.2141, grad_fn=<DivBackward0>)
# eval l : 0.7275375127792358
# p.grad :  tensor([[ 0.3838],
#         [-0.4320],
#         [ 1.1177],
#         [-1.2346],
#         [ 0.4959]])
# p.grad :  tensor([-0.9403])
# l :  tensor(0.4421, grad_fn=<DivBackward0>)
# eval l : 0.7296682596206665
# p.grad :  tensor([[ 0.0126],
#         [-0.1734],
#         [-0.1797],
#         [-0.1861],
#         [-0.1231]])
# p.grad :  tensor([0.1512])
# l :  tensor(0.0114, grad_fn=<DivBackward0>)
# eval l : 0.7290310263633728
# p.grad :  tensor([[ 0.1996],
#         [ 0.4898],
#         [-0.1203],
#         [-0.9319],
#         [ 0.4698]])
# p.grad :  tensor([-0.7098])
# l :  tensor(0.2519, grad_fn=<DivBackward0>)
# eval l : 0.728066623210907
# p.grad :  tensor([[ 0.0146],
#         [-0.1415],
#         [ 0.1724],
#         [-0.1267],
#         [-0.1022]])
# p.grad :  tensor([0.1751])
# l :  tensor(0.0153, grad_fn=<DivBackward0>)
# eval l : 0.7283891439437866
# p.grad :  tensor([[ 0.8902],
#         [ 1.9335],
#         [-1.2172],
#         [ 0.3956],
#         [ 1.6209]])
# p.grad :  tensor([1.3274])
# l :  tensor(0.8809, grad_fn=<DivBackward0>)
# eval l : 0.7243991494178772
# p.grad :  tensor([[-1.7539],
#         [-0.7761],
#         [-2.7531],
#         [-1.6754],
#         [-1.8029]])
# p.grad :  tensor([2.3162])
# l :  tensor(2.6825, grad_fn=<DivBackward0>)
# eval l : 0.715850830078125
# p.grad :  tensor([[ 0.1132],
#         [ 0.5435],
#         [ 0.3451],
#         [-1.2123],
#         [ 0.6400]])
# p.grad :  tensor([-0.9233])
# l :  tensor(0.4263, grad_fn=<DivBackward0>)
# eval l : 0.7159804701805115
# p.grad :  tensor([[ 0.6849],
#         [-0.1001],
#         [-1.1264],
#         [-1.5023],
#         [ 0.0609]])
# p.grad :  tensor([-1.1442])
# l :  tensor(0.6546, grad_fn=<DivBackward0>)
# eval l : 0.7124188542366028
# p.grad :  tensor([[-0.3791],
#         [-0.3756],
#         [ 0.4574],
#         [-0.3361],
#         [-0.2713]])
# p.grad :  tensor([0.4647])
# l :  tensor(0.1080, grad_fn=<DivBackward0>)
# eval l : 0.7132646441459656
# p.grad :  tensor([[ 2.3384],
#         [-0.8483],
#         [-0.5386],
#         [-1.0425],
#         [-0.9525]])
# p.grad :  tensor([1.4412])
# l :  tensor(1.0385, grad_fn=<DivBackward0>)
# eval l : 0.7108165621757507
# p.grad :  tensor([[ 0.1584],
#         [-0.1783],
#         [ 0.4613],
#         [ 0.2807],
#         [ 0.1961]])
# p.grad :  tensor([-0.3881])
# l :  tensor(0.0753, grad_fn=<DivBackward0>)
# eval l : 0.7122334837913513
# p.grad :  tensor([[-0.4793],
#         [ 0.9220],
#         [-0.5804],
#         [-0.7790],
#         [ 0.8592]])
# p.grad :  tensor([0.6329])
# l :  tensor(0.2003, grad_fn=<DivBackward0>)
# eval l : 0.7097959518432617
# p.grad :  tensor([[ 0.8023],
#         [-0.8491],
#         [-0.2768],
#         [-0.5358],
#         [-0.5452]])
# p.grad :  tensor([0.7407])
# l :  tensor(0.2743, grad_fn=<DivBackward0>)
# eval l : 0.7086450457572937
# p.grad :  tensor([[0.1188],
#         [0.0021],
#         [0.0563],
#         [0.1853],
#         [0.0597]])
# p.grad :  tensor([-0.1506])
# l :  tensor(0.0113, grad_fn=<DivBackward0>)
# eval l : 0.7089276313781738
# p.grad :  tensor([[ 0.8503],
#         [-0.2962],
#         [ 0.2149],
#         [-1.5605],
#         [-0.5676]])
# p.grad :  tensor([1.2679])
# l :  tensor(0.8038, grad_fn=<DivBackward0>)
# eval l : 0.7083098888397217
# p.grad :  tensor([[-0.1580],
#         [ 0.1302],
#         [-0.2624],
#         [-0.1915],
#         [ 0.0862]])
# p.grad :  tensor([-0.1458])
# l :  tensor(0.0106, grad_fn=<DivBackward0>)
# eval l : 0.7075430154800415
# p.grad :  tensor([[ 0.2675],
#         [ 1.1025],
#         [-0.6941],
#         [ 0.2256],
#         [ 0.9243]])
# p.grad :  tensor([0.7569])
# l :  tensor(0.2865, grad_fn=<DivBackward0>)
# eval l : 0.7054194808006287
# p.grad :  tensor([[ 0.0167],
#         [-0.1616],
#         [ 0.1968],
#         [-0.2461],
#         [-0.1128]])
# p.grad :  tensor([0.2000])
# l :  tensor(0.0200, grad_fn=<DivBackward0>)
# eval l : 0.7057396173477173
# p.grad :  tensor([[ 0.0245],
#         [ 0.2290],
#         [-0.3595],
#         [ 0.1445],
#         [ 0.1222]])
# p.grad :  tensor([-0.1998])
# l :  tensor(0.0200, grad_fn=<DivBackward0>)
# eval l : 0.7049530148506165
# p.grad :  tensor([[ 0.1914],
#         [-0.8415],
#         [ 0.5573],
#         [ 0.3392],
#         [-0.2169]])
# p.grad :  tensor([-0.4689])
# l :  tensor(0.1099, grad_fn=<DivBackward0>)
# eval l : 0.7067318558692932
# p.grad :  tensor([[-0.3937],
#         [-0.3900],
#         [ 0.4750],
#         [-0.5939],
#         [-0.2722]])
# p.grad :  tensor([0.4825])
# l :  tensor(0.1164, grad_fn=<DivBackward0>)
# eval l : 0.7075388431549072
# p.grad :  tensor([[-0.0255],
#         [ 0.0106],
#         [-0.0354],
#         [-0.0475],
#         [-0.0157]])
# p.grad :  tensor([0.0386])
# l :  tensor(0.0007, grad_fn=<DivBackward0>)
# eval l : 0.7074167132377625
# p.grad :  tensor([[ 0.9444],
#         [ 1.1778],
#         [-2.3735],
#         [ 0.9542],
#         [ 0.7244]])
# p.grad :  tensor([-1.3191])
# l :  tensor(0.8700, grad_fn=<DivBackward0>)
# eval l : 0.7022491693496704
# p.grad :  tensor([[ 0.3741],
#         [ 0.0302],
#         [ 0.3400],
#         [ 0.4534],
#         [-0.0184]])
# p.grad :  tensor([0.3454])
# l :  tensor(0.0596, grad_fn=<DivBackward0>)
# eval l : 0.7032685875892639
# p.grad :  tensor([[0.0366],
#         [0.1759],
#         [0.1117],
#         [0.2161],
#         [0.1975]])
# p.grad :  tensor([-0.2988])
# l :  tensor(0.0446, grad_fn=<DivBackward0>)
# eval l : 0.703717827796936
# p.grad :  tensor([[ 7.3203],
#         [-1.5454],
#         [-1.6023],
#         [ 0.4017],
#         [-1.1001]])
# p.grad :  tensor([1.3481])
# l :  tensor(0.9086, grad_fn=<DivBackward0>)
# eval l : 0.7008426189422607
# p.grad :  tensor([[-0.2387],
#         [ 0.7743],
#         [ 0.8028],
#         [-0.8868],
#         [ 0.5518]])
# p.grad :  tensor([-0.6754])
# l :  tensor(0.2281, grad_fn=<DivBackward0>)
# eval l : 0.7021299004554749
# p.grad :  tensor([[ 3.8245],
#         [-1.1691],
#         [ 0.2872],
#         [-1.2256],
#         [-1.0558]])
# p.grad :  tensor([1.6943])
# l :  tensor(1.4354, grad_fn=<DivBackward0>)
# eval l : 0.703033983707428
# p.grad :  tensor([[-1.1892],
#         [ 1.5491],
#         [-0.6208],
#         [-2.0444],
#         [ 3.8835]])
# p.grad :  tensor([1.6610])
# l :  tensor(1.3794, grad_fn=<DivBackward0>)
# eval l : 0.6981444358825684
# p.grad :  tensor([[ 2.1080],
#         [-0.6444],
#         [ 0.1583],
#         [ 1.2261],
#         [-0.6181]])
# p.grad :  tensor([0.9339])
# l :  tensor(0.4361, grad_fn=<DivBackward0>)
# eval l : 0.6998187303543091
# p.grad :  tensor([[ 0.0316],
#         [-0.0572],
#         [ 0.1610],
#         [-0.0647],
#         [-0.0421]])
# p.grad :  tensor([0.0895])
# l :  tensor(0.0040, grad_fn=<DivBackward0>)
# eval l : 0.7001800537109375
# p.grad :  tensor([[-0.4501],
#         [ 0.2286],
#         [ 0.2370],
#         [ 0.2454],
#         [ 0.1623]])
# p.grad :  tensor([-0.1994])
# l :  tensor(0.0199, grad_fn=<DivBackward0>)
# eval l : 0.700754702091217
# p.grad :  tensor([[ 0.1069],
#         [-2.2721],
#         [ 1.0363],
#         [-1.1447],
#         [-0.6817]])
# p.grad :  tensor([-0.8719])
# l :  tensor(0.3801, grad_fn=<DivBackward0>)
# eval l : 0.7032086253166199
# p.grad :  tensor([[ 0.0083],
#         [ 0.0337],
#         [-0.0050],
#         [ 0.0362],
#         [ 0.0202]])
# p.grad :  tensor([-0.0294])
# l :  tensor(0.0004, grad_fn=<DivBackward0>)
# eval l : 0.7032143473625183
# p.grad :  tensor([[-0.5121],
#         [ 1.0660],
#         [-0.2673],
#         [ 0.9391],
#         [ 1.7729]])
# p.grad :  tensor([0.7152])
# l :  tensor(0.2558, grad_fn=<DivBackward0>)
# eval l : 0.7021176815032959
# p.grad :  tensor([[ 0.3965],
#         [-1.3706],
#         [ 0.9077],
#         [-0.2276],
#         [-0.3155]])
# p.grad :  tensor([-0.7637])
# l :  tensor(0.2916, grad_fn=<DivBackward0>)
# eval l : 0.7046909332275391
# p.grad :  tensor([[ 1.1328],
#         [ 0.3964],
#         [-1.5575],
#         [ 1.1444],
#         [ 0.6014]])
# p.grad :  tensor([-1.5821])
# l :  tensor(1.2516, grad_fn=<DivBackward0>)
# eval l : 0.7019904255867004
# p.grad :  tensor([[ 0.1934],
#         [-0.1711],
#         [ 0.4426],
#         [ 0.4583],
#         [ 0.1849]])
# p.grad :  tensor([-0.3724])
# l :  tensor(0.0693, grad_fn=<DivBackward0>)
# eval l : 0.7034764289855957
# p.grad :  tensor([[ 0.3633],
#         [-0.2528],
#         [-0.0813],
#         [-0.1430],
#         [-0.3541]])
# p.grad :  tensor([-0.4797])
# l :  tensor(0.1151, grad_fn=<DivBackward0>)
# eval l : 0.7035693526268005
# p.grad :  tensor([[ 1.1855],
#         [ 0.6327],
#         [-0.6607],
#         [-1.2786],
#         [ 0.1775]])
# p.grad :  tensor([1.7677])
# l :  tensor(1.5624, grad_fn=<DivBackward0>)
# eval l : 0.7010149359703064
# p.grad :  tensor([[-0.0982],
#         [ 0.3187],
#         [ 0.2549],
#         [ 0.2011],
#         [ 0.2188]])
# p.grad :  tensor([-0.2780])
# l :  tensor(0.0386, grad_fn=<DivBackward0>)
# eval l : 0.7017004489898682
# p.grad :  tensor([[-0.3214],
#         [ 0.2830],
#         [ 0.0910],
#         [-0.6609],
#         [ 0.5775]])
# p.grad :  tensor([0.5370])
# l :  tensor(0.1442, grad_fn=<DivBackward0>)
# eval l : 0.7010911703109741
# p.grad :  tensor([[-0.8732],
#         [ 0.2701],
#         [ 0.9582],
#         [-0.2402],
#         [ 0.6296]])
# p.grad :  tensor([-0.8062])
# l :  tensor(0.3250, grad_fn=<DivBackward0>)
# eval l : 0.7030031085014343
# p.grad :  tensor([[ 1.1338],
#         [ 1.0949],
#         [-3.0815],
#         [-2.2486],
#         [ 0.8967]])
# p.grad :  tensor([-1.7126])
# l :  tensor(1.4666, grad_fn=<DivBackward0>)
# eval l : 0.6948574185371399
# p.grad :  tensor([[ 0.0442],
#         [ 0.1446],
#         [-0.4851],
#         [-0.3826],
#         [-0.2204]])
# p.grad :  tensor([0.5290])
# l :  tensor(0.1399, grad_fn=<DivBackward0>)
# eval l : 0.6934369206428528
# p.grad :  tensor([[-0.1012],
#         [ 0.7697],
#         [-0.3084],
#         [ 1.0836],
#         [ 1.4213]])
# p.grad :  tensor([0.8253])
# l :  tensor(0.3406, grad_fn=<DivBackward0>)
# eval l : 0.6928257346153259
# p.grad :  tensor([[ 0.5731],
#         [ 0.3559],
#         [-0.7450],
#         [-0.9937],
#         [ 0.4107]])
# p.grad :  tensor([-0.7568])
# l :  tensor(0.2864, grad_fn=<DivBackward0>)
# eval l : 0.6908906102180481
# p.grad :  tensor([[ 0.6979],
#         [-0.7387],
#         [ 0.6343],
#         [ 0.1920],
#         [-0.4336]])
# p.grad :  tensor([0.6444])
# l :  tensor(0.2076, grad_fn=<DivBackward0>)
# eval l : 0.6925239562988281
# p.grad :  tensor([[ 0.8146],
#         [-1.4880],
#         [ 0.3731],
#         [-1.3108],
#         [-2.4748]])
# p.grad :  tensor([-0.9984])
# l :  tensor(0.4984, grad_fn=<DivBackward0>)
# eval l : 0.6938139200210571
# p.grad :  tensor([[-1.7604],
#         [-0.7790],
#         [-2.7634],
#         [-2.8614],
#         [-1.8055]])
# p.grad :  tensor([2.3248])
# l :  tensor(2.7024, grad_fn=<DivBackward0>)
# eval l : 0.6853498220443726
# p.grad :  tensor([[-0.1358],
#         [ 0.4405],
#         [ 0.4567],
#         [ 0.4729],
#         [ 0.3128]])
# p.grad :  tensor([-0.3842])
# l :  tensor(0.0738, grad_fn=<DivBackward0>)
# eval l : 0.6865535974502563
# p.grad :  tensor([[ 1.5182],
#         [ 0.0990],
#         [ 0.2376],
#         [-1.0138],
#         [-0.2184]])
# p.grad :  tensor([1.4016])
# l :  tensor(0.9822, grad_fn=<DivBackward0>)
# eval l : 0.68697589635849
# p.grad :  tensor([[ 0.6460],
#         [ 0.3632],
#         [-1.3895],
#         [ 0.5586],
#         [ 0.3139]])
# p.grad :  tensor([-0.7722])
# l :  tensor(0.2982, grad_fn=<DivBackward0>)
# eval l : 0.6842982172966003
# p.grad :  tensor([[-0.1133],
#         [-0.2171],
#         [ 0.0321],
#         [ 0.2486],
#         [-0.1374]])
# p.grad :  tensor([0.1894])
# l :  tensor(0.0179, grad_fn=<DivBackward0>)
# eval l : 0.6844425201416016
# p.grad :  tensor([[ 0.0135],
#         [-0.0095],
#         [ 0.0198],
#         [ 0.0060],
#         [-0.0105]])
# p.grad :  tensor([0.0201])
# l :  tensor(0.0002, grad_fn=<DivBackward0>)
# eval l : 0.6844950318336487
# p.grad :  tensor([[-0.3797],
#         [-0.5107],
#         [ 0.8015],
#         [-0.3222],
#         [-0.2724]])
# p.grad :  tensor([0.4455])
# l :  tensor(0.0992, grad_fn=<DivBackward0>)
# eval l : 0.6860677003860474
# p.grad :  tensor([[ 0.5217],
#         [-0.0638],
#         [-0.7174],
#         [ 0.8969],
#         [-0.1179]])
# p.grad :  tensor([-0.7287])
# l :  tensor(0.2655, grad_fn=<DivBackward0>)
# eval l : 0.6851992607116699
# p.grad :  tensor([[ 1.0197],
#         [-0.1131],
#         [-1.2723],
#         [ 1.5908],
#         [-0.2092]])
# p.grad :  tensor([-1.2925])
# l :  tensor(0.8352, grad_fn=<DivBackward0>)
# eval l : 0.6838364005088806
# p.grad :  tensor([[ 0.0886],
#         [ 2.3127],
#         [-0.9713],
#         [ 1.3906],
#         [ 1.8514]])
# p.grad :  tensor([1.0592])
# l :  tensor(0.5609, grad_fn=<DivBackward0>)
# eval l : 0.6817041039466858
# p.grad :  tensor([[-0.0091],
#         [ 0.0038],
#         [-0.0127],
#         [ 0.0181],
#         [-0.0061]])
# p.grad :  tensor([0.0138])
# l :  tensor(9.5383e-05, grad_fn=<DivBackward0>)
# eval l : 0.6816811561584473
# p.grad :  tensor([[ 0.1356],
#         [-0.0944],
#         [-0.0304],
#         [ 0.2204],
#         [-0.1926]])
# p.grad :  tensor([-0.1791])
# l :  tensor(0.0160, grad_fn=<DivBackward0>)
# eval l : 0.6818708777427673
# p.grad :  tensor([[-0.6166],
#         [ 2.0447],
#         [-0.8194],
#         [-1.5858],
#         [ 4.9510]])
# p.grad :  tensor([2.1924])
# l :  tensor(2.4033, grad_fn=<DivBackward0>)
# eval l : 0.678027868270874
# p.grad :  tensor([[-0.1682],
#         [ 0.4249],
#         [-0.8563],
#         [-0.6249],
#         [ 0.2814]])
# p.grad :  tensor([-0.4759])
# l :  tensor(0.1133, grad_fn=<DivBackward0>)
# eval l : 0.675997793674469
# p.grad :  tensor([[ 0.3214],
#         [-0.3402],
#         [-0.2721],
#         [-0.3653],
#         [-0.2331]])
# p.grad :  tensor([0.2968])
# l :  tensor(0.0440, grad_fn=<DivBackward0>)
# eval l : 0.6752312779426575
# p.grad :  tensor([[ 0.2598],
#         [ 0.5737],
#         [-0.4926],
#         [ 0.6159],
#         [ 0.3204]])
# p.grad :  tensor([-0.5004])
# l :  tensor(0.1252, grad_fn=<DivBackward0>)
# eval l : 0.6748092770576477
# p.grad :  tensor([[ 2.3863],
#         [ 2.1423],
#         [-1.3486],
#         [ 1.9309],
#         [ 1.7102]])
# p.grad :  tensor([1.4707])
# ...
#         [ 0.5746],
#         [-0.3176]])
# p.grad :  tensor([0.4376])
# l :  tensor(0.0958, grad_fn=<DivBackward0>)
# eval l : 0.7302458882331848
# p.grad :  tensor([[ 0.1853],
#         [-0.3027],
#         [ 0.7832],
#         [-0.1964],
#         [ 0.3414]])
# p.grad :  tensor([-0.6589])
# l :  tensor(0.2171, grad_fn=<DivBackward0>)
# eval l : 0.7316862344741821
# p.grad :  tensor([[ 0.9226],
#         [-0.4361],
#         [ 0.4554],
#         [-1.5998],
#         [ 0.0770]])
# p.grad :  tensor([-1.2185])
# l :  tensor(0.7423, grad_fn=<DivBackward0>)
# eval l : 0.7346403002738953
# p.grad :  tensor([[ 0.1300],
#         [-0.2124],
#         [ 0.5495],
#         [ 0.3344],
#         [ 0.2336]])
# p.grad :  tensor([-0.4623])
# l :  tensor(0.1069, grad_fn=<DivBackward0>)
# eval l : 0.735424280166626
# p.grad :  tensor([[ 0.7026],
#         [-0.1516],
#         [ 0.1100],
#         [ 0.1933],
#         [-0.3359]])
# p.grad :  tensor([0.6487])
# l :  tensor(0.2104, grad_fn=<DivBackward0>)
# eval l : 0.736262321472168
# p.grad :  tensor([[ 0.1519],
#         [-0.1209],
#         [-0.0389],
#         [-0.0684],
#         [-0.1694]])
# p.grad :  tensor([-0.2295])
# l :  tensor(0.0263, grad_fn=<DivBackward0>)
# eval l : 0.7362546920776367
# p.grad :  tensor([[-0.2971],
#         [-0.3540],
#         [-1.2558],
#         [ 0.3148],
#         [-0.8251]])
# p.grad :  tensor([1.0565])
# l :  tensor(0.5581, grad_fn=<DivBackward0>)
# eval l : 0.7328189611434937
# p.grad :  tensor([[ 1.1804],
#         [-0.3455],
#         [ 0.6962],
#         [-0.2799],
#         [-0.2125]])
# p.grad :  tensor([0.3869])
# l :  tensor(0.0749, grad_fn=<DivBackward0>)
# eval l : 0.7355777621269226
# p.grad :  tensor([[ 0.1557],
#         [-0.0820],
#         [ 0.2750],
#         [-0.0894],
#         [ 0.1298]])
# p.grad :  tensor([-0.2998])
# l :  tensor(0.0450, grad_fn=<DivBackward0>)
# eval l : 0.7363395094871521
# p.grad :  tensor([[ 1.2191],
#         [-0.1352],
#         [-1.5211],
#         [-0.4605],
#         [-0.0036]])
# p.grad :  tensor([-1.5452])
# l :  tensor(1.1939, grad_fn=<DivBackward0>)
# eval l : 0.7375633716583252
# p.grad :  tensor([[-0.8471],
#         [-0.8392],
#         [ 1.0220],
#         [-0.7510],
#         [-0.6061]])
# p.grad :  tensor([1.0382])
# l :  tensor(0.5389, grad_fn=<DivBackward0>)
# eval l : 0.7358198165893555
# p.grad :  tensor([[ 0.3080],
#         [-0.2037],
#         [ 0.1478],
#         [-1.0729],
#         [-0.3902]])
# p.grad :  tensor([0.8717])
# l :  tensor(0.3799, grad_fn=<DivBackward0>)
# eval l : 0.7366349697113037
# p.grad :  tensor([[ 0.4552],
#         [ 0.3576],
#         [-1.3683],
#         [-0.9985],
#         [ 0.3565]])
# p.grad :  tensor([-0.7605])
# l :  tensor(0.2892, grad_fn=<DivBackward0>)
# eval l : 0.7375428676605225
# p.grad :  tensor([[ 0.3432],
#         [-0.0454],
#         [-0.5104],
#         [-0.1545],
#         [-0.0012]])
# p.grad :  tensor([-0.5185])
# l :  tensor(0.1344, grad_fn=<DivBackward0>)
# eval l : 0.7378408908843994
# p.grad :  tensor([[-0.0740],
#         [ 0.2965],
#         [ 1.0520],
#         [ 1.0893],
#         [ 0.6873]])
# p.grad :  tensor([-0.8850])
# l :  tensor(0.3916, grad_fn=<DivBackward0>)
# eval l : 0.7391635179519653
# p.grad :  tensor([[-0.0103],
#         [-0.0032],
#         [ 0.0023],
#         [ 0.0041],
#         [-0.0071]])
# p.grad :  tensor([0.0137])
# l :  tensor(9.3259e-05, grad_fn=<DivBackward0>)
# eval l : 0.739129364490509
# p.grad :  tensor([[ 0.5845],
#         [-1.0414],
#         [ 0.2611],
#         [ 0.5054],
#         [-2.2168]])
# p.grad :  tensor([-0.6987])
# l :  tensor(0.2441, grad_fn=<DivBackward0>)
# eval l : 0.736869215965271
# p.grad :  tensor([[ 0.8764],
#         [-0.5521],
#         [-0.1776],
#         [-0.3122],
#         [-0.7733]])
# p.grad :  tensor([-1.0476])
# l :  tensor(0.5487, grad_fn=<DivBackward0>)
# eval l : 0.7375747561454773
# p.grad :  tensor([[ 0.0114],
#         [ 0.0249],
#         [-0.0501],
#         [-0.0366],
#         [ 0.0165]])
# p.grad :  tensor([-0.0279])
# l :  tensor(0.0004, grad_fn=<DivBackward0>)
# eval l : 0.7376073002815247
# p.grad :  tensor([[ 0.1698],
#         [-0.2046],
#         [ 0.2492],
#         [-0.3116],
#         [-0.1428]])
# p.grad :  tensor([0.2532])
# l :  tensor(0.0320, grad_fn=<DivBackward0>)
# eval l : 0.7381137609481812
# p.grad :  tensor([[-0.5662],
#         [-0.5802],
#         [ 0.7065],
#         [-0.5192],
#         [-0.4190]])
# p.grad :  tensor([0.7177])
# l :  tensor(0.2576, grad_fn=<DivBackward0>)
# eval l : 0.7370624542236328
# p.grad :  tensor([[-0.2016],
#         [ 0.2134],
#         [ 0.0696],
#         [ 0.1346],
#         [ 0.1370]])
# p.grad :  tensor([-0.1861])
# l :  tensor(0.0173, grad_fn=<DivBackward0>)
# eval l : 0.7369076013565063
# p.grad :  tensor([[-0.0430],
#         [-0.0183],
#         [ 0.0472],
#         [-0.0118],
#         [ 0.0206]])
# p.grad :  tensor([-0.0397])
# l :  tensor(0.0008, grad_fn=<DivBackward0>)
# eval l : 0.7368876934051514
# p.grad :  tensor([[0.4961],
#         [0.0096],
#         [0.2590],
#         [0.5013],
#         [0.2825]])
# p.grad :  tensor([-0.6930])
# l :  tensor(0.2401, grad_fn=<DivBackward0>)
# eval l : 0.7383226752281189
# p.grad :  tensor([[-0.2838],
#         [-1.1568],
#         [-1.1994],
#         [ 0.3007],
#         [-0.8234]])
# p.grad :  tensor([1.0090])
# l :  tensor(0.5091, grad_fn=<DivBackward0>)
# eval l : 0.7345514893531799
# p.grad :  tensor([[ 0.8502],
#         [-0.3858],
#         [ 0.4028],
#         [-1.4149],
#         [ 0.0681]])
# p.grad :  tensor([-1.0777])
# l :  tensor(0.5807, grad_fn=<DivBackward0>)
# eval l : 0.7376859784126282
# p.grad :  tensor([[-1.1585],
#         [ 0.6362],
#         [-1.6461],
#         [-1.7045],
#         [-0.6875]])
# p.grad :  tensor([1.3849])
# l :  tensor(0.9589, grad_fn=<DivBackward0>)
# eval l : 0.7340248823165894
# p.grad :  tensor([[ 0.0260],
#         [ 0.0407],
#         [-0.1145],
#         [-0.0190],
#         [ 0.0320]])
# p.grad :  tensor([-0.0636])
# l :  tensor(0.0020, grad_fn=<DivBackward0>)
# eval l : 0.7340391278266907
# p.grad :  tensor([[ 0.0353],
#         [ 0.0040],
#         [ 0.1076],
#         [-0.3779],
#         [ 0.1392]])
# p.grad :  tensor([-0.2879])
# l :  tensor(0.0414, grad_fn=<DivBackward0>)
# eval l : 0.7346652746200562
# p.grad :  tensor([[ 0.1187],
#         [-0.0446],
#         [ 0.0700],
#         [ 0.0511],
#         [-0.0251]])
# p.grad :  tensor([0.0389])
# l :  tensor(0.0008, grad_fn=<DivBackward0>)
# eval l : 0.734904408454895
# p.grad :  tensor([[ 0.0338],
#         [ 0.3164],
#         [ 0.1031],
#         [-0.0822],
#         [ 0.2062]])
# p.grad :  tensor([-0.2760])
# l :  tensor(0.0381, grad_fn=<DivBackward0>)
# eval l : 0.735575258731842
# p.grad :  tensor([[ 0.2024],
#         [-0.1430],
#         [-0.0466],
#         [-0.1535],
#         [-0.0914]])
# p.grad :  tensor([0.1247])
# l :  tensor(0.0078, grad_fn=<DivBackward0>)
# eval l : 0.7358815670013428
# p.grad :  tensor([[-0.0617],
#         [-0.3389],
#         [ 0.8769],
#         [-0.2199],
#         [ 0.3823]])
# p.grad :  tensor([-0.7378])
# l :  tensor(0.2721, grad_fn=<DivBackward0>)
# eval l : 0.7371125817298889
# p.grad :  tensor([[ 0.1292],
#         [ 0.1091],
#         [-0.3071],
#         [-0.2241],
#         [ 0.0894]])
# p.grad :  tensor([-0.1707])
# l :  tensor(0.0146, grad_fn=<DivBackward0>)
# eval l : 0.7374083399772644
# p.grad :  tensor([[-0.0338],
#         [-0.0210],
#         [ 0.0439],
#         [ 0.0133],
#         [-0.0233]])
# p.grad :  tensor([0.0446])
# l :  tensor(0.0010, grad_fn=<DivBackward0>)
# eval l : 0.7373289465904236
# p.grad :  tensor([[ 0.0452],
#         [ 0.1269],
#         [-0.1090],
#         [ 0.0801],
#         [ 0.0725]])
# p.grad :  tensor([-0.1107])
# l :  tensor(0.0061, grad_fn=<DivBackward0>)
# eval l : 0.7374209761619568
# p.grad :  tensor([[ 0.1252],
#         [-0.2444],
#         [ 0.0600],
#         [-0.2562],
#         [-0.2207]])
# p.grad :  tensor([0.3542])
# l :  tensor(0.0627, grad_fn=<DivBackward0>)
# eval l : 0.7375215291976929
# p.grad :  tensor([[-0.0338],
#         [-0.0971],
#         [ 0.1182],
#         [-0.1478],
#         [-0.0677]])
# p.grad :  tensor([0.1201])
# l :  tensor(0.0072, grad_fn=<DivBackward0>)
# eval l : 0.7375383377075195
# p.grad :  tensor([[ 0.0652],
#         [-0.2444],
#         [ 0.6325],
#         [ 0.6549],
#         [ 0.2641]])
# p.grad :  tensor([-0.5321])
# l :  tensor(0.1416, grad_fn=<DivBackward0>)
# eval l : 0.7380932569503784
# p.grad :  tensor([[ 1.0937],
#         [ 0.0476],
#         [ 0.1143],
#         [-0.4876],
#         [-0.1050]])
# p.grad :  tensor([0.6741])
# l :  tensor(0.2272, grad_fn=<DivBackward0>)
# eval l : 0.7408269047737122
# p.grad :  tensor([[0.1616],
#         [0.6586],
#         [0.2147],
#         [0.7071],
#         [0.4212]])
# p.grad :  tensor([-0.5745])
# l :  tensor(0.1650, grad_fn=<DivBackward0>)
# eval l : 0.7417981624603271
# p.grad :  tensor([[ 0.0771],
#         [-0.1765],
#         [ 0.2149],
#         [ 0.2866],
#         [-0.1363]])
# p.grad :  tensor([0.2183])
# l :  tensor(0.0238, grad_fn=<DivBackward0>)
# eval l : 0.7417318820953369
# p.grad :  tensor([[ 0.0252],
#         [ 0.0825],
#         [-0.2765],
#         [-0.2181],
#         [-0.1257]])
# p.grad :  tensor([0.3016])
# l :  tensor(0.0455, grad_fn=<DivBackward0>)
# eval l : 0.7415215373039246
# p.grad :  tensor([[ 0.7084],
#         [-0.5005],
#         [ 0.4298],
#         [ 0.5732],
#         [-0.2988]])
# p.grad :  tensor([0.4366])
# l :  tensor(0.0953, grad_fn=<DivBackward0>)
# eval l : 0.742544412612915
# p.grad :  tensor([[-0.2845],
#         [-0.6281],
#         [-0.5024],
#         [-0.3963],
#         [-0.4313]])
# p.grad :  tensor([0.5479])
# l :  tensor(0.1501, grad_fn=<DivBackward0>)
# eval l : 0.7408022880554199
# p.grad :  tensor([[-0.2794],
#         [-0.3633],
#         [ 0.9400],
#         [-1.0383],
#         [ 0.4171]])
# p.grad :  tensor([-0.7908])
# l :  tensor(0.3127, grad_fn=<DivBackward0>)
# eval l : 0.7422562837600708
# p.grad :  tensor([[ 1.3777],
#         [-0.1528],
#         [-1.7191],
#         [-2.2928],
#         [ 0.0929]])
# p.grad :  tensor([-1.7463])
# l :  tensor(1.5248, grad_fn=<DivBackward0>)
# eval l : 0.7453610301017761
# p.grad :  tensor([[ 0.2226],
#         [-0.9789],
#         [ 0.6483],
#         [ 0.3945],
#         [-0.2523]])
# p.grad :  tensor([-0.5454])
# l :  tensor(0.1488, grad_fn=<DivBackward0>)
# eval l : 0.7455908060073853
# p.grad :  tensor([[ 1.2126],
#         [-1.3860],
#         [ 0.5554],
#         [-0.4429],
#         [-2.9035]])
# p.grad :  tensor([-1.4861])
# l :  tensor(1.1043, grad_fn=<DivBackward0>)
# eval l : 0.7460703253746033
# p.grad :  tensor([[-0.1888],
#         [ 0.1334],
#         [-0.0197],
#         [ 0.0842],
#         [ 0.0815]])
# p.grad :  tensor([-0.1164])
# l :  tensor(0.0068, grad_fn=<DivBackward0>)
# eval l : 0.745688259601593
# p.grad :  tensor([[ 0.1248],
#         [ 0.1437],
#         [-0.3009],
#         [-0.0911],
#         [ 0.1594]])
# p.grad :  tensor([-0.3057])
# l :  tensor(0.0467, grad_fn=<DivBackward0>)
# eval l : 0.7459636330604553
# p.grad :  tensor([[-2.3827],
#         [ 1.6834],
#         [ 1.7454],
#         [-0.4376],
#         [ 1.1983]])
# p.grad :  tensor([-1.4684])
# l :  tensor(1.0781, grad_fn=<DivBackward0>)
# eval l : 0.7450023293495178
# p.grad :  tensor([[ 0.0727],
#         [-0.2358],
#         [ 0.2025],
#         [ 0.0613],
#         [-0.1384]])
# p.grad :  tensor([0.2057])
# l :  tensor(0.0211, grad_fn=<DivBackward0>)
# eval l : 0.7450664639472961
# p.grad :  tensor([[ 0.0845],
#         [-0.1445],
#         [ 0.0214],
#         [ 0.0376],
#         [-0.0903]])
# p.grad :  tensor([0.1260])
# l :  tensor(0.0079, grad_fn=<DivBackward0>)
# eval l : 0.7450745105743408
# p.grad :  tensor([[-0.2556],
#         [ 0.3300],
#         [ 0.1062],
#         [-0.7708],
#         [ 0.6735]])
# p.grad :  tensor([0.6262])
# l :  tensor(0.1961, grad_fn=<DivBackward0>)
# eval l : 0.745945155620575
# p.grad :  tensor([[ 0.3002],
#         [ 0.4807],
#         [-0.4128],
#         [ 0.5161],
#         [ 0.2685]])
# p.grad :  tensor([-0.4193])
# l :  tensor(0.0879, grad_fn=<DivBackward0>)
# eval l : 0.7463100552558899
# p.grad :  tensor([[ 0.0701],
#         [-0.0059],
#         [-0.0142],
#         [ 0.0606],
#         [ 0.0131]])
# p.grad :  tensor([-0.0838])
# l :  tensor(0.0035, grad_fn=<DivBackward0>)
# eval l : 0.746431291103363
# p.grad :  tensor([[ 1.5847],
#         [ 0.0690],
#         [ 0.1656],
#         [ 1.2823],
#         [-0.2689]])
# p.grad :  tensor([0.9767])
# l :  tensor(0.4769, grad_fn=<DivBackward0>)
# eval l : 0.7488015294075012
# p.grad :  tensor([[ 1.2328],
#         [-0.1322],
#         [-1.4874],
#         [-0.4503],
#         [-0.0035]])
# p.grad :  tensor([-1.5109])
# l :  tensor(1.1415, grad_fn=<DivBackward0>)
# eval l : 0.750539243221283
# p.grad :  tensor([[-0.4849],
#         [ 0.9184],
#         [ 0.1583],
#         [-0.6756],
#         [ 3.3584]])
# p.grad :  tensor([0.9339])
# l :  tensor(0.4361, grad_fn=<DivBackward0>)
# eval l : 0.7540361881256104
# p.grad :  tensor([[-0.2198],
#         [-0.3805],
#         [ 0.0563],
#         [-0.2401],
#         [-0.2325]])
# p.grad :  tensor([0.3319])
# l :  tensor(0.0551, grad_fn=<DivBackward0>)
# eval l : 0.7532568573951721
# p.grad :  tensor([[ 0.1882],
#         [-0.1320],
#         [ 0.2763],
#         [-0.2030],
#         [-0.1367]])
# p.grad :  tensor([0.2806])
# l :  tensor(0.0394, grad_fn=<DivBackward0>)
# eval l : 0.7538763284683228
# p.grad :  tensor([[ 0.1152],
#         [-0.0526],
#         [ 0.1766],
#         [ 0.2370],
#         [ 0.0781]])
# p.grad :  tensor([-0.1925])
# l :  tensor(0.0185, grad_fn=<DivBackward0>)
# eval l : 0.7542438507080078
# p.grad :  tensor([[-0.7232],
#         [-1.7401],
#         [ 0.7937],
#         [-0.8767],
#         [-0.5220]])
# p.grad :  tensor([-0.6677])
# l :  tensor(0.2229, grad_fn=<DivBackward0>)
# eval l : 0.7529007792472839
# p.grad :  tensor([[ 0.0582],
#         [-0.0098],
#         [-0.1103],
#         [-0.1471],
#         [ 0.0060]])
# p.grad :  tensor([-0.1120])
# l :  tensor(0.0063, grad_fn=<DivBackward0>)
# eval l : 0.7530498504638672
# p.grad :  tensor([[ 0.5921],
#         [-0.1145],
#         [-0.2405],
#         [-0.1897],
#         [-0.1918]])
# p.grad :  tensor([0.2623])
# l :  tensor(0.0344, grad_fn=<DivBackward0>)
# eval l : 0.7539786696434021
# p.grad :  tensor([[-0.4111],
#         [ 1.3339],
#         [ 1.3830],
#         [ 1.4321],
#         [ 0.9471]])
# p.grad :  tensor([-1.1635])
# l :  tensor(0.6769, grad_fn=<DivBackward0>)
# eval l : 0.7553699612617493
# p.grad :  tensor([[-0.0234],
#         [-0.0765],
#         [ 0.2567],
#         [-0.3675],
#         [ 0.1244]])
# p.grad :  tensor([-0.2799])
# l :  tensor(0.0392, grad_fn=<DivBackward0>)
# eval l : 0.7560644745826721
# p.grad :  tensor([[-0.7262],
#         [-1.3909],
#         [-1.4421],
#         [-1.4933],
#         [-0.9876]])
# p.grad :  tensor([1.2133])
# l :  tensor(0.7360, grad_fn=<DivBackward0>)
# eval l : 0.7519786357879639
# p.grad :  tensor([[-0.0319],
#         [ 0.0047],
#         [ 0.0525],
#         [-0.0386],
#         [ 0.0049]])
# p.grad :  tensor([0.0533])
# l :  tensor(0.0014, grad_fn=<DivBackward0>)
# eval l : 0.7519952058792114
# p.grad :  tensor([[ 0.3424],
#         [ 0.6559],
#         [-1.0294],
#         [ 0.7042],
#         [ 0.3406]])
# p.grad :  tensor([-0.5721])
# l :  tensor(0.1637, grad_fn=<DivBackward0>)
# eval l : 0.7518191337585449
# p.grad :  tensor([[0.1804],
#         [0.0447],
#         [0.5026],
#         [0.1522],
#         [0.0012]])
# p.grad :  tensor([0.5106])
# l :  tensor(0.1303, grad_fn=<DivBackward0>)
# eval l : 0.7525883913040161
# p.grad :  tensor([[-0.8520],
#         [-1.4754],
#         [-0.4810],
#         [ 1.6898],
#         [-0.9721]])
# p.grad :  tensor([1.2870])
# l :  tensor(0.8282, grad_fn=<DivBackward0>)
# eval l : 0.7468392252922058
# p.grad :  tensor([[ 0.8676],
#         [ 1.1667],
#         [-0.7345],
#         [ 0.2387],
#         [ 0.9781]])
# p.grad :  tensor([0.8010])
# l :  tensor(0.3208, grad_fn=<DivBackward0>)
# eval l : 0.7492718696594238
# p.grad :  tensor([[ 0.7277],
#         [-0.0841],
#         [-0.9460],
#         [ 0.6951],
#         [-0.0883]])
# p.grad :  tensor([-0.9610])
# l :  tensor(0.4617, grad_fn=<DivBackward0>)
# eval l : 0.7494105696678162
# p.grad :  tensor([[ 0.1255],
#         [-0.1220],
#         [ 0.4092],
#         [-0.5859],
#         [ 0.1984]])
# p.grad :  tensor([-0.4462])
# l :  tensor(0.0996, grad_fn=<DivBackward0>)
# eval l : 0.7508139610290527
# p.grad :  tensor([[-0.2519],
#         [ 0.3281],
#         [-0.1315],
#         [-0.4330],
#         [ 0.8225]])
# p.grad :  tensor([0.3518])
# l :  tensor(0.0619, grad_fn=<DivBackward0>)
# eval l : 0.7514269351959229
# p.grad :  tensor([[-0.0058],
#         [-0.0101],
#         [ 0.0015],
#         [-0.0108],
#         [-0.0060]])
# p.grad :  tensor([0.0088])
# l :  tensor(3.8638e-05, grad_fn=<DivBackward0>)
# eval l : 0.7514100670814514
# loss : 0.751410 ,6.264358 sec per epoch

# %%
train_sgd(0.05,10)

# %%
data_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
    features, labels),10,shuffle=True)

# %%
for x,y in data_iter:
    print(x)
    print(y)
    break

# %%
def train_pytorch_ch71(optimizer_fn,optimizer_hyperparams,features,labels,batch_size=10,
                     num_epochs=2):
    net=nn.Sequential(
        nn.Linear(features.shape[-1],1)
    )
    loss=nn.MSELoss()
    optimizer=optimizer_fn(net.parameters(),**optimizer_hyperparams)
    
    def eval_loss():
        return loss(net(features).view(-1),labels).item()/2
    ls=[eval_loss()]
    data_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
        features, labels),batch_size,shuffle=True)
    
    for _ in range(num_epochs):
        start=time.time()
        for batch_i,(X,y) in enumerate(data_iter):
            l=loss(net(X).view(-1),y)/2
            
            optimizer.zero_grad()
            l.backward()
#             print('----------------------------')
#             for i in net.parameters():
#                 print(i.grad.data)
#             print('----------------------------')
            optimizer.step()
            if (batch_i + 1) * batch_size % 100 ==0:
                ls.append(eval_loss())
    print('loss : %f ,%f sec per epoch' % (ls[-1], time.time() - start))
    plt.plot(np.linspace(0, num_epochs, len(ls)), ls)
    plt.xlabel('epoch')
    plt.ylabel('loss')

# %%
 train_pytorch_ch71(optim.SGD, {"lr": 1.0}, features, labels, 1500,6)
# Out:
# loss : 0.794979 ,0.010000 sec per epoch

# %%
 train_pytorch_ch71(optim.SGD, {"lr": 0.05}, features, labels, 10)
