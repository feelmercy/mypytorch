# %%
import torch
import numpy as np
import random
from IPython import display
from matplotlib import pyplot as plt
# %matplotlib auto

# %%
num_inputs=2
num_examples=1000
true_w=[2,-3,4]
true_b=4.2
features=torch.from_numpy(np.random.normal(0,1,(num_examples,num_inputs)))
labels=true_w[0]*features[:,0]+true_w[1]+features[:,1]+true_b
labels+=torch.from_numpy(np.random.normal(0,0.01,size=labels.size()))

# %%
print(features[0],labels[0])
# Out:
# tensor([-0.0489,  1.5016], dtype=torch.float64) tensor(2.6206, dtype=torch.float64)

# %%
def use_svg_display():
    display.set_matplotlib_formats('svg')
def set_figsize(figsize=(3.5,2.5)):
    use_svg_display()
    plt.rcParams['figure.figsize']=figsize

# %%
plt.scatter(features[:,1].numpy(),labels.numpy(),1)
plt.show()

# %%
def data_iter(batch_size,features,labels):
    num_examples=len(features)
    indices=list(range(num_examples))
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        j=torch.LongTensor(indices[i:min(i+batch_size,num_examples)])
        yield features.index_select(0,j),labels.index_select(0,j)

# %%
w=torch.tensor(np.random.normal(0,0.01,(num_inputs,1)),dtype=torch.float64)
b=torch.zeros([1],dtype=torch.float64)

# %%
w.requires_grad_(True)
b.requires_grad_(True)
# Out:
# tensor([0.], dtype=torch.float64, requires_grad=True)

# %%
def linreg(x,w,b):
    return torch.mm(x,w)+b

# %%
def squared_loss(y_hat,y):
    return (y_hat-y.view(y_hat.size()))**2/2

# %%
def sgd(params,lr,batch_size):
    for param in params:
        param.data -=lr*param.grad/batch_size

# %%
# w.grad.data.zero_()
# b.grad.data.zero_()
print(w)
print(b)
lr=0.03
num_epochs=30
net=linreg
batch_size=10
loss=squared_loss
for epoch in range(num_epochs):
    for x,y in data_iter(10,features,labels):
        l=loss(net(x,w,b),y).sum()
        print('net :',net(x,w,b))
        print('loss: ',loss(net(x,w,b),y))
        print('loss.sum : ',loss(net(x,w,b),y).sum())
        l.backward()
        sgd([w,b],lr,batch_size)
        
        w.grad.data.zero_()
        b.grad.data.zero_()
    train_l=loss(net(features,w,b),labels)
    print('epoch %d ,loss %f' % (epoch+1,train_l.mean().item()))
# Out:
# tensor([[-0.0195],
#         [ 0.0080]], dtype=torch.float64, requires_grad=True)
# tensor([0.], dtype=torch.float64, requires_grad=True)
# net : tensor([[ 0.0042],
#         [ 0.0058],
#         [ 0.0188],
#         [-0.0314],
#         [ 0.0266],
#         [-0.0092],
#         [ 0.0066],
#         [-0.0444],
#         [-0.0310],
#         [ 0.0136]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.7341e-01],
#         [5.7013e-01],
#         [2.5527e-01],
#         [6.7584e-02],
#         [4.5971e-04],
#         [1.1545e+00],
#         [6.8869e-01],
#         [9.9114e-01],
#         [4.8584e-02],
#         [7.5895e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.1257, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.4684e-02],
#         [ 9.0326e-05],
#         [ 2.0616e-02],
#         [-2.0617e-02],
#         [ 1.5015e-02],
#         [-6.7632e-03],
#         [ 4.7523e-03],
#         [ 3.1702e-02],
#         [ 1.4184e-02],
#         [ 2.6980e-03]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.3722],
#         [6.4111],
#         [3.3511],
#         [8.5206],
#         [1.8596],
#         [0.5816],
#         [1.5509],
#         [0.6964],
#         [1.8051],
#         [8.7230]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(35.8716, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.1328],
#         [ 0.0825],
#         [ 0.1518],
#         [ 0.0125],
#         [ 0.1243],
#         [-0.0003],
#         [ 0.0827],
#         [ 0.0704],
#         [-0.0045],
#         [-0.0269]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[7.0873],
#         [1.3076],
#         [7.5940],
#         [0.9943],
#         [4.6421],
#         [1.4105],
#         [0.9091],
#         [1.0050],
#         [2.4593],
#         [4.7124]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(32.1215, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.3287],
#         [ 0.1304],
#         [ 0.3562],
#         [ 0.1551],
#         [ 0.0216],
#         [ 0.0167],
#         [ 0.2277],
#         [ 0.2727],
#         [ 0.0838],
#         [-0.1105]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[11.5087],
#         [ 1.6790],
#         [13.7107],
#         [ 2.5128],
#         [ 0.0166],
#         [ 0.0965],
#         [ 5.1130],
#         [ 7.7224],
#         [ 0.5459],
#         [ 2.6230]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(45.5284, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.1288],
#         [-0.1302],
#         [ 0.2760],
#         [ 0.0717],
#         [ 0.6203],
#         [ 0.0167],
#         [ 0.0949],
#         [-0.2280],
#         [-0.2001],
#         [ 0.2259]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.0147e+00],
#         [1.0354e+00],
#         [2.1684e+00],
#         [5.7410e-02],
#         [1.3774e+01],
#         [4.6498e-03],
#         [1.4690e-01],
#         [2.4588e+00],
#         [1.9193e+00],
#         [1.4073e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(23.9870, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.4694],
#         [ 0.0930],
#         [-0.3583],
#         [ 0.3665],
#         [ 0.7787],
#         [-0.0553],
#         [ 0.2470],
#         [-0.1977],
#         [ 0.0735],
#         [ 0.3320]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[ 4.5159],
#         [ 0.2390],
#         [ 2.9732],
#         [ 3.0160],
#         [12.6147],
#         [ 0.0381],
#         [ 1.3116],
#         [ 0.9774],
#         [ 0.1429],
#         [ 2.2386]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(28.0673, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.3061],
#         [-0.3095],
#         [ 0.1380],
#         [ 0.0361],
#         [ 0.9362],
#         [ 0.5917],
#         [-0.0576],
#         [ 0.4470],
#         [-0.1833],
#         [ 0.2615]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[ 1.1775],
#         [ 1.2138],
#         [ 0.2346],
#         [ 0.0206],
#         [11.4948],
#         [ 4.6838],
#         [ 0.0455],
#         [ 2.6479],
#         [ 0.4441],
#         [ 0.8494]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(22.8119, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2995],
#         [ 0.5835],
#         [ 0.2520],
#         [-0.1888],
#         [-0.1807],
#         [ 0.2619],
#         [ 0.0496],
#         [ 0.1948],
#         [ 0.3246],
#         [ 0.4650]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.8134],
#         [3.2381],
#         [0.6011],
#         [0.3094],
#         [0.2852],
#         [0.6813],
#         [0.0353],
#         [0.3672],
#         [1.0163],
#         [1.9766]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(9.3237, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2316],
#         [-0.1064],
#         [-0.3134],
#         [ 0.5690],
#         [ 0.3878],
#         [ 0.8738],
#         [ 1.2031],
#         [ 0.4995],
#         [ 0.6393],
#         [-0.3295]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[ 0.4873],
#         [ 0.1719],
#         [ 0.6440],
#         [ 2.7316],
#         [ 1.3669],
#         [ 6.2629],
#         [11.6791],
#         [ 1.9003],
#         [ 3.5871],
#         [ 1.0156]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(29.8467, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.0644],
#         [ 0.8993],
#         [ 0.4274],
#         [ 0.9006],
#         [-0.3913],
#         [ 0.5043],
#         [ 0.7062],
#         [ 0.2146],
#         [ 1.2001],
#         [ 0.2414]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0339],
#         [3.9801],
#         [0.8988],
#         [4.2394],
#         [0.8477],
#         [1.3184],
#         [2.6569],
#         [0.1835],
#         [7.5305],
#         [0.2134]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(21.9027, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.1822],
#         [ 1.0396],
#         [ 1.3547],
#         [-0.1630],
#         [ 0.6339],
#         [ 0.1812],
#         [ 0.2560],
#         [ 0.7280],
#         [-0.3905],
#         [-0.0123]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.7043e+00],
#         [3.8730e+00],
#         [6.1342e+00],
#         [2.9185e-02],
#         [1.7222e+00],
#         [4.8026e-02],
#         [1.6670e-01],
#         [1.7404e+00],
#         [1.1381e+00],
#         [1.5404e-03]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(20.5577, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.8081],
#         [ 0.4250],
#         [-0.2369],
#         [ 1.2347],
#         [ 0.0211],
#         [ 1.3294],
#         [-0.0318],
#         [ 0.7301],
#         [ 0.7067],
#         [ 0.2193]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.9828],
#         [0.5576],
#         [0.1436],
#         [5.2903],
#         [0.0239],
#         [4.9487],
#         [0.0772],
#         [1.0165],
#         [1.4703],
#         [0.0855]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(16.5964, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.1129],
#         [-1.1837],
#         [ 1.3742],
#         [ 1.0053],
#         [ 1.1943],
#         [ 0.3129],
#         [ 0.9679],
#         [-0.3417],
#         [ 0.7347],
#         [ 0.3885]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0495],
#         [4.4054],
#         [4.0482],
#         [2.0804],
#         [3.1681],
#         [0.1860],
#         [2.0428],
#         [0.5922],
#         [1.7528],
#         [0.5186]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(18.8441, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2332],
#         [ 0.1982],
#         [ 0.0436],
#         [ 0.3153],
#         [ 0.5362],
#         [ 1.0068],
#         [-0.4008],
#         [-0.2523],
#         [ 0.9376],
#         [ 1.6574]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.8778e-02],
#         [1.4315e-01],
#         [1.6925e-03],
#         [1.1018e-01],
#         [4.8959e-01],
#         [1.7210e+00],
#         [4.2694e-01],
#         [1.6935e-01],
#         [1.6427e+00],
#         [5.0078e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(9.7412, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.8951],
#         [ 1.0256],
#         [ 0.5638],
#         [-0.5161],
#         [ 1.8038],
#         [ 1.3492],
#         [ 0.4314],
#         [ 0.7307],
#         [ 0.3987],
#         [ 0.9403]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.4290],
#         [1.0560],
#         [0.5822],
#         [0.8659],
#         [5.6104],
#         [3.3754],
#         [0.1858],
#         [0.8874],
#         [0.1530],
#         [1.4280]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(15.5731, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.5040],
#         [ 0.7245],
#         [ 0.3962],
#         [ 1.3329],
#         [ 0.2835],
#         [-0.0569],
#         [ 0.2040],
#         [ 0.7133],
#         [ 0.4180],
#         [ 1.2643]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.1591e-01],
#         [4.0561e-01],
#         [8.8539e-02],
#         [2.4980e+00],
#         [3.9397e-02],
#         [4.5249e-02],
#         [9.6824e-05],
#         [5.1514e-01],
#         [2.1196e-01],
#         [1.6181e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(5.9379, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.5857],
#         [-0.0228],
#         [-0.1984],
#         [ 0.2463],
#         [ 0.3491],
#         [-0.1399],
#         [ 1.9169],
#         [ 0.5949],
#         [-0.4390],
#         [-1.0968]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.2367],
#         [0.0229],
#         [0.0517],
#         [0.0671],
#         [0.0493],
#         [0.0308],
#         [5.1239],
#         [0.4832],
#         [0.2735],
#         [1.8513]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(11.1903, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.0374],
#         [-0.2553],
#         [-0.1492],
#         [ 0.1906],
#         [ 0.6605],
#         [ 1.5742],
#         [-0.3928],
#         [-0.2927],
#         [ 0.6087],
#         [ 0.6714]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0322],
#         [0.0988],
#         [0.0358],
#         [0.0802],
#         [0.2539],
#         [3.1198],
#         [0.2181],
#         [0.2712],
#         [0.4124],
#         [0.4084]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.9308, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[1.8446],
#         [1.1148],
#         [1.4567],
#         [1.4087],
#         [0.9075],
#         [0.4396],
#         [0.5038],
#         [1.1575],
#         [0.3886],
#         [0.3354]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[4.4883],
#         [1.2430],
#         [2.1055],
#         [1.5302],
#         [0.8560],
#         [0.0446],
#         [0.1547],
#         [1.4721],
#         [0.1436],
#         [0.1047]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(12.1427, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.3322],
#         [ 0.6211],
#         [-0.0661],
#         [ 1.7126],
#         [ 1.7562],
#         [ 0.4458],
#         [ 0.9720],
#         [ 0.6707],
#         [ 0.6622],
#         [ 0.5787]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.1059e-03],
#         [4.4142e-01],
#         [2.4365e-02],
#         [2.5547e+00],
#         [2.8906e+00],
#         [1.1802e-01],
#         [5.2839e-01],
#         [2.6564e-01],
#         [3.5469e-01],
#         [2.2697e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(7.4059, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2448],
#         [ 0.7193],
#         [ 1.3419],
#         [ 0.7547],
#         [ 0.4142],
#         [ 0.8869],
#         [ 0.4888],
#         [ 0.7344],
#         [-1.0690],
#         [ 0.1527]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[7.0063e-07],
#         [3.4885e-01],
#         [1.2602e+00],
#         [2.7617e-01],
#         [2.8457e-02],
#         [4.4991e-01],
#         [8.0230e-02],
#         [2.8474e-01],
#         [1.4645e+00],
#         [9.5080e-03]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.2026, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.3922],
#         [ 1.4318],
#         [-1.4021],
#         [-0.3854],
#         [ 1.0835],
#         [ 1.0779],
#         [ 0.3988],
#         [ 1.0064],
#         [ 1.9135],
#         [-1.7229]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.3364],
#         [0.8981],
#         [2.5020],
#         [0.5258],
#         [0.8313],
#         [0.5194],
#         [0.0562],
#         [0.8074],
#         [2.8548],
#         [3.3080]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(12.6393, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.3367],
#         [ 1.1141],
#         [-0.2086],
#         [ 0.2387],
#         [ 1.2758],
#         [-1.3596],
#         [ 1.6222],
#         [ 2.5269],
#         [-0.1578],
#         [-0.3476]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.3638e+00],
#         [6.7606e-01],
#         [1.8551e-01],
#         [8.9837e-04],
#         [7.2656e-01],
#         [1.6499e+00],
#         [1.6953e+00],
#         [4.4346e+00],
#         [9.3797e-02],
#         [2.2348e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(11.0499, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.9977],
#         [ 0.8761],
#         [ 0.7961],
#         [ 0.8209],
#         [-0.1785],
#         [ 1.8021],
#         [ 0.7912],
#         [ 1.7451],
#         [ 1.4007],
#         [ 0.8917]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.7397],
#         [0.4565],
#         [0.4413],
#         [0.2244],
#         [0.0833],
#         [2.5028],
#         [0.4235],
#         [1.6055],
#         [1.0642],
#         [0.2453]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(7.7865, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.6720],
#         [ 0.4781],
#         [ 1.5349],
#         [-0.1823],
#         [ 2.2944],
#         [ 0.5211],
#         [ 0.4609],
#         [ 1.7006],
#         [ 0.7475],
#         [-1.0401]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1844],
#         [0.0379],
#         [0.9853],
#         [0.0476],
#         [2.7649],
#         [0.0846],
#         [0.0307],
#         [1.7187],
#         [0.1700],
#         [0.7291]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(6.7533, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.4095],
#         [ 0.8052],
#         [ 0.2734],
#         [-0.3542],
#         [ 2.3049],
#         [ 2.5446],
#         [ 1.1212],
#         [ 0.8195],
#         [-0.0055],
#         [-0.3348]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[7.6670e-01],
#         [2.2760e-01],
#         [3.4149e-04],
#         [9.4905e-02],
#         [2.2176e+00],
#         [3.2059e+00],
#         [4.7924e-01],
#         [2.6771e-01],
#         [5.8335e-02],
#         [7.3002e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(7.3914, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.7831],
#         [-0.1161],
#         [ 1.3381],
#         [ 0.9390],
#         [ 1.0345],
#         [ 3.0208],
#         [ 0.4489],
#         [-0.4319],
#         [ 1.0905],
#         [-1.2648]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.5048],
#         [0.0388],
#         [0.5132],
#         [0.2448],
#         [0.3703],
#         [3.4306],
#         [0.0247],
#         [0.1565],
#         [0.5339],
#         [1.0248]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(6.8425, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9009],
#         [ 1.9662],
#         [ 0.3656],
#         [-1.8857],
#         [ 1.7096],
#         [ 3.3377],
#         [ 1.4375],
#         [ 1.8898],
#         [ 0.0541],
#         [-0.3923]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.0249e+00],
#         [1.2212e+00],
#         [8.5141e-02],
#         [1.6243e+00],
#         [1.1283e+00],
#         [3.8545e+00],
#         [5.2341e-01],
#         [1.2564e+00],
#         [1.4096e-04],
#         [1.2493e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(10.8433, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.3579],
#         [ 1.1953],
#         [ 0.1569],
#         [ 1.5762],
#         [ 2.0373],
#         [ 2.1582],
#         [ 3.2645],
#         [ 0.8565],
#         [ 0.3367],
#         [ 1.9602]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[8.0256e-02],
#         [5.6852e-01],
#         [4.4498e-03],
#         [8.7849e-01],
#         [1.3154e+00],
#         [1.1498e+00],
#         [4.3670e+00],
#         [3.0384e-01],
#         [1.4601e-03],
#         [1.2888e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(9.9580, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.3648],
#         [ 1.3514],
#         [ 0.0710],
#         [ 0.9731],
#         [ 1.7791],
#         [ 1.0890],
#         [-1.0976],
#         [ 0.7954],
#         [ 0.3717],
#         [ 1.6570]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.2164e-01],
#         [3.3032e-01],
#         [2.1064e-04],
#         [2.1896e-01],
#         [7.3065e-01],
#         [1.9108e-01],
#         [3.8250e-01],
#         [5.6240e-02],
#         [1.6152e-02],
#         [7.8523e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.8330, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.7712],
#         [ 2.6510],
#         [ 1.4001],
#         [ 0.5490],
#         [-2.9126],
#         [ 0.5091],
#         [ 0.2461],
#         [ 0.3385],
#         [ 1.6966],
#         [-1.1292]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.2869],
#         [1.9105],
#         [0.4181],
#         [0.0763],
#         [3.0896],
#         [0.0329],
#         [0.0195],
#         [0.0162],
#         [0.5271],
#         [0.5084]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(6.8856, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.5615],
#         [ 0.8996],
#         [ 0.5265],
#         [-0.7092],
#         [ 0.2361],
#         [-0.7386],
#         [ 0.8294],
#         [ 1.3753],
#         [ 0.4810],
#         [ 2.5957]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.4905],
#         [0.0767],
#         [0.0449],
#         [0.1646],
#         [0.0037],
#         [0.1475],
#         [0.0730],
#         [0.2864],
#         [0.0174],
#         [1.5689]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.8736, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.0494],
#         [ 2.8367],
#         [ 1.2987],
#         [ 0.5636],
#         [-0.2485],
#         [ 1.5147],
#         [ 1.3995],
#         [ 1.1007],
#         [ 0.8060],
#         [ 2.6621]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1641],
#         [1.7536],
#         [0.2702],
#         [0.0864],
#         [0.0338],
#         [0.3735],
#         [0.5391],
#         [0.2520],
#         [0.0661],
#         [1.4428]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.9817, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.8800],
#         [-0.3799],
#         [ 1.1661],
#         [-0.4374],
#         [ 1.7426],
#         [ 2.7653],
#         [ 0.6146],
#         [ 2.8545],
#         [ 0.5201],
#         [ 2.2870]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.2753],
#         [0.0935],
#         [0.2566],
#         [0.0500],
#         [0.5176],
#         [1.2631],
#         [0.0493],
#         [1.7667],
#         [0.0449],
#         [0.9539]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(5.2709, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.2408],
#         [ 2.9891],
#         [-0.3462],
#         [ 0.8630],
#         [-0.4172],
#         [ 2.0094],
#         [ 2.8301],
#         [ 0.1921],
#         [ 1.5922],
#         [ 0.3890]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[4.7804e-01],
#         [1.6319e+00],
#         [1.4068e-01],
#         [8.1927e-02],
#         [6.7216e-02],
#         [6.0403e-01],
#         [1.3169e+00],
#         [2.0631e-06],
#         [3.5719e-01],
#         [3.5414e-04]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.6782, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.0451],
#         [ 0.9698],
#         [ 0.0923],
#         [ 0.1548],
#         [ 3.2844],
#         [ 0.5071],
#         [ 0.7955],
#         [ 0.8963],
#         [-0.1822],
#         [ 1.0524]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.5796],
#         [0.0703],
#         [0.0029],
#         [0.0019],
#         [1.6196],
#         [0.0145],
#         [0.0474],
#         [0.0742],
#         [0.0293],
#         [0.1281]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.5679, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[1.0371],
#         [2.3186],
#         [1.7973],
#         [1.5265],
#         [2.1600],
#         [1.0159],
#         [1.7924],
#         [0.8107],
#         [2.4172],
#         [2.0448]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1319],
#         [0.7320],
#         [0.4695],
#         [0.1948],
#         [0.6023],
#         [0.1283],
#         [0.3877],
#         [0.0297],
#         [0.8029],
#         [0.5862]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.0653, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.0422],
#         [ 1.8702],
#         [ 0.1103],
#         [ 2.7973],
#         [ 1.0388],
#         [ 2.5337],
#         [ 1.1073],
#         [ 2.2244],
#         [ 0.9340],
#         [ 1.4447]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0367],
#         [0.4034],
#         [0.0120],
#         [0.9885],
#         [0.0981],
#         [0.8186],
#         [0.0873],
#         [0.5135],
#         [0.0680],
#         [0.1999]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(3.2259, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 3.1129],
#         [ 1.3050],
#         [-0.3284],
#         [-0.9185],
#         [ 1.3231],
#         [-0.5025],
#         [-2.4914],
#         [-0.7970],
#         [ 2.1395],
#         [ 0.9174]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.1655],
#         [0.1303],
#         [0.0756],
#         [0.2549],
#         [0.1435],
#         [0.1369],
#         [1.2033],
#         [0.1673],
#         [0.3825],
#         [0.0560]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(3.7158, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.7144],
#         [ 1.3152],
#         [-0.9231],
#         [-0.4764],
#         [ 0.6030],
#         [ 0.9179],
#         [ 1.7252],
#         [ 0.2160],
#         [-0.7636],
#         [-0.5932]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.2733],
#         [0.1073],
#         [0.2258],
#         [0.0765],
#         [0.0203],
#         [0.0583],
#         [0.2348],
#         [0.0009],
#         [0.1550],
#         [0.0910]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.2431, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[1.4583],
#         [0.2299],
#         [1.0992],
#         [1.4432],
#         [1.1441],
#         [1.8029],
#         [0.4909],
#         [2.9514],
#         [2.8914],
#         [1.0447]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.5544e-01],
#         [2.7599e-04],
#         [1.0206e-01],
#         [1.4809e-01],
#         [8.9502e-02],
#         [2.4307e-01],
#         [7.0173e-03],
#         [9.3929e-01],
#         [8.4613e-01],
#         [7.6113e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.6070, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 4.3510],
#         [-0.0771],
#         [ 1.3427],
#         [ 0.3745],
#         [ 1.8837],
#         [ 0.0420],
#         [-0.7058],
#         [ 2.0549],
#         [ 1.9871],
#         [ 3.1843]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.0936e+00],
#         [1.3527e-02],
#         [1.2288e-01],
#         [4.7339e-04],
#         [3.0062e-01],
#         [1.5434e-03],
#         [1.4487e-01],
#         [3.4132e-01],
#         [2.8085e-01],
#         [1.0376e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(4.3373, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2083],
#         [-0.5932],
#         [ 0.6141],
#         [ 3.6433],
#         [ 2.0134],
#         [-1.0793],
#         [-0.4467],
#         [ 1.1502],
#         [ 0.7199],
#         [ 2.9096]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0016],
#         [0.0944],
#         [0.0115],
#         [1.1251],
#         [0.3054],
#         [0.2069],
#         [0.0716],
#         [0.0554],
#         [0.0113],
#         [0.6245]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.5077, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.9089],
#         [ 1.3302],
#         [ 3.3347],
#         [ 0.2437],
#         [-0.1459],
#         [ 0.8492],
#         [-0.6779],
#         [-0.6778],
#         [ 1.1556],
#         [ 0.5410]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.6438],
#         [0.1053],
#         [0.8434],
#         [0.0113],
#         [0.0390],
#         [0.0064],
#         [0.1275],
#         [0.0878],
#         [0.0703],
#         [0.0012]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.9360, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.8375],
#         [ 0.2454],
#         [-3.1758],
#         [-0.0828],
#         [ 0.7970],
#         [ 1.1863],
#         [-0.5217],
#         [ 0.6458],
#         [-1.8381],
#         [-0.3485]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0238],
#         [0.0013],
#         [1.1989],
#         [0.0054],
#         [0.0107],
#         [0.0673],
#         [0.0687],
#         [0.0035],
#         [0.4816],
#         [0.0303]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.8917, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 3.2051],
#         [ 2.0960],
#         [ 0.3527],
#         [ 0.2719],
#         [ 0.7611],
#         [ 1.4999],
#         [ 1.4885],
#         [-3.7503],
#         [ 2.4419],
#         [ 0.9169]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[6.3975e-01],
#         [2.4815e-01],
#         [2.4770e-04],
#         [6.9267e-04],
#         [1.2639e-02],
#         [1.4509e-01],
#         [1.3956e-01],
#         [1.3261e+00],
#         [3.7267e-01],
#         [2.0327e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.9052, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.0840],
#         [ 2.0652],
#         [ 2.1187],
#         [-0.8587],
#         [-0.9919],
#         [ 3.0969],
#         [-1.1937],
#         [ 3.4915],
#         [ 0.2307],
#         [-1.5238]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.7553e-02],
#         [2.1136e-01],
#         [2.6224e-01],
#         [1.0843e-01],
#         [1.1546e-01],
#         [5.3599e-01],
#         [1.5551e-01],
#         [9.8489e-01],
#         [9.1978e-04],
#         [2.9377e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.7261, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.0402],
#         [ 0.2279],
#         [ 0.2687],
#         [ 0.6128],
#         [-0.5095],
#         [ 0.4648],
#         [ 0.7359],
#         [ 2.6525],
#         [ 0.1061],
#         [ 2.3038]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0521],
#         [0.0008],
#         [0.0076],
#         [0.0047],
#         [0.0230],
#         [0.0247],
#         [0.0324],
#         [0.3151],
#         [0.0029],
#         [0.3127]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.7760, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.9812],
#         [ 2.4363],
#         [ 1.4456],
#         [-1.1117],
#         [-0.3803],
#         [ 1.7793],
#         [ 1.6045],
#         [-0.7245],
#         [-1.5897],
#         [ 2.5494]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0477],
#         [0.3426],
#         [0.0623],
#         [0.1470],
#         [0.0201],
#         [0.1588],
#         [0.1150],
#         [0.0811],
#         [0.2468],
#         [0.2935]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.5148, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.6007],
#         [ 0.0511],
#         [ 2.7749],
#         [ 0.2700],
#         [ 4.5326],
#         [ 0.9023],
#         [ 1.5275],
#         [-1.5160],
#         [ 0.3099],
#         [ 1.6183]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.1131e-01],
#         [4.9444e-04],
#         [3.8894e-01],
#         [2.7171e-03],
#         [1.0608e+00],
#         [2.0125e-02],
#         [1.3402e-01],
#         [1.9618e-01],
#         [1.0513e-03],
#         [1.4888e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.0645, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9980],
#         [ 3.3737],
#         [ 1.0091],
#         [ 1.0589],
#         [-0.9279],
#         [-1.0849],
#         [-0.8231],
#         [ 0.6403],
#         [ 1.2644],
#         [ 1.7054]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1492],
#         [0.7111],
#         [0.0553],
#         [0.0275],
#         [0.0747],
#         [0.1196],
#         [0.1061],
#         [0.0099],
#         [0.0360],
#         [0.1271]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.4165, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.0043],
#         [ 0.1512],
#         [ 2.7896],
#         [ 2.3598],
#         [-0.2465],
#         [ 4.2670],
#         [ 1.4024],
#         [ 0.1924],
#         [ 1.7927],
#         [-0.6589]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1868],
#         [0.0011],
#         [0.3589],
#         [0.1913],
#         [0.0111],
#         [0.7649],
#         [0.0938],
#         [0.0018],
#         [0.0829],
#         [0.0481]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.7407, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9920],
#         [-1.4995],
#         [ 3.5452],
#         [ 0.6660],
#         [ 1.0045],
#         [ 0.8296],
#         [-2.4382],
#         [ 0.0744],
#         [ 4.0881],
#         [-1.3025]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1369],
#         [0.1687],
#         [0.4892],
#         [0.0041],
#         [0.0237],
#         [0.0234],
#         [0.4710],
#         [0.0074],
#         [0.6681],
#         [0.1547]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.1473, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.5243],
#         [ 0.7515],
#         [-0.1734],
#         [-0.0089],
#         [ 0.9293],
#         [-0.8445],
#         [-0.1641],
#         [ 4.3117],
#         [ 0.3280],
#         [-0.8799]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.0671e-02],
#         [3.3898e-02],
#         [9.1706e-03],
#         [1.3474e-02],
#         [2.4395e-02],
#         [8.4292e-02],
#         [3.5078e-03],
#         [7.2089e-01],
#         [1.0250e-04],
#         [3.8137e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.9785, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.4247],
#         [ 3.3734],
#         [-2.0480],
#         [ 2.3526],
#         [-0.5906],
#         [ 1.5646],
#         [-3.4002],
#         [ 3.6969],
#         [ 0.4552],
#         [-1.4307]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0557],
#         [0.5254],
#         [0.2140],
#         [0.1928],
#         [0.0614],
#         [0.0574],
#         [0.4745],
#         [0.6058],
#         [0.0013],
#         [0.1272]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(2.3155, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 4.2216],
#         [ 1.4813],
#         [ 0.3201],
#         [ 0.3254],
#         [-1.6839],
#         [-0.7442],
#         [-0.9159],
#         [ 3.5291],
#         [ 0.6381],
#         [ 0.4535]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.6438e-01],
#         [6.8489e-02],
#         [2.3123e-04],
#         [3.1971e-03],
#         [1.9348e-01],
#         [3.7834e-02],
#         [3.1544e-02],
#         [4.3447e-01],
#         [5.8877e-03],
#         [2.7631e-04]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.3398, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.2616],
#         [ 0.5665],
#         [-0.0611],
#         [ 1.0473],
#         [ 0.7553],
#         [-0.0670],
#         [-1.9631],
#         [ 0.6393],
#         [-2.2935],
#         [ 0.0490]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.2205e-01],
#         [6.5288e-03],
#         [2.9770e-04],
#         [2.4414e-02],
#         [1.0739e-04],
#         [4.2165e-03],
#         [2.2317e-01],
#         [3.4426e-03],
#         [2.9183e-01],
#         [1.6996e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.6931, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.3827],
#         [ 0.9668],
#         [ 1.8158],
#         [ 2.4429],
#         [ 3.6084],
#         [ 2.7467],
#         [ 1.7687],
#         [-0.0135],
#         [ 3.4617],
#         [-1.7451]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0179],
#         [0.0139],
#         [0.0738],
#         [0.2006],
#         [0.4040],
#         [0.2835],
#         [0.0451],
#         [0.0012],
#         [0.3242],
#         [0.1021]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.4661, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.0071],
#         [ 0.2030],
#         [ 1.8410],
#         [ 1.7795],
#         [ 1.7253],
#         [ 3.3570],
#         [ 0.8374],
#         [ 0.9308],
#         [-0.0049],
#         [ 3.3286]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.9847e-02],
#         [2.7049e-03],
#         [1.3583e-01],
#         [1.1425e-01],
#         [6.7785e-02],
#         [4.1177e-01],
#         [1.2846e-02],
#         [2.4696e-02],
#         [3.4156e-04],
#         [2.8842e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.0785, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.2372],
#         [-1.5018],
#         [ 0.9432],
#         [ 3.0583],
#         [-0.5793],
#         [ 1.4359],
#         [-1.3022],
#         [ 1.3144],
#         [ 0.2940],
#         [ 1.7568]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0712],
#         [0.1199],
#         [0.0102],
#         [0.2190],
#         [0.0226],
#         [0.0253],
#         [0.0884],
#         [0.0385],
#         [0.0012],
#         [0.0590]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.6552, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.5209],
#         [-2.2196],
#         [ 1.6206],
#         [ 2.0981],
#         [ 3.0862],
#         [ 3.1923],
#         [ 1.3873],
#         [-0.1044],
#         [-0.9567],
#         [ 3.9748]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0037],
#         [0.1953],
#         [0.0591],
#         [0.0744],
#         [0.2332],
#         [0.2400],
#         [0.0348],
#         [0.0028],
#         [0.0352],
#         [0.4030]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.2814, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.2966],
#         [ 3.5700],
#         [ 0.1315],
#         [-0.4152],
#         [ 1.0300],
#         [ 0.1124],
#         [ 0.8933],
#         [-1.6260],
#         [ 3.8906],
#         [ 0.7569]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0898],
#         [0.2962],
#         [0.0015],
#         [0.0085],
#         [0.0151],
#         [0.0018],
#         [0.0084],
#         [0.0918],
#         [0.3955],
#         [0.0037]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.9122, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.1595],
#         [-0.0546],
#         [ 6.3374],
#         [-1.8586],
#         [-0.6901],
#         [ 0.1216],
#         [ 3.2696],
#         [ 1.0521],
#         [ 2.2419],
#         [ 1.0320]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.7247e-02],
#         [3.1926e-03],
#         [9.6489e-01],
#         [1.2193e-01],
#         [1.5994e-02],
#         [7.5257e-04],
#         [2.0562e-01],
#         [1.4397e-02],
#         [1.0908e-01],
#         [1.2979e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.4661, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2320],
#         [ 3.2302],
#         [ 3.7189],
#         [-1.1443],
#         [ 2.9897],
#         [-1.5816],
#         [ 3.5971],
#         [ 1.4176],
#         [ 3.0752],
#         [ 4.7691]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0005],
#         [0.2032],
#         [0.2684],
#         [0.0354],
#         [0.1825],
#         [0.0670],
#         [0.2568],
#         [0.0295],
#         [0.1924],
#         [0.4198]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.6553, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 3.0077],
#         [-1.9555],
#         [-0.1978],
#         [-2.2153],
#         [-0.4930],
#         [ 1.2866],
#         [ 1.6941],
#         [-2.0060],
#         [ 4.6375],
#         [ 4.8012]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.1447],
#         [0.0968],
#         [0.0057],
#         [0.1350],
#         [0.0165],
#         [0.0129],
#         [0.0403],
#         [0.0809],
#         [0.3985],
#         [0.4050]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(1.3363, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.8487],
#         [-0.1203],
#         [ 3.4312],
#         [ 3.0650],
#         [-1.3620],
#         [-0.9057],
#         [ 0.9503],
#         [ 2.7933],
#         [ 3.5958],
#         [ 2.2635]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0508],
#         [0.0021],
#         [0.1595],
#         [0.1298],
#         [0.0460],
#         [0.0263],
#         [0.0088],
#         [0.1111],
#         [0.2157],
#         [0.0638]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.8140, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.5246],
#         [ 2.2740],
#         [-1.9188],
#         [-0.3258],
#         [ 0.1099],
#         [-0.1099],
#         [ 4.6333],
#         [ 2.1411],
#         [ 2.3666],
#         [ 2.1210]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.3478e-02],
#         [5.3470e-02],
#         [9.4548e-02],
#         [2.1593e-03],
#         [2.6659e-04],
#         [1.5248e-03],
#         [3.1483e-01],
#         [6.7792e-02],
#         [7.5157e-02],
#         [5.6195e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.6994, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.5893],
#         [ 4.6675],
#         [-1.4250],
#         [ 0.4610],
#         [ 0.1727],
#         [ 0.4377],
#         [-1.8582],
#         [ 0.7428],
#         [ 2.3305],
#         [ 2.4388]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.0513e-03],
#         [3.1016e-01],
#         [3.8423e-02],
#         [4.5413e-04],
#         [6.2191e-04],
#         [1.3352e-04],
#         [7.3211e-02],
#         [2.0237e-03],
#         [4.2968e-02],
#         [7.1098e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.5411, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.7650],
#         [ 0.1647],
#         [ 3.3761],
#         [ 4.3228],
#         [ 2.7351],
#         [-2.6358],
#         [ 3.0123],
#         [ 3.2582],
#         [-1.6470],
#         [ 1.1417]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0274],
#         [0.0004],
#         [0.1320],
#         [0.2414],
#         [0.0907],
#         [0.1181],
#         [0.1044],
#         [0.1225],
#         [0.0619],
#         [0.0057]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.9045, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.8102],
#         [ 2.1089],
#         [ 2.7291],
#         [-1.4450],
#         [ 1.6545],
#         [ 3.1360],
#         [ 2.2869],
#         [ 3.2674],
#         [-1.2075],
#         [ 1.4044]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0262],
#         [0.0440],
#         [0.0699],
#         [0.0318],
#         [0.0243],
#         [0.0909],
#         [0.0528],
#         [0.1218],
#         [0.0231],
#         [0.0129]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.4977, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.5648],
#         [ 3.0140],
#         [-0.5507],
#         [ 4.8464],
#         [ 0.8490],
#         [-1.6692],
#         [ 1.8269],
#         [ 1.3666],
#         [ 3.4861],
#         [ 4.7136]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0620],
#         [0.0892],
#         [0.0058],
#         [0.2499],
#         [0.0033],
#         [0.0495],
#         [0.0284],
#         [0.0138],
#         [0.1214],
#         [0.2268]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.8501, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9070],
#         [-0.2359],
#         [-0.2804],
#         [ 2.8481],
#         [ 1.6305],
#         [ 0.1123],
#         [ 1.1886],
#         [ 2.9425],
#         [ 4.4361],
#         [ 2.4082]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0337],
#         [0.0020],
#         [0.0037],
#         [0.0591],
#         [0.0182],
#         [0.0012],
#         [0.0090],
#         [0.0707],
#         [0.1731],
#         [0.0443]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.4151, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.4257],
#         [-0.3614],
#         [ 1.4415],
#         [ 1.5306],
#         [ 1.3759],
#         [ 2.1672],
#         [ 1.7495],
#         [ 0.9575],
#         [ 2.3262],
#         [-0.8344]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0324],
#         [0.0042],
#         [0.0108],
#         [0.0150],
#         [0.0109],
#         [0.0288],
#         [0.0188],
#         [0.0042],
#         [0.0306],
#         [0.0152]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.1710, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.2605],
#         [-1.3613],
#         [ 2.0257],
#         [ 1.3187],
#         [ 1.9110],
#         [ 0.6916],
#         [ 0.4282],
#         [ 1.1579],
#         [ 4.2211],
#         [ 0.7899]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.7170e-02],
#         [2.7577e-02],
#         [2.5628e-02],
#         [7.2470e-03],
#         [2.1918e-02],
#         [1.4272e-04],
#         [1.6309e-05],
#         [5.7463e-03],
#         [1.4660e-01],
#         [1.5542e-03]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2736, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 3.3553],
#         [ 2.7941],
#         [ 1.6510],
#         [ 2.3946],
#         [-0.1169],
#         [-1.5551],
#         [ 1.8058],
#         [ 2.0402],
#         [ 0.6561],
#         [ 2.2872]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0857],
#         [0.0499],
#         [0.0108],
#         [0.0402],
#         [0.0013],
#         [0.0281],
#         [0.0149],
#         [0.0220],
#         [0.0008],
#         [0.0277]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2812, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.2654],
#         [ 0.7137],
#         [ 2.3566],
#         [-0.8877],
#         [ 2.2505],
#         [-1.2149],
#         [-1.6699],
#         [ 2.2495],
#         [ 2.1711],
#         [-2.5075]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0163],
#         [0.0015],
#         [0.0310],
#         [0.0085],
#         [0.0302],
#         [0.0247],
#         [0.0430],
#         [0.0315],
#         [0.0341],
#         [0.0698]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2905, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.5828],
#         [ 2.7002],
#         [ 2.2853],
#         [ 1.3901],
#         [ 1.7027],
#         [ 0.7346],
#         [ 1.6051],
#         [-5.4083],
#         [ 0.4639],
#         [ 1.1838]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0360],
#         [0.0590],
#         [0.0302],
#         [0.0031],
#         [0.0162],
#         [0.0015],
#         [0.0134],
#         [0.2864],
#         [0.0018],
#         [0.0032]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.4508, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.1085],
#         [ 1.0579],
#         [-0.9158],
#         [-0.8384],
#         [ 4.5594],
#         [ 2.5745],
#         [ 1.9520],
#         [ 1.3020],
#         [-0.2595],
#         [ 3.4075]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0178],
#         [0.0031],
#         [0.0099],
#         [0.0088],
#         [0.1550],
#         [0.0357],
#         [0.0180],
#         [0.0072],
#         [0.0028],
#         [0.0769]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.3352, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.8129],
#         [ 0.0069],
#         [-0.0705],
#         [ 1.7392],
#         [-0.7620],
#         [-0.3026],
#         [ 1.5548],
#         [ 0.6563],
#         [ 1.2707],
#         [ 0.2030]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.8420e-02],
#         [5.7536e-05],
#         [1.5774e-03],
#         [1.3113e-02],
#         [1.2487e-02],
#         [5.4761e-03],
#         [8.4295e-03],
#         [1.3303e-03],
#         [3.9222e-03],
#         [1.5559e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0848, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.1280],
#         [ 1.2411],
#         [ 2.0413],
#         [-0.1113],
#         [ 1.5113],
#         [ 0.5227],
#         [ 3.9012],
#         [-2.6047],
#         [ 2.3091],
#         [ 3.0219]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.0452e-02],
#         [7.7424e-03],
#         [2.0668e-02],
#         [1.1036e-03],
#         [1.4242e-02],
#         [1.9787e-05],
#         [8.8884e-02],
#         [6.3619e-02],
#         [2.8330e-02],
#         [5.0307e-02]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2954, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.0662],
#         [ 0.8183],
#         [-1.2616],
#         [-2.2833],
#         [ 2.3899],
#         [ 2.4193],
#         [ 6.9834],
#         [-0.5349],
#         [-2.6294],
#         [ 1.6758]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0023],
#         [0.0014],
#         [0.0193],
#         [0.0485],
#         [0.0217],
#         [0.0308],
#         [0.3130],
#         [0.0081],
#         [0.0624],
#         [0.0143]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.5218, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.6235],
#         [ 1.1633],
#         [ 3.7667],
#         [-0.0920],
#         [-0.3686],
#         [-0.8866],
#         [ 1.9517],
#         [ 4.7210],
#         [ 1.0351],
#         [ 2.9584]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0024],
#         [0.0025],
#         [0.0782],
#         [0.0018],
#         [0.0012],
#         [0.0103],
#         [0.0171],
#         [0.1225],
#         [0.0033],
#         [0.0422]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2815, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.1171],
#         [ 2.4036],
#         [ 2.1249],
#         [-1.1939],
#         [-2.1302],
#         [-2.8494],
#         [-0.1139],
#         [ 2.9113],
#         [-0.2872],
#         [ 1.7896]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0030],
#         [0.0268],
#         [0.0155],
#         [0.0113],
#         [0.0357],
#         [0.0647],
#         [0.0006],
#         [0.0317],
#         [0.0021],
#         [0.0158]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.2071, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 4.2454],
#         [-0.1499],
#         [ 1.4361],
#         [ 6.1308],
#         [ 1.2467],
#         [ 3.0652],
#         [-0.0712],
#         [ 4.7541],
#         [ 0.8114],
#         [-0.3320]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0815],
#         [0.0015],
#         [0.0075],
#         [0.1975],
#         [0.0034],
#         [0.0363],
#         [0.0006],
#         [0.0986],
#         [0.0010],
#         [0.0019]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.4298, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.8186],
#         [ 2.5085],
#         [ 1.8980],
#         [ 1.5201],
#         [ 1.7493],
#         [ 3.3675],
#         [ 1.2189],
#         [ 2.8491],
#         [ 3.1213],
#         [ 1.9098]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[0.0059],
#         [0.0232],
#         [0.0137],
#         [0.0055],
#         [0.0121],
#         [0.0457],
#         [0.0048],
#         [0.0291],
#         [0.0359],
#         [0.0148]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.1906, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9880],
#         [ 0.9314],
#         [ 3.0898],
#         [ 0.6925],
#         [-3.0284],
#         [ 2.8028],
#         [ 0.3746],
#         [ 0.6496],
#         [ 1.5452],
# ...
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.9474],
#         [ 0.4058],
#         [ 1.4088],
#         [ 2.4199],
#         [ 4.4109],
#         [ 4.7581],
#         [ 0.1637],
#         [ 4.2551],
#         [ 1.1324],
#         [ 0.8244]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.0584e-05],
#         [3.2963e-06],
#         [1.6674e-06],
#         [1.6026e-04],
#         [2.1858e-11],
#         [1.0028e-05],
#         [7.1086e-05],
#         [4.3867e-05],
#         [1.1791e-05],
#         [2.7164e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0003, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.2610],
#         [-0.6642],
#         [ 4.8741],
#         [ 3.1578],
#         [ 3.5576],
#         [ 0.4244],
#         [ 1.0479],
#         [ 1.5410],
#         [ 4.4529],
#         [ 3.7687]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.6791e-04],
#         [5.6247e-05],
#         [1.3533e-06],
#         [5.0076e-08],
#         [4.6236e-06],
#         [9.5155e-05],
#         [3.1667e-05],
#         [3.4134e-05],
#         [3.2549e-09],
#         [1.8880e-07]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.2826],
#         [ 1.7832],
#         [-0.1142],
#         [-2.0625],
#         [ 1.2434],
#         [ 2.7040],
#         [ 1.5735],
#         [ 2.2566],
#         [-2.3903],
#         [ 1.9000]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.5459e-04],
#         [1.7291e-05],
#         [4.1342e-04],
#         [1.6560e-04],
#         [4.5768e-05],
#         [1.9473e-06],
#         [1.0121e-05],
#         [1.2926e-05],
#         [1.3358e-05],
#         [5.9126e-06]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0008, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2579],
#         [ 2.8561],
#         [ 3.2714],
#         [ 2.5172],
#         [-0.7800],
#         [ 2.5555],
#         [ 2.5499],
#         [-0.5070],
#         [ 2.6254],
#         [ 1.7375]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[7.7736e-05],
#         [6.1331e-06],
#         [2.3441e-04],
#         [1.7602e-06],
#         [4.8588e-05],
#         [6.2221e-06],
#         [1.5729e-05],
#         [8.4015e-05],
#         [1.1881e-05],
#         [1.9962e-06]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0005, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.4320],
#         [-1.0091],
#         [ 1.5485],
#         [ 0.5409],
#         [-0.4706],
#         [ 1.7776],
#         [ 1.9000],
#         [ 0.9298],
#         [ 3.5741],
#         [ 0.9207]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.4375e-05],
#         [2.2409e-08],
#         [1.0970e-05],
#         [2.9860e-04],
#         [1.4676e-04],
#         [1.6860e-05],
#         [5.9380e-07],
#         [2.3721e-05],
#         [1.9564e-04],
#         [1.7426e-07]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0007, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.8318],
#         [-1.7608],
#         [ 6.1197],
#         [ 1.3512],
#         [ 5.1342],
#         [ 3.1289],
#         [ 2.6047],
#         [ 2.7686],
#         [ 2.5931],
#         [ 0.0757]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.5854e-05],
#         [1.8773e-05],
#         [1.4924e-05],
#         [1.7954e-05],
#         [1.8682e-04],
#         [9.9323e-07],
#         [1.2662e-04],
#         [3.6500e-05],
#         [3.0248e-05],
#         [2.4984e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0005, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-3.4349],
#         [-1.2929],
#         [ 0.9958],
#         [-0.0114],
#         [ 0.6204],
#         [-0.1692],
#         [ 4.0031],
#         [ 3.1065],
#         [-1.0475],
#         [-1.8798]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.4083e-04],
#         [6.1768e-05],
#         [1.3897e-05],
#         [2.9479e-05],
#         [7.5647e-05],
#         [5.8890e-05],
#         [2.4428e-05],
#         [1.3449e-04],
#         [2.3640e-04],
#         [7.4560e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0011, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 3.1118],
#         [ 2.7149],
#         [-1.6134],
#         [ 2.6115],
#         [ 2.4542],
#         [ 0.2121],
#         [ 1.8142],
#         [ 3.3022],
#         [ 4.5794],
#         [-1.4767]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[5.0446e-05],
#         [8.9466e-08],
#         [1.4725e-04],
#         [7.4648e-08],
#         [1.9624e-05],
#         [1.2747e-05],
#         [8.2995e-06],
#         [8.9376e-05],
#         [3.4535e-04],
#         [9.0351e-06]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0007, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.9111],
#         [-0.2869],
#         [ 4.1499],
#         [-0.0130],
#         [-1.2652],
#         [ 1.1521],
#         [ 2.6077],
#         [ 0.2345],
#         [-1.5897],
#         [-0.8238]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.8221e-05],
#         [2.6072e-09],
#         [7.5602e-05],
#         [4.1972e-05],
#         [1.7041e-04],
#         [2.2642e-04],
#         [2.4722e-06],
#         [5.4904e-04],
#         [1.8784e-05],
#         [6.1984e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0012, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.4333],
#         [-1.0170],
#         [ 2.6301],
#         [-1.6638],
#         [ 1.5904],
#         [-1.7115],
#         [ 1.4612],
#         [-0.4228],
#         [-0.4876],
#         [ 2.2907]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[8.5006e-06],
#         [6.6589e-07],
#         [4.2299e-04],
#         [1.1893e-06],
#         [1.6668e-04],
#         [4.2958e-05],
#         [2.1243e-04],
#         [2.8269e-04],
#         [5.6788e-06],
#         [9.2538e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0012, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.7133],
#         [ 0.9425],
#         [ 2.4917],
#         [ 6.7419],
#         [ 0.7244],
#         [-0.6846],
#         [ 3.0528],
#         [ 4.3179],
#         [ 2.4797],
#         [ 1.5070]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.2636e-04],
#         [5.0421e-05],
#         [8.4100e-06],
#         [1.5122e-04],
#         [8.6230e-06],
#         [3.2425e-05],
#         [5.4728e-05],
#         [1.1069e-04],
#         [5.0738e-05],
#         [5.6739e-06]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0006, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.0877],
#         [ 2.5882],
#         [-1.0226],
#         [ 0.7785],
#         [-1.9569],
#         [ 7.7304],
#         [ 0.1077],
#         [ 0.4227],
#         [ 0.2434],
#         [ 5.7063]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.2793e-04],
#         [2.2625e-04],
#         [1.3330e-05],
#         [1.0619e-04],
#         [1.9310e-05],
#         [7.4519e-06],
#         [2.8173e-06],
#         [1.0210e-04],
#         [7.0631e-06],
#         [1.2556e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0006, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.6597],
#         [ 3.5384],
#         [ 3.7990],
#         [ 5.6984],
#         [ 4.3076],
#         [ 5.2718],
#         [-1.8914],
#         [ 0.3080],
#         [ 1.0544],
#         [ 0.6362]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.4199e-05],
#         [2.5647e-05],
#         [2.1935e-06],
#         [8.4481e-05],
#         [1.0392e-04],
#         [7.4028e-05],
#         [3.0542e-05],
#         [4.3739e-05],
#         [8.1907e-09],
#         [2.2756e-07]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.1309],
#         [-1.6067],
#         [ 4.4085],
#         [ 3.0357],
#         [ 0.2003],
#         [ 0.2042],
#         [ 3.1192],
#         [ 1.6705],
#         [ 0.7303],
#         [ 5.4162]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.0076e-05],
#         [2.9719e-05],
#         [1.0188e-05],
#         [5.9500e-05],
#         [6.8439e-05],
#         [1.5406e-04],
#         [4.1189e-05],
#         [5.1702e-05],
#         [3.1908e-05],
#         [5.6864e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0005, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.3260],
#         [ 3.1074],
#         [-0.6688],
#         [ 3.3392],
#         [ 0.1358],
#         [ 0.4721],
#         [ 0.7707],
#         [ 1.4498],
#         [ 1.2185],
#         [-0.1747]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[7.4443e-07],
#         [1.0060e-05],
#         [4.1847e-05],
#         [9.5788e-06],
#         [1.8976e-04],
#         [1.1927e-05],
#         [4.9892e-05],
#         [5.3307e-05],
#         [2.3640e-05],
#         [2.1775e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.2009],
#         [-2.5523],
#         [ 4.3590],
#         [ 2.9003],
#         [ 1.5620],
#         [ 3.4864],
#         [ 4.3599],
#         [ 1.5344],
#         [ 1.5999],
#         [-0.3729]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.5193e-05],
#         [2.3049e-04],
#         [1.5785e-06],
#         [4.9587e-05],
#         [6.0955e-05],
#         [2.5928e-04],
#         [1.3930e-05],
#         [7.3989e-06],
#         [1.0609e-05],
#         [2.1757e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0007, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 1.6231],
#         [-0.0437],
#         [-0.7443],
#         [ 6.9079],
#         [-2.5868],
#         [ 1.7790],
#         [ 2.8870],
#         [ 1.7344],
#         [ 1.2837],
#         [-1.3564]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.9393e-07],
#         [4.6617e-05],
#         [2.1596e-04],
#         [2.2182e-04],
#         [3.2992e-05],
#         [4.9459e-05],
#         [8.1878e-06],
#         [1.2617e-04],
#         [1.1951e-04],
#         [7.3025e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0009, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-2.3831],
#         [ 2.9350],
#         [ 3.9549],
#         [ 0.6034],
#         [ 1.0374],
#         [ 1.1152],
#         [-0.5920],
#         [ 1.0170],
#         [ 2.5378],
#         [-0.4152]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[9.2784e-07],
#         [6.3891e-06],
#         [2.8518e-05],
#         [7.5507e-05],
#         [6.3751e-06],
#         [7.5336e-05],
#         [1.4839e-05],
#         [1.8405e-05],
#         [2.4277e-05],
#         [5.5834e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0003, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.3545],
#         [ 3.1682],
#         [ 4.4892],
#         [ 0.4559],
#         [-0.7844],
#         [ 0.9291],
#         [ 0.5186],
#         [ 1.4769],
#         [ 3.9156],
#         [ 4.0200]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.3327e-05],
#         [2.6776e-05],
#         [9.5251e-05],
#         [1.5894e-06],
#         [2.7225e-05],
#         [2.1390e-07],
#         [6.9018e-05],
#         [4.7243e-06],
#         [1.1156e-05],
#         [1.8856e-04]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.4811],
#         [ 6.0001],
#         [ 3.4031],
#         [-1.6443],
#         [ 2.5955],
#         [-1.4350],
#         [-3.2482],
#         [ 1.9887],
#         [ 1.4267],
#         [ 2.7300]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.6108e-06],
#         [5.9828e-05],
#         [2.5113e-04],
#         [6.9843e-05],
#         [2.4105e-04],
#         [1.2416e-05],
#         [8.5310e-05],
#         [5.5103e-05],
#         [5.6287e-06],
#         [2.2854e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0008, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.5466],
#         [-0.0237],
#         [ 3.3441],
#         [-2.3456],
#         [-2.0551],
#         [ 1.1190],
#         [ 0.3029],
#         [ 1.3125],
#         [ 0.0907],
#         [-0.3001]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.8215e-07],
#         [4.1717e-05],
#         [1.2592e-05],
#         [3.1845e-05],
#         [1.9723e-07],
#         [1.3101e-07],
#         [2.9690e-05],
#         [4.7381e-05],
#         [8.7443e-05],
#         [3.7792e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0003, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.8693],
#         [-3.0963],
#         [-0.4061],
#         [ 2.1185],
#         [ 0.9251],
#         [-0.4168],
#         [ 3.3160],
#         [ 2.3320],
#         [ 2.7543],
#         [ 1.0996]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.6758e-05],
#         [1.3109e-07],
#         [7.2168e-07],
#         [1.3923e-05],
#         [2.0927e-07],
#         [3.0902e-05],
#         [4.5654e-05],
#         [1.8510e-04],
#         [5.3722e-11],
#         [8.8604e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-1.0986],
#         [ 2.7857],
#         [-1.5665],
#         [ 2.4686],
#         [ 1.4419],
#         [ 1.8594],
#         [ 5.3859],
#         [-1.1785],
#         [ 3.8891],
#         [ 2.3638]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[1.3356e-05],
#         [1.0897e-04],
#         [8.7338e-05],
#         [1.9270e-04],
#         [8.1684e-05],
#         [6.3602e-05],
#         [6.9330e-05],
#         [6.5965e-05],
#         [3.7085e-05],
#         [1.4392e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0007, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 0.4234],
#         [ 1.9003],
#         [ 2.4680],
#         [-1.3238],
#         [-0.8168],
#         [-0.1243],
#         [ 4.0944],
#         [-0.8642],
#         [ 0.9258],
#         [ 1.0397]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[3.0306e-05],
#         [9.6875e-05],
#         [2.6557e-05],
#         [5.8280e-06],
#         [1.5302e-04],
#         [2.8058e-06],
#         [8.5575e-05],
#         [5.5932e-06],
#         [8.1120e-06],
#         [2.0757e-04]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0006, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 2.0711],
#         [ 2.2055],
#         [-0.9779],
#         [ 0.8080],
#         [ 1.6996],
#         [-4.7270],
#         [ 0.3538],
#         [-2.8008],
#         [ 1.2041],
#         [ 2.0191]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.3063e-06],
#         [1.7430e-06],
#         [3.9627e-05],
#         [7.6238e-05],
#         [7.1552e-05],
#         [3.5944e-06],
#         [3.3183e-05],
#         [2.0756e-04],
#         [4.5205e-05],
#         [1.8132e-04]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0007, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[ 4.5009],
#         [ 1.5299],
#         [ 2.0884],
#         [-0.2010],
#         [-1.1539],
#         [ 2.0905],
#         [-2.4082],
#         [-2.8412],
#         [-1.5588],
#         [ 2.3090]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[8.9454e-05],
#         [2.6778e-04],
#         [8.6720e-06],
#         [6.4574e-06],
#         [2.3828e-06],
#         [4.6987e-05],
#         [4.6850e-10],
#         [5.7329e-06],
#         [1.1627e-04],
#         [1.5813e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0006, dtype=torch.float64, grad_fn=<SumBackward0>)
# net : tensor([[-0.5874],
#         [ 2.3073],
#         [ 1.6791],
#         [ 0.0657],
#         [-1.4571],
#         [ 0.6058],
#         [ 2.4074],
#         [ 0.2348],
#         [ 0.7849],
#         [ 3.0860]], dtype=torch.float64, grad_fn=<AddBackward0>)
# loss:  tensor([[2.6745e-05],
#         [2.1011e-05],
#         [1.5668e-05],
#         [1.1676e-04],
#         [6.2610e-05],
#         [9.7646e-07],
#         [5.5144e-05],
#         [8.8853e-06],
#         [1.4693e-08],
#         [4.6660e-05]], dtype=torch.float64, grad_fn=<DivBackward0>)
# loss.sum :  tensor(0.0004, dtype=torch.float64, grad_fn=<SumBackward0>)
# epoch 30 ,loss 0.000055

# %%
print(true_w, '\n', w)
print(true_b, '\n', b)

# %%
w.grad.zero_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-835ddfa2b231> in <module>()
# ----> 1 w.grad.zero_()
#
# AttributeError: 'NoneType' object has no attribute 'zero_'

# %%
w=torch.tensor(np.random.normal(0,0.01,(num_inputs,1)),dtype=torch.float64)
b=torch.zeros([1],dtype=torch.float64)

# %%
w.grad.data.zero_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-880675575f19> in <module>()
# ----> 1 w.grad.data.zero_()
#
# AttributeError: 'NoneType' object has no attribute 'data'
